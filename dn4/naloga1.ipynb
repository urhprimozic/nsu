# %% [markdown]
# ## Predznanje
#
# - Namesto dveh značilk za temperaturo bom uvedel novo spremenljivko delta_t
# - poleg spremenljivke theta bom uvedel še cos(theta)
# - zdi se smiselno uvesti spremenljivko 1/izolacijski_indeks
#
# Enote nam v tem primeru ne pomagajo, saj je količina, ki nosi neko informacijo o enotah le temperatura. Enote izolacijskega indeksa so verjetno take, da se v enačbi lepo pokrajšajo v W. Ker enote indeksa niso podane, si z njimi ne moremo pomagati. Očitno je le, da se je treba delta_t pomnožiti z neko drugo enačbo, da je Celzija izniči.
#
# ## Algoritem - naiven poskus
# Pričakujem, da formula za toplotni tok posnema preproste oblike osnovnih formul pri toploti (Recimo Q=-kA deltaT). Zato bom poskusil z generiranjem vseh možnih enačb kratke oblike, ki posnemajo zgoraj izpeljana pravila. Formule bom generiral s pomočjo ProGeda, ker z gramatikami na enostaven način opišem željen prostor enačb.

# %%
import ProGED as pg
import pandas as pd
import numpy as np
from sklearn.preprocessing import PolynomialFeatures

# %%
# priprava podatkov
data = pd.read_csv('DN4_1_podatki.csv')
data['deltaT'] = data['Tw'] - data['Ta']
data['one_over_eta'] = 1 / data['eta']
proged_data = data.drop(columns=['Tw', 'Ta', 'eta'])
proged_data.head()
# Out:
#           Q     theta     deltaT  one_over_eta
# 0  1.711929  0.321921  42.217191      2.864645
# 1  0.067135  2.705824   8.535838      1.217925
# 2  0.034759  1.873776   3.654556      1.322609
# 3  0.417783  2.089589  12.586385      1.937483
# 4  1.667614  0.328350  34.837551     12.000908

# %% [markdown]
# Uporabil bom gramatiko, ki dela linearne izraze v produktih(kvocientih) spremenljivk đ. Prioritiziral bom enačbe z malo plusi (sledim klasičnih oblikam fizikalnih formul), prioritiziral bom spremenljivko sin(theta).

# %%
# priprava naivne gramatike
# grammar = "E -> E '+' 'c' '*' V [0.1] | 'c' '*' V [0.9]\n"
grammar = "V -> V '*' F [0.6]| 'c' '*' F [0.4]\n" #  | V '/' F [0.2] 
grammar += "F -> 'theta' [0.1] | 'cos' '(' 'theta'  ')' [0.3] | 'deltaT' [0.3] | 'one_over_eta' [0.3]"

grammar = pg.GeneratorGrammar(grammar)

# %%
ED = pg.EqDisco(data=proged_data, 
                sample_size=500,
                lhs_vars=["Q"],
                rhs_vars=["theta", "deltaT", "1/eta"],
                strategy_settings = {"max_repeat":1000},
                generator = grammar,
                verbosity=1)

# %%
ED.generate_models()
# Out:
# [c*deltaT**2]
# [c*deltaT]
# [c*cos(theta)]
# [c*theta**3]
# [c*deltaT*cos(theta)]
# [c*deltaT*cos(theta)]
# [c*deltaT**2*theta]
# [c*deltaT**2*theta]
# [c*deltaT**2*theta]
# [c*deltaT**2*theta]
# [c*deltaT**2*cos(theta)**5]
# [c*cos(theta)**2]
# [c*theta]
# [c*deltaT*one_over_eta]
# [c*deltaT**4*one_over_eta*theta*cos(theta)**3]
# [c*deltaT*one_over_eta*theta*cos(theta)]
# [c*deltaT**2*one_over_eta**2*cos(theta)]
# [c*deltaT**2*one_over_eta**2*cos(theta)]
# [c*deltaT**2*one_over_eta**2*cos(theta)]
# [c*deltaT**2*one_over_eta**2*cos(theta)]
# [c*deltaT**2*one_over_eta**2*cos(theta)]
# [c*deltaT**3*one_over_eta**3*cos(theta)]
# [c*deltaT**3*one_over_eta**3*cos(theta)]
# [c*deltaT**3*one_over_eta**3*cos(theta)]
# [c*deltaT**3*one_over_eta**3*cos(theta)]
# [c*deltaT*one_over_eta**3]
# [c*deltaT*one_over_eta**3]
# [c*one_over_eta**2*cos(theta)**2]
# [c*one_over_eta**2*cos(theta)**2]
# [c*one_over_eta**2*cos(theta)**2]
# [c*one_over_eta**2*cos(theta)**2]
# [c*deltaT*one_over_eta*cos(theta)]
# [c*theta*cos(theta)**2]
# [c*theta*cos(theta)**2]
# [c*one_over_eta*cos(theta)]
# [c*one_over_eta*cos(theta)]
# [c*one_over_eta*cos(theta)]
# [c*one_over_eta*cos(theta)]
# [c*one_over_eta*cos(theta)]
# [c*deltaT**3*one_over_eta**2*cos(theta)**6]
# [c*deltaT**3*one_over_eta**2*cos(theta)**6]
# [c*cos(theta)**3]
# [c*cos(theta)**3]
# [c*cos(theta)**3]
# [c*cos(theta)**3]
# [c*cos(theta)**3]
# [c*cos(theta)**3]
# [c*cos(theta)**3]
# [c*deltaT**3*cos(theta)]
# [c*deltaT**3*cos(theta)]
# [c*deltaT*one_over_eta*theta**3*cos(theta)**2]
# [c*deltaT**2*one_over_eta*theta*cos(theta)**3]
# [c*deltaT**5*one_over_eta*theta**2*cos(theta)]
# [c*deltaT**2*one_over_eta*cos(theta)]
# [c*deltaT**2*one_over_eta*cos(theta)]
# [c*deltaT**2*one_over_eta*cos(theta)]
# [c*deltaT**2*one_over_eta*cos(theta)]
# [c*deltaT**2*one_over_eta*cos(theta)]
# [c*deltaT**2*one_over_eta]
# [c*deltaT**2*one_over_eta]
# [c*deltaT**2*one_over_eta]
# [c*deltaT**2*one_over_eta]
# [c*one_over_eta*theta*cos(theta)**2]
# [c*one_over_eta*theta]
# [c*deltaT*theta**2]
# [c*deltaT*theta**2]
# [c*deltaT*theta**2]
# [c*deltaT*theta**2]
# [c*deltaT*theta**2]
# [c*deltaT*one_over_eta**2*cos(theta)]
# [c*deltaT*one_over_eta**2*cos(theta)]
# [c*deltaT*one_over_eta**2*cos(theta)]
# [c*deltaT*one_over_eta**2*cos(theta)]
# [c*deltaT*one_over_eta**2*cos(theta)]
# [c*deltaT*cos(theta)**2]
# [c*deltaT*cos(theta)**2]
# [c*deltaT*cos(theta)**2]
# [c*deltaT*cos(theta)**2]
# [c*deltaT**2*one_over_eta**2*cos(theta)**2]
# [c*deltaT**2*one_over_eta**3*theta*cos(theta)**4]
# [c*deltaT**2*one_over_eta**3*theta*cos(theta)**4]
# [c*theta*cos(theta)]
# [c*theta*cos(theta)]
# [c*deltaT*cos(theta)**3]
# [c*deltaT*cos(theta)**3]
# [c*deltaT*cos(theta)**3]
# [c*deltaT*cos(theta)**3]
# [c*deltaT*cos(theta)**3]
# [c*deltaT*cos(theta)**3]
# [c*deltaT*cos(theta)**3]
# [c*deltaT*cos(theta)**3]
# [c*one_over_eta*cos(theta)**2]
# [c*deltaT*theta]
# [c*deltaT*theta]
# [c*deltaT*theta]
# [c*deltaT*theta]
# [c*deltaT*theta]
# [c*deltaT**2*theta*cos(theta)**3]
# [c*deltaT**2*theta*cos(theta)**3]
# [c*deltaT**2*theta*cos(theta)**3]
# [c*deltaT*one_over_eta**4*cos(theta)**2]
# [c*deltaT*one_over_eta*theta]
# [c*deltaT*theta*cos(theta)]
# [c*deltaT*theta*cos(theta)]
# [c*deltaT*theta*cos(theta)]
# [c*deltaT*one_over_eta*cos(theta)**2]
# [c*deltaT*one_over_eta*cos(theta)**2]
# [c*deltaT**2*one_over_eta**3*cos(theta)**2]
# [c*theta**2*cos(theta)**5]
# [c*theta**2*cos(theta)**5]
# [c*theta**2*cos(theta)**5]
# [c*one_over_eta**4*theta*cos(theta)]
# [c*one_over_eta**4*theta*cos(theta)]
# [c*deltaT*one_over_eta*theta*cos(theta)**3]
# [c*deltaT*one_over_eta*theta*cos(theta)**3]
# [c*deltaT*one_over_eta*theta*cos(theta)**3]
# [c*deltaT*one_over_eta*theta*cos(theta)**3]
# [c*deltaT*one_over_eta*theta*cos(theta)**3]
# [c*deltaT*one_over_eta*theta*cos(theta)**3]
# [c*deltaT*one_over_eta*theta*cos(theta)**3]
# [c*deltaT**2*cos(theta)]
# [c*deltaT**2*cos(theta)]
# [c*deltaT**2*cos(theta)]
# [c*deltaT**3*one_over_eta**2*theta*cos(theta)**4]
# [c*deltaT**3*one_over_eta**2*theta*cos(theta)**4]
# [c*deltaT**3*one_over_eta**2*theta*cos(theta)**4]
# [c*deltaT**3*one_over_eta**2*theta*cos(theta)**4]
# [c*deltaT**3*theta]
# [c*deltaT**3*theta]
# [c*deltaT**3*theta]
# [c*deltaT**3*theta]
# [c*deltaT**3*theta]
# [c*deltaT**3*theta]
# [c*deltaT**3*theta]
# [c*deltaT**3*theta]
# [c*deltaT**3*theta]
# [c*deltaT**3*theta]
# [c*deltaT**3*theta]
# [c*deltaT*one_over_eta**2*cos(theta)**2]
# [c*deltaT*one_over_eta**2*cos(theta)**2]
# [c*deltaT*one_over_eta**2*cos(theta)**2]
# [c*deltaT*one_over_eta**2*cos(theta)**2]
# [c*deltaT*one_over_eta**2*cos(theta)**2]
# [c*deltaT*one_over_eta**2*cos(theta)**2]
# [c*deltaT*one_over_eta**2*cos(theta)**2]
# [c*deltaT*one_over_eta**2*theta**2]
# [c*deltaT*one_over_eta**2*theta**2]
# [c*deltaT*one_over_eta**2*theta**2]
# [c*deltaT*one_over_eta**2*theta**2]
# [c*deltaT*one_over_eta**2*theta**2]
# [c*deltaT*one_over_eta**2*theta**2]
# [c*deltaT*one_over_eta**2*theta**2]
# [c*one_over_eta*cos(theta)**3]
# [c*one_over_eta*cos(theta)**3]
# [c*one_over_eta*cos(theta)**3]
# [c*one_over_eta*cos(theta)**3]
# [c*deltaT**2*one_over_eta*cos(theta)**2]
# [c*deltaT**2*one_over_eta*cos(theta)**2]
# [c*deltaT**2*one_over_eta*cos(theta)**2]
# [c*deltaT**2*one_over_eta*cos(theta)**2]
# [c*deltaT**2*one_over_eta*cos(theta)**2]
# [c*deltaT**2*one_over_eta**3]
# [c*deltaT**2*one_over_eta**3]
# [c*deltaT**2*one_over_eta**3]
# [c*deltaT**2*one_over_eta**3]
# [c*deltaT**2*one_over_eta**3]
# [c*deltaT**2*cos(theta)**2]
# [c*deltaT**2*cos(theta)**2]
# [c*deltaT**2*cos(theta)**2]
# [c*deltaT**2*cos(theta)**2]
# [c*deltaT**3*one_over_eta**3*theta*cos(theta)]
# [c*deltaT**3*one_over_eta**3*theta*cos(theta)]
# [c*deltaT**3*one_over_eta**3*theta*cos(theta)]
# [c*one_over_eta**2*theta*cos(theta)**2]
# [c*one_over_eta**2*theta*cos(theta)**2]
# [c*one_over_eta**2*theta*cos(theta)**2]
# [c*one_over_eta**2*theta*cos(theta)**2]
# [c*one_over_eta**2*theta*cos(theta)]
# [c*one_over_eta**2*cos(theta)]
# [c*deltaT**4*one_over_eta**5*theta*cos(theta)**2]
# [c*deltaT**4*one_over_eta**5*theta*cos(theta)**2]
# [c*deltaT**4*one_over_eta**5*theta*cos(theta)**2]
# [c*deltaT**4*one_over_eta**5*theta*cos(theta)**2]
# [c*deltaT**4*one_over_eta**5*theta*cos(theta)**2]
# [c*deltaT**4*one_over_eta**5*theta*cos(theta)**2]
# [c*deltaT**4*one_over_eta**5*theta*cos(theta)**2]
# [c*deltaT**4*one_over_eta**5*theta*cos(theta)**2]
# [c*deltaT**4*one_over_eta**5*theta*cos(theta)**2]
# [c*deltaT**4*one_over_eta**5*theta*cos(theta)**2]
# [c*deltaT**4*one_over_eta**5*theta*cos(theta)**2]
# [c*deltaT**4*one_over_eta**5*theta*cos(theta)**2]
# [c*deltaT**4*one_over_eta**5*theta*cos(theta)**2]
# [c*deltaT**4*one_over_eta**5*theta*cos(theta)**2]
# [c*theta*cos(theta)**3]
# [c*theta*cos(theta)**3]
# [c*theta*cos(theta)**3]
# [c*theta*cos(theta)**3]
# [c*theta*cos(theta)**3]
# [c*deltaT*one_over_eta**2]
# [c*deltaT*one_over_eta**2]
# [c*deltaT*one_over_eta**2]
# [c*deltaT*one_over_eta*theta**2*cos(theta)**3]
# [c*deltaT*one_over_eta*theta**2*cos(theta)**3]
# [c*deltaT*one_over_eta*theta**2*cos(theta)**3]
# [c*deltaT*one_over_eta*theta**2*cos(theta)**3]
# [c*deltaT*one_over_eta*theta**2*cos(theta)**3]
# [c*deltaT*one_over_eta*theta**2*cos(theta)**3]
# [c*deltaT*one_over_eta*theta**2*cos(theta)**3]
# [c*deltaT*one_over_eta*theta**2*cos(theta)**3]
# [c*deltaT*one_over_eta*theta**2*cos(theta)**3]
# [c*deltaT*one_over_eta*theta**2*cos(theta)**3]
# [c*deltaT*one_over_eta*theta**2*cos(theta)**3]
# [c*deltaT*one_over_eta*theta**2*cos(theta)**3]
# [c*deltaT*one_over_eta*theta**2*cos(theta)**3]
# [c*deltaT*one_over_eta*theta**2*cos(theta)**3]
# [c*deltaT*one_over_eta*theta**2*cos(theta)**3]
# [c*deltaT*one_over_eta*theta**2*cos(theta)**3]
# [c*deltaT*one_over_eta*theta**2*cos(theta)**3]
# [c*deltaT*one_over_eta*theta**2*cos(theta)**3]
# [c*deltaT*one_over_eta*theta**2*cos(theta)**3]
# [c*deltaT*one_over_eta*theta**2*cos(theta)**3]
# [c*one_over_eta**2*theta]
# [c*deltaT**3]
# [c*deltaT**3]
# [c*deltaT**3]
# [c*deltaT**3]
# [c*deltaT**3]
# [c*deltaT**3]
# [c*deltaT**3]
# [c*deltaT**3]
# [c*deltaT**3]
# [c*deltaT**3]
# [c*cos(theta)**4]
# [c*cos(theta)**4]
# [c*deltaT*one_over_eta**2*theta*cos(theta)]
# [c*deltaT*one_over_eta**2*theta*cos(theta)]
# [c*theta*cos(theta)**5]
# [c*theta*cos(theta)**5]
# [c*theta*cos(theta)**5]
# [c*theta*cos(theta)**5]
# [c*theta*cos(theta)**5]
# [c*theta*cos(theta)**5]
# [c*theta*cos(theta)**5]
# [c*theta*cos(theta)**5]
# [c*theta*cos(theta)**5]
# [c*theta*cos(theta)**5]
# [c*theta*cos(theta)**5]
# [c*theta*cos(theta)**5]
# [c*theta*cos(theta)**5]
# [c*theta*cos(theta)**5]
# [c*one_over_eta*theta**2*cos(theta)]
# [c*one_over_eta*theta**2*cos(theta)]
# [c*one_over_eta*theta**2*cos(theta)]
# [c*one_over_eta*theta**2*cos(theta)]
# [c*one_over_eta*theta**2*cos(theta)]
# [c*deltaT*one_over_eta**3*cos(theta)]
# [c*deltaT*one_over_eta**3*cos(theta)]
# [c*deltaT*one_over_eta**3*cos(theta)]
# [c*deltaT*one_over_eta**3*cos(theta)]
# [c*deltaT*one_over_eta**3*cos(theta)]
# [c*deltaT*one_over_eta**3*cos(theta)]
# [c*one_over_eta*theta*cos(theta)]
# [c*one_over_eta*theta*cos(theta)]
# [c*deltaT*one_over_eta**3*theta**2*cos(theta)**3]
# [c*deltaT*one_over_eta**3*theta**2*cos(theta)**3]
# [c*deltaT*one_over_eta**3*theta**2*cos(theta)**3]
# [c*deltaT*one_over_eta**3*theta**2*cos(theta)**3]
# [c*deltaT*one_over_eta**3*theta**2*cos(theta)**3]
# [c*deltaT*one_over_eta**3*theta**2*cos(theta)**3]
# [c*one_over_eta*theta*cos(theta)**3]
# [c*one_over_eta*theta*cos(theta)**3]
# [c*one_over_eta*theta*cos(theta)**3]
# [c*one_over_eta*theta*cos(theta)**3]
# [c*one_over_eta**3*theta]
# [c*one_over_eta**3*theta]
# [c*one_over_eta**3*theta]
# [c*one_over_eta**3*theta*cos(theta)**3]
# [c*one_over_eta**3*theta*cos(theta)**3]
# [c*one_over_eta**3*theta*cos(theta)**3]
# [c*one_over_eta**3*theta*cos(theta)**3]
# [c*one_over_eta**3*theta*cos(theta)**3]
# [c*one_over_eta*theta*cos(theta)**5]
# [c*one_over_eta*theta*cos(theta)**5]
# [c*one_over_eta*theta*cos(theta)**5]
# [c*deltaT*one_over_eta**5*theta**2*cos(theta)**3]
# [c*deltaT*one_over_eta**5*theta**2*cos(theta)**3]
# [c*deltaT*one_over_eta**5*theta**2*cos(theta)**3]
# [c*deltaT*one_over_eta**5*theta**2*cos(theta)**3]
# [c*deltaT*one_over_eta**5*theta**2*cos(theta)**3]
# [c*deltaT*one_over_eta**5*theta**2*cos(theta)**3]
# [c*deltaT*one_over_eta**5*theta**2*cos(theta)**3]
# [c*deltaT*one_over_eta**5*theta**2*cos(theta)**3]
# [c*deltaT*one_over_eta**5*theta**2*cos(theta)**3]
# [c*deltaT*one_over_eta**3*theta]
# [c*deltaT*one_over_eta**3*theta]
# [c*deltaT*one_over_eta**3*theta]
# [c*deltaT*one_over_eta**3*theta]
# [c*deltaT*one_over_eta**3*theta]
# [c*deltaT*one_over_eta**3*theta]
# [c*deltaT*one_over_eta**4]
# [c*deltaT**3*one_over_eta**2*cos(theta)**2]
# [c*deltaT**3*one_over_eta**2*cos(theta)**2]
# [c*deltaT**3*one_over_eta**2*cos(theta)**2]
# [c*deltaT**3*one_over_eta**2*cos(theta)**2]
# [c*deltaT**3*one_over_eta**2*cos(theta)**2]
# [c*deltaT**3*one_over_eta**2*cos(theta)**2]
# [c*deltaT**3*one_over_eta**2*cos(theta)**2]
# [c*deltaT**3*one_over_eta**2*cos(theta)**2]
# [c*deltaT**3*one_over_eta**2*cos(theta)**2]
# [c*deltaT**3*one_over_eta**2*cos(theta)**2]
# [c*deltaT**3*one_over_eta**2*cos(theta)**2]
# [c*deltaT**3*one_over_eta**2*cos(theta)**2]
# [c*deltaT**3*one_over_eta**2*cos(theta)**2]
# [c*deltaT**3*one_over_eta**2*cos(theta)**2]
# [c*deltaT**3*one_over_eta**2*cos(theta)**2]
# [c*deltaT**3*one_over_eta**2*cos(theta)**2]
# [c*deltaT**3*one_over_eta**2*cos(theta)**2]
# [c*deltaT**3*one_over_eta**2*cos(theta)**2]
# [c*deltaT**3*one_over_eta**2*cos(theta)**2]
# [c*deltaT**3*one_over_eta*cos(theta)]
# [c*deltaT**3*one_over_eta*cos(theta)]
# [c*deltaT**3*one_over_eta*cos(theta)]
# [c*deltaT**3*one_over_eta*cos(theta)]
# [c*deltaT**3*one_over_eta*cos(theta)]
# [c*deltaT**3*one_over_eta*cos(theta)]
# [c*deltaT**3*one_over_eta*cos(theta)]
# [c*deltaT**3*one_over_eta*cos(theta)]
# [c*deltaT**3*one_over_eta*cos(theta)]
# [c*deltaT**2*one_over_eta**2*theta*cos(theta)**4]
# [c*deltaT**2*one_over_eta**2*theta*cos(theta)**4]
# [c*deltaT**2*one_over_eta**2*theta*cos(theta)**4]
# [c*deltaT**2*one_over_eta**2*theta*cos(theta)**4]
# [c*deltaT**2*one_over_eta**2*theta*cos(theta)**4]
# [c*deltaT**2*one_over_eta**2*theta*cos(theta)**4]
# [c*deltaT**2*one_over_eta**2*theta*cos(theta)**4]
# [c*deltaT**2*one_over_eta**2*theta*cos(theta)**4]
# [c*deltaT**2*one_over_eta**2*theta*cos(theta)**4]
# [c*deltaT**2*one_over_eta**2*theta*cos(theta)**4]
# [c*deltaT**2*one_over_eta**2*theta*cos(theta)**4]
# [c*deltaT**2*one_over_eta**2*theta*cos(theta)**4]
# [c*deltaT**2*one_over_eta**2*theta*cos(theta)**4]
# [c*deltaT**2*one_over_eta**2*theta*cos(theta)**4]
# [c*deltaT**2*one_over_eta**2*theta*cos(theta)**4]
# [c*deltaT**2*one_over_eta**2*theta*cos(theta)**4]
# [c*deltaT**2*one_over_eta**2*theta*cos(theta)**4]
# [c*deltaT**2*one_over_eta**2*theta*cos(theta)**4]
# [c*deltaT**2*one_over_eta**2*theta*cos(theta)**4]
# [c*deltaT**2*one_over_eta**2*theta*cos(theta)**4]
# [c*deltaT**2*one_over_eta**2*theta*cos(theta)**4]
# [c*deltaT**2*one_over_eta**2*theta*cos(theta)**4]
# [c*deltaT**2*one_over_eta**2*theta*cos(theta)**4]
# [c*deltaT**2*one_over_eta**2*theta*cos(theta)**4]
# [c*deltaT**2*one_over_eta**2*theta*cos(theta)**4]
# [c*deltaT**3*one_over_eta**4]
# [c*deltaT**3*one_over_eta**4]
# [c*deltaT**3*one_over_eta**4]
# [c*deltaT**3*one_over_eta**4]
# [c*deltaT**3*one_over_eta**4]
# [c*deltaT**3*one_over_eta**4]
# [c*deltaT**3*one_over_eta**4]
# [c*deltaT**3*one_over_eta**4]
# [c*deltaT**3*one_over_eta**4]
# [c*deltaT**2*one_over_eta**2*theta]
# [c*deltaT**2*one_over_eta**2*theta]
# [c*deltaT**2*one_over_eta**2*theta]
# [c*deltaT*theta**2*cos(theta)]
# [c*deltaT*theta**2*cos(theta)]
# [c*deltaT*theta**2*cos(theta)]
# [c*deltaT*theta**2*cos(theta)]
# [c*deltaT*theta**2*cos(theta)]
# [c*deltaT*theta**2*cos(theta)]
# [c*deltaT*theta**2*cos(theta)]
# [c*deltaT*theta**2*cos(theta)]
# [c*deltaT*theta**2*cos(theta)]
# [c*deltaT*theta**2*cos(theta)]
# [c*deltaT*theta**2*cos(theta)]
# [c*deltaT*theta**2*cos(theta)]
# [c*deltaT*theta**2*cos(theta)]
# [c*deltaT*theta**2*cos(theta)]
# [c*deltaT*theta**2*cos(theta)]
# [c*deltaT*theta**2*cos(theta)]
# [c*deltaT*theta**2*cos(theta)]
# [c*deltaT*cos(theta)**4]
# [c*deltaT*cos(theta)**4]
# [c*deltaT*cos(theta)**4]
# [c*deltaT*cos(theta)**4]
# [c*deltaT*cos(theta)**4]
# [c*deltaT*one_over_eta**3*cos(theta)**4]
# [c*deltaT*one_over_eta**3*cos(theta)**4]
# [c*deltaT*one_over_eta**3*cos(theta)**4]
# [c*deltaT*one_over_eta**3*cos(theta)**4]
# [c*deltaT*one_over_eta**3*cos(theta)**4]
# [c*deltaT*one_over_eta**2*theta]
# [c*deltaT*one_over_eta**2*theta]
# [c*deltaT*one_over_eta*theta**2*cos(theta)]
# [c*deltaT*one_over_eta*theta**2*cos(theta)]
# [c*deltaT*one_over_eta*theta**2*cos(theta)]
# [c*deltaT*one_over_eta*theta**2*cos(theta)]
# [c*deltaT*one_over_eta*theta**2*cos(theta)]
# [c*deltaT*one_over_eta*theta**2*cos(theta)]
# [c*deltaT*one_over_eta*theta**2*cos(theta)]
# [c*deltaT*one_over_eta*theta**2*cos(theta)]
# [c*deltaT*one_over_eta*theta**2*cos(theta)]
# [c*deltaT*one_over_eta*theta**2*cos(theta)]
# [c*deltaT*one_over_eta*theta**2*cos(theta)]
# [c*deltaT*one_over_eta*theta**2*cos(theta)]
# [c*deltaT*one_over_eta*theta**2*cos(theta)]
# [c*deltaT*one_over_eta*theta**2*cos(theta)]
# [c*deltaT*one_over_eta*theta**2*cos(theta)]
# [c*deltaT**4*one_over_eta**2*cos(theta)]
# [c*deltaT**4*one_over_eta**2*cos(theta)]
# [c*deltaT**4*one_over_eta**2*cos(theta)]
# [c*deltaT**4*one_over_eta**2*cos(theta)]
# [c*deltaT**4*one_over_eta**2*cos(theta)]
# [c*deltaT**4*one_over_eta**2*cos(theta)]
# [c*deltaT**4*one_over_eta**2*cos(theta)]
# [c*deltaT**4*one_over_eta**2*cos(theta)]
# [c*deltaT**4*one_over_eta**2*cos(theta)]
# [c*deltaT**4*one_over_eta**2*cos(theta)]
# [c*deltaT**4*one_over_eta**2*cos(theta)]
# [c*deltaT**4*one_over_eta**2*cos(theta)]
# [c*deltaT**4*one_over_eta**2*cos(theta)]
# [c*deltaT*one_over_eta**2*theta*cos(theta)**3]
# [c*deltaT*one_over_eta**2*theta*cos(theta)**3]
# [c*deltaT*one_over_eta**2*theta*cos(theta)**3]
# [c*deltaT*one_over_eta**2*theta*cos(theta)**3]
# [c*deltaT*one_over_eta**2*theta*cos(theta)**3]
# [c*deltaT*one_over_eta**2*theta*cos(theta)**3]
# [c*deltaT*one_over_eta**2*theta*cos(theta)**3]
# [c*deltaT*one_over_eta**2*theta*cos(theta)**3]
# [c*deltaT*one_over_eta**2*theta*cos(theta)**3]
# [c*deltaT*one_over_eta**2*theta*cos(theta)**3]
# [c*deltaT*one_over_eta**2*theta*cos(theta)**3]
# [c*deltaT*one_over_eta**2*theta*cos(theta)**3]
# [c*deltaT*one_over_eta**2*theta*cos(theta)**3]
# [c*deltaT*one_over_eta**2*theta*cos(theta)**3]
# [c*deltaT*one_over_eta**2*theta*cos(theta)**3]
# [c*deltaT*one_over_eta**2*theta*cos(theta)**3]
# [c*deltaT*one_over_eta**2*theta*cos(theta)**3]
# [c*deltaT*one_over_eta**2*theta*cos(theta)**3]
# [c*deltaT*one_over_eta**2*theta*cos(theta)**3]
# [c*deltaT*one_over_eta**2*theta*cos(theta)**3]
# [c*deltaT*one_over_eta**2*theta*cos(theta)**3]
# [c*deltaT*one_over_eta**2*theta*cos(theta)**3]
# [c*deltaT*one_over_eta**2*theta*cos(theta)**3]
# [c*deltaT*one_over_eta**2*theta*cos(theta)**3]
# [c*deltaT*one_over_eta**2*theta*cos(theta)**3]
# [c*deltaT*one_over_eta**2*theta*cos(theta)**3]
# [c*deltaT*one_over_eta**2*theta*cos(theta)**3]
# [c*deltaT*one_over_eta**2*theta*cos(theta)**3]
# [c*deltaT*one_over_eta**2*theta*cos(theta)**3]
# [c*deltaT*one_over_eta**2*theta*cos(theta)**3]
# [c*deltaT*one_over_eta**2*theta*cos(theta)**3]
# [c*deltaT*one_over_eta**2*theta*cos(theta)**3]
# [c*deltaT*one_over_eta**2*theta*cos(theta)**3]
# [c*deltaT*one_over_eta**2*theta*cos(theta)**3]
# [c*deltaT*one_over_eta**2*theta*cos(theta)**3]
# [c*deltaT*one_over_eta**2*theta*cos(theta)**3]
# [c*deltaT*one_over_eta*cos(theta)**4]
# [c*deltaT*one_over_eta*cos(theta)**4]
# [c*deltaT*one_over_eta*cos(theta)**4]
# [c*deltaT*one_over_eta*cos(theta)**4]
# [c*deltaT*one_over_eta*cos(theta)**4]
# [c*one_over_eta**2*cos(theta)**4]
# [c*one_over_eta**2*cos(theta)**4]
# [c*one_over_eta**2*cos(theta)**4]
# [c*one_over_eta**2*cos(theta)**4]
# [c*one_over_eta**2*cos(theta)**4]
# [c*one_over_eta**2*cos(theta)**4]
# [c*one_over_eta**4*cos(theta)]
# [c*one_over_eta**4*cos(theta)]
# [c*one_over_eta**4*cos(theta)]
# [c*one_over_eta**4*cos(theta)]
# [c*one_over_eta**4*cos(theta)]
# [c*one_over_eta**4*cos(theta)]
# [c*one_over_eta**4*cos(theta)]
# [c*one_over_eta**4*cos(theta)]
# [c*deltaT**3*one_over_eta]
# [c*deltaT**3*one_over_eta]
# [c*deltaT*one_over_eta*theta**2*cos(theta)**2]
# [c*deltaT**3*one_over_eta**3*theta*cos(theta)**2]
# [c*deltaT**3*one_over_eta**3*theta*cos(theta)**2]
# [c*deltaT**3*one_over_eta**3*theta*cos(theta)**2]
# [c*deltaT**3*one_over_eta**3*theta*cos(theta)**2]
# [c*deltaT**3*one_over_eta**3*theta*cos(theta)**2]
# [c*deltaT**3*one_over_eta**3*theta*cos(theta)**2]
# [c*deltaT**3*one_over_eta**3*theta*cos(theta)**2]
# [c*deltaT**3*one_over_eta*theta]
# [c*deltaT**3*one_over_eta*theta]
# [c*deltaT**3*one_over_eta*theta]
# [c*deltaT**3*one_over_eta*theta]
# [c*deltaT**3*one_over_eta*theta]
# [c*deltaT**3*one_over_eta*theta]
# [c*deltaT**3*one_over_eta*theta]
# [c*deltaT**3*one_over_eta*theta]
# [c*deltaT**3*one_over_eta*theta]
# [c*deltaT**3*one_over_eta*theta]
# [c*deltaT**3*one_over_eta*theta]
# [c*deltaT**3*one_over_eta*theta]
# [c*deltaT**3*one_over_eta*theta]
# [c*deltaT**3*one_over_eta*theta]
# [c*deltaT**3*one_over_eta*theta]
# [c*deltaT**3*one_over_eta**3*cos(theta)**2]
# [c*deltaT**3*one_over_eta**3*cos(theta)**2]
# [c*deltaT**3*one_over_eta**3*cos(theta)**2]
# [c*deltaT*theta*cos(theta)**2]
# [c*deltaT*theta*cos(theta)**2]
# [c*deltaT*theta*cos(theta)**2]
# [c*deltaT*theta*cos(theta)**2]
# [c*deltaT*theta*cos(theta)**2]
# [c*deltaT*theta*cos(theta)**2]
# [c*deltaT*theta*cos(theta)**2]
# [c*deltaT*theta*cos(theta)**2]
# [c*deltaT*theta*cos(theta)**2]
# [c*deltaT*theta*cos(theta)**2]
# [c*deltaT*one_over_eta**5*theta*cos(theta)**2]
# [c*deltaT*one_over_eta**5*theta*cos(theta)**2]
# [c*deltaT*one_over_eta**5*theta*cos(theta)**2]
# [c*deltaT*one_over_eta**5*theta*cos(theta)**2]
# [c*deltaT*one_over_eta**5*theta*cos(theta)**2]
# [c*deltaT**3*one_over_eta**4*theta**3*cos(theta)**2]
# [c*deltaT**3*one_over_eta**4*theta**3*cos(theta)**2]
# [c*deltaT**3*one_over_eta**4*theta**3*cos(theta)**2]
# [c*deltaT**3*one_over_eta**4*theta**3*cos(theta)**2]
# [c*deltaT*one_over_eta**2*theta**2*cos(theta)**2]
# [c*deltaT*one_over_eta**2*theta**2*cos(theta)**2]
# [c*deltaT*one_over_eta**2*theta**2*cos(theta)**2]
# [c*deltaT*one_over_eta**2*theta**2*cos(theta)**2]
# [c*theta**2]
# [c*theta**2]
# [c*theta**2]
# [c*theta**2]
# [c*theta**2]
# [c*theta**2]
# [c*theta**2]
# [c*theta**2]
# [c*theta**2]
# [c*deltaT**2*one_over_eta**2*theta*cos(theta)]
# [c*deltaT**2*one_over_eta**2*theta*cos(theta)]
# [c*deltaT**2*one_over_eta**2*theta*cos(theta)]
# [c*deltaT**2*one_over_eta**2*theta*cos(theta)]
# [c*deltaT**2*one_over_eta**2*theta*cos(theta)]
# [c*deltaT**2*one_over_eta**2*theta*cos(theta)]
# [c*deltaT**4*one_over_eta*cos(theta)]
# [c*deltaT**4*one_over_eta*cos(theta)]
# [c*deltaT**4*one_over_eta*cos(theta)]
# [c*deltaT**4*one_over_eta*cos(theta)]
# [c*deltaT**4*one_over_eta*cos(theta)]
# [c*deltaT**4*one_over_eta*cos(theta)]
# [c*deltaT**4*one_over_eta*cos(theta)]
# [c*deltaT**4*one_over_eta*cos(theta)]
# [c*deltaT**4*one_over_eta*cos(theta)]
# [c*deltaT**4*one_over_eta*cos(theta)]
# [c*deltaT**4*one_over_eta*cos(theta)]
# [c*deltaT**4*one_over_eta*cos(theta)]
# [c*deltaT**4*one_over_eta*cos(theta)]
# [c*deltaT**4*one_over_eta*cos(theta)]
# [c*deltaT**4*one_over_eta*cos(theta)]
# [c*deltaT**4*one_over_eta*cos(theta)]
# [c*deltaT**4*one_over_eta*cos(theta)]
# [c*deltaT**4*one_over_eta*cos(theta)]
# [c*deltaT**4*one_over_eta*cos(theta)]
# [c*deltaT**4*one_over_eta*cos(theta)]
# [c*deltaT**4*one_over_eta*cos(theta)]
# [c*deltaT**4*one_over_eta*cos(theta)]
# [c*deltaT**4*one_over_eta*cos(theta)]
# [c*deltaT**4*one_over_eta*cos(theta)]
# [c*deltaT**4*one_over_eta*cos(theta)]
# [c*deltaT**4*one_over_eta*cos(theta)]
# [c*deltaT**4*one_over_eta*cos(theta)]
# [c*deltaT**4*one_over_eta*cos(theta)]
# [c*deltaT**4*one_over_eta*cos(theta)]
# [c*deltaT**4*one_over_eta*cos(theta)]
# [c*deltaT**4*one_over_eta*cos(theta)]
# [c*deltaT**4*one_over_eta*cos(theta)]
# [c*deltaT**4*one_over_eta*cos(theta)]
# [c*deltaT**4*one_over_eta*cos(theta)]
# [c*deltaT**4*one_over_eta*cos(theta)]
# [c*deltaT**4*one_over_eta*cos(theta)]
# [c*deltaT**4*one_over_eta*cos(theta)]
# [c*deltaT**4*one_over_eta*cos(theta)]
# [c*deltaT**4*one_over_eta*cos(theta)]
# [c*deltaT**4*one_over_eta*cos(theta)]
# [c*deltaT**4*one_over_eta*cos(theta)]
# [c*deltaT**4*one_over_eta*cos(theta)]
# [c*deltaT**4*one_over_eta*cos(theta)]
# [c*deltaT**3*one_over_eta**2*theta*cos(theta)**3]
# [c*deltaT**3*one_over_eta**2*theta*cos(theta)**3]
# [c*deltaT**3*one_over_eta**2*theta*cos(theta)**3]
# [c*deltaT**3*one_over_eta**2*theta*cos(theta)**3]
# [c*deltaT**3*one_over_eta**2*theta*cos(theta)**3]
# [c*deltaT**3*one_over_eta**2*theta*cos(theta)**3]
# [c*deltaT**3*one_over_eta**2*theta*cos(theta)**3]
# [c*deltaT**3*one_over_eta**2*theta*cos(theta)**3]
# [c*deltaT**3*one_over_eta**2*theta*cos(theta)**3]
# [c*deltaT**3*one_over_eta**2*theta*cos(theta)**3]
# [c*deltaT**3*one_over_eta**2*theta*cos(theta)**3]
# [c*deltaT**3*one_over_eta**2*theta*cos(theta)**3]
# [c*deltaT**3*one_over_eta**2*theta*cos(theta)**3]
# [c*deltaT**3*one_over_eta**2*theta*cos(theta)**3]
# [c*deltaT**3*one_over_eta**2*theta*cos(theta)**3]
# [c*deltaT**3*one_over_eta**2*theta*cos(theta)**3]
# [c*deltaT**3*one_over_eta**2*theta*cos(theta)**3]
# [c*deltaT**2*one_over_eta*theta*cos(theta)**2]
# [c*deltaT**2*one_over_eta*theta*cos(theta)**2]
# [c*deltaT**2*one_over_eta*theta*cos(theta)**2]
# [c*deltaT**2*one_over_eta*theta*cos(theta)**2]
# [c*deltaT**2*one_over_eta*theta*cos(theta)**2]
# [c*deltaT**2*one_over_eta*theta*cos(theta)**2]
# [c*deltaT**2*one_over_eta*theta*cos(theta)**2]
# [c*deltaT**2*one_over_eta*theta*cos(theta)**2]
# [c*deltaT**2*one_over_eta*theta*cos(theta)**2]
# [c*deltaT**2*one_over_eta*theta*cos(theta)**2]
# [c*deltaT**2*one_over_eta*theta*cos(theta)**2]
# [c*deltaT**2*one_over_eta*theta*cos(theta)**2]
# [c*deltaT**2*one_over_eta*theta*cos(theta)**2]
# [c*one_over_eta**4*theta*cos(theta)**2]
# [c*one_over_eta**4*theta*cos(theta)**2]
# [c*one_over_eta**4*theta*cos(theta)**2]
# [c*one_over_eta**4*theta*cos(theta)**2]
# [c*one_over_eta**4*theta*cos(theta)**2]
# [c*one_over_eta**4*theta*cos(theta)**2]
# [c*one_over_eta**4*theta*cos(theta)**2]
# [c*deltaT**5*one_over_eta*theta**3*cos(theta)**5]
# [c*deltaT**5*one_over_eta*theta**3*cos(theta)**5]
# [c*deltaT**5*one_over_eta*theta**3*cos(theta)**5]
# [c*deltaT**5*one_over_eta*theta**3*cos(theta)**5]
# [c*deltaT**5*one_over_eta*theta**3*cos(theta)**5]
# [c*deltaT**5*one_over_eta*theta**3*cos(theta)**5]
# [c*deltaT**5*one_over_eta*theta**3*cos(theta)**5]
# [c*deltaT**5*one_over_eta*theta**3*cos(theta)**5]
# [c*deltaT**5*one_over_eta*theta**3*cos(theta)**5]
# [c*deltaT**5*one_over_eta*theta**3*cos(theta)**5]
# [c*deltaT**2*one_over_eta*cos(theta)**3]
# [c*deltaT**2*one_over_eta*cos(theta)**3]
# [c*deltaT**2*one_over_eta*cos(theta)**3]
# [c*deltaT**2*one_over_eta*cos(theta)**3]
# [c*deltaT**2*one_over_eta*cos(theta)**3]
# [c*deltaT**2*one_over_eta*cos(theta)**3]
# [c*deltaT**2*one_over_eta*cos(theta)**3]
# [c*deltaT**2*one_over_eta*cos(theta)**3]
# [c*deltaT**2*one_over_eta*cos(theta)**3]
# [c*deltaT**2*one_over_eta*cos(theta)**3]
# [c*one_over_eta**2*cos(theta)**3]
# [c*deltaT**3*cos(theta)**2]
# [c*deltaT**3*cos(theta)**2]
# [c*deltaT**2*one_over_eta**3*cos(theta)]
# [c*deltaT**2*one_over_eta**3*cos(theta)]
# [c*deltaT**2*one_over_eta**3*cos(theta)]
# [c*deltaT**2*one_over_eta**3*cos(theta)]
# [c*deltaT**2*cos(theta)**3]
# [c*deltaT**3*one_over_eta*theta*cos(theta)**3]
# [c*deltaT**3*one_over_eta*theta*cos(theta)**3]
# [c*deltaT**3*one_over_eta*theta*cos(theta)**3]
# [c*deltaT**3*one_over_eta*theta*cos(theta)**3]
# [c*deltaT**3*one_over_eta*theta*cos(theta)**3]
# [c*deltaT**3*one_over_eta*theta*cos(theta)**3]
# [c*deltaT**3*one_over_eta*theta*cos(theta)**3]
# [c*deltaT**3*one_over_eta*theta*cos(theta)**3]
# [c*deltaT**3*one_over_eta*theta*cos(theta)**3]
# [c*deltaT**3*one_over_eta*theta*cos(theta)**3]
# [c*deltaT**3*one_over_eta*theta*cos(theta)**3]
# [c*deltaT**3*one_over_eta*theta*cos(theta)**3]
# [c*deltaT**3*one_over_eta*theta*cos(theta)**3]
# [c*deltaT**4*one_over_eta**5*theta*cos(theta)**9]
# [c*deltaT**4*one_over_eta**5*theta*cos(theta)**9]
# [c*deltaT**4*one_over_eta**5*theta*cos(theta)**9]
# [c*deltaT**4*one_over_eta**5*theta*cos(theta)**9]
# [c*deltaT**4*one_over_eta**5*theta*cos(theta)**9]
# [c*deltaT**4*one_over_eta**5*theta*cos(theta)**9]
# [c*deltaT**4*one_over_eta**5*theta*cos(theta)**9]
# [c*deltaT**4*one_over_eta**5*theta*cos(theta)**9]
# [c*deltaT**4*one_over_eta**5*theta*cos(theta)**9]
# [c*deltaT**4*one_over_eta**5*theta*cos(theta)**9]
# [c*deltaT**6*one_over_eta**2*theta*cos(theta)**3]
# [c*deltaT**6*one_over_eta**2*theta*cos(theta)**3]
# [c*deltaT**6*one_over_eta**2*theta*cos(theta)**3]
# [c*deltaT**6*one_over_eta**2*theta*cos(theta)**3]
# [c*deltaT**6*one_over_eta**2*theta*cos(theta)**3]
# [c*deltaT**6*one_over_eta**2*theta*cos(theta)**3]
# [c*deltaT**6*one_over_eta**2*theta*cos(theta)**3]
# [c*deltaT**6*one_over_eta**2*theta*cos(theta)**3]
# [c*deltaT**6*one_over_eta**2*theta*cos(theta)**3]
# [c*deltaT**6*one_over_eta**2*theta*cos(theta)**3]
# [c*deltaT**6*one_over_eta**2*theta*cos(theta)**3]
# [c*deltaT**6*one_over_eta**2*theta*cos(theta)**3]
# [c*deltaT**6*one_over_eta**2*theta*cos(theta)**3]
# [c*deltaT**6*one_over_eta**2*theta*cos(theta)**3]
# [c*deltaT**6*one_over_eta**2*theta*cos(theta)**3]
# [c*deltaT**6*one_over_eta**2*theta*cos(theta)**3]
# [c*deltaT**6*one_over_eta**2*theta*cos(theta)**3]
# [c*deltaT**6*one_over_eta**2*theta*cos(theta)**3]
# [c*deltaT**6*one_over_eta**2*theta*cos(theta)**3]
# [c*deltaT*one_over_eta**3*cos(theta)**2]
# [c*deltaT*one_over_eta**3*cos(theta)**2]
# [c*deltaT*one_over_eta**3*cos(theta)**2]
# [c*deltaT*one_over_eta**3*cos(theta)**2]
# [c*deltaT*one_over_eta**3*cos(theta)**2]
# [c*deltaT*one_over_eta**3*cos(theta)**2]
# [c*deltaT*one_over_eta**3*cos(theta)**2]
# [c*deltaT*one_over_eta**3*cos(theta)**2]
# [c*deltaT*one_over_eta**3*cos(theta)**2]
# [c*deltaT*one_over_eta**3*cos(theta)**2]
# [c*deltaT*one_over_eta**3*cos(theta)**2]
# [c*deltaT*one_over_eta**3*cos(theta)**2]
# [c*deltaT*one_over_eta**3*cos(theta)**2]
# [c*deltaT*one_over_eta**3*cos(theta)**2]
# [c*deltaT*one_over_eta**3*cos(theta)**2]
# [c*deltaT**4*one_over_eta*theta*cos(theta)**2]
# [c*deltaT**4*one_over_eta*theta*cos(theta)**2]
# [c*deltaT**4*one_over_eta*theta*cos(theta)**2]
# [c*deltaT**4*one_over_eta*theta*cos(theta)**2]
# [c*deltaT*one_over_eta**2*cos(theta)**3]
# [c*deltaT*one_over_eta**2*cos(theta)**3]
# [c*deltaT*one_over_eta**2*cos(theta)**3]
# [c*deltaT*one_over_eta**2*cos(theta)**3]
# [c*deltaT*one_over_eta**2*cos(theta)**3]
# [c*deltaT*one_over_eta**2*cos(theta)**3]
# [c*deltaT*one_over_eta**2*cos(theta)**3]
# [c*deltaT**3*one_over_eta*theta*cos(theta)]
# [c*deltaT**3*one_over_eta*theta*cos(theta)]
# [c*deltaT**6*one_over_eta*theta**2*cos(theta)]
# [c*deltaT**6*one_over_eta*theta**2*cos(theta)]
# [c*deltaT**6*one_over_eta*theta**2*cos(theta)]
# [c*deltaT**6*one_over_eta*theta**2*cos(theta)]
# [c*deltaT**6*one_over_eta*theta**2*cos(theta)]
# [c*deltaT**6*one_over_eta*theta**2*cos(theta)]
# [c*deltaT**6*one_over_eta*theta**2*cos(theta)]
# [c*deltaT**6*one_over_eta*theta**2*cos(theta)]
# [c*deltaT**6*one_over_eta*theta**2*cos(theta)]
# [c*deltaT**6*one_over_eta*theta**2*cos(theta)]
# [c*deltaT**6*one_over_eta*theta**2*cos(theta)]
# [c*deltaT**6*one_over_eta*theta**2*cos(theta)]
# [c*deltaT**6*one_over_eta*theta**2*cos(theta)]
# [c*deltaT**6*one_over_eta*theta**2*cos(theta)]
# [c*deltaT**6*one_over_eta*theta**2*cos(theta)]
# [c*deltaT**6*one_over_eta*theta**2*cos(theta)]
# [c*deltaT**6*one_over_eta*theta**2*cos(theta)]
# [c*deltaT**6*one_over_eta*theta**2*cos(theta)]
# [c*deltaT**6*one_over_eta*theta**2*cos(theta)]
# [c*deltaT**6*one_over_eta*theta**2*cos(theta)]
# [c*deltaT**6*one_over_eta*theta**2*cos(theta)]
# [c*deltaT**6*one_over_eta*theta**2*cos(theta)]
# [c*deltaT**6*one_over_eta*theta**2*cos(theta)]
# [c*deltaT*one_over_eta*theta**2]
# [c*deltaT*one_over_eta*theta**2]
# [c*deltaT*one_over_eta*theta**2]
# [c*deltaT*one_over_eta*theta**2]
# [c*deltaT**6*one_over_eta**3*cos(theta)**2]
# [c*deltaT**6*one_over_eta**3*cos(theta)**2]
# [c*deltaT**6*one_over_eta**3*cos(theta)**2]
# [c*deltaT**2*one_over_eta*theta]
# [c*deltaT**2*one_over_eta*theta]
# [c*deltaT**2*one_over_eta*theta]
# [c*deltaT**2*one_over_eta*theta]
# [c*deltaT**2*one_over_eta*theta]
# [c*deltaT**2*one_over_eta**3*theta**2*cos(theta)]
# [c*deltaT**2*one_over_eta**3*theta**2*cos(theta)]
# [c*deltaT**2*one_over_eta**3*theta**2*cos(theta)]
# [c*deltaT**2*one_over_eta**3*theta**2*cos(theta)]
# [c*deltaT**2*one_over_eta**3*theta**2*cos(theta)]
# [c*deltaT**2*one_over_eta**3*theta**2*cos(theta)]
# [c*deltaT**2*one_over_eta**3*theta**2*cos(theta)]
# [c*deltaT**2*one_over_eta**3*theta**2*cos(theta)]
# [c*deltaT**2*one_over_eta**3*theta**2*cos(theta)]
# [c*deltaT**2*one_over_eta**3*theta**2*cos(theta)]
# [c*deltaT**2*one_over_eta**3*theta**2*cos(theta)]
# [c*deltaT**2*one_over_eta**3*theta**2*cos(theta)]
# [c*deltaT**2*theta*cos(theta)**2]
# [c*deltaT**2*theta*cos(theta)**2]
# [c*deltaT**2*theta*cos(theta)**2]
# [c*deltaT**2*theta*cos(theta)**2]
# [c*deltaT**2*theta*cos(theta)**2]
# [c*deltaT**2*theta*cos(theta)**2]
# [c*deltaT**2*theta*cos(theta)**2]
# [c*deltaT**2*theta*cos(theta)**2]
# [c*deltaT**2*theta*cos(theta)**2]
# [c*deltaT**2*theta*cos(theta)**2]
# [c*deltaT**2*theta*cos(theta)**2]
# [c*deltaT**2*theta*cos(theta)**2]
# [c*deltaT**2*theta*cos(theta)**2]
# [c*deltaT**2*one_over_eta**2*cos(theta)**3]
# [c*deltaT**2*one_over_eta**2*cos(theta)**3]
# [c*deltaT**2*one_over_eta**2*cos(theta)**3]
# [c*deltaT**2*one_over_eta**2*cos(theta)**3]
# [c*deltaT**2*one_over_eta**2*cos(theta)**3]
# [c*deltaT**2*one_over_eta**3*theta*cos(theta)**2]
# [c*deltaT**2*one_over_eta**3*theta*cos(theta)**2]
# [c*deltaT**2*one_over_eta**3*theta*cos(theta)**2]
# [c*deltaT**2*one_over_eta**3*theta*cos(theta)**2]
# [c*deltaT**3*one_over_eta*theta**2*cos(theta)**2]
# [c*deltaT**3*one_over_eta*theta**2*cos(theta)**2]
# [c*deltaT**3*one_over_eta*theta**2*cos(theta)**2]
# [c*deltaT**3*one_over_eta*theta**2*cos(theta)**2]
# [c*deltaT**3*one_over_eta*theta**2*cos(theta)**2]
# [c*one_over_eta**5*cos(theta)]
# [c*one_over_eta**5*cos(theta)]
# [c*one_over_eta**5*cos(theta)]
# [c*one_over_eta**5*cos(theta)]
# [c*one_over_eta**5*cos(theta)]
# [c*one_over_eta**5*cos(theta)]
# [c*deltaT**2*one_over_eta**3*cos(theta)**3]
# [c*deltaT**2*one_over_eta**3*cos(theta)**3]
# [c*deltaT**2*one_over_eta**3*cos(theta)**3]
# [c*deltaT**2*one_over_eta**3*cos(theta)**3]
# [c*deltaT**2*one_over_eta**3*cos(theta)**3]
# [c*deltaT**2*one_over_eta**3*cos(theta)**3]
# [c*deltaT**2*one_over_eta**3*cos(theta)**3]
# [c*deltaT**2*one_over_eta**3*cos(theta)**3]
# [c*deltaT**2*one_over_eta**3*cos(theta)**3]
# [c*deltaT**2*one_over_eta**3*cos(theta)**3]
# [c*deltaT**2*one_over_eta**3*cos(theta)**3]
# [c*deltaT**2*one_over_eta**3*cos(theta)**3]
# [c*deltaT**2*one_over_eta**3*cos(theta)**3]
# [c*deltaT**2*one_over_eta**3*cos(theta)**3]
# [c*deltaT**2*one_over_eta**3*cos(theta)**3]
# [c*one_over_eta*cos(theta)**4]
# [c*one_over_eta*cos(theta)**4]
# [c*one_over_eta*cos(theta)**4]
# [c*one_over_eta*cos(theta)**4]
# [c*one_over_eta*cos(theta)**4]
# [c*deltaT**2*theta*cos(theta)]
# [c*deltaT**2*theta*cos(theta)]
# [c*deltaT**2*theta*cos(theta)]
# [c*deltaT**2*theta*cos(theta)]
# [c*deltaT**2*theta*cos(theta)]
# [c*deltaT**2*theta*cos(theta)]
# [c*deltaT**3*one_over_eta*cos(theta)**2]
# [c*deltaT**3*one_over_eta*cos(theta)**2]
# [c*deltaT**3*one_over_eta*cos(theta)**2]
# [c*deltaT**3*one_over_eta*cos(theta)**2]
# [c*deltaT**3*one_over_eta*cos(theta)**2]
# [c*deltaT**3*one_over_eta*cos(theta)**2]
# [c*deltaT**3*one_over_eta*cos(theta)**2]
# [c*deltaT**3*one_over_eta*cos(theta)**2]
# [c*deltaT**3*one_over_eta*cos(theta)**2]
# [c*deltaT**3*one_over_eta*cos(theta)**2]
# [c*deltaT**3*one_over_eta*cos(theta)**2]
# [c*deltaT**3*one_over_eta*cos(theta)**2]
# [c*one_over_eta**3*theta**2*cos(theta)**2]
# [c*one_over_eta**3*theta**2*cos(theta)**2]
# [c*one_over_eta**3*theta**2*cos(theta)**2]
# [c*one_over_eta**3*theta**2*cos(theta)**2]
# [c*one_over_eta*theta*cos(theta)**4]
# [c*one_over_eta*theta*cos(theta)**4]
# [c*one_over_eta*theta*cos(theta)**4]
# [c*one_over_eta*theta*cos(theta)**4]
# [c*one_over_eta*theta*cos(theta)**4]
# [c*one_over_eta*theta*cos(theta)**4]
# [c*one_over_eta*theta*cos(theta)**4]
# [c*one_over_eta*theta*cos(theta)**4]
# [c*one_over_eta*theta*cos(theta)**4]
# [c*deltaT**2*one_over_eta**2*theta*cos(theta)**2]
# [c*deltaT**2*one_over_eta**2*theta*cos(theta)**2]
# [c*deltaT**2*one_over_eta**2*theta*cos(theta)**2]
# [c*deltaT**2*one_over_eta**2*theta*cos(theta)**2]
# [c*deltaT**2*one_over_eta**2*theta*cos(theta)**2]
# [c*deltaT**2*one_over_eta**2*theta*cos(theta)**2]
# [c*deltaT**2*one_over_eta**2*theta*cos(theta)**2]
# [c*deltaT**2*one_over_eta**2*theta*cos(theta)**2]
# [c*deltaT**2*one_over_eta**2*theta*cos(theta)**2]
# [c*deltaT**2*one_over_eta**2*theta*cos(theta)**2]
# [c*deltaT**2*one_over_eta**2*theta*cos(theta)**2]
# [c*deltaT**2*one_over_eta**2*theta*cos(theta)**2]
# [c*deltaT**2*one_over_eta**2*theta*cos(theta)**2]
# [c*deltaT**2*one_over_eta**2*theta*cos(theta)**2]
# [c*deltaT**2*one_over_eta**2*theta*cos(theta)**2]
# [c*deltaT**2*one_over_eta**2*theta*cos(theta)**2]
# [c*deltaT**2*one_over_eta**2*theta*cos(theta)**2]
# [c*deltaT**2*one_over_eta**2*theta*cos(theta)**2]
# [c*deltaT**2*one_over_eta**2*theta*cos(theta)**2]
# [c*deltaT**2*one_over_eta**2*theta*cos(theta)**2]
# [c*deltaT**2*one_over_eta**2*theta*cos(theta)**2]
# [c*deltaT**2*one_over_eta**2*theta*cos(theta)**2]
# [c*deltaT**2*one_over_eta**2*theta*cos(theta)**2]
# [c*deltaT**2*one_over_eta**2*theta*cos(theta)**2]
# [c*deltaT**2*one_over_eta**2*theta*cos(theta)**2]
# [c*deltaT**2*one_over_eta**2*theta*cos(theta)**2]
# [c*deltaT**2*one_over_eta**2*theta*cos(theta)**2]
# [c*deltaT**2*one_over_eta**2*theta*cos(theta)**2]
# [c*deltaT**2*one_over_eta**2*theta*cos(theta)**2]
# [c*deltaT**2*one_over_eta**2*theta*cos(theta)**2]
# [c*deltaT**2*one_over_eta**2*theta*cos(theta)**2]
# [c*deltaT**2*one_over_eta**2*theta*cos(theta)**2]
# [c*deltaT**2*one_over_eta**2*theta*cos(theta)**2]
# [c*deltaT**2*one_over_eta**2*theta*cos(theta)**2]
# [c*deltaT**2*one_over_eta**2*theta*cos(theta)**2]
# [c*deltaT*one_over_eta**2*theta*cos(theta)**2]
# [c*deltaT*one_over_eta**2*theta*cos(theta)**2]
# [c*deltaT*one_over_eta**2*theta*cos(theta)**2]
# [c*deltaT**4*theta]
# [c*deltaT**4*theta]
# [c*deltaT**4*theta]
# [c*deltaT**4*theta]
# [c*one_over_eta**3*theta*cos(theta)]
# [c*one_over_eta**3*theta*cos(theta)]
# [c*one_over_eta**3*theta*cos(theta)]
# [c*one_over_eta**3*theta*cos(theta)]
# [c*one_over_eta**3*theta*cos(theta)]
# [c*one_over_eta**3*theta*cos(theta)]
# [c*one_over_eta**3*theta*cos(theta)]
# [c*one_over_eta**3*theta*cos(theta)]
# [c*one_over_eta**3*theta*cos(theta)]
# [c*one_over_eta**3*theta*cos(theta)]
# [c*one_over_eta**3*theta*cos(theta)]
# [c*one_over_eta**3*theta*cos(theta)]
# [c*one_over_eta**3*theta*cos(theta)]
# [c*one_over_eta**3*theta*cos(theta)]
# [c*one_over_eta**3*theta*cos(theta)]
# [c*one_over_eta**3*theta*cos(theta)]
# [c*one_over_eta**3*theta*cos(theta)]
# [c*one_over_eta**3*theta*cos(theta)]
# [c*one_over_eta**3*theta*cos(theta)]
# [c*one_over_eta**3*theta*cos(theta)]
# [c*one_over_eta**3*theta*cos(theta)]
# [c*one_over_eta**3*theta*cos(theta)]
# [c*one_over_eta**3*theta*cos(theta)]
# [c*one_over_eta**3*theta*cos(theta)]
# [c*one_over_eta**3*theta*cos(theta)]
# [c*one_over_eta**3*theta*cos(theta)]
# [c*one_over_eta**3*theta*cos(theta)]
# [c*one_over_eta**3*theta*cos(theta)]
# [c*one_over_eta**3*theta*cos(theta)]
# [c*one_over_eta**3*theta*cos(theta)]
# [c*one_over_eta**3*theta*cos(theta)]
# [c*one_over_eta**3*theta*cos(theta)]
# [c*one_over_eta**3*theta*cos(theta)]
# [c*one_over_eta**3*theta*cos(theta)]
# [c*one_over_eta**3*theta*cos(theta)]
# [c*one_over_eta**3*theta*cos(theta)]
# [c*one_over_eta**3*theta*cos(theta)]
# [c*one_over_eta**3*theta*cos(theta)]
# [c*one_over_eta**3*theta*cos(theta)]
# [c*one_over_eta**3*theta*cos(theta)]
# [c*one_over_eta**3*theta*cos(theta)]
# [c*one_over_eta**3*theta*cos(theta)]
# [c*deltaT**3*one_over_eta**2]
# [c*deltaT*one_over_eta**5]
# [c*deltaT*one_over_eta**5]
# [c*deltaT**5*theta*cos(theta)**2]
# [c*deltaT**5*theta*cos(theta)**2]
# [c*deltaT**5*theta*cos(theta)**2]
# [c*deltaT**5*theta*cos(theta)**2]
# [c*deltaT**5*theta*cos(theta)**2]
# [c*deltaT**5*theta*cos(theta)**2]
# [c*deltaT**5*theta*cos(theta)**2]
# [c*deltaT**5*theta*cos(theta)**2]
# [c*deltaT**5*theta*cos(theta)**2]
# [c*deltaT**5*theta*cos(theta)**2]
# [c*deltaT**5*theta*cos(theta)**2]
# [c*deltaT**5*theta*cos(theta)**2]
# [c*deltaT**5*theta*cos(theta)**2]
# [c*deltaT**5*theta*cos(theta)**2]
# [c*deltaT**5*theta*cos(theta)**2]
# [c*deltaT**5*theta*cos(theta)**2]
# [c*deltaT**5*theta*cos(theta)**2]
# [c*deltaT**5*theta*cos(theta)**2]
# [c*deltaT**5*theta*cos(theta)**2]
# [c*deltaT**5*theta*cos(theta)**2]
# [c*deltaT**5*theta*cos(theta)**2]
# [c*deltaT**5*theta*cos(theta)**2]
# [c*deltaT**5*theta*cos(theta)**2]
# [c*deltaT*theta**2*cos(theta)**4]
# [c*deltaT*theta**2*cos(theta)**4]
# [c*deltaT*theta**2*cos(theta)**4]
# [c*deltaT*theta**2*cos(theta)**4]
# [c*deltaT*theta**2*cos(theta)**4]
# [c*deltaT*theta**2*cos(theta)**4]
# [c*deltaT*theta**2*cos(theta)**4]
# [c*deltaT*theta**2*cos(theta)**4]
# [c*deltaT*theta**2*cos(theta)**4]
# [c*deltaT*theta**2*cos(theta)**4]
# [c*deltaT*theta**2*cos(theta)**4]
# [c*deltaT*theta**2*cos(theta)**4]
# [c*deltaT*theta**2*cos(theta)**4]
# [c*deltaT*theta**2*cos(theta)**4]
# [c*deltaT*theta**2*cos(theta)**4]
# [c*deltaT*theta**2*cos(theta)**4]
# [c*deltaT*theta**2*cos(theta)**4]
# [c*deltaT*theta**2*cos(theta)**4]
# [c*deltaT*theta**2*cos(theta)**4]
# [c*deltaT*theta**2*cos(theta)**4]
# [c*deltaT*theta**2*cos(theta)**4]
# [c*deltaT**2*one_over_eta**2*theta**2*cos(theta)**3]
# [c*deltaT**2*one_over_eta**2*theta**2*cos(theta)**3]
# [c*deltaT**2*one_over_eta**2*theta**2*cos(theta)**3]
# [c*deltaT**2*one_over_eta**2*theta**2*cos(theta)**3]
# [c*deltaT**2*one_over_eta**2*theta**2*cos(theta)**3]
# [c*deltaT**2*one_over_eta**2*theta**2*cos(theta)**3]
# [c*deltaT**2*one_over_eta**2*theta**2*cos(theta)**3]
# [c*deltaT**2*one_over_eta**2*theta**2*cos(theta)**3]
# [c*deltaT**2*one_over_eta**2*theta**2*cos(theta)**3]
# [c*deltaT**2*one_over_eta**2*theta**2*cos(theta)**3]
# [c*deltaT**2*one_over_eta**4*cos(theta)**3]
# [c*deltaT**2*one_over_eta**4*cos(theta)**3]
# [c*deltaT**2*one_over_eta**4*cos(theta)**3]
# [c*deltaT**2*one_over_eta**4*cos(theta)**3]
# [c*deltaT**2*one_over_eta**4*cos(theta)**3]
# [c*deltaT**2*one_over_eta**4*cos(theta)**3]
# [c*deltaT**2*one_over_eta**4*cos(theta)**3]
# [c*deltaT**2*one_over_eta**4*cos(theta)**3]
# [c*deltaT**2*one_over_eta**4*cos(theta)**3]
# [c*deltaT**2*one_over_eta**4*cos(theta)**3]
# [c*deltaT**2*one_over_eta**4*cos(theta)**3]
# [c*deltaT**2*one_over_eta**4*cos(theta)**3]
# [c*deltaT**2*one_over_eta**4*cos(theta)**3]
# [c*deltaT**2*one_over_eta**4*cos(theta)**3]
# [c*deltaT**2*one_over_eta**4*cos(theta)**3]
# [c*one_over_eta**2*theta**2*cos(theta)**3]
# [c*one_over_eta**2*theta**2*cos(theta)**3]
# [c*one_over_eta**2*theta**2*cos(theta)**3]
# [c*one_over_eta**2*theta**2*cos(theta)**3]
# [c*one_over_eta**2*theta**2*cos(theta)**3]
# [c*one_over_eta**2*theta**2*cos(theta)**3]
# [c*one_over_eta**2*theta**2*cos(theta)**3]
# [c*one_over_eta**2*theta**2*cos(theta)**3]
# [c*one_over_eta**2*theta**2*cos(theta)**3]
# [c*one_over_eta**2*theta**2*cos(theta)**3]
# [c*one_over_eta**2*theta**2*cos(theta)**3]
# [c*one_over_eta**2*theta**2*cos(theta)**3]
# [c*one_over_eta**2*theta**2*cos(theta)**3]
# [c*one_over_eta**2*theta**2*cos(theta)**3]
# [c*one_over_eta**2*theta**2*cos(theta)**3]
# [c*one_over_eta**2*theta**2*cos(theta)**3]
# [c*one_over_eta**2*theta**2*cos(theta)**3]
# [c*one_over_eta**2*theta**2*cos(theta)**3]
# [c*one_over_eta**2*theta**2*cos(theta)**3]
# [c*one_over_eta**2*theta**2*cos(theta)**3]
# [c*one_over_eta**2*theta**2*cos(theta)**3]
# [c*one_over_eta**2*theta**2*cos(theta)**3]
# [c*one_over_eta**2*theta**2*cos(theta)**3]
# [c*one_over_eta**2*theta**2*cos(theta)**3]
# [c*one_over_eta**2*theta**2*cos(theta)**3]
# [c*one_over_eta**2*theta**2*cos(theta)**3]
# [c*one_over_eta**2*theta**2*cos(theta)**3]
# [c*one_over_eta**2*theta**2*cos(theta)**3]
# [c*one_over_eta**2*theta**2*cos(theta)**3]
# [c*one_over_eta**4*theta]
# [c*one_over_eta**4*theta]
# [c*one_over_eta**4*theta]
# [c*one_over_eta**4*theta]
# [c*one_over_eta**4*theta]
# [c*one_over_eta**4*theta]
# [c*one_over_eta**4*theta]
# [c*one_over_eta**4*theta]
# [c*one_over_eta**4*theta]
# [c*one_over_eta**4*theta]
# [c*one_over_eta**4*theta]
# [c*one_over_eta**4*theta]
# [c*one_over_eta**4*theta]
# [c*one_over_eta**4*theta]
# [c*deltaT**6*one_over_eta*cos(theta)]
# [c*deltaT**6*one_over_eta*cos(theta)]
# [c*deltaT**6*one_over_eta*cos(theta)]
# [c*deltaT**6*one_over_eta*cos(theta)]
# [c*deltaT**6*one_over_eta*cos(theta)]
# [c*deltaT**6*one_over_eta*cos(theta)]
# [c*deltaT**6*one_over_eta*cos(theta)]
# [c*deltaT**6*one_over_eta*cos(theta)]
# [c*deltaT**6*one_over_eta*cos(theta)]
# [c*deltaT**6*one_over_eta*cos(theta)]
# [c*deltaT**6*one_over_eta*cos(theta)]
# [c*deltaT**6*one_over_eta*cos(theta)]
# [c*deltaT**6*one_over_eta*cos(theta)]
# [c*deltaT**6*one_over_eta*cos(theta)]
# [c*deltaT**6*one_over_eta*cos(theta)]
# [c*deltaT**6*one_over_eta*cos(theta)]
# [c*deltaT*one_over_eta**2*cos(theta)**5]
# [c*deltaT*one_over_eta**2*cos(theta)**5]
# [c*deltaT*one_over_eta**2*cos(theta)**5]
# [c*deltaT*one_over_eta**2*cos(theta)**5]
# [c*deltaT*one_over_eta**2*cos(theta)**5]
# [c*deltaT*one_over_eta**2*cos(theta)**5]
# [c*deltaT**2*one_over_eta*theta**2]
# [c*deltaT**2*one_over_eta*theta**2]
# [c*deltaT**2*one_over_eta*theta**2]
# [c*deltaT**2*one_over_eta*theta**2]
# [c*deltaT**2*one_over_eta*theta**2]
# [c*deltaT**2*one_over_eta*theta**2]
# [c*deltaT**2*one_over_eta*theta**2]
# [c*deltaT**2*one_over_eta*theta**2]
# [c*deltaT**2*one_over_eta*theta**2]
# [c*theta**2*cos(theta)]
# [c*theta**2*cos(theta)]
# [c*theta**2*cos(theta)]
# [c*theta**2*cos(theta)]
# [c*theta**2*cos(theta)]
# [c*theta**2*cos(theta)]
# [c*theta**2*cos(theta)]
# [c*theta**2*cos(theta)]
# [c*theta**2*cos(theta)]
# [c*theta**2*cos(theta)]
# [c*theta**2*cos(theta)]
# [c*theta**2*cos(theta)]
# [c*theta**2*cos(theta)]
# [c*theta**2*cos(theta)]
# [c*deltaT**2*one_over_eta**3*theta**2*cos(theta)**2]
# [c*deltaT**2*one_over_eta**3*theta**2*cos(theta)**2]
# [c*deltaT**2*one_over_eta**3*theta**2*cos(theta)**2]
# [c*deltaT**2*one_over_eta**3*theta**2*cos(theta)**2]
# [c*deltaT**2*one_over_eta**3*theta**2*cos(theta)**2]
# [c*deltaT**2*one_over_eta**3*theta**2*cos(theta)**2]
# [c*deltaT**2*one_over_eta**3*theta**2*cos(theta)**2]
# [c*deltaT**2*one_over_eta**3*theta**2*cos(theta)**2]
# [c*deltaT*one_over_eta**5*theta]
# [c*deltaT*one_over_eta**5*theta]
# [c*deltaT*one_over_eta**5*theta]
# [c*deltaT*one_over_eta**5*theta]
# [c*deltaT*one_over_eta**5*theta]
# [c*one_over_eta*theta**3*cos(theta)]
# [c*one_over_eta*theta**3*cos(theta)]
# [c*one_over_eta*theta**3*cos(theta)]
# [c*one_over_eta*theta**3*cos(theta)]
# [c*one_over_eta*theta**3*cos(theta)]
# [c*one_over_eta*theta**3*cos(theta)]
# [c*one_over_eta*theta**3*cos(theta)]
# [c*one_over_eta*theta**3*cos(theta)]
# [c*one_over_eta*theta**3*cos(theta)]
# [c*one_over_eta*theta**3*cos(theta)]
# [c*one_over_eta*theta**3*cos(theta)]
# [c*one_over_eta*theta**3*cos(theta)]
# [c*one_over_eta*theta**3*cos(theta)]
# [c*one_over_eta*theta**3*cos(theta)]
# [c*one_over_eta*theta**3*cos(theta)]
# [c*one_over_eta*theta**3*cos(theta)]
# [c*one_over_eta*theta**3*cos(theta)]
# [c*one_over_eta*theta**3*cos(theta)]
# [c*one_over_eta*theta**3*cos(theta)]
# [c*one_over_eta*theta**3*cos(theta)]
# [c*one_over_eta*theta**3*cos(theta)]
# [c*one_over_eta*theta**3*cos(theta)]
# [c*one_over_eta*theta**3*cos(theta)]
# [c*one_over_eta*theta**3*cos(theta)]
# [c*one_over_eta*theta**3*cos(theta)]
# [c*one_over_eta*theta**3*cos(theta)]
# [c*one_over_eta*theta**3*cos(theta)]
# [c*deltaT**4*one_over_eta*cos(theta)**2]
# [c*deltaT**4*one_over_eta*cos(theta)**2]
# [c*deltaT**4*one_over_eta*cos(theta)**2]
# [c*deltaT**4*one_over_eta*cos(theta)**2]
# [c*deltaT**4*one_over_eta*cos(theta)**2]
# [c*deltaT**4*one_over_eta*cos(theta)**2]
# [c*deltaT**4*one_over_eta*cos(theta)**2]
# [c*deltaT**4*one_over_eta*cos(theta)**2]
# [c*deltaT**4*one_over_eta*cos(theta)**2]
# [c*deltaT**4*one_over_eta*cos(theta)**2]
# [c*deltaT**4*one_over_eta*cos(theta)**2]
# [c*deltaT**4*one_over_eta*cos(theta)**2]
# [c*deltaT**4*one_over_eta*cos(theta)**2]
# [c*deltaT**4*one_over_eta*cos(theta)**2]
# [c*one_over_eta**2*theta**2*cos(theta)]
# [c*one_over_eta**2*theta**2*cos(theta)]
# [c*deltaT*theta**2*cos(theta)**3]
# [c*deltaT**5*one_over_eta**3*cos(theta)**5]
# [c*deltaT**5*one_over_eta**3*cos(theta)**5]
# [c*deltaT**5*one_over_eta**3*cos(theta)**5]
# [c*deltaT**5*one_over_eta**3*cos(theta)**5]
# [c*deltaT**5*one_over_eta**3*cos(theta)**5]
# [c*deltaT**5*one_over_eta**3*cos(theta)**5]
# [c*deltaT**5*one_over_eta**3*cos(theta)**5]
# [c*deltaT**5*one_over_eta**3*cos(theta)**5]
# [c*deltaT**5*one_over_eta**3*cos(theta)**5]
# [c*deltaT**5*one_over_eta**3*cos(theta)**5]
# [c*deltaT*one_over_eta*theta*cos(theta)**2]
# [c*deltaT*one_over_eta*theta*cos(theta)**2]
# [c*deltaT*one_over_eta*theta*cos(theta)**2]
# [c*deltaT*one_over_eta*theta*cos(theta)**2]
# [c*deltaT*one_over_eta*theta*cos(theta)**2]
# [c*deltaT*one_over_eta*theta*cos(theta)**2]
# [c*deltaT*one_over_eta*theta*cos(theta)**2]
# [c*deltaT*one_over_eta*theta*cos(theta)**2]
# [c*deltaT*one_over_eta*theta*cos(theta)**2]
# [c*theta**2*cos(theta)**3]
# [c*theta**2*cos(theta)**3]
# [c*theta**2*cos(theta)**3]
# [c*theta**2*cos(theta)**3]
# [c*theta**2*cos(theta)**3]
# [c*theta**2*cos(theta)**3]
# [c*theta**2*cos(theta)**3]
# [c*theta**2*cos(theta)**3]
# [c*theta**2*cos(theta)**3]
# [c*theta**2*cos(theta)**3]
# [c*theta**2*cos(theta)**3]
# [c*theta**2*cos(theta)**3]
# [c*theta**2*cos(theta)**3]
# [c*theta**2*cos(theta)**3]
# [c*theta**2*cos(theta)**3]
# [c*theta**2*cos(theta)**3]
# [c*theta**2*cos(theta)**3]
# [c*theta**2*cos(theta)**3]
# [c*theta**2*cos(theta)**3]
# [c*theta**2*cos(theta)**3]
# [c*theta**2*cos(theta)**3]
# [c*theta**2*cos(theta)**3]
# [c*theta**2*cos(theta)**3]
# [c*theta**2*cos(theta)**3]
# [c*theta**2*cos(theta)**3]
# [c*theta**2*cos(theta)**3]
# [c*theta**2*cos(theta)**3]
# [c*theta**2*cos(theta)**3]
# [c*theta**2*cos(theta)**3]
# [c*theta**2*cos(theta)**3]
# [c*theta**2*cos(theta)**3]
# [c*theta**2*cos(theta)**3]
# [c*theta**2*cos(theta)**3]
# [c*theta**2*cos(theta)**3]
# [c*theta**2*cos(theta)**3]
# [c*theta**2*cos(theta)**3]
# [c*one_over_eta**3*cos(theta)**2]
# [c*one_over_eta**3*cos(theta)**2]
# [c*one_over_eta**3*cos(theta)**2]
# [c*one_over_eta**3*cos(theta)**2]
# [c*one_over_eta**3*cos(theta)**2]
# [c*one_over_eta**3*cos(theta)**2]
# [c*one_over_eta**3*cos(theta)**2]
# [c*one_over_eta**3*cos(theta)**2]
# [c*one_over_eta**3*cos(theta)**2]
# [c*one_over_eta**3*cos(theta)**2]
# [c*one_over_eta**3*cos(theta)**2]
# [c*one_over_eta**3*cos(theta)**2]
# [c*one_over_eta**3*cos(theta)**2]
# [c*one_over_eta**3*cos(theta)**2]
# [c*one_over_eta**3*cos(theta)**2]
# [c*one_over_eta**3*cos(theta)**2]
# [c*one_over_eta**3*cos(theta)**2]
# [c*one_over_eta**3*cos(theta)**2]
# [c*one_over_eta**3*cos(theta)**2]
# [c*one_over_eta**3*cos(theta)**2]
# [c*one_over_eta**3*cos(theta)**2]
# [c*one_over_eta**3*cos(theta)**2]
# [c*one_over_eta**3*cos(theta)**2]
# [c*one_over_eta**3*cos(theta)**2]
# [c*one_over_eta**3*cos(theta)**2]
# [c*one_over_eta**3*cos(theta)**2]
# [c*one_over_eta**3*cos(theta)**2]
# [c*one_over_eta**3*cos(theta)**2]
# [c*one_over_eta**3*cos(theta)**2]
# [c*one_over_eta**3*cos(theta)**2]
# [c*one_over_eta**3*cos(theta)**2]
# [c*one_over_eta**3*cos(theta)**2]
# [c*one_over_eta**3*cos(theta)**2]
# [c*one_over_eta**3*cos(theta)**2]
# [c*one_over_eta**3*cos(theta)**2]
# [c*one_over_eta**3*cos(theta)**2]
# [c*deltaT**3*theta*cos(theta)]
# [c*deltaT**3*theta*cos(theta)]
# [c*deltaT**3*theta*cos(theta)]
# [c*deltaT**3*theta*cos(theta)]
# [c*deltaT**2*one_over_eta**2]
# [c*deltaT**2*one_over_eta**2]
# [c*deltaT**2*one_over_eta**2]
# [c*deltaT**2*one_over_eta**2]
# [c*deltaT**2*one_over_eta**2]
# ...
# -> [c*deltaT**2*one_over_eta**6], p = 7.346640383999997e-07
# -> [c*deltaT**2*one_over_eta**4], p = 9.069926399999997e-05
# -> [c*deltaT**3*one_over_eta**4*cos(theta)**2], p = 3.9671858073599974e-07
# -> [c*deltaT**3*theta**2*cos(theta)**2], p = 4.5349631999999986e-07
# -> [c*deltaT**5*theta*cos(theta)], p = 4.081466879999999e-06
# -> [c*deltaT**3*one_over_eta**3*theta**2*cos(theta)], p = 1.4693280767999997e-08
# -> [c*deltaT**2*one_over_eta**4*cos(theta)**2], p = 2.9386561535999988e-06
# -> [c*deltaT**5*one_over_eta*theta*cos(theta)], p = 7.346640383999998e-07
# -> [c*deltaT**4*theta**2*cos(theta)**4], p = 2.6447905382399986e-09
# -> [c*deltaT**2*one_over_eta*theta*cos(theta)**4], p = 1.2244400639999995e-06
# -> [c*deltaT**3*one_over_eta**2*cos(theta)**3], p = 4.407984230399998e-06
# -> [c*deltaT**3*one_over_eta**2*theta*cos(theta)**2], p = 1.2244400639999995e-06
# -> [c*deltaT*one_over_eta**6*theta*cos(theta)**3], p = 1.4281868906495992e-09
# -> [c*one_over_eta*cos(theta)**6], p = 4.081466879999998e-06
# -> [c*deltaT**2*one_over_eta**2*theta**2*cos(theta)**5], p = 4.760622968831998e-10
# -> [c*deltaT**2*one_over_eta**4*cos(theta)], p = 4.081466879999997e-05
# -> [c*deltaT**5*one_over_eta*cos(theta)**2], p = 1.4693280767999994e-06
# -> [c*deltaT**2*one_over_eta**5*cos(theta)**3], p = 4.760622968831997e-08
# -> [c*one_over_eta**2*theta*cos(theta)**3], p = 3.0233087999999994e-05
# -> [c*one_over_eta**4*theta**3], p = 1.5116544e-07
# -> [c*deltaT**3*theta**2*cos(theta)**4], p = 1.4693280767999992e-08
# -> [c*deltaT**6*one_over_eta**2*theta**8*cos(theta)**8], p = 1.3598118630822476e-22
# -> [c*deltaT**4*cos(theta)**2], p = 6.802444799999997e-05
# -> [c*one_over_eta**5*cos(theta)**4], p = 1.3223952691199992e-07
# -> [c*one_over_eta**3*theta**2], p = 6.9984e-05
# -> [c*deltaT**3*one_over_eta**2*theta**2*cos(theta)], p = 8.162933759999998e-08
# -> [c*deltaT**2*one_over_eta**2*cos(theta)**4], p = 5.142648268799998e-06
# -> [c*one_over_eta*theta**3*cos(theta)**3], p = 1.5116544e-07
# -> [c*deltaT**2*one_over_eta**5*theta], p = 2.448880127999999e-07
# -> [c*deltaT**2*one_over_eta**4*theta*cos(theta)**3], p = 2.3803114844159988e-08
# -> [c*deltaT**2*one_over_eta**2*theta**4*cos(theta)**2], p = 2.9386561535999996e-10
# -> [c*deltaT**3*one_over_eta**4*theta**2*cos(theta)**2], p = 4.760622968831998e-10
# -> [c*deltaT**4*one_over_eta**4*theta*cos(theta)**6], p = 1.4992534703283229e-12
# -> [c*deltaT**3*one_over_eta**3*theta**2], p = 8.162933759999998e-08
# -> [c*deltaT*one_over_eta**2*theta**2*cos(theta)**3], p = 8.162933759999996e-08
# -> [c*deltaT**3*one_over_eta**4*theta*cos(theta)**7], p = 1.4992534703283229e-12
# -> [c*one_over_eta**3*cos(theta)**4], p = 1.2244400639999995e-05
# -> [c*deltaT**4], p = 0.0006998399999999999
# -> [c*deltaT**3*one_over_eta*theta**3], p = 1.5116543999999997e-07
# -> [c*deltaT**4*one_over_eta**2*theta*cos(theta)], p = 4.897760255999998e-07
# -> [c*one_over_eta**3*theta*cos(theta)**6], p = 1.5868743229439992e-08
# -> [c*deltaT**4*one_over_eta**4*cos(theta)**5], p = 2.77639531542282e-10
# -> [c*deltaT**2*one_over_eta**2*theta*cos(theta)**3], p = 1.2244400639999995e-06
# -> [c*deltaT**4*one_over_eta**5*theta], p = 7.934371614719996e-09
# -> [c*deltaT**5*one_over_eta**3*theta**3*cos(theta)], p = 2.856373781299198e-11
# -> [c*theta**3*cos(theta)**2], p = 4.6656e-06
# -> [c*deltaT**6*one_over_eta*theta**2*cos(theta)**2], p = 4.760622968831999e-10
# -> [c*deltaT**3*one_over_eta**2*theta**2*cos(theta)**3], p = 5.289581076479998e-09
# -> [c*one_over_eta*theta*cos(theta)**6], p = 2.448880127999999e-07
# -> [c*deltaT**3*theta*cos(theta)**6], p = 7.934371614719996e-09
# -> [c*deltaT**3*one_over_eta**5*cos(theta)**4], p = 1.5424418419015667e-09
# -> [c*deltaT**6*one_over_eta**2*cos(theta)], p = 1.3223952691199992e-07
# -> [c*deltaT**3*one_over_eta**4*theta*cos(theta)**5], p = 4.627325525704701e-11
# -> [c*one_over_eta**4*cos(theta)**4], p = 7.346640383999997e-07
# -> [c*deltaT**2*one_over_eta**5], p = 4.081466879999998e-06
# -> [c*deltaT*one_over_eta**3*theta**2], p = 2.519424e-06
# -> [c*deltaT**5*one_over_eta**3*cos(theta)**4], p = 7.712209209507833e-10
# -> [c*deltaT*theta*cos(theta)**5], p = 1.3604889599999997e-06
# -> [c*deltaT**7*cos(theta)], p = 7.346640383999997e-07
# -> [c*deltaT*one_over_eta**3*cos(theta)**3], p = 2.040733439999999e-05
# -> [c*deltaT*one_over_eta**4*theta], p = 1.5116543999999997e-05
# -> [c*one_over_eta**5*theta], p = 1.5116543999999997e-05
# -> [c*deltaT**2*one_over_eta**2*theta**2*cos(theta)], p = 2.2674815999999992e-06
# -> [c*deltaT**4*one_over_eta*theta], p = 1.5116543999999997e-05
# -> [c*deltaT*one_over_eta**6*theta**2*cos(theta)**2], p = 4.760622968831997e-10
# -> [c*deltaT*one_over_eta**3*cos(theta)**5], p = 2.6447905382399985e-07
# -> [c*deltaT**2*one_over_eta*theta**2*cos(theta)], p = 7.558271999999999e-06
# -> [c*deltaT**3*one_over_eta*theta**2*cos(theta)], p = 9.069926399999998e-07
# -> [c*deltaT**5*one_over_eta**6*theta**2*cos(theta)**5], p = 2.914548746318259e-15
# -> [c*deltaT**3*one_over_eta**6], p = 1.3223952691199992e-07
# -> [c*deltaT**6*one_over_eta*cos(theta)**3], p = 2.3803114844159985e-08
# -> [c*deltaT**2*one_over_eta**5*cos(theta)], p = 7.346640383999997e-07
# -> [c*deltaT*one_over_eta**5*theta**2*cos(theta)**4], p = 8.569121343897596e-11
# -> [c*deltaT**4*one_over_eta*theta**2], p = 4.5349631999999986e-07
# -> [c*deltaT*one_over_eta**3*theta*cos(theta)**4], p = 4.4079842303999983e-08
# -> [c*deltaT**5], p = 0.00012597119999999996
# -> [c*deltaT**5*theta**2], p = 4.5349631999999986e-07
# -> [c*deltaT**6*one_over_eta**2], p = 7.346640383999997e-07
# -> [c*deltaT**3*theta**2], p = 4.1990400000000004e-05
# -> [c*deltaT*theta**2*cos(theta)**5], p = 8.162933759999998e-08
# -> [c*deltaT**3*one_over_eta**3*theta**3*cos(theta)**3], p = 2.856373781299199e-11
# -> [c*deltaT**2*one_over_eta**4*cos(theta)**4], p = 2.3803114844159985e-08
# -> [c*deltaT**5*one_over_eta], p = 2.2674815999999992e-05
# -> [c*deltaT**3*one_over_eta**4*theta**2*cos(theta)**5], p = 2.7763953154228204e-12
# -> [c*deltaT*one_over_eta**7], p = 7.346640383999997e-07
# -> [c*deltaT*one_over_eta**4*theta*cos(theta)**3], p = 8.815968460799997e-08
# -> [c*deltaT**6*one_over_eta**2*theta*cos(theta)**2], p = 2.8563737812991984e-09
# -> [c*deltaT**3*one_over_eta**2*theta**3*cos(theta)], p = 4.897760255999999e-09
# -> [c*deltaT**5*one_over_eta*theta*cos(theta)**2], p = 8.815968460799997e-08
# -> [c*deltaT**2*one_over_eta**4*theta], p = 1.3604889599999997e-06
# -> [c*deltaT**5*one_over_eta**3*cos(theta)**6], p = 2.498755783880538e-11
# -> [c*deltaT**4*one_over_eta*cos(theta)**3], p = 2.203992115199999e-06
# -> [c*theta**3*cos(theta)], p = 7.776000000000001e-05
# -> [c*deltaT**2*one_over_eta**2*theta*cos(theta)**7], p = 2.570736403169278e-10
# -> [c*deltaT**2*one_over_eta**4*theta*cos(theta)], p = 9.795520511999997e-07
# -> [c*deltaT**3*one_over_eta**5*cos(theta)], p = 1.3223952691199992e-07
# -> [c*deltaT**4*one_over_eta**2], p = 9.069926399999997e-05
# -> [c*deltaT*one_over_eta**4*theta**2*cos(theta)], p = 8.16293376e-08
# -> [c*deltaT**2*one_over_eta**5*cos(theta)**2], p = 5.289581076479997e-07
# -> [c*deltaT**3*one_over_eta**4*theta**3*cos(theta)**3], p = 5.1414728063385565e-12
# -> [c*deltaT**3*one_over_eta**2*theta*cos(theta)**5], p = 1.4281868906495992e-09
# -> [c*deltaT**2*one_over_eta*theta**2*cos(theta)**5], p = 2.644790538239998e-09
# -> [c*one_over_eta**5*cos(theta)**5], p = 2.3803114844159985e-08
# -> [c*deltaT**2*one_over_eta**4*theta**2*cos(theta)], p = 2.9386561535999987e-08
# -> [c*deltaT**5*one_over_eta**7*cos(theta)**4], p = 8.095968739772942e-13
# -> [c*deltaT**5*one_over_eta**6*theta*cos(theta)**5], p = 4.857581243863765e-14
# -> [c*deltaT**4*one_over_eta**2*cos(theta)**5], p = 8.569121343897593e-09
# -> [c*deltaT**4*theta**2*cos(theta)], p = 4.5349631999999986e-07
# -> [c*deltaT*one_over_eta**5*cos(theta)], p = 8.162933759999996e-06
# -> [c*deltaT**2*one_over_eta**3*theta**2*cos(theta)**4], p = 9.521245937663996e-10
# -> [c*deltaT**5*one_over_eta**2*theta*cos(theta)], p = 4.4079842303999983e-08
# -> [c*deltaT**4*one_over_eta*theta*cos(theta)**5], p = 1.4281868906495992e-09
# -> [c*deltaT*one_over_eta*theta*cos(theta)**4], p = 5.441955839999998e-06
# -> [c*deltaT**5*one_over_eta**3*cos(theta)**3], p = 4.284560671948796e-09
# -> [c*one_over_eta**6*cos(theta)], p = 4.081466879999998e-06
# -> [c*deltaT*one_over_eta**2*cos(theta)**6], p = 1.3223952691199992e-07
# -> [c*deltaT**3*one_over_eta**2*theta*cos(theta)], p = 6.8024447999999985e-06
# -> [c*one_over_eta*theta**3], p = 5.1840000000000005e-05
# -> [c*deltaT**3*one_over_eta**4*theta*cos(theta)**3], p = 1.4281868906495992e-09
# -> [c*deltaT**3*one_over_eta**6*theta*cos(theta)**2], p = 5.141472806338557e-10
# -> [c*deltaT*one_over_eta*theta**3*cos(theta)], p = 1.679616e-06
# -> [c*deltaT**5*cos(theta)], p = 0.00011337407999999997
# -> [c*theta**2*cos(theta)**2], p = 0.00015552000000000003
# -> [c*deltaT**5*one_over_eta**4*theta*cos(theta)**2], p = 2.570736403169278e-10
# -> [c*deltaT**4*cos(theta)**3], p = 4.081466879999998e-06
# -> [c*deltaT**2*one_over_eta**7*theta**2*cos(theta)**3], p = 2.7763953154228208e-12
# -> [c*one_over_eta*theta**2*cos(theta)**3], p = 2.5194239999999994e-06
# -> [c*one_over_eta**2*theta*cos(theta)**7], p = 7.934371614719996e-09
# -> [c*one_over_eta**2*theta**3], p = 4.665600000000001e-06
# -> [c*deltaT*one_over_eta**4*theta*cos(theta)**4], p = 7.934371614719996e-09
# -> [c*deltaT**4*one_over_eta*theta**2*cos(theta)**2], p = 4.407984230399999e-08
# -> [c*deltaT**3*one_over_eta**4*theta*cos(theta)], p = 8.815968460799997e-08
# -> [c*deltaT**5*one_over_eta**4*cos(theta)], p = 2.3803114844159985e-08
# -> [c*deltaT**4*theta**2*cos(theta)**2], p = 8.162933759999996e-08
# -> [c*deltaT**2*one_over_eta**3*theta**3*cos(theta)], p = 4.897760256e-09
# -> [c*deltaT**3*one_over_eta*theta**3*cos(theta)**2], p = 4.897760255999998e-09
# -> [c*deltaT*one_over_eta**6*theta**2*cos(theta)**5], p = 2.776395315422821e-12
# -> [c*deltaT*one_over_eta*theta**2*cos(theta)**4], p = 8.162933759999996e-08
# -> [c*deltaT**6*one_over_eta**2*theta**3*cos(theta)**4], p = 1.6658371892536922e-13
# -> [c*deltaT*one_over_eta**5*theta**2*cos(theta)**2], p = 2.64479053824e-09
# -> [c*deltaT**5*one_over_eta*cos(theta)], p = 8.162933759999996e-06
# -> [c*deltaT**2*one_over_eta**4*theta**2*cos(theta)**5], p = 1.542441841901567e-11
# -> [c*deltaT**5*one_over_eta**2], p = 4.081466879999998e-06
# -> [c*cos(theta)**5], p = 0.00012597119999999996
# -> [c*deltaT*one_over_eta**5*theta*cos(theta)], p = 2.448880127999999e-07
# -> [c*deltaT*one_over_eta**2*theta**3*cos(theta)**2], p = 2.7209779199999993e-08
# -> [c*deltaT**4*one_over_eta**4*theta], p = 4.4079842303999983e-08
# -> [c*deltaT**2*one_over_eta**4*theta*cos(theta)**4], p = 1.4281868906495992e-09
# -> [c*deltaT**5*one_over_eta**5], p = 2.3803114844159985e-08
# -> [c*deltaT**3*one_over_eta**3], p = 2.2674815999999992e-05
# -> [c*deltaT**3*one_over_eta*theta**3*cos(theta)**3], p = 8.815968460799999e-10
# -> [c*deltaT**5*one_over_eta**5*cos(theta)], p = 4.284560671948796e-09
# -> [c*deltaT**4*theta*cos(theta)], p = 2.2674815999999996e-05
# -> [c*deltaT**4*one_over_eta**2*theta**2*cos(theta)], p = 2.9386561535999993e-08
# -> [c*deltaT**3*one_over_eta**4*theta*cos(theta)**2], p = 7.934371614719996e-09
# -> [c*deltaT**4*one_over_eta**4*theta*cos(theta)**2], p = 1.4281868906495992e-09
# -> [c*deltaT*one_over_eta**3*theta*cos(theta)**5], p = 1.5868743229439992e-08
# -> [c*deltaT**5*one_over_eta**2*cos(theta)**4], p = 4.284560671948796e-09
# -> [c*one_over_eta**5*theta**2*cos(theta)], p = 8.162933759999997e-08
# -> [c*deltaT**3*one_over_eta**6*theta*cos(theta)**4], p = 8.32918594626846e-12
# -> [c*deltaT*one_over_eta**7*cos(theta)**2], p = 2.3803114844159985e-08
# -> [c*deltaT**4*one_over_eta**3*theta**3*cos(theta)], p = 1.5868743229439995e-10
# -> [c*deltaT**4*one_over_eta**4*theta**2*cos(theta)**5], p = 4.997511567761076e-13
# -> [c*deltaT**3*one_over_eta**4*cos(theta)**3], p = 2.3803114844159985e-08
# -> [c*deltaT*one_over_eta**3*cos(theta)**6], p = 2.3803114844159985e-08
# -> [c*deltaT**7*one_over_eta**4*theta*cos(theta)], p = 4.627325525704701e-11
# -> [c*deltaT**6*one_over_eta*cos(theta)**2], p = 1.3223952691199992e-07
# -> [c*deltaT**2*one_over_eta**3*theta*cos(theta)**6], p = 2.570736403169278e-10
# -> [c*deltaT**3*theta*cos(theta)**3], p = 1.3604889599999997e-06
# -> [c*deltaT**3*one_over_eta*cos(theta)**5], p = 1.3223952691199992e-07
# -> [c*deltaT*one_over_eta**6*theta**2*cos(theta)], p = 2.64479053824e-09
# -> [c*deltaT**8*one_over_eta**3*theta**2*cos(theta)**3], p = 8.995520821969936e-14
# -> [c*deltaT**4*one_over_eta**5*theta*cos(theta)], p = 1.4281868906495992e-09
# -> [c*deltaT**3*one_over_eta**5*theta*cos(theta)**3], p = 2.570736403169278e-10
# -> [c*deltaT**5*one_over_eta**2*theta*cos(theta)**3], p = 1.428186890649599e-09
# -> [c*deltaT**4*theta**2*cos(theta)**3], p = 2.9386561535999987e-08
# -> [c*deltaT**5*theta], p = 7.558271999999998e-06
# -> [c*deltaT**3*theta*cos(theta)**4], p = 2.448880127999999e-07
# -> [c*deltaT**2*one_over_eta*theta**2*cos(theta)**3], p = 8.16293376e-08
# -> [c*one_over_eta**2*cos(theta)**5], p = 4.081466879999998e-06
# -> [c*one_over_eta*theta**3*cos(theta)**2], p = 8.398079999999999e-07
# -> [c*deltaT*one_over_eta**5*cos(theta)**3], p = 2.6447905382399985e-07
# -> [c*deltaT**4*one_over_eta**5*cos(theta)**3], p = 7.712209209507833e-10
# -> [c*deltaT**3*one_over_eta**3*theta**2*cos(theta)**3], p = 4.760622968831999e-10
# -> [c*deltaT**6*one_over_eta**3*theta*cos(theta)**3], p = 4.627325525704701e-11
# -> [c*deltaT*theta**3*cos(theta)], p = 4.6656000000000015e-06
# -> [c*deltaT**4*one_over_eta*cos(theta)**4], p = 1.3223952691199992e-07
# -> [c*deltaT**4*one_over_eta*theta**5*cos(theta)**3], p = 5.7127475625984e-13
# -> [c*deltaT**3*cos(theta)**4], p = 4.081466879999998e-06
# -> [c*deltaT*one_over_eta**2*theta**3], p = 8.398080000000001e-07
# -> [c*one_over_eta**5*cos(theta)**3], p = 7.346640383999997e-07
# -> [c*theta**3*cos(theta)**3], p = 8.398079999999999e-07
# -> [c*deltaT**4*one_over_eta**3*cos(theta)**3], p = 2.3803114844159985e-08
# -> [c*deltaT**2*one_over_eta*theta**3], p = 8.398079999999999e-07
# -> [c*deltaT**5*one_over_eta*cos(theta)**4], p = 2.3803114844159985e-08
# -> [c*one_over_eta**3*theta*cos(theta)**4], p = 4.897760255999998e-07
# -> [c*deltaT**4*one_over_eta**3*cos(theta)**4], p = 4.284560671948796e-09
# -> [c*deltaT**2*one_over_eta**5*theta**2*cos(theta)**3], p = 8.569121343897596e-11
# -> [c*deltaT*one_over_eta**4*theta*cos(theta)**2], p = 2.448880127999999e-07
# -> [c*deltaT**5*one_over_eta**2*theta*cos(theta)**2], p = 7.934371614719996e-09
# -> [c*deltaT**9*one_over_eta**3*theta**4*cos(theta)**2], p = 3.238387495909177e-16
# -> [c*one_over_eta**2*theta*cos(theta)**5], p = 2.448880127999999e-07
# -> [c*deltaT**6*one_over_eta**6*cos(theta)**4], p = 8.095968739772942e-13
# -> [c*deltaT**5*one_over_eta**4*cos(theta)**3], p = 7.712209209507833e-10
# -> [c*one_over_eta**4*theta*cos(theta)**3], p = 2.448880127999999e-07
# -> [c*deltaT*one_over_eta**2*theta**3*cos(theta)], p = 1.5116544e-07
# -> [c*deltaT*one_over_eta**3*theta**2*cos(theta)**2], p = 8.162933759999996e-08
# -> [c*deltaT**5*one_over_eta**3*theta**2*cos(theta)], p = 4.760622968831997e-10
# -> [c*deltaT**5*theta**2*cos(theta)**5], p = 8.569121343897597e-11
# -> [c*deltaT*one_over_eta**5*cos(theta)**2], p = 7.346640383999997e-07
# -> [c*one_over_eta*theta**2*cos(theta)**4], p = 4.5349631999999997e-07
# -> [c*deltaT**4*one_over_eta**3*cos(theta)**2], p = 1.3223952691199992e-07
# -> [c*deltaT*one_over_eta**4*cos(theta)**4], p = 1.3223952691199992e-07
# -> [c*deltaT**3*theta**3*cos(theta)**2], p = 2.7209779199999993e-08
# -> [c*deltaT**2*one_over_eta*cos(theta)**6], p = 1.3223952691199992e-07
# -> [c*deltaT**6*one_over_eta**5*theta*cos(theta)**4], p = 2.698656246590981e-13
# -> [c*deltaT**2*one_over_eta**3*theta*cos(theta)**8], p = 8.32918594626846e-12
# -> [c*deltaT**4*one_over_eta**2*theta**3*cos(theta)], p = 8.815968460799998e-10
# -> [c*deltaT**4*one_over_eta**2*cos(theta)**4], p = 2.3803114844159985e-08
# -> [c*deltaT**4*theta*cos(theta)**2], p = 1.3604889599999997e-06
# -> [c*deltaT*one_over_eta**8*theta*cos(theta)], p = 1.4281868906495992e-09
# -> [c*deltaT**2*one_over_eta**3*theta**3*cos(theta)**4], p = 2.856373781299198e-11
# -> [c*deltaT**6], p = 2.2674815999999992e-05

# %%
ED.fit_models()
# Out:
# ModelBox: 500 models
# -> [0.00208863155644536*deltaT**2], p = 0.021599999999999998, error = 0.6556113356661527, time = 0.18965721130371094
# -> [0.0563767583856052*deltaT], p = 0.12, error = 0.7560964680393287, time = 0.13784074783325195
# -> [0.0161840936823956*cos(theta)], p = 0.12, error = 1.2713405897993268, time = 0.04746055603027344
# -> [0.0306150350590362*theta**3], p = 0.00014400000000000003, error = 1.2226484279777616, time = 0.1310257911682129
# -> [0.00240772519430417*deltaT*cos(theta)], p = 0.043199999999999995, error = 1.2710289378107122, time = 0.10943603515625
# -> [0.00107152571936803*deltaT**2*theta], p = 0.003888, error = 0.8261948614369855, time = 0.2217569351196289
# -> [0.000133668137037507*deltaT**2*cos(theta)**5], p = 4.081466879999998e-06, error = 1.2709217131383665, time = 0.18060040473937988
# -> [0.571913943307724*cos(theta)**2], p = 0.021599999999999998, error = 1.2221660655705235, time = 0.0683138370513916
# -> [0.337834861309631*theta], p = 0.04000000000000001, error = 1.1213145900644064, time = 0.10469889640808105
# -> [0.0563767296355316*deltaT], p = 0.043199999999999995, error = 0.7560964680396268, time = 0.2027888298034668
# -> [-2.64570047292053e-7*deltaT**4*theta*cos(theta)**3], p = 2.2039921151999992e-07, error = 1.2600219143535678, time = 1.2407593727111816
# -> [-0.0107752188044687*deltaT*theta*cos(theta)], p = 0.005598719999999996, error = 1.2450644206066028, time = 0.2034752368927002
# -> [0.000129683353187564*deltaT**2*cos(theta)], p = 0.003275251199999999, error = 1.2705157015487973, time = 0.4857923984527588
# -> [-8.41373979371616e-14*deltaT**3*cos(theta)], p = 3.6733201919999976e-05, error = 1.2713920832387704, time = 0.2991197109222412
# -> [0.0563767812419665*deltaT], p = 0.0027993599999999994, error = 0.7560964680393482, time = 0.21588921546936035
# -> [0.571914389476208*cos(theta)**2], p = 0.004199039999999999, error = 1.222166065570551, time = 0.11209392547607422
# -> [0.00240772357035403*deltaT*cos(theta)], p = 0.023327999999999995, error = 1.2710289378107142, time = 0.09831976890563965
# -> [0.232202284949499*theta*cos(theta)**2], p = 0.003888, error = 1.240795825238186, time = 0.05226778984069824
# -> [0.0160949631904916*cos(theta)], p = 0.043199999999999995, error = 1.2713405913633957, time = 0.09702205657958984
# -> [3.22815142558575e-5*deltaT**3*cos(theta)**6], p = 4.284560671948796e-09, error = 1.239253415285957, time = 0.9471790790557861
# -> [0.013710641330204*cos(theta)**3], p = 0.003887999999999999, error = 1.2713689888113975, time = 0.03498244285583496
# -> [4.48418438913569e-6*deltaT**3*cos(theta)], p = 0.0027993599999999994, error = 1.270168201295556, time = 0.4249436855316162
# -> [0.00151613386304137*deltaT*theta**3*cos(theta)**2], p = 3.0233088e-07, error = 1.2449231083811958, time = 0.18303442001342773
# -> [-0.000354961024085005*deltaT**2*theta*cos(theta)**3], p = 1.0883911679999998e-05, error = 1.2560216989047444, time = 0.765047550201416
# -> [1.64694119183951e-8*deltaT**5*theta**2*cos(theta)], p = 1.4693280768e-08, error = 1.98827611545675, time = 0.8874368667602539
# -> [0.00012972013766619*deltaT**2*cos(theta)], p = 0.00839808, error = 1.2705157012676613, time = 0.7864840030670166
# -> [0.0020886386685374*deltaT**2], p = 0.011663999999999997, error = 0.6556113356546611, time = 0.5064349174499512
# -> [0.232202337003899*theta*cos(theta)**2], p = 0.002799359999999999, error = 1.2407958252381877, time = 0.08108878135681152
# -> [0.337834882342637*theta], p = 0.0144, error = 1.1213145900644044, time = 0.08914351463317871
# -> [0.00880594685403944*deltaT*theta**2], p = 0.0012960000000000003, error = 1.0751775558156844, time = 0.10506701469421387
# -> [1.8191877858782e-12*deltaT*cos(theta)], p = 0.00839808, error = 1.2713920831923917, time = 0.06371784210205078
# -> [0.0483984208589442*deltaT*cos(theta)**2], p = 0.011663999999999997, error = 1.157022488314413, time = 0.07403850555419922
# -> [-2.11398646405677e-17*deltaT**2*cos(theta)**2], p = 0.0006802444799999995, error = 1.2713920831929433, time = 0.15259337425231934
# -> [0.000542763344200385*deltaT**2*theta*cos(theta)**4], p = 1.5868743229439992e-08, error = 1.2387516261209124, time = 0.8554024696350098
# -> [-0.132555207150282*theta*cos(theta)], p = 0.0144, error = 1.2588507174561059, time = 0.040924072265625
# -> [0.00234712800050864*deltaT*cos(theta)**3], p = 0.0027993599999999994, error = 1.2711787274546729, time = 0.053339242935180664
# -> [0.571913933108849*cos(theta)**2], p = 0.011663999999999997, error = 1.2221660655705235, time = 0.15944433212280273
# -> [0.0278328276903663*deltaT*theta], p = 0.0144, error = 0.9051018447029932, time = 0.07338380813598633
# -> [-0.000355049378216458*deltaT**2*theta*cos(theta)**3], p = 6.0466175999999974e-05, error = 1.2560216981085448, time = 0.15300559997558594
# -> [0.0483984261698537*deltaT*cos(theta)**2], p = 2.4488801279999986e-05, error = 1.1570224883144105, time = 0.26940131187438965
# -> [0.0278328371246233*deltaT*theta], p = 0.007776, error = 0.9051018447029638, time = 0.5731399059295654
# -> [-0.0107751631224502*deltaT*theta*cos(theta)], p = 0.007776, error = 1.2450644206057018, time = 0.11304903030395508
# -> [0.0483984405886798*deltaT*cos(theta)**2], p = 0.00839808, error = 1.1570224883144178, time = 0.6606423854827881
# -> [0.00173361785884002*deltaT**2*cos(theta)**2], p = 7.754787071999995e-05, error = 1.147340830522932, time = 0.2491319179534912
# -> [-0.0407054414267307*theta**2*cos(theta)**5], p = 4.5349631999999986e-07, error = 1.2659882718277278, time = 0.07282853126525879
# -> [-0.132555155410549*theta*cos(theta)], p = 3.023308799999999e-05, error = 1.2588507174560972, time = 0.1761631965637207
# -> [-0.010055895683081*deltaT*theta*cos(theta)**3], p = 0.00012093235199999994, error = 1.256184241932701, time = 0.8483927249908447
# -> [0.000129767610015106*deltaT**2*cos(theta)], p = 0.011663999999999997, error = 1.2705157011130523, time = 0.1311817169189453
# -> [1.56213071740117e-5*deltaT**3*theta*cos(theta)**4], p = 1.5868743229439992e-08, error = 1.2411697386709832, time = 0.8984811305999756
# -> [3.19682828265108e-5*deltaT**3*theta], p = 0.00093312, error = 0.8310185387995156, time = 0.38494443893432617
# -> [0.0483982654714402*deltaT*cos(theta)**2], p = 0.002897337599999999, error = 1.1570224883157691, time = 0.5717194080352783
# -> [-6.56026004860361e-16*deltaT*theta**2], p = 0.00011197439999999998, error = 1.2713920831929673, time = 0.14436650276184082
# -> [0.0137109757717663*cos(theta)**3], p = 0.0027993599999999994, error = 1.271368988811417, time = 0.05594277381896973
# -> [0.00173357014774179*deltaT**2*cos(theta)**2], p = 0.003401222399999999, error = 1.1473408306212667, time = 0.5338366031646729
# -> [0.00208863989008618*deltaT**2], p = 0.0011337407999999997, error = 0.6556113356547991, time = 0.18055081367492676
# -> [0.00173361023857601*deltaT**2*cos(theta)**2], p = 0.004199039999999999, error = 1.1473408305253463, time = 0.12464213371276855
# -> [-5.30709244329971e-6*deltaT**3*theta*cos(theta)], p = 2.203992115199999e-06, error = 1.253219942141591, time = 0.8245844841003418
# -> [-9.85685984102703e-17*theta*cos(theta)**2], p = 0.0007138368000000001, error = 1.2713920831929404, time = 0.13242840766906738
# -> [-0.132555708995189*theta*cos(theta)], p = 0.002799359999999999, error = 1.258850717456389, time = 0.1410202980041504
# -> [-8.99988302070438e-10*cos(theta)], p = 0.011663999999999997, error = 1.2713920831986671, time = 0.13489556312561035
# -> [5.82277264668233e-7*deltaT**4*theta*cos(theta)**2], p = 2.570736403169278e-10, error = 1.2062174277558202, time = 0.38961172103881836
# -> [-0.122268078966686*theta*cos(theta)**3], p = 0.00093312, error = 1.2642134138894776, time = 0.06543254852294922
# -> [-6.34449277873016e-17*deltaT], p = 0.011663999999999997, error = 1.2713920831929413, time = 0.10642623901367188
# -> [-0.00393760639810355*deltaT*theta**2*cos(theta)**3], p = 1.8139852799999997e-06, error = 1.2523184611875564, time = 0.19745349884033203
# -> [0.337834882216541*theta], p = 0.003888, error = 1.1213145900644044, time = 0.09467244148254395
# -> [5.94389597782609e-5*deltaT**3], p = 0.003887999999999999, error = 0.6986822321681855, time = 0.37227773666381836
# -> [0.466082255124952*cos(theta)**4], p = 0.0006998399999999999, error = 1.2478732458649655, time = 0.035361289978027344
# -> [-0.0107751581380535*deltaT*theta*cos(theta)], p = 0.0010917504, error = 1.2450644206056904, time = 0.14608287811279297
# -> [-0.108897585163675*theta*cos(theta)**5], p = 7.5582719999999985e-06, error = 1.266808481752868, time = 0.0586857795715332
# -> [-0.0578707945699278*theta**2*cos(theta)], p = 0.0007776, error = 1.2538991686527239, time = 0.09303689002990723
# -> [0.00240774142268086*deltaT*cos(theta)], p = 0.0022674815999999993, error = 1.2710289378107105, time = 0.200120210647583
# -> [-0.132556198183959*theta*cos(theta)], p = 0.007776, error = 1.2588507174570127, time = 0.07920360565185547
# -> [-0.00394106051136419*deltaT*theta**2*cos(theta)**3], p = 1.4693280767999992e-08, error = 1.252318476458604, time = 0.6363213062286377
# -> [-0.12226804706074*theta*cos(theta)**3], p = 0.0005458751999999999, error = 1.2642134138894778, time = 0.13004565238952637
# -> [-1.67407264705274e-9*theta], p = 0.00093312, error = 1.2713920845925126, time = 0.2222588062286377
# -> [2.49335328066816e-8*theta*cos(theta)**3], p = 4.081466879999999e-06, error = 1.2713920861124972, time = 0.1710207462310791
# -> [-0.108897545098999*theta*cos(theta)**5], p = 1.3604889599999995e-06, error = 1.2668084817528684, time = 0.11049365997314453
# -> [-0.00393754906623123*deltaT*theta**2*cos(theta)**3], p = 4.760622968831998e-10, error = 1.2523184611836353, time = 0.2660050392150879
# -> [0.0278328313874039*deltaT*theta], p = 0.00029393279999999995, error = 0.9051018447029696, time = 0.21508121490478516
# -> [-2.29953009849249e-10*deltaT], p = 0.0005038847999999999, error = 1.2713920865447108, time = 0.24173688888549805
# -> [4.78047517174672e-5*deltaT**3*cos(theta)**2], p = 6.938493695999995e-05, error = 1.1602933687144434, time = 0.5209312438964844
# -> [4.43089400142592e-6*deltaT**3*cos(theta)], p = 0.0022674815999999993, error = 1.2701684216462554, time = 0.820723295211792
# -> [0.00054269921538681*deltaT**2*theta*cos(theta)**4], p = 2.644790538239999e-07, error = 1.238751625640336, time = 0.2412424087524414
# -> [-2.73442332363784e-14*deltaT**3], p = 8.162933759999996e-06, error = 1.271392083601145, time = 0.3632533550262451
# -> [-1.94590623547827e-17*deltaT**2*theta], p = 0.0005038848000000001, error = 1.2713920831929535, time = 1.09613037109375
# -> [-0.00477133034066133*deltaT*theta**2*cos(theta)], p = 0.00054432, error = 1.2335655982831175, time = 0.12588977813720703
# -> [0.0396702482483738*deltaT*cos(theta)**4], p = 0.0003779135999999999, error = 1.217002181128412, time = 0.07680583000183105
# -> [0.0396713748021029*deltaT*cos(theta)**4], p = 1.4693280767999994e-06, error = 1.2170021811726675, time = 0.2382345199584961
# -> [0.0278325591428227*deltaT*theta], p = 0.0025660799999999992, error = 0.9051018447462691, time = 0.19656085968017578
# -> [-0.0047712514035586*deltaT*theta**2*cos(theta)], p = 0.00019595520000000006, error = 1.2335655982916454, time = 0.23546433448791504
# -> [-2.3102912468035e-16*deltaT**4*cos(theta)], p = 2.4488801279999986e-05, error = 1.2713920831976453, time = 1.0969033241271973
# -> [8.16027167277088e-16*deltaT*theta*cos(theta)**3], p = 1.3604889599999995e-05, error = 1.2713920831929428, time = 0.1826169490814209
# -> [0.0396702451891209*deltaT*cos(theta)**4], p = 0.00015872371199999997, error = 1.217002181128414, time = 0.5018653869628906
# -> [-2.39141835867588e-14*cos(theta)**4], p = 9.069926399999997e-05, error = 1.2713920831929428, time = 0.1309037208557129
# -> [0.0162000209256238*cos(theta)], p = 0.0006298559999999998, error = 1.2713405898487986, time = 0.14819908142089844
# -> [5.93941671121879e-5*deltaT**3], p = 0.0027993599999999994, error = 0.6986828428971932, time = 0.7478539943695068
# -> [0.00525416436098167*deltaT*theta**2*cos(theta)**2], p = 1.259712e-05, error = 1.2328164266829718, time = 0.7800102233886719
# -> [-6.72845180985737e-16*deltaT**3*theta*cos(theta)**2], p = 3.085588961279999e-07, error = 1.271392083197287, time = 0.44188880920410156
# -> [3.19273087542898e-5*deltaT**3*theta], p = 0.0005458752, error = 0.8310197861265621, time = 0.8344583511352539
# -> [4.78047239113143e-5*deltaT**3*cos(theta)**2], p = 8.081304422399997e-06, error = 1.1602933687143393, time = 0.22970271110534668
# -> [0.0195369081528188*deltaT*theta*cos(theta)**2], p = 0.0025660799999999992, error = 1.2026133259623746, time = 0.1112966537475586
# -> [0.0195369124775496*deltaT*theta*cos(theta)**2], p = 4.4079842303999983e-08, error = 1.2026133259623681, time = 0.11823725700378418
# -> [1.55472700796614e-6*deltaT**3*theta**3*cos(theta)**2], p = 2.856373781299198e-11, error = 1.2461780148593455, time = 0.2854022979736328
# -> [0.00525380823252143*deltaT*theta**2*cos(theta)**2], p = 3.1744742399999987e-06, error = 1.232816426848337, time = 0.6697914600372314
# -> [0.105920890501518*theta**2], p = 0.0024000000000000007, error = 1.1872487788822723, time = 0.08396458625793457
# -> [-0.000395814493828437*deltaT**2*theta*cos(theta)], p = 0.00014360716799999995, error = 1.2435122300302888, time = 0.25656819343566895
# -> [1.26576536639851e-7*deltaT**4*cos(theta)], p = 0.00015872371199999997, error = 1.2701505225690826, time = 0.99153733253479
# -> [-1.00164153821789e-5*deltaT**3*theta*cos(theta)**3], p = 2.644790538239999e-07, error = 1.258031140599401, time = 0.7182431221008301
# -> [0.000723523876847707*deltaT**2*theta*cos(theta)**2], p = 0.000196515072, error = 1.1959635737533925, time = 0.14780688285827637
# -> [-2.62293369871542e-8*theta*cos(theta)**2], p = 4.081466879999999e-06, error = 1.2713920900220137, time = 0.24100065231323242
# -> [4.33345365810329e-8*deltaT**5*theta**3*cos(theta)**5], p = 9.254651051409403e-13, error = 8.582578745219426, time = 0.8670203685760498
# -> [0.000137346941024951*deltaT**2*cos(theta)**3], p = 0.0003854718719999998, error = 1.2707702105972876, time = 0.6129522323608398
# -> [-1.10777350687124e-7*cos(theta)**3], p = 0.0010077695999999997, error = 1.2713920835661299, time = 0.13786625862121582
# -> [4.78039539968588e-5*deltaT**3*cos(theta)**2], p = 0.0010077695999999997, error = 1.1602933687427404, time = 0.5465006828308105
# -> [0.000129774676430083*deltaT**2*cos(theta)], p = 0.0003854718719999998, error = 1.2705157011101, time = 0.19634318351745605
# -> [0.000137288221451811*deltaT**2*cos(theta)**3], p = 0.0012597119999999996, error = 1.2707702105123821, time = 0.11344361305236816
# -> [-1.00126257964033e-5*deltaT**3*theta*cos(theta)**3], p = 4.897760255999998e-07, error = 1.2580311423972363, time = 0.9336898326873779
# -> [4.7639318071159e-14*deltaT**4*theta*cos(theta)**9], p = 1.5738563230118595e-15, error = 1.2713920852605916, time = 0.2508509159088135
# -> [7.80828675904211e-16*deltaT**6*theta*cos(theta)**3], p = 5.141472806338557e-10, error = 1.2713921634106267, time = 0.11301136016845703
# -> [0.0483985013547635*deltaT*cos(theta)**2], p = 0.00040814668799999976, error = 1.1570224883146831, time = 0.09437799453735352
# -> [5.31504903471833e-7*deltaT**4*theta*cos(theta)**2], p = 9.795520511999997e-07, error = 1.2067262277425923, time = 0.96337890625
# -> [-9.89179804717642e-13*deltaT*cos(theta)**3], p = 0.00043082150399999974, error = 1.27139208319312, time = 0.07571530342102051
# -> [-1.17227097769679e-5*deltaT**3*theta*cos(theta)], p = 0.00012849062399999993, error = 1.2454415588142795, time = 0.8586697578430176
# -> [-5.16515676743413e-8*deltaT**6*theta**2*cos(theta)], p = 2.6447905382399986e-09, error = 148.45692015135666, time = 0.965172290802002
# -> [0.00880595201429018*deltaT*theta**2], p = 0.00054432, error = 1.075177555815544, time = 0.8444123268127441
# -> [6.35204508662778e-10*deltaT**6*cos(theta)**2], p = 4.284560671948796e-09, error = 1.2048840472694877, time = 0.3396604061126709
# -> [0.00107149456393518*deltaT**2*theta], p = 0.002799359999999999, error = 0.8261948621433055, time = 0.6604807376861572
# -> [6.14020719184669e-14*deltaT**2*theta**2*cos(theta)], p = 3.265173504e-07, error = 1.2713920832209569, time = 0.36063623428344727
# -> [0.000723512435680174*deltaT**2*theta*cos(theta)**2], p = 0.0003359232, error = 1.1959635737590697, time = 0.46834754943847656
# -> [0.000136368229923333*deltaT**2*cos(theta)**3], p = 8.979227135999994e-05, error = 1.2707702388941564, time = 0.7864611148834229
# -> [-2.2958354463471e-13*deltaT**2*theta*cos(theta)**2], p = 1.7142160895999992e-06, error = 1.2713920832393895, time = 0.36727333068847656
# -> [5.5895565732327e-6*deltaT**3*theta**2*cos(theta)**2], p = 2.4488801279999997e-07, error = 1.233606057250667, time = 0.9011847972869873
# -> [0.0162361180916793*cos(theta)], p = 6.802444799999997e-05, error = 1.2713405903301191, time = 0.2507178783416748
# -> [0.000131633083230992*deltaT**2*cos(theta)**3], p = 4.407984230399998e-06, error = 1.2707712686036807, time = 1.0939109325408936
# -> [0.466091362053493*cos(theta)**4], p = 0.0006298559999999998, error = 1.2478732458559783, time = 0.10634446144104004
# -> [-0.000395820731385794*deltaT**2*theta*cos(theta)], p = 0.002799359999999999, error = 1.2435122300400132, time = 0.14477062225341797
# -> [4.78023665983911e-5*deltaT**3*cos(theta)**2], p = 0.0003854718719999998, error = 1.1602933689919228, time = 1.2400920391082764
# -> [0.0631124380336617*theta**2*cos(theta)**2], p = 9.069926399999999e-07, error = 1.2538331000366185, time = 0.4987306594848633
# -> [0.179350578333197*theta*cos(theta)**4], p = 3.0233087999999994e-05, error = 1.2576516759006382, time = 0.08060956001281738
# -> [0.000723520939288125*deltaT**2*theta*cos(theta)**2], p = 2.993075711999998e-05, error = 1.1959635737511374, time = 0.9814231395721436
# -> [0.019536887999484*deltaT*theta*cos(theta)**2], p = 0.00015872371199999997, error = 1.2026133259624974, time = 0.12610936164855957
# -> [8.41734576841426e-7*deltaT**4*theta], p = 0.0001679616, error = 0.8657932345588056, time = 0.5477604866027832
# -> [-0.132555825949303*theta*cos(theta)], p = 0.0005458752, error = 1.258850717456507, time = 0.17516779899597168
# -> [-1.04529053513525e-16*deltaT**3], p = 0.0011337407999999997, error = 1.2713920831945007, time = 0.9667696952819824
# -> [0.056376775775486*deltaT], p = 4.5349631999999984e-05, error = 0.7560964680393228, time = 0.2116408348083496
# -> [1.55652600117882e-8*deltaT**5*theta*cos(theta)**2], p = 4.897760255999998e-07, error = 1.2110712869377847, time = 0.5717432498931885
# -> [0.00405268372148521*deltaT*theta**2*cos(theta)**4], p = 4.5349631999999986e-07, error = 1.2529471449303022, time = 0.0818014144897461
# -> [-0.000139661145449881*deltaT**2*theta**2*cos(theta)**3], p = 1.4693280767999992e-08, error = 1.2516447878473982, time = 0.9138824939727783
# -> [0.000137294935873236*deltaT**2*cos(theta)**3], p = 6.611976345599996e-07, error = 1.2707702105105683, time = 0.28014659881591797
# -> [-0.0476570213361067*theta**2*cos(theta)**3], p = 1.3604889599999997e-06, error = 1.2625576401296843, time = 0.17341923713684082
# -> [0.337798928406572*theta], p = 0.0001679616, error = 1.1213145918803324, time = 0.8160326480865479
# -> [-5.80125776168493e-8*deltaT**6*cos(theta)], p = 7.346640383999997e-07, error = 41.63339838622004, time = 0.8475484848022461
# -> [-2.57847515523482e-11*deltaT*cos(theta)**5], p = 3.6733201919999983e-06, error = 1.2713920831968386, time = 0.13996410369873047
# -> [0.000337516027047503*deltaT**2*theta**2], p = 4.19904e-05, error = 1.0408757455689734, time = 0.6449379920959473
# -> [-0.0578708606707359*theta**2*cos(theta)], p = 0.0012960000000000003, error = 1.253899168652706, time = 0.08862137794494629
# -> [-3.38285640254252e-14*deltaT**2*theta**2*cos(theta)**2], p = 5.8773123071999987e-08, error = 1.271392083207295, time = 0.3968672752380371
# -> [0.0269470861000879*deltaT*theta], p = 4.081466879999999e-06, error = 0.9055477625762898, time = 0.7709252834320068
# -> [-0.0195218229143853*theta**3*cos(theta)], p = 4.6656000000000015e-06, error = 1.2556840707527328, time = 0.11176109313964844
# -> [1.22651601014796e-6*deltaT**4*cos(theta)**2], p = 4.489613567999997e-05, error = 1.1773206672768153, time = 0.8139674663543701
# -> [-0.0578714631471125*theta**2*cos(theta)], p = 8.39808e-05, error = 1.2538991686546601, time = 0.20606374740600586
# -> [-0.00393755760255523*deltaT*theta**2*cos(theta)**3], p = 1.2597119999999998e-05, error = 1.2523184611837028, time = 0.12176084518432617
# -> [4.16433065682687e-9*deltaT**5*cos(theta)**5], p = 1.38819765771141e-10, error = 1.270142566665922, time = 0.9662940502166748
# -> [0.0195368672798858*deltaT*theta*cos(theta)**2], p = 0.0012177215999999997, error = 1.2026133259627807, time = 0.1418910026550293
# -> [-0.047656307302812*theta**2*cos(theta)**3], p = 2.7993599999999996e-05, error = 1.2625576401280199, time = 0.08615303039550781
# -> [0.571914083550759*cos(theta)**2], p = 0.0010077695999999997, error = 1.2221660655705258, time = 0.17629504203796387
# -> [-1.16766631280016e-5*deltaT**3*theta*cos(theta)], p = 0.00029393279999999995, error = 1.245441159342561, time = 0.5178670883178711
# -> [0.00208863640269478*deltaT**2], p = 0.004199039999999999, error = 0.6556113356560442, time = 0.25513458251953125
# -> [4.4916508096376e-6*deltaT**3*cos(theta)], p = 2.3803114844159985e-08, error = 1.2701681979556816, time = 0.37322521209716797
# -> [2.51353648329252e-7*deltaT**4*theta], p = 2.7209779199999994e-06, error = 1.0846527607950722, time = 0.65390944480896
# -> [9.26873312361627e-16*deltaT**4*theta**2*cos(theta)**3], p = 4.760622968831996e-10, error = 1.271392083464993, time = 0.10624074935913086
# -> [0.105920940892145*theta**2], p = 0.0012960000000000003, error = 1.1872487788822856, time = 0.15282654762268066
# -> [-4.12889137599894e-6*cos(theta)], p = 0.0027993599999999994, error = 1.271392109469679, time = 0.22340869903564453
# -> [-0.000175142850511098*deltaT**2*theta**2*cos(theta)], p = 4.19904e-05, error = 1.230788424725201, time = 0.13402414321899414
# -> [0.0631120715087659*theta**2*cos(theta)**2], p = 1.0077695999999997e-05, error = 1.253833100036026, time = 0.14470791816711426
# -> [3.5993423188834e-10*deltaT*theta*cos(theta)], p = 7.558271999999996e-05, error = 1.271392084933632, time = 0.16892576217651367
# -> [1.57291072879053e-5*deltaT**3*theta*cos(theta)**4], p = 8.815968460799997e-08, error = 1.2411682773181525, time = 0.8816092014312744
# -> [1.22039924733313e-7*deltaT**4*cos(theta)], p = 2.9386561535999988e-06, error = 1.2701488024730143, time = 0.2961151599884033
# -> [4.49148377485899e-6*deltaT**3*cos(theta)], p = 0.00034012223999999985, error = 1.270168197956398, time = 0.2162928581237793
# -> [2.83585227297891e-9*deltaT**5*cos(theta)], p = 7.346640383999997e-07, error = 1.2703800769642681, time = 0.4463624954223633
# -> [-2.74263519191379e-17*deltaT**5*cos(theta)**2], p = 3.9671858073599974e-07, error = 1.271392083344076, time = 0.17649626731872559
# -> [0.000190223034846766*deltaT**2*theta**2*cos(theta)**2], p = 2.2674815999999996e-06, error = 1.2303554915189685, time = 0.6500675678253174
# -> [0.00019029361905895*deltaT**2*theta**2*cos(theta)**2], p = 3.2651735039999994e-07, error = 1.2303554857023795, time = 0.1457657814025879
# -> [0.00234713629384543*deltaT*cos(theta)**3], p = 0.0020155391999999994, error = 1.2711787274546744, time = 0.8490204811096191
# -> [-0.131772167205298*theta*cos(theta)], p = 1.3604889599999997e-06, error = 1.25885115711907, time = 0.7900590896606445
# -> [1.19204648984834e-10*deltaT*theta*cos(theta)**3], p = 4.897760255999998e-07, error = 1.2713920835513397, time = 0.2832498550415039
# -> [1.22038866116072e-7*deltaT**4*cos(theta)], p = 2.6447905382399985e-07, error = 1.2701488024728302, time = 0.3617737293243408
# -> [0.013713806099383*cos(theta)**3], p = 4.5349631999999984e-05, error = 1.2713689888126805, time = 0.6205694675445557
# -> [-0.000395865236795852*deltaT**2*theta*cos(theta)], p = 0.0009237888000000002, error = 1.2435122305157853, time = 0.3193850517272949
# -> [0.000190286638811733*deltaT**2*theta**2*cos(theta)**2], p = 5.0388479999999996e-06, error = 1.230355485766081, time = 0.15365910530090332
# -> [-0.0100558484165926*deltaT*theta*cos(theta)**3], p = 0.00037791359999999995, error = 1.2561842419322564, time = 0.08668828010559082
# -> [1.6469295608947e-16*deltaT**2*theta*cos(theta)**5], p = 1.5868743229439992e-08, error = 1.2713920831929506, time = 0.17077064514160156
# -> [0.0631120753771063*theta**2*cos(theta)**2], p = 6.9984e-05, error = 1.2538331000360259, time = 0.13706111907958984
# -> [-0.000347805056797348*deltaT**2*theta*cos(theta)**3], p = 1.3223952691199995e-07, error = 1.2560281231340455, time = 0.9847869873046875
# -> [-6.78832591951977e-11*deltaT*theta*cos(theta)**2], p = 1.3604889599999995e-05, error = 1.2713920836579717, time = 0.22441411018371582
# -> [1.20746243089582e-7*deltaT**4*cos(theta)], p = 0.0005038847999999999, error = 1.270148941913098, time = 0.5486528873443604
# -> [0.000137307785420053*deltaT**2*cos(theta)**3], p = 4.284560671948796e-09, error = 1.2707702105153924, time = 0.38001322746276855
# -> [-3.37289934868518e-7*deltaT**4*theta*cos(theta)], p = 6.8024447999999985e-06, error = 1.2472450734397384, time = 1.0554230213165283
# -> [2.15713736030697e-20*deltaT**5*theta*cos(theta)], p = 1.5868743229439992e-08, error = 1.2713920831930572, time = 0.559795618057251
# -> [0.0150720886876147*deltaT*theta*cos(theta)**4], p = 3.023308799999999e-05, error = 1.2408071545715673, time = 0.0876164436340332
# -> [5.39902807691e-5*deltaT**2*theta**3*cos(theta)**2], p = 9.795520511999997e-09, error = 1.243726067415896, time = 0.15665149688720703
# -> [3.80535193039888e-5*deltaT**3*cos(theta)**4], p = 1.4693280767999994e-06, error = 1.2193871631354742, time = 1.1044921875
# -> [2.13746791209091e-5*deltaT**3*theta*cos(theta)**2], p = 8.162933759999998e-06, error = 1.2003780122485745, time = 1.2259845733642578
# -> [0.0396702360595634*deltaT*cos(theta)**4], p = 2.4488801279999986e-05, error = 1.2170021811284235, time = 0.3178091049194336
# -> [0.00140151133363099*deltaT**2*cos(theta)**4], p = 1.3223952691199992e-07, error = 1.2129589733802648, time = 0.24465036392211914
# -> [0.00248552287936879*deltaT*cos(theta)**5], p = 2.4488801279999986e-05, error = 1.2712041694377423, time = 0.16736435890197754
# -> [0.000133686341273256*deltaT**2*cos(theta)**5], p = 2.3803114844159985e-08, error = 1.2709217131399508, time = 0.15281939506530762
# -> [0.0150721071356091*deltaT*theta*cos(theta)**4], p = 1.2244400639999995e-06, error = 1.2408071545715749, time = 0.11398935317993164
# -> [3.75124439811639e-6*deltaT**4*theta*cos(theta)**2], p = 1.5868743229439992e-08, error = 2.497565419601733, time = 0.9912934303283691
# -> [-3.20303294565515e-7*deltaT**4*theta*cos(theta)], p = 7.934371614719996e-09, error = 1.2471762994851674, time = 0.3426060676574707
# -> [0.1059209009922*theta**2], p = 0.00038880000000000007, error = 1.1872487788822719, time = 0.10843825340270996
# -> [1.49115287478978e-6*deltaT**4], p = 0.0003779135999999999, error = 0.7784366686560773, time = 0.789161205291748
# -> [0.00140150772037015*deltaT**2*cos(theta)**4], p = 0.00015872371199999997, error = 1.212958973381131, time = 0.5272963047027588
# -> [9.40389524566976e-11*deltaT**2*theta*cos(theta)**3], p = 4.284560671948797e-09, error = 1.271392091285945, time = 0.4390254020690918
# -> [5.1972064506111e-6*deltaT**3*cos(theta)**3], p = 4.081466879999997e-05, error = 1.2702980091277514, time = 0.9288845062255859
# -> [-1.92934865587722e-14*deltaT**2*theta], p = 3.0233087999999994e-05, error = 1.2713920832061654, time = 0.3759002685546875
# -> [0.179350601744171*theta*cos(theta)**4], p = 0.0001259712, error = 1.2576516759006375, time = 0.05579638481140137
# -> [-1.21149705205436e-8*theta*cos(theta)**2], p = 5.290790399999998e-05, error = 1.2713920863471952, time = 0.23314547538757324
# -> [-1.00162997810933e-5*deltaT**3*theta*cos(theta)**3], p = 2.3803114844159988e-08, error = 1.2580311405973816, time = 0.3544039726257324
# -> [0.000133638720582748*deltaT**2*cos(theta)**5], p = 1.4693280767999994e-06, error = 1.2709217131726873, time = 0.2762744426727295
# -> [0.00336866170427228*deltaT*theta**2*cos(theta)**6], p = 2.6447905382399994e-09, error = 1.2602686109625787, time = 0.2165818214416504
# -> [0.00254866030055251*deltaT*theta**3], p = 2.5920000000000003e-05, error = 1.1606701454807253, time = 0.1435561180114746
# -> [5.82259674939965e-7*deltaT**4*theta*cos(theta)**2], p = 8.815968460799997e-08, error = 1.2062174278113937, time = 0.6352701187133789
# -> [3.3211795318311e-9*theta**2*cos(theta)], p = 5.0388479999999996e-06, error = 1.2713920851869471, time = 0.11867070198059082
# -> [172.595932072503*deltaT**4*cos(theta)**2], p = 3.6733201919999983e-06, error = 70087915.34053901, time = 0.6885514259338379
# -> [3.7586992531846e-5*deltaT**3*cos(theta)**4], p = 3.9671858073599974e-07, error = 1.2193952372953127, time = 0.8460073471069336
# -> [0.0183838399576657*theta**3*cos(theta)**2], p = 2.72097792e-08, error = 1.2591859154212521, time = 0.20212411880493164
# -> [0.00525414243835567*deltaT*theta**2*cos(theta)**2], p = 9.797759999999999e-05, error = 1.232816426682753, time = 0.11572599411010742
# -> [5.25897930650212e-6*deltaT**3*cos(theta)**3], p = 3.9671858073599974e-07, error = 1.2702978581913364, time = 0.2753729820251465
# -> [-0.000139668336465084*deltaT**2*theta**2*cos(theta)**3], p = 9.069926399999997e-07, error = 1.251644787903973, time = 0.14242243766784668
# -> [0.000337471730931849*deltaT**2*theta**2], p = 0.00031104000000000006, error = 1.0408757424652206, time = 0.3827693462371826
# -> [0.000185796847839763*deltaT**2*theta**2*cos(theta)**2], p = 2.6447905382399994e-09, error = 1.2303787876348735, time = 1.0686662197113037
# -> [0.000128846851208961*deltaT*cos(theta)], p = 7.346640383999997e-07, error = 1.2713542614470181, time = 0.9133906364440918
# -> [-1.4302415067312e-7*deltaT**4*theta**2*cos(theta)], p = 8.162933759999998e-08, error = 1.2360827093408628, time = 1.1291007995605469
# -> [3.19753777042925e-5*deltaT**3*theta], p = 4.5349631999999984e-05, error = 0.8310185086270063, time = 0.20980572700500488
# -> [-1.15128067557279e-11*deltaT**2*theta*cos(theta)**2], p = 1.3223952691199995e-07, error = 1.2713920855222034, time = 0.33048057556152344
# -> [1.63393237095902e-7*deltaT**4*cos(theta)**3], p = 6.611976345599996e-07, error = 1.2699009962662673, time = 0.5318019390106201
# -> [-0.0107771542664667*deltaT*theta*cos(theta)], p = 5.441955839999999e-06, error = 1.2450644215210493, time = 1.0227406024932861
# -> [0.000337458386575831*deltaT**2*theta**2], p = 1.2597119999999996e-05, error = 1.0408757432594011, time = 0.7631537914276123
# -> [-6.28989749629413e-16*deltaT**3*theta**2*cos(theta)**2], p = 1.3223952691199996e-08, error = 1.2713920832014016, time = 0.33421921730041504
# -> [6.09731302649458e-5*deltaT**4*theta**5*cos(theta)], p = 1.8509302102818806e-14, error = 3151.01046157473, time = 0.9952788352966309
# -> [4.51444379772871e-7*deltaT**4*theta*cos(theta)**4], p = 1.5868743229439992e-08, error = 1.2440604848719075, time = 0.8578100204467773
# -> [-1.53400561798034e-15*deltaT**4*cos(theta)**4], p = 7.712209209507833e-10, error = 1.2713920833353438, time = 0.4976809024810791
# -> [1.49492832471402e-6*deltaT**4], p = 1.2244400639999995e-05, error = 0.7784323697661102, time = 0.46425509452819824
# -> [0.00240774626582754*deltaT*cos(theta)], p = 0.00022674815999999996, error = 1.2710289378107162, time = 0.22708678245544434
# -> [-0.00477132554748227*deltaT*theta**2*cos(theta)], p = 1.3604889599999997e-06, error = 1.2335655982830356, time = 0.2022550106048584
# -> [0.0165878127189674*cos(theta)**5], p = 4.5349631999999984e-05, error = 1.2713655928780696, time = 0.07359170913696289
# -> [2.13645513317989e-5*deltaT**3*theta*cos(theta)**2], p = 7.558271999999996e-05, error = 1.200378019986933, time = 0.16682982444763184
# -> [1.0523426629549e-13*deltaT**2*theta**2*cos(theta)**3], p = 2.644790538239998e-09, error = 1.2713920832224683, time = 0.26698851585388184
# -> [-4.07109444765733e-27*deltaT**6*theta**3*cos(theta)**2], p = 9.254651051409401e-13, error = 1.2713920831929404, time = 0.6574516296386719
# -> [0.000542690459265324*deltaT**2*theta*cos(theta)**4], p = 8.162933759999998e-06, error = 1.2387516256463778, time = 0.16916346549987793
# -> [-2.69457064853692e-7*deltaT**4*theta*cos(theta)**3], p = 2.448880127999999e-07, error = 1.2600300575110646, time = 0.39713597297668457
# -> [-1.69660904390858e-6*deltaT**3*theta**3*cos(theta)], p = 8.815968460799998e-10, error = 1.2379794989405257, time = 0.7727525234222412
# -> [1.18272541123382e-6*deltaT**4*cos(theta)**2], p = 4.760622968831997e-08, error = 1.1771863498476274, time = 0.30429959297180176
# -> [5.2515077181481e-6*deltaT**3*cos(theta)**3], p = 0.00020407334399999996, error = 1.2702978603885433, time = 0.18030214309692383
# -> [959030.706688457*deltaT**2*theta*cos(theta)], p = 1.4281868906495992e-09, error = 641576022.6427276, time = 0.5967628955841064
# -> [0.00254866922547318*deltaT*theta**3], p = 9.795520512e-09, error = 1.1606701454797645, time = 0.2359170913696289
# -> [3.1975754288758e-5*deltaT**3*theta], p = 5.441955839999999e-06, error = 0.8310185085584388, time = 0.2662169933319092
# -> [-1.31139431902541e-5*deltaT**3*theta], p = 8.815968460799997e-08, error = 1.5910952778279273, time = 0.7139010429382324
# -> [-0.000395813266324341*deltaT**2*theta*cos(theta)], p = 9.523422719999997e-06, error = 1.243512230030024, time = 0.1979522705078125
# -> [-0.00477131862755977*deltaT*theta**2*cos(theta)], p = 1.7635967999999998e-05, error = 1.2335655982830545, time = 0.2971038818359375
# -> [4.11092820411192e-6*deltaT**3*theta**2*cos(theta)**4], p = 5.289581076479998e-09, error = 1.253849615815977, time = 0.5990087985992432
# -> [0.000337477998256142*deltaT**2*theta**2], p = 4.5349631999999997e-07, error = 1.0408757423685473, time = 0.22787237167358398
# -> [-1.24059563504235e-8*deltaT**4*theta**2*cos(theta)**2], p = 2.644790538239998e-09, error = 1.27720307212842, time = 0.8314125537872314
# -> [5.39905253645468e-5*deltaT**2*theta**3*cos(theta)**2], p = 2.720977919999999e-08, error = 1.243726067416189, time = 0.6643950939178467
# -> [0.00140146018651776*deltaT**2*cos(theta)**4], p = 2.8570268159999983e-05, error = 1.2129589734665964, time = 0.9015204906463623
# -> [-0.00334397055636054*deltaT*theta**2*cos(theta)**5], p = 5.289581076479998e-09, error = 1.259747132264354, time = 0.25954651832580566
# -> [1.02580048760665e-5*deltaT**3*theta**2], p = 5.038848e-06, error = 1.0414021223594168, time = 0.8929412364959717
# -> [4.47962747099746e-6*deltaT**3*cos(theta)], p = 2.203992115199999e-06, error = 1.270168206659351, time = 0.8546421527862549
# -> [-1.0408281526556e-15*deltaT**5*theta], p = 4.897760255999998e-07, error = 1.2713921146955336, time = 0.9296705722808838
# -> [0.000143364223823674*deltaT**2*theta**2*cos(theta)**4], p = 1.542441841901567e-11, error = 1.2521489213642112, time = 0.31294870376586914
# -> [1.11063253370638e-8*deltaT**5*theta*cos(theta)**4], p = 2.698656246590981e-13, error = 1.2462527866258952, time = 0.43451404571533203
# -> [-6.00655772307527e-19*deltaT**5*cos(theta)], p = 5.289581076479997e-07, error = 1.2713920831933694, time = 0.49654316902160645
# -> [0.00277397801427714*deltaT*cos(theta)**7], p = 1.3223952691199992e-07, error = 1.2711928427885646, time = 0.1485297679901123
# -> [1.0243271923386e-12*deltaT*cos(theta)**5], p = 2.3803114844159985e-08, error = 1.2713920831927854, time = 0.07762432098388672
# -> [-9.79705649320352e-8*cos(theta)**2], p = 9.069926399999997e-05, error = 1.2713920997315749, time = 0.40586352348327637
# -> [-5.28083173369851e-7*deltaT**3*theta**4*cos(theta)], p = 2.938656153599999e-10, error = 1.2452854320241418, time = 1.1275978088378906
# -> [0.0015160547797861*deltaT*theta**3*cos(theta)**2], p = 1.679616e-06, error = 1.2449231083187287, time = 0.5110442638397217
# -> [0.00208863884866988*deltaT**2], p = 7.346640383999997e-07, error = 0.6556113356546425, time = 0.3012824058532715
# -> [0.00200933608176753*deltaT**2], p = 9.069926399999997e-05, error = 0.6569146594475433, time = 0.9301877021789551
# -> [2.55322772150458e-5*deltaT**3*cos(theta)**2], p = 3.9671858073599974e-07, error = 1.1852944324313428, time = 0.8640844821929932
# -> [5.52756559012127e-6*deltaT**3*theta**2*cos(theta)**2], p = 4.5349631999999986e-07, error = 1.2336024013638411, time = 0.1913468837738037
# -> [-9.77909713735388e-9*deltaT**5*theta*cos(theta)], p = 4.081466879999999e-06, error = 1.2483609777686635, time = 0.7432606220245361
# -> [-5.1669963426709e-6*deltaT**3*theta**2*cos(theta)], p = 1.4693280767999997e-08, error = 1.233350319623338, time = 0.29642415046691895
# -> [-1.10840714109767e-11*deltaT**2*cos(theta)**2], p = 2.9386561535999988e-06, error = 1.2713920847018232, time = 0.42459726333618164
# -> [3.45826383153432e-8*deltaT**5*theta*cos(theta)], p = 7.346640383999998e-07, error = 1.7470900720035554, time = 0.901099443435669
# -> [1.09643483075536e-7*deltaT**4*theta**2*cos(theta)**4], p = 2.6447905382399986e-09, error = 1.2556605215123156, time = 0.6130433082580566
# -> [0.00054271304820621*deltaT**2*theta*cos(theta)**4], p = 1.2244400639999995e-06, error = 1.2387516256658768, time = 0.6777238845825195
# -> [4.75224430028917e-6*deltaT**3*cos(theta)**3], p = 4.407984230399998e-06, error = 1.2703080211054303, time = 0.8047945499420166
# -> [2.12969632150866e-5*deltaT**3*theta*cos(theta)**2], p = 1.2244400639999995e-06, error = 1.20037891243189, time = 0.9194498062133789
# -> [-0.0100558394230237*deltaT*theta*cos(theta)**3], p = 1.4281868906495992e-09, error = 1.2561842419322484, time = 0.2684295177459717
# -> [0.40251397801653*cos(theta)**6], p = 4.081466879999998e-06, error = 1.2570544612336152, time = 0.09628748893737793
# -> [-0.000117314145364687*deltaT**2*theta**2*cos(theta)**5], p = 4.760622968831998e-10, error = 1.2593700566494355, time = 0.9623379707336426
# -> [0.000129777209138709*deltaT**2*cos(theta)], p = 4.081466879999997e-05, error = 1.2705157011103074, time = 0.2680521011352539
# -> [2.77672826080085e-8*deltaT**5*cos(theta)**2], p = 1.4693280767999994e-06, error = 1.1923611997640724, time = 0.8435890674591064
# -> [-1.74274355942368e-9*deltaT**2*cos(theta)**3], p = 4.760622968831997e-08, error = 1.2713920989764884, time = 0.21175503730773926
# -> [1.42067150714469e-15*theta*cos(theta)**3], p = 3.0233087999999994e-05, error = 1.2713920831929404, time = 0.09993624687194824
# -> [0.0306093745853724*theta**3], p = 1.5116544e-07, error = 1.2226484296941287, time = 0.8775255680084229
# -> [4.10644597232503e-6*deltaT**3*theta**2*cos(theta)**4], p = 1.4693280767999992e-08, error = 1.2538496366919276, time = 0.6125242710113525
# -> [-48.0239026624543*deltaT**6*theta**8*cos(theta)**8], p = 1.3598118630822476e-22, error = 83517217659315.33, time = 0.5885546207427979
# -> [1.18202342966837e-6*deltaT**4*cos(theta)**2], p = 6.802444799999997e-05, error = 1.1771863841369752, time = 0.594041109085083
# -> [-3.26991174529053e-7*cos(theta)**4], p = 1.3223952691199992e-07, error = 1.2713921158874941, time = 0.311084508895874
# -> [-1.71713539041665e-10*theta**2], p = 6.9984e-05, error = 1.27139208345673, time = 0.21902251243591309
# -> [5.81990121262422e-18*deltaT**3*theta**2*cos(theta)], p = 8.162933759999998e-08, error = 1.2713920831930248, time = 1.14727783203125
# -> [0.00140151315418985*deltaT**2*cos(theta)**4], p = 5.142648268799998e-06, error = 1.2129589733801294, time = 0.7125585079193115
# -> [-0.0154332234480051*theta**3*cos(theta)**3], p = 1.5116544e-07, error = 1.2636094961693398, time = 0.1703200340270996
# -> [-6.89588744646729e-12*deltaT**2*theta], p = 2.448880127999999e-07, error = 1.2713920879198517, time = 0.41306543350219727
# -> [9.69852631065674e-11*deltaT**2*theta*cos(theta)**3], p = 2.3803114844159988e-08, error = 1.271392091539505, time = 0.4357297420501709
# -> [1.57689609232184e-5*deltaT**2*theta**4*cos(theta)**2], p = 2.9386561535999996e-10, error = 1.2511067755000305, time = 0.892540693283081
# -> [-5.19146832661992e-14*deltaT**3*theta**2*cos(theta)**2], p = 4.760622968831998e-10, error = 1.2713920838912895, time = 0.6159186363220215
# -> [3.4298325080386e-7*deltaT**4*theta*cos(theta)**6], p = 1.4992534703283229e-12, error = 1.2555854615337796, time = 0.40223002433776855
# -> [1.010838500262e-5*deltaT**3*theta**2], p = 8.162933759999998e-08, error = 1.0414187763166554, time = 0.9404938220977783
# -> [-0.00393755942728004*deltaT*theta**2*cos(theta)**3], p = 8.162933759999996e-08, error = 1.2523184611837406, time = 0.17354440689086914
# -> [-7.71390771905069e-6*deltaT**3*theta*cos(theta)**7], p = 1.4992534703283229e-12, error = 1.26535983298185, time = 0.1360623836517334
# -> [0.466091730029586*cos(theta)**4], p = 1.2244400639999995e-05, error = 1.247873245855996, time = 0.17355608940124512
# -> [1.4887545953565e-6*deltaT**4], p = 0.0006998399999999999, error = 0.7784436991111419, time = 0.3599817752838135
# -> [2.87126803957274e-6*deltaT**3*theta**3], p = 1.5116543999999997e-07, error = 1.1475173845643092, time = 0.7041206359863281
# -> [5.6302852805965e-18*deltaT**4*theta*cos(theta)], p = 4.897760255999998e-07, error = 1.2713920831937835, time = 1.1188929080963135
# -> [-2.80041323131565e-8*theta*cos(theta)**6], p = 1.5868743229439992e-08, error = 1.271392086171267, time = 0.21807169914245605
# -> [-3.39396328808373e-14*deltaT**4*cos(theta)**5], p = 2.77639531542282e-10, error = 1.2713920836636083, time = 0.5706706047058105
# -> [-0.000355041936901285*deltaT**2*theta*cos(theta)**3], p = 1.2244400639999995e-06, error = 1.2560216981017365, time = 0.8859241008758545
# -> [8.42752501109848e-7*deltaT**4*theta], p = 7.934371614719996e-09, error = 0.8657925032749598, time = 0.3584713935852051
# -> [1.63496365391115e-21*deltaT**5*theta**3*cos(theta)], p = 2.856373781299198e-11, error = 1.2713920831930163, time = 0.5864818096160889
# -> [0.018383796817039*theta**3*cos(theta)**2], p = 4.6656e-06, error = 1.2591859154212086, time = 0.07753729820251465
# -> [-5.78242069369867e-8*deltaT**6*theta**2*cos(theta)**2], p = 4.760622968831999e-10, error = 154.5290071224922, time = 0.9216549396514893
# -> [-4.50315431621448e-6*deltaT**3*theta**2*cos(theta)**3], p = 5.289581076479998e-09, error = 1.2539108700709154, time = 0.8213520050048828
# -> [0.149381949878822*theta*cos(theta)**6], p = 2.448880127999999e-07, error = 1.2634234916397968, time = 0.12192392349243164
# -> [1.27183854943698e-5*deltaT**3*theta*cos(theta)**6], p = 7.934371614719996e-09, error = 1.2540896359705929, time = 0.17538785934448242
# -> [5.41876608911323e-5*deltaT**3*cos(theta)**4], p = 1.5424418419015667e-09, error = 1.2288935157912568, time = 0.8310987949371338
# -> [-1.40353382203889e-16*deltaT**6*cos(theta)], p = 1.3223952691199992e-07, error = 1.2713920864639672, time = 1.102078914642334
# -> [-8.75203124967752e-6*deltaT**3*theta*cos(theta)**5], p = 4.627325525704701e-11, error = 1.2627539750332013, time = 0.2976663112640381
# -> [0.466076410759678*cos(theta)**4], p = 7.346640383999997e-07, error = 1.2478732458802821, time = 0.22713971138000488
# -> [-1.06337486945088e-11*deltaT**2], p = 4.081466879999998e-06, error = 1.271392087944674, time = 0.38371872901916504
# -> [0.00880595666664127*deltaT*theta**2], p = 2.519424e-06, error = 1.0751775558155436, time = 0.16743159294128418
# -> [2.14337965886651e-8*deltaT**5*cos(theta)**4], p = 7.712209209507833e-10, error = 1.2350379921610717, time = 0.9302873611450195
# -> [-0.00894314748159531*deltaT*theta*cos(theta)**5], p = 1.3604889599999997e-06, error = 1.2616437591106726, time = 0.08608579635620117
# -> [-2.75980749364635e-9*deltaT**7*cos(theta)], p = 7.346640383999997e-07, error = 80.82905158037359, time = 0.569556474685669
# -> [0.00234719335305731*deltaT*cos(theta)**3], p = 2.040733439999999e-05, error = 1.2711787274548285, time = 0.17044329643249512
# -> [-1.68547547572965e-10*deltaT*theta], p = 1.5116543999999997e-05, error = 1.2713920869901825, time = 0.2771024703979492
# -> [-3.58728562563249e-8*theta], p = 1.5116543999999997e-05, error = 1.2713921131836665, time = 0.16016364097595215
# -> [2.1242414659777e-16*deltaT**2*theta**2*cos(theta)], p = 2.2674815999999992e-06, error = 1.2713920831930374, time = 0.09960532188415527
# -> [8.39839863402214e-7*deltaT**4*theta], p = 1.5116543999999997e-05, error = 0.8657984854933871, time = 0.8303749561309814
# -> [0.00525414900835874*deltaT*theta**2*cos(theta)**2], p = 4.760622968831997e-10, error = 1.2328164266826755, time = 0.26317286491394043
# -> [-9.11008312112296e-9*deltaT*cos(theta)**5], p = 2.6447905382399985e-07, error = 1.2713920845703066, time = 0.26967453956604004
# -> [-0.000175192350554438*deltaT**2*theta**2*cos(theta)], p = 7.558271999999999e-06, error = 1.2307884290148534, time = 0.9814615249633789
# -> [-5.16796841498454e-6*deltaT**3*theta**2*cos(theta)], p = 9.069926399999998e-07, error = 1.2333503210412506, time = 0.7620179653167725
# -> [3.67446993790883e-16*deltaT**5*theta**2*cos(theta)**5], p = 2.914548746318259e-15, error = 1.2713920859694254, time = 0.2311091423034668
# -> [5.94464202940147e-5*deltaT**3], p = 1.3223952691199992e-07, error = 0.6986822195185236, time = 0.13394808769226074
# -> [4.56831995839979e-8*deltaT**6*cos(theta)**3], p = 2.3803114844159985e-08, error = 27.329163244682995, time = 0.8537871837615967
# -> [0.000129774646339267*deltaT**2*cos(theta)], p = 7.346640383999997e-07, error = 1.2705157011101016, time = 0.25245118141174316
# -> [-1.50269753633599e-9*deltaT*theta**2*cos(theta)**4], p = 8.569121343897596e-11, error = 1.2713920967721208, time = 0.4958963394165039
# -> [2.81632915059332e-7*deltaT**4*theta**2], p = 4.5349631999999986e-07, error = 1.0504451720733732, time = 1.1179206371307373
# -> [0.0150720852931927*deltaT*theta*cos(theta)**4], p = 4.4079842303999983e-08, error = 1.2408071545715762, time = 0.2086181640625
# -> [2.82815094127803e-8*deltaT**5], p = 0.00012597119999999996, error = 0.8721096445723943, time = 0.46730637550354004
# -> [1.12058729622617e-10*deltaT**5*theta**2], p = 4.5349631999999986e-07, error = 1.2653856142320272, time = 0.5468616485595703
# -> [-5.08496955748845e-9*deltaT**6], p = 7.346640383999997e-07, error = 6.581747222915239, time = 0.8131096363067627
# -> [1.01984428941089e-5*deltaT**3*theta**2], p = 4.1990400000000004e-05, error = 1.0413955999685198, time = 0.6493198871612549
# -> [-0.0033439738856119*deltaT*theta**2*cos(theta)**5], p = 8.162933759999998e-08, error = 1.2597471322643712, time = 0.09848427772521973
# -> [-9.38061696578142e-7*deltaT**3*theta**3*cos(theta)**3], p = 2.856373781299199e-11, error = 1.256830198812069, time = 1.0996832847595215
# -> [0.00140138641325697*deltaT**2*cos(theta)**4], p = 2.3803114844159985e-08, error = 1.212958973871878, time = 1.1172332763671875
# -> [5.02615866183264e-8*deltaT**5], p = 2.2674815999999992e-05, error = 0.9422468149115679, time = 0.8506424427032471
# -> [1.51512129723419e-13*deltaT**3*theta**2*cos(theta)**5], p = 2.7763953154228204e-12, error = 1.2713920841784343, time = 0.5321559906005859
# -> [0.0563697540930989*deltaT], p = 7.346640383999997e-07, error = 0.7560964787325457, time = 0.764277458190918
# -> [-0.0100557356131909*deltaT*theta*cos(theta)**3], p = 8.815968460799997e-08, error = 1.2561842419339275, time = 1.1839840412139893
# -> [3.98045978791819e-10*deltaT**6*theta*cos(theta)**2], p = 2.8563737812991984e-09, error = 1.2146151323828647, time = 0.6712589263916016
# -> [-1.69654767681851e-6*deltaT**3*theta**3*cos(theta)], p = 4.897760255999999e-09, error = 1.2379794989876327, time = 0.6825666427612305
# -> [30.8824234253987*deltaT**5*theta*cos(theta)**2], p = 8.815968460799997e-08, error = 778897671.8667157, time = 0.6965663433074951
# -> [-6.00115834070872e-13*deltaT**2*theta], p = 1.3604889599999997e-06, error = 1.2713920836043007, time = 0.37444376945495605
# -> [1.10210107246526e-6*deltaT**5*cos(theta)**6], p = 2.498755783880538e-11, error = 14.239531571172023, time = 0.7562093734741211
# -> [1.67452125365815e-7*deltaT**4*cos(theta)**3], p = 2.203992115199999e-06, error = 1.2699019062542736, time = 0.6984279155731201
# -> [-0.0195218702051994*theta**3*cos(theta)], p = 7.776000000000001e-05, error = 1.2556840707526695, time = 0.07081151008605957
# -> [6.33827820881373e-16*deltaT**2*theta*cos(theta)**7], p = 2.570736403169278e-10, error = 1.2713920831929715, time = 0.09820795059204102
# -> [-0.000395813448935108*deltaT**2*theta*cos(theta)], p = 9.795520511999997e-07, error = 1.243512230030029, time = 0.22072839736938477
# ...
# -> [-0.000175186865488846*deltaT**2*theta**2*cos(theta)], p = 2.9386561535999987e-08, error = 1.2307884282146535, time = 0.8998894691467285
# -> [2.14341286551082e-8*deltaT**5*cos(theta)**4], p = 8.095968739772942e-13, error = 1.2350379921508927, time = 0.4208672046661377
# -> [-0.00140008113499129*deltaT**5*theta*cos(theta)**5], p = 4.857581243863765e-14, error = 30679.887363513633, time = 0.9463996887207031
# -> [-4.42481274033477e-18*deltaT**4*cos(theta)**5], p = 8.569121343897593e-09, error = 1.2713920831930017, time = 1.2951443195343018
# -> [-1.41745542318227e-7*deltaT**4*theta**2*cos(theta)], p = 4.5349631999999986e-07, error = 1.236078991702379, time = 0.6255011558532715
# -> [-7.32728782485367e-8*deltaT*cos(theta)], p = 8.162933759999996e-06, error = 1.271392105292815, time = 0.41388368606567383
# -> [-1.54247461059081e-13*deltaT**2*theta**2*cos(theta)**4], p = 9.521245937663996e-10, error = 1.2713920832340349, time = 0.35976362228393555
# -> [-8.58366539972772e-9*deltaT**5*theta*cos(theta)], p = 4.4079842303999983e-08, error = 1.2479054227775683, time = 0.28292107582092285
# -> [-1.76493419211317e-7*deltaT**4*theta*cos(theta)**5], p = 1.4281868906495992e-09, error = 1.264356072297025, time = 0.7293822765350342
# -> [0.0150720883800254*deltaT*theta*cos(theta)**4], p = 5.441955839999998e-06, error = 1.240807154571568, time = 0.14179229736328125
# -> [255.514328258236*deltaT**5*cos(theta)**3], p = 4.284560671948796e-09, error = 3783793910.0666943, time = 0.708430290222168
# -> [-1.13794301622751e-5*cos(theta)], p = 4.081466879999998e-06, error = 1.271392155629159, time = 0.3323705196380615
# -> [-6.96426767200872e-16*deltaT*cos(theta)**6], p = 1.3223952691199992e-07, error = 1.2713920831929417, time = 0.16460800170898438
# -> [-1.16769628164053e-5*deltaT**3*theta*cos(theta)], p = 6.8024447999999985e-06, error = 1.2454411593060526, time = 0.27715182304382324
# -> [0.0306150318934223*theta**3], p = 5.1840000000000005e-05, error = 1.2226484279777716, time = 0.13632607460021973
# -> [2.54964277322932e-13*deltaT**3*theta*cos(theta)**3], p = 1.4281868906495992e-09, error = 1.2713920838695707, time = 0.40865206718444824
# -> [-6.74343796512941e-13*deltaT**3*theta*cos(theta)**2], p = 5.141472806338557e-10, error = 1.2713920875491538, time = 0.6748182773590088
# -> [-0.00160799763129828*deltaT*theta**3*cos(theta)], p = 1.679616e-06, error = 1.2373800095721, time = 1.1369264125823975
# -> [1.51437123867709e-9*deltaT**5*cos(theta)], p = 0.00011337407999999997, error = 1.2705993633994084, time = 0.782982587814331
# -> [0.0631118257421815*theta**2*cos(theta)**2], p = 0.00015552000000000003, error = 1.2538331000362968, time = 0.036597251892089844
# -> [-7.21701352833811e-18*deltaT**5*theta*cos(theta)**2], p = 2.570736403169278e-10, error = 1.2713920832483476, time = 0.6152229309082031
# -> [1.5596880102074e-7*deltaT**4*cos(theta)**3], p = 4.081466879999998e-06, error = 1.2699040949285443, time = 0.3975076675415039
# -> [6.19223001316128e-11*deltaT**2*theta**2*cos(theta)**3], p = 2.7763953154228208e-12, error = 1.2713921005679116, time = 0.44443607330322266
# -> [-0.047656427800637*theta**2*cos(theta)**3], p = 2.5194239999999994e-06, error = 1.2625576401280216, time = 0.09920501708984375
# -> [-0.0973730175079955*theta*cos(theta)**7], p = 7.934371614719996e-09, error = 1.2682378557759444, time = 0.14256572723388672
# -> [0.0306150703454084*theta**3], p = 4.665600000000001e-06, error = 1.2226484279777226, time = 0.15193819999694824
# -> [0.0150154059382343*deltaT*theta*cos(theta)**4], p = 7.934371614719996e-09, error = 1.2408075925982776, time = 0.628021240234375
# -> [1.5791713276383e-7*deltaT**4*theta**2*cos(theta)**2], p = 4.407984230399999e-08, error = 1.2373676764618544, time = 1.1329824924468994
# -> [-6.94389530196831e-5*deltaT**3*theta*cos(theta)], p = 8.815968460799997e-08, error = 1.7746185847568026, time = 0.929931640625
# -> [-6.48484466217511e-17*deltaT**5*cos(theta)], p = 2.3803114844159985e-08, error = 1.271392083239255, time = 0.5631186962127686
# -> [1.41976179932555e-7*deltaT**4*theta**2*cos(theta)**2], p = 8.162933759999996e-08, error = 1.2373419761552726, time = 0.6979382038116455
# -> [3.03457144388313e-14*deltaT**2*theta**3*cos(theta)], p = 4.897760256e-09, error = 1.2713920832300483, time = 0.3178291320800781
# -> [1.52037892205841e-6*deltaT**3*theta**3*cos(theta)**2], p = 4.897760255999998e-09, error = 1.2461904479230206, time = 0.9598903656005859
# -> [-0.00334399645950356*deltaT*theta**2*cos(theta)**5], p = 2.776395315422821e-12, error = 1.2597471322650975, time = 0.8901419639587402
# -> [0.00405261478139673*deltaT*theta**2*cos(theta)**4], p = 8.162933759999996e-08, error = 1.2529471449368403, time = 0.23285412788391113
# -> [2.12671368794699e-11*deltaT**6*theta**3*cos(theta)**4], p = 1.6658371892536922e-13, error = 1.2617468820018745, time = 0.9803907871246338
# -> [0.0052541297285203*deltaT*theta**2*cos(theta)**2], p = 2.64479053824e-09, error = 1.232816426683251, time = 0.16533207893371582
# -> [2.4589331761259e-9*deltaT**5*cos(theta)], p = 8.162933759999996e-06, error = 1.2703977131248636, time = 0.8960435390472412
# -> [-0.00011704376119825*deltaT**2*theta**2*cos(theta)**5], p = 1.542441841901567e-11, error = 1.2593699921521824, time = 0.36986255645751953
# -> [-1.22732066216508e-15*deltaT**5], p = 4.081466879999998e-06, error = 1.2713921075908978, time = 0.7241950035095215
# -> [0.0165847824034252*cos(theta)**5], p = 0.00012597119999999996, error = 1.2713655928789345, time = 0.05020904541015625
# -> [4.44444424655842e-9*deltaT*theta*cos(theta)], p = 2.448880127999999e-07, error = 1.27139210468689, time = 0.2074117660522461
# -> [-8.88907622608221e-16*deltaT*theta**3*cos(theta)**2], p = 2.7209779199999993e-08, error = 1.271392083192971, time = 0.1900804042816162
# -> [8.42751444827147e-7*deltaT**4*theta], p = 4.4079842303999983e-08, error = 0.8657925032767247, time = 0.2604658603668213
# -> [0.000542698441197067*deltaT**2*theta*cos(theta)**4], p = 1.4281868906495992e-09, error = 1.238751625640176, time = 0.22212719917297363
# -> [-8.42709346114181e-18*deltaT**5], p = 2.3803114844159985e-08, error = 1.2713920833604628, time = 0.5805962085723877
# -> [5.94100455224967e-5*deltaT**3], p = 2.2674815999999992e-05, error = 0.6986825215019145, time = 0.9781351089477539
# -> [-1.2088030701316e-6*deltaT**3*theta**3*cos(theta)**3], p = 8.815968460799999e-10, error = 1.2557822357008168, time = 0.8976273536682129
# -> [-1.33154944760631e-15*deltaT**5*cos(theta)], p = 4.284560671948796e-09, error = 1.2713920841439315, time = 0.5607690811157227
# -> [-3.20837278042485e-7*deltaT**4*theta*cos(theta)], p = 2.2674815999999996e-05, error = 1.247176367674855, time = 0.6725800037384033
# -> [4.07767703380693e-16*deltaT**4*theta**2*cos(theta)], p = 2.9386561535999993e-08, error = 1.2713920833935402, time = 0.9977452754974365
# -> [1.06066881907783e-5*deltaT**3*theta*cos(theta)**2], p = 7.934371614719996e-09, error = 1.21878784276489, time = 1.0209832191467285
# -> [5.71256461207236e-7*deltaT**4*theta*cos(theta)**2], p = 1.4281868906495992e-09, error = 1.206241402677918, time = 1.2700004577636719
# -> [-0.00894314329212809*deltaT*theta*cos(theta)**5], p = 1.5868743229439992e-08, error = 1.2616437591106666, time = 0.18291306495666504
# -> [265.246657459252*deltaT**5*cos(theta)**4], p = 4.284560671948796e-09, error = 3735493843.0836487, time = 0.5717775821685791
# -> [-0.0578706957353633*theta**2*cos(theta)], p = 8.162933759999997e-08, error = 1.2538991686528367, time = 0.7437655925750732
# -> [-1.78519690933381e-12*deltaT**3*theta*cos(theta)**4], p = 8.32918594626846e-12, error = 1.2713920899715832, time = 0.5038752555847168
# -> [0.0618851713987372*deltaT*cos(theta)**2], p = 2.3803114844159985e-08, error = 1.166305194315217, time = 0.6673059463500977
# -> [-341.457703877327*deltaT**4*theta**3*cos(theta)], p = 1.5868743229439995e-10, error = 2053538630.8382595, time = 0.6545689105987549
# -> [-8.89400104467275e-8*deltaT**4*theta**2*cos(theta)**5], p = 4.997511567761076e-13, error = 1.2616719161920216, time = 0.42630696296691895
# -> [-4.31772731353193e-6*deltaT**3*cos(theta)**3], p = 2.3803114844159985e-08, error = 1.2739228366467696, time = 1.1814968585968018
# -> [0.0342994174939868*deltaT*cos(theta)**6], p = 2.3803114844159985e-08, error = 1.2381724822663782, time = 0.30243444442749023
# -> [2.36710168818259e-22*deltaT**7*theta*cos(theta)], p = 4.627325525704701e-11, error = 1.2713920831948615, time = 0.666135311126709
# -> [4.66782202101944e-8*deltaT**6*cos(theta)**2], p = 1.3223952691199992e-07, error = 29.443076520668143, time = 0.7740817070007324
# -> [0.000441592529723685*deltaT**2*theta*cos(theta)**6], p = 2.570736403169278e-10, error = 1.252747572907772, time = 0.7726163864135742
# -> [-1.0023742930297e-5*deltaT**3*theta*cos(theta)**3], p = 1.3604889599999997e-06, error = 1.258031148029336, time = 0.17309904098510742
# -> [4.97070306044256e-6*deltaT**3*cos(theta)**5], p = 1.3223952691199992e-07, error = 1.2706129097788317, time = 0.8561639785766602
# -> [-0.00477132075232614*deltaT*theta**2*cos(theta)], p = 2.64479053824e-09, error = 1.2335655982830316, time = 0.17608404159545898
# -> [-9.55509150419032e-16*deltaT**8*theta**2*cos(theta)**3], p = 8.995520821969936e-14, error = 1.2709307228850018, time = 1.6218628883361816
# -> [-141418.735967223*deltaT**4*theta*cos(theta)], p = 1.4281868906495992e-09, error = 109036757126.51694, time = 0.6245923042297363
# -> [-3.56996793206811e-5*deltaT**3*theta*cos(theta)**3], p = 2.570736403169278e-10, error = 1.343445192999491, time = 0.9969871044158936
# -> [4.99316030765769e-17*deltaT**5*theta*cos(theta)**3], p = 1.428186890649599e-09, error = 1.2713920833393513, time = 1.0718433856964111
# -> [-1.13892240150995e-7*deltaT**4*theta**2*cos(theta)**3], p = 2.9386561535999987e-08, error = 1.2557510062893165, time = 0.7998900413513184
# -> [1.50773615784068e-8*deltaT**5*theta], p = 7.558271999999998e-06, error = 0.9373350839467932, time = 0.5233533382415771
# -> [1.57225793261263e-5*deltaT**3*theta*cos(theta)**4], p = 2.448880127999999e-07, error = 1.2411682840761018, time = 0.1904904842376709
# -> [-0.000139618736847989*deltaT**2*theta**2*cos(theta)**3], p = 8.16293376e-08, error = 1.2516447896601126, time = 0.9333822727203369
# -> [0.016595626133408*cos(theta)**5], p = 4.081466879999998e-06, error = 1.2713655928839964, time = 0.17694807052612305
# -> [0.0183838114972829*theta**3*cos(theta)**2], p = 8.398079999999999e-07, error = 1.2591859154212082, time = 0.4758479595184326
# -> [-1.92173659746466e-7*deltaT*cos(theta)**3], p = 2.6447905382399985e-07, error = 1.271392118128876, time = 0.24939870834350586
# -> [1.63417452333308e-7*deltaT**4*cos(theta)**3], p = 7.712209209507833e-10, error = 1.2699009962368466, time = 0.49420833587646484
# -> [-4.45234943747195e-6*deltaT**3*theta**2*cos(theta)**3], p = 4.760622968831999e-10, error = 1.2538558451762878, time = 1.0007340908050537
# -> [1.19957616818589e-21*deltaT**6*theta*cos(theta)**3], p = 4.627325525704701e-11, error = 1.2713920831930636, time = 0.5434081554412842
# -> [-0.00160807364398455*deltaT*theta**3*cos(theta)], p = 4.6656000000000015e-06, error = 1.2373800095096432, time = 0.131819486618042
# -> [9.29332334530387e-7*deltaT**4*cos(theta)**4], p = 1.3223952691199992e-07, error = 1.2275987786267317, time = 0.9502301216125488
# -> [-1.98667961451098e-9*deltaT**4*theta**5*cos(theta)**3], p = 5.7127475625984e-13, error = 1.2633286474539396, time = 1.2050859928131104
# -> [3.80487636754332e-5*deltaT**3*cos(theta)**4], p = 4.081466879999998e-06, error = 1.2193871649049284, time = 0.137559175491333
# -> [0.00254866756238522*deltaT*theta**3], p = 8.398080000000001e-07, error = 1.160670145479728, time = 0.5552260875701904
# -> [0.0138429151199996*cos(theta)**3], p = 7.346640383999997e-07, error = 1.2713689909631385, time = 0.8762149810791016
# -> [-0.0154331650202278*theta**3*cos(theta)**3], p = 8.398079999999999e-07, error = 1.263609496169185, time = 0.04554152488708496
# -> [1.63415849874709e-7*deltaT**4*cos(theta)**3], p = 2.3803114844159985e-08, error = 1.269900996236769, time = 0.7193417549133301
# -> [9.59160381066286e-5*deltaT**2*theta**3], p = 8.398079999999999e-07, error = 1.1457109655860094, time = 0.7803287506103516
# -> [3.40564812561492e-8*deltaT**5*cos(theta)**4], p = 2.3803114844159985e-08, error = 1.2477651908011382, time = 0.8577470779418945
# -> [0.179350679738836*theta*cos(theta)**4], p = 4.897760255999998e-07, error = 1.2576516759006389, time = 0.17995858192443848
# -> [9.27266208373583e-7*deltaT**4*cos(theta)**4], p = 4.284560671948796e-09, error = 1.2275985559312579, time = 0.22197723388671875
# -> [-0.00024634910253803*deltaT**2*theta**2*cos(theta)**3], p = 8.569121343897596e-11, error = 1.2632059722348508, time = 1.0743460655212402
# -> [0.0194330070271889*deltaT*theta*cos(theta)**2], p = 2.448880127999999e-07, error = 1.2026153271154414, time = 0.8067381381988525
# -> [1.53376643878017e-8*deltaT**5*theta*cos(theta)**2], p = 7.934371614719996e-09, error = 1.211058492279389, time = 0.9091858863830566
# -> [3153.88078533018*deltaT**9*theta**4*cos(theta)**2], p = 3.238387495909177e-16, error = 4.052514862937565e+18, time = 0.5538101196289062
# -> [-0.108897583463217*theta*cos(theta)**5], p = 2.448880127999999e-07, error = 1.266808481752868, time = 0.1616666316986084
# -> [-1.29600237500413e-5*deltaT**6*cos(theta)**4], p = 8.095968739772942e-13, error = 7414.598236979651, time = 0.9377987384796143
# -> [-1.76847801570943e-16*deltaT**5*cos(theta)**3], p = 7.712209209507833e-10, error = 1.271392083330828, time = 0.34525489807128906
# -> [-0.122268101795094*theta*cos(theta)**3], p = 2.448880127999999e-07, error = 1.264213413889478, time = 0.12893390655517578
# -> [7.80107980239868e-16*deltaT*theta**3*cos(theta)], p = 1.5116544e-07, error = 1.2713920831929728, time = 0.17856860160827637
# -> [-9.69368850686513e-12*deltaT*theta**2*cos(theta)**2], p = 8.162933759999996e-08, error = 1.2713920833331218, time = 0.2604696750640869
# -> [4.44782590420125e-20*deltaT**5*theta**2*cos(theta)], p = 4.760622968831997e-10, error = 1.2713920831937209, time = 0.3799917697906494
# -> [-3.26490548287692e-9*deltaT**5*theta**2*cos(theta)**5], p = 8.569121343897597e-11, error = 1.2641502095762038, time = 0.7100732326507568
# -> [-2.31383836760613e-9*deltaT*cos(theta)**2], p = 7.346640383999997e-07, error = 1.2713920936366714, time = 0.30354881286621094
# -> [0.0489629955758476*theta**2*cos(theta)**4], p = 4.5349631999999997e-07, error = 1.262919885046744, time = 0.15265440940856934
# -> [-8.28803868942089e-17*deltaT**4*cos(theta)**2], p = 1.3223952691199992e-07, error = 1.2713920832056542, time = 0.2609436511993408
# -> [-2.6468196237592e-9*deltaT*cos(theta)**4], p = 1.3223952691199992e-07, error = 1.2713920902955398, time = 0.3104889392852783
# -> [1.54727922260629e-6*deltaT**3*theta**3*cos(theta)**2], p = 2.7209779199999993e-08, error = 1.2461785997633785, time = 0.19508886337280273
# -> [0.00120711730280769*deltaT**2*cos(theta)**6], p = 1.3223952691199992e-07, error = 1.2355443827313028, time = 0.17266321182250977
# -> [2.86472509465051e-10*deltaT**6*theta*cos(theta)**4], p = 2.698656246590981e-13, error = 1.2480574440221999, time = 0.5549726486206055
# -> [0.000375728358487986*deltaT**2*theta*cos(theta)**8], p = 8.32918594626846e-12, error = 1.2591910973039475, time = 0.34445643424987793
# -> [-4.61345848346216e-8*deltaT**4*theta**3*cos(theta)], p = 8.815968460799998e-10, error = 1.2407353212399987, time = 0.7549295425415039
# -> [-9.1190352131145e-17*deltaT**4*cos(theta)**4], p = 2.3803114844159985e-08, error = 1.2713920832014056, time = 0.2315077781677246
# -> [5.79268455308026e-7*deltaT**4*theta*cos(theta)**2], p = 1.3604889599999997e-06, error = 1.2062192140685888, time = 0.5450844764709473
# -> [-0.0107751370300228*deltaT*theta*cos(theta)], p = 1.4281868906495992e-09, error = 1.2450644206057684, time = 0.28518152236938477
# -> [4.16667967345588e-5*deltaT**2*theta**3*cos(theta)**4], p = 2.856373781299198e-11, error = 1.2571869810561391, time = 0.27864527702331543
# -> [-3.08677261529056e-9*deltaT**6], p = 2.2674815999999992e-05, error = 4.400565543172118, time = 0.5223476886749268

# %%
ED.get_results(5)
# Out:
# ModelBox: 5 models
# -> [0.00208863884866988*deltaT**2], p = 7.346640383999997e-07, error = 0.6556113356546425, time = 0.3012824058532715
# -> [0.0020886386685374*deltaT**2], p = 0.011663999999999997, error = 0.6556113356546611, time = 0.5064349174499512
# -> [0.00208863989008618*deltaT**2], p = 0.0011337407999999997, error = 0.6556113356547991, time = 0.18055081367492676
# -> [0.00208863640269478*deltaT**2], p = 0.004199039999999999, error = 0.6556113356560442, time = 0.25513458251953125
# -> [0.00208863155644536*deltaT**2], p = 0.021599999999999998, error = 0.6556113356661527, time = 0.18965721130371094

# %%
def f_gramatika(df):
    return 0.00208864*df['deltaT']**2

def povprecna_kvadratna_napaka(f, data):
    return np.sum((f(data) -  data['Q'])**2)/len(data)

povprecna_kvadratna_napaka(f_gramatika, data)
# Out:
# 0.4298262234391257

# %% [markdown]
# Gramatike se obnesejo slabo. Poskusil bom še z linearno regresijo. Ponovno bom dodal značilki 1/eta in sin(theta), ter deltaT. Zanimajo me linearni izrazi v produktih spremenljivk.

# %%
data['sin_of_theta'] = np.sin(data['theta'])
data_lr = data.drop(columns=['Tw', 'Ta', 'eta', 'theta'])

poly = PolynomialFeatures(5, include_bias=False)
X = poly.fit_transform(data_lr.drop('Q', axis=1))

imena_stolpcev = poly.get_feature_names_out()
data_lr = pd.DataFrame(X, columns=imena_stolpcev)
data_lr.head()
# Out:
#       deltaT  one_over_eta  sin_of_theta     deltaT^2  deltaT one_over_eta  \
# 0  42.217191      2.864645      0.316390  1782.291254           120.937275
# 1   8.535838      1.217925      0.422107    72.860533            10.396010
# 2   3.654556      1.322609      0.954452    13.355782             4.833548
# 3  12.586385      1.937483      0.868418   158.417075            24.385901
# 4  34.837551     12.000908      0.322482  1213.654987           418.082233
#
#    deltaT sin_of_theta  one_over_eta^2  one_over_eta sin_of_theta  \
# 0            13.357081        8.206192                   0.906344
# 1             3.603040        1.483341                   0.514095
# 2             3.488097        1.749294                   1.262366
# 3            10.930248        3.753839                   1.682546
# 4            11.234482      144.021782                   3.870076
#
#    sin_of_theta^2      deltaT^3  ...  deltaT one_over_eta^3 sin_of_theta  \
# 0        0.100102  75243.331122  ...                          313.995968
# 1        0.178175    621.925724  ...                            6.509246
# 2        0.910978     48.809456  ...                            8.070168
# 3        0.754151   1993.898215  ...                           79.495662
# 4        0.103995  42280.768004  ...                        19417.589949
#
#    deltaT one_over_eta^2 sin_of_theta^2  deltaT one_over_eta sin_of_theta^3  \
# 0                             34.679708                            3.830247
# 1                              2.255969                            0.781872
# 2                              5.823782                            4.202693
# 3                             35.631544                           15.970769
# 4                            521.779089                           14.020969
#
#    deltaT sin_of_theta^4  one_over_eta^5  one_over_eta^4 sin_of_theta  \
# 0               0.423037      192.909764                    21.306179
# 1               0.270980        2.679802                     0.928763
# 2               3.032845        4.047219                     2.920648
# 3               7.158418       27.301659                    12.237149
# 4               0.376764   248926.107778                  6689.009194
#
#    one_over_eta^3 sin_of_theta^2  one_over_eta^2 sin_of_theta^3  \
# 0                       2.353190                       0.259901
# 1                       0.321890                       0.111560
# 2                       2.107666                       1.520983
# 3                       5.484935                       2.458457
# 4                     179.743476                       4.829971
#
#    one_over_eta sin_of_theta^4  sin_of_theta^5
# 0                     0.028705        0.003170
# 1                     0.038664        0.013400
# 2                     1.097607        0.792081
# 3                     1.101930        0.493907
# 4                     0.129788        0.003488
#
# [5 rows x 55 columns]

# %%
from lr import lasso_regresija
izraz, napaka, beta = lasso_regresija(data_lr, data['Q'], lam=1)
print(izraz)
print(napaka)
# Out:
# 500
# 0.412*deltaT + 0.623*one_over_eta + 0.173*sin_of_theta + 0.470*deltaT^2 + 0.316*deltaT one_over_eta + 0.015*deltaT sin_of_theta + 0.176*one_over_eta^2 + 0.871*one_over_eta sin_of_theta + 0.475*sin_of_theta^2 + 0.160*deltaT^3 + 0.915*deltaT^2 one_over_eta + 0.323*deltaT^2 sin_of_theta + 0.770*deltaT one_over_eta^2 + 0.050*deltaT one_over_eta sin_of_theta + 0.644*deltaT sin_of_theta^2 + 0.239*one_over_eta^3 + 0.357*one_over_eta^2 sin_of_theta + 0.207*one_over_eta sin_of_theta^2 + 0.329*sin_of_theta^3 + 0.066*deltaT^4 + 0.332*deltaT^3 one_over_eta + 0.021*deltaT^3 sin_of_theta + 0.217*deltaT^2 one_over_eta^2 + 0.388*deltaT^2 one_over_eta sin_of_theta + 0.455*deltaT^2 sin_of_theta^2 + 0.129*deltaT one_over_eta^3 + 0.259*deltaT one_over_eta^2 sin_of_theta + 0.459*deltaT one_over_eta sin_of_theta^2 + 0.719*deltaT sin_of_theta^3 + 0.126*one_over_eta^4 + 0.343*one_over_eta^3 sin_of_theta + 0.624*one_over_eta^2 sin_of_theta^2 + 0.798*one_over_eta sin_of_theta^3 + 0.245*sin_of_theta^4 + 0.059*deltaT^4 one_over_eta + 0.102*deltaT^4 sin_of_theta + 0.945*deltaT^3 one_over_eta sin_of_theta + 0.176*deltaT^3 sin_of_theta^2 + 0.058*deltaT^2 one_over_eta^3 + 0.036*deltaT^2 one_over_eta^2 sin_of_theta + 0.566*deltaT^2 one_over_eta sin_of_theta^2 + 0.968*deltaT^2 sin_of_theta^3 + 0.437*deltaT one_over_eta^3 sin_of_theta + 0.666*deltaT one_over_eta^2 sin_of_theta^2 + 0.957*deltaT one_over_eta sin_of_theta^3 + 0.351*deltaT sin_of_theta^4 + 0.610*one_over_eta^3 sin_of_theta^2 + 0.416*one_over_eta^2 sin_of_theta^3 + 0.265*one_over_eta sin_of_theta^4 + 0.943*sin_of_theta^5
# 71820990853669.36

# %%
def f_lr(data):
    data['sin_of_theta'] = np.sin(data['theta'])
    data_lr = data.drop(columns=['Tw', 'Ta', 'eta', 'theta'])
    poly = PolynomialFeatures(5, include_bias=False)
    X = poly.fit_transform(data_lr.drop('Q', axis=1))
    imena_stolpcev = poly.get_feature_names_out()
    data_lr = pd.DataFrame(X, columns=imena_stolpcev)
    # izračun Q
    return data_lr.dot(beta)

povprecna_kvadratna_napaka(f_lr, data)
# Out:
# 71820990853669.36

# %% [markdown]
# Tudi linearna regresija ne daje odličnih rezultatov.

# %%
data_pysr = data[[ 'deltaT', 'sin_of_theta', 'one_over_eta']]
data_pysr.head()
# Out:
#       deltaT  sin_of_theta  one_over_eta
# 0  42.217191      0.316390      2.864645
# 1   8.535838      0.422107      1.217925
# 2   3.654556      0.954452      1.322609
# 3  12.586385      0.868418      1.937483
# 4  34.837551      0.322482     12.000908

# %%
from pysr import PySRRegressor

model = PySRRegressor(
    niterations=100,  # < Increase me for better results
    binary_operators=["+", "*"],
    unary_operators=[
        # "cos",
        # "exp",
        # "sin",
        "inv(x) = 1/x",
        # ^ Custom operator (julia syntax)
    ],
    extra_sympy_mappings={"inv": lambda x: 1 / x},
    # ^ Define operator for SymPy as well
    loss="loss(prediction, target) = (prediction - target)^2",
    # ^ Custom loss function (julia syntax)
)

# %%
model.fit(data_pysr, data['Q'])
# Out:
# /home/urh/.local/lib/python3.10/site-packages/pysr/sr.py:1296: UserWarning: Note: it looks like you are running in Jupyter. The progress bar will be turned off.
#   warnings.warn(
# /home/urh/.local/lib/python3.10/site-packages/pysr/sr.py:1364: FutureWarning: Index.is_object is deprecated.Use pandas.api.types.is_object_dtype instead
#   if X.columns.is_object() and X.columns.str.contains(" ").any():
# Compiling Julia backend...
# /home/urh/.local/lib/python3.10/site-packages/julia/juliainfo.py:93: UserWarning: julia warned:
# Juliaup configuration is locked by another process, waiting for it to unlock.
#   warnings.warn("{} warned:\n{}".format(julia, stderr))
# /home/urh/.local/lib/python3.10/site-packages/julia/juliainfo.py:93: UserWarning: julia warned:
# Juliaup configuration is locked by another process, waiting for it to unlock.
#   warnings.warn("{} warned:\n{}".format(julia, stderr))
# /home/urh/.local/lib/python3.10/site-packages/pysr/julia_helpers.py:195: UserWarning: Your system's Python library is static (e.g., conda), so precompilation will be turned off. For a dynamic library, try `pyenv`.
#   warnings.warn(
# Started!
#
# Expressions evaluated per second: 7.290e+04
# Head worker occupation: 13.5%
# Progress: 166 / 1500 total iterations (11.067%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.026e+00  1.144e-01  sin_of_theta
# 3           5.717e-01  2.922e-01  (0.056376774 * deltaT)
# 5           3.159e-01  2.965e-01  ((sin_of_theta * 0.08760614) * deltaT)
# 7           1.251e-01  4.632e-01  ((0.0032668805 * (deltaT * deltaT)) * sin_of_theta)
# 9           1.226e-01  1.009e-02  ((0.0032617897 * ((deltaT * deltaT) + one_over_eta)) * sin_of_...
#                                   theta)
# 11          1.114e-01  4.778e-02  (0.0031340758 * ((deltaT + (one_over_eta * 0.22086121)) * (del...
#                                   taT * sin_of_theta)))
# 12          1.001e-01  1.076e-01  ((0.0032617897 * deltaT) * ((deltaT + inv(-0.19932508 * one_ov...
#                                   er_eta)) * sin_of_theta))
# 14          8.972e-02  5.461e-02  ((0.0032617897 * (deltaT + 1.7507482)) * ((deltaT + inv(-0.199...
#                                   32508 * one_over_eta)) * sin_of_theta))
# 16          8.679e-02  1.659e-02  ((0.0032617897 * (deltaT + (inv((-1.2641068 * one_over_eta) + ...
#                                   1.1208712) * 2.332222))) * (deltaT * sin_of_theta))
# 17          8.670e-02  1.022e-03  ((0.0032617897 * (deltaT * sin_of_theta)) * ((deltaT + (inv(on...
#                                   e_over_eta) * inv(-0.20489675))) + (0.30510032 * one_over_eta)...
#                                   ))
# 18          7.845e-02  1.000e-01  ((0.0031340758 * ((sin_of_theta * deltaT) + -1.5134735)) * (de...
#                                   ltaT + inv(inv(one_over_eta) + inv(deltaT + sin_of_theta))))
# 19          6.927e-02  1.244e-01  ((0.0032617897 * (deltaT + (inv(inv(inv(inv(one_over_eta * one...
#                                   _over_eta) + 0.08513658))) + -1.8575085))) * (deltaT * sin_of_...
#                                   theta))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 7.530e+04
# Head worker occupation: 21.4%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.
# Progress: 343 / 1500 total iterations (22.867%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.026e+00  1.144e-01  sin_of_theta
# 3           5.717e-01  2.922e-01  (0.056376774 * deltaT)
# 5           3.159e-01  2.965e-01  ((sin_of_theta * 0.08760614) * deltaT)
# 7           1.251e-01  4.632e-01  ((0.0032668805 * (deltaT * deltaT)) * sin_of_theta)
# 9           1.226e-01  1.009e-02  ((0.0032617897 * ((deltaT * deltaT) + one_over_eta)) * sin_of_...
#                                   theta)
# 11          1.114e-01  4.778e-02  (0.0031340758 * ((deltaT + (one_over_eta * 0.22086121)) * (del...
#                                   taT * sin_of_theta)))
# 12          9.918e-02  1.165e-01  ((0.0032617897 * deltaT) * (sin_of_theta * (deltaT + inv(one_o...
#                                   ver_eta * -0.1816665))))
# 13          8.818e-02  1.176e-01  ((0.0031276578 * (deltaT * sin_of_theta)) * (deltaT + inv(inv(...
#                                   one_over_eta) + 0.041921936)))
# 14          8.405e-02  4.801e-02  (0.0031340758 * ((deltaT + inv(inv(one_over_eta) + inv(deltaT)...
#                                   )) * (deltaT * sin_of_theta)))
# 15          7.024e-02  1.795e-01  (((0.0032617897 * deltaT) * 1.1053722) * ((deltaT + (inv(one_o...
#                                   ver_eta) * inv(-0.109367095))) * sin_of_theta))
# 16          6.280e-02  1.119e-01  (((0.0032617897 * deltaT) * ((deltaT + inv(-0.19932508 * (one_...
#                                   over_eta * 0.3906025))) * sin_of_theta)) * 1.1506501)
# 17          4.992e-02  2.295e-01  (((0.0032617897 * deltaT) * ((deltaT + inv(-0.19932508 * (one_...
#                                   over_eta * 0.3906025))) * sin_of_theta)) * inv(0.7957632))
# 18          4.983e-02  1.845e-03  (((0.0032617897 * (deltaT + 2.030387)) * ((deltaT + inv(-0.199...
#                                   32508 * (one_over_eta * 0.3906025))) * sin_of_theta)) * 1.1506...
#                                   501)
# 20          4.954e-02  2.936e-03  (((0.0032617897 * (deltaT + 2.030387)) * ((deltaT + inv(-0.199...
#                                   32508 * ((one_over_eta + -0.029026328) * 0.3906025))) * sin_of...
#                                   _theta)) * 1.1506501)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 8.220e+04
# Head worker occupation: 20.1%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.
# Progress: 548 / 1500 total iterations (36.533%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.026e+00  1.144e-01  sin_of_theta
# 3           5.717e-01  2.922e-01  (0.056376774 * deltaT)
# 5           3.159e-01  2.965e-01  ((sin_of_theta * 0.08760614) * deltaT)
# 7           1.251e-01  4.632e-01  ((0.0032668805 * (deltaT * deltaT)) * sin_of_theta)
# 9           1.226e-01  1.009e-02  ((0.0032617897 * ((deltaT * deltaT) + one_over_eta)) * sin_of_...
#                                   theta)
# 11          1.114e-01  4.778e-02  (0.0031340758 * ((deltaT + (one_over_eta * 0.22086121)) * (del...
#                                   taT * sin_of_theta)))
# 12          9.824e-02  1.260e-01  ((0.0032617897 * deltaT) * ((deltaT + inv(-0.13814864 * one_ov...
#                                   er_eta)) * sin_of_theta))
# 13          8.818e-02  1.081e-01  ((0.0031276578 * (deltaT * sin_of_theta)) * (deltaT + inv(inv(...
#                                   one_over_eta) + 0.041921936)))
# 14          8.054e-02  9.062e-02  (((0.0032617897 * deltaT) * ((deltaT + inv(-0.13814864 * one_o...
#                                   ver_eta)) * sin_of_theta)) * 1.0675089)
# 15          7.024e-02  1.368e-01  (((0.0032617897 * deltaT) * 1.1053722) * ((deltaT + (inv(one_o...
#                                   ver_eta) * inv(-0.109367095))) * sin_of_theta))
# 16          2.957e-02  8.651e-01  ((0.0032745667 * deltaT) * (((1.2610228 * deltaT) + (inv(-1.40...
#                                   10212 * one_over_eta) * deltaT)) * sin_of_theta))
# 18          1.434e-02  3.617e-01  ((0.0032745667 * (deltaT * 1.0922754)) * (((1.3558667 * deltaT...
#                                   ) + (inv(-1.1326332 * one_over_eta) * deltaT)) * sin_of_theta)...
#                                   )
# 20          1.359e-02  2.695e-02  ((0.005723568 * deltaT) * ((((1.1544513 * (deltaT + 0.69417685...
#                                   )) + (inv(-1.2654952 * one_over_eta) * deltaT)) * sin_of_theta...
#                                   ) * 0.7026764))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 8.800e+04
# Head worker occupation: 17.7%
# Progress: 764 / 1500 total iterations (50.933%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.026e+00  1.144e-01  sin_of_theta
# 3           5.717e-01  2.922e-01  (0.056376774 * deltaT)
# 5           3.159e-01  2.965e-01  ((sin_of_theta * 0.08760614) * deltaT)
# 7           1.251e-01  4.632e-01  ((0.0032668805 * (deltaT * deltaT)) * sin_of_theta)
# 9           1.226e-01  1.009e-02  ((0.0032617897 * ((deltaT * deltaT) + one_over_eta)) * sin_of_...
#                                   theta)
# 11          1.114e-01  4.778e-02  (0.0031340758 * ((deltaT + (one_over_eta * 0.22086121)) * (del...
#                                   taT * sin_of_theta)))
# 12          9.453e-02  1.646e-01  ((0.0035923906 * (deltaT + inv(-0.24373516 * one_over_eta))) *...
#                                    (deltaT * sin_of_theta))
# 13          8.818e-02  6.953e-02  ((0.0031276578 * (deltaT * sin_of_theta)) * (deltaT + inv(inv(...
#                                   one_over_eta) + 0.041921936)))
# 14          7.087e-02  2.186e-01  ((0.0035923906 * (deltaT + inv((-1.131331 * one_over_eta) * 0....
#                                   08263721))) * (deltaT * sin_of_theta))
# 15          7.024e-02  8.889e-03  (((0.0032617897 * deltaT) * 1.1053722) * ((deltaT + (inv(one_o...
#                                   ver_eta) * inv(-0.109367095))) * sin_of_theta))
# 16          1.333e-02  1.662e+00  ((0.0035923906 * deltaT) * (((1.3285637 * deltaT) + (inv(-1.13...
#                                   1331 * one_over_eta) * deltaT)) * sin_of_theta))
# 18          1.333e-02  2.265e-06  ((0.0035923906 * deltaT) * (((1.3285637 * deltaT) + (inv(-1.13...
#                                   1331 * one_over_eta) * (deltaT + 0.0035923906))) * sin_of_thet...
#                                   a))
# 19          1.333e-02  2.396e-05  ((0.0035923906 * deltaT) * (((1.3285637 * deltaT) + (inv(-1.13...
#                                   1331 * one_over_eta) * (deltaT + inv(deltaT)))) * sin_of_theta...
#                                   ))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 9.430e+04
# Head worker occupation: 16.6%
# Progress: 977 / 1500 total iterations (65.133%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.026e+00  1.144e-01  sin_of_theta
# 3           5.717e-01  2.922e-01  (0.056376774 * deltaT)
# 5           3.159e-01  2.965e-01  ((sin_of_theta * 0.08760614) * deltaT)
# 7           1.251e-01  4.632e-01  ((0.0032668805 * (deltaT * deltaT)) * sin_of_theta)
# 9           1.226e-01  1.010e-02  ((0.0032606693 * ((deltaT * deltaT) + one_over_eta)) * sin_of_...
#                                   theta)
# 11          1.114e-01  4.777e-02  (0.0031340758 * ((deltaT + (one_over_eta * 0.22122014)) * (del...
#                                   taT * sin_of_theta)))
# 12          7.052e-02  4.576e-01  (((0.0035923906 * (deltaT + inv(one_over_eta * -0.1021943))) *...
#                                    sin_of_theta) * deltaT)
# 14          6.219e-02  6.282e-02  (((0.0035923906 * ((deltaT + inv(one_over_eta * -0.1021943)) +...
#                                    1.2504143)) * sin_of_theta) * deltaT)
# 16          1.333e-02  7.702e-01  ((0.0035923906 * deltaT) * (((1.3285637 * deltaT) + (inv(-1.13...
#                                   1331 * one_over_eta) * deltaT)) * sin_of_theta))
# 18          1.332e-02  4.249e-04  ((0.0035923906 * deltaT) * (((1.3285637 * deltaT) + (inv(-1.13...
#                                   1331 * (one_over_eta + 0.0068283747)) * deltaT)) * sin_of_thet...
#                                   a))
# 20          1.328e-02  1.404e-03  ((0.0035923906 * deltaT) * (((1.3285637 * deltaT) + (inv((-1.1...
#                                   055444 * one_over_eta) + (-0.3625585 * 0.070017576)) * deltaT)...
#                                   ) * sin_of_theta))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.010e+05
# Head worker occupation: 15.2%
# Progress: 1195 / 1500 total iterations (79.667%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.026e+00  1.144e-01  sin_of_theta
# 3           5.717e-01  2.922e-01  (0.056376774 * deltaT)
# 5           3.159e-01  2.965e-01  ((sin_of_theta * 0.08760614) * deltaT)
# 7           1.251e-01  4.632e-01  ((0.0032668805 * (deltaT * deltaT)) * sin_of_theta)
# 9           1.226e-01  1.010e-02  ((0.0032606693 * ((deltaT * deltaT) + one_over_eta)) * sin_of_...
#                                   theta)
# 11          1.114e-01  4.787e-02  (0.0031340758 * (((0.2255092 * one_over_eta) + deltaT) * (delt...
#                                   aT * sin_of_theta)))
# 12          7.052e-02  4.574e-01  (((0.0035923906 * (deltaT + inv(one_over_eta * -0.1021943))) *...
#                                    sin_of_theta) * deltaT)
# 14          6.163e-02  6.733e-02  (((0.0035923906 * (deltaT + (inv(one_over_eta * -0.1021943) + ...
#                                   1.4061368))) * sin_of_theta) * deltaT)
# 16          1.333e-02  7.657e-01  ((0.0035923906 * deltaT) * (((1.3285637 * deltaT) + (inv(-1.13...
#                                   1331 * one_over_eta) * deltaT)) * sin_of_theta))
# 18          1.321e-02  4.498e-03  ((0.0035923906 * deltaT) * (((1.3285637 * deltaT) + (inv((-1.0...
#                                   954552 * one_over_eta) + -0.05281516) * deltaT)) * sin_of_thet...
#                                   a))
# 20          1.321e-02  9.332e-05  ((0.0035923906 * deltaT) * (((1.3285637 * deltaT) + (inv((-1.0...
#                                   954552 * one_over_eta) + -0.05281516) * (deltaT + 0.12035081))...
#                                   ) * sin_of_theta))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.040e+05
# Head worker occupation: 15.2%
# Progress: 1420 / 1500 total iterations (94.667%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.026e+00  1.144e-01  sin_of_theta
# 3           5.717e-01  2.922e-01  (0.056376774 * deltaT)
# 5           3.159e-01  2.965e-01  ((sin_of_theta * 0.08760614) * deltaT)
# 7           1.251e-01  4.632e-01  ((0.0032668805 * (deltaT * deltaT)) * sin_of_theta)
# 9           1.226e-01  1.010e-02  ((0.0032606693 * ((deltaT * deltaT) + one_over_eta)) * sin_of_...
#                                   theta)
# 11          1.114e-01  4.787e-02  (0.0031340758 * (((0.2255092 * one_over_eta) + deltaT) * (delt...
#                                   aT * sin_of_theta)))
# 12          7.052e-02  4.574e-01  (((0.0035923906 * (deltaT + inv(one_over_eta * -0.1021943))) *...
#                                    sin_of_theta) * deltaT)
# 14          6.001e-02  8.069e-02  (((0.0035923906 * (deltaT + inv(one_over_eta * -0.1021943))) *...
#                                    sin_of_theta) * (deltaT + 1.7909516))
# 16          1.333e-02  7.523e-01  ((0.0035923906 * deltaT) * (((1.3285637 * deltaT) + (inv(-1.13...
#                                   1331 * one_over_eta) * deltaT)) * sin_of_theta))
# 18          1.321e-02  4.498e-03  ((0.0035923906 * deltaT) * (((1.3285637 * deltaT) + (inv((-1.0...
#                                   954552 * one_over_eta) + -0.05281516) * deltaT)) * sin_of_thet...
#                                   a))
# 20          1.320e-02  2.092e-04  ((0.0035923906 * (deltaT + 0.09100331)) * (((1.3285637 * delta...
#                                   T) + (inv((-1.0954552 * one_over_eta) + -0.05281516) * deltaT)...
#                                   ) * sin_of_theta))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
# PySRRegressor.equations_ = [
# 	    pick     score                                           equation  \
# 	0         0.000000                                       sin_of_theta
# 	1         0.292234                             (0.056376774 * deltaT)
# 	2         0.296516             ((sin_of_theta * 0.08760614) * deltaT)
# 	3         0.463177  ((0.0032668805 * (deltaT * deltaT)) * sin_of_t...
# 	4         0.010104  ((0.0032606693 * ((deltaT * deltaT) + one_over...
# 	5         0.047874  (0.0031340758 * (((0.2255092 * one_over_eta) +...
# 	6         0.457375  (((0.0035923906 * (deltaT + inv(one_over_eta *...
# 	7         0.195868  ((((-0.00462467 * (deltaT + inv(-0.06772108 * ...
# 	8   >>>>  0.637115  ((0.0035923906 * deltaT) * (((1.3285637 * delt...
# 	9         0.004498  ((0.0035923906 * deltaT) * (((1.3285637 * delt...
# 	10        0.000209  ((0.0035923906 * (deltaT + 0.09100331)) * (((1...
#
# 	        loss  complexity
# 	0   1.025619           1
# 	1   0.571682           3
# 	2   0.315940           5
# 	3   0.125111           7
# 	4   0.122608           9
# 	5   0.111413          11
# 	6   0.070518          12
# 	7   0.047662          14
# 	8   0.013328          16
# 	9   0.013209          18
# 	10  0.013204          20
# ]

# %%
model.get_best()
print(model.get_best()['sympy_format'])
# Out:
# 0.0035923906*deltaT*sin_of_theta*(1.3285637*deltaT - 0.883914610312985*deltaT/one_over_eta)

# %%
# 0.005024702*deltaT**2*sin_of_theta*(0.949868 - 0.63198835/one_over_eta)
def f_pysr(data):
    return 0.005024702*data['deltaT']**2*data['sin_of_theta']*(0.949868 - 0.63198835/data['one_over_eta'])
povprecna_kvadratna_napaka(f_pysr, data)
# Out:
# 0.013328424604298457

# %% [markdown]
# ## Ročna oblika
# Poskusil bom še z ročno hervistiko. Iskal bom enačbo oblike deltaT^csin(theta)^c eta^c

# %%
data_rocno = data[ ['deltaT', 'sin_of_theta', 'one_over_eta']]
data_rocno.head()
# Out:
#       deltaT  sin_of_theta  one_over_eta
# 0  42.217191      0.316390      2.864645
# 1   8.535838      0.422107      1.217925
# 2   3.654556      0.954452      1.322609
# 3  12.586385      0.868418      1.937483
# 4  34.837551      0.322482     12.000908

# %%
from scipy.optimize import minimize

def equation(params):
    a, b, c, d = params
    q = a * data['deltaT']**b * data['sin_of_theta']**c * data['one_over_eta']**d
    return np.sum((data['Q'] - q)**2) / len(data)

results= minimize(equation, [1,1,1,1])
results["x"]
# Out:
# array([0.0021297 , 2.05180646, 1.02670162, 0.22636962])

# %%
a, b, c, d = results["x"]
print(f'Povprečna kvadratna napaka enačbe {a}deltaT^{b}sin(theta)^{c}eta^(-{d}) je  {results["fun"]}' )
# Out:
# Povprečna kvadratna napaka enačbe 0.0021297039865321972deltaT^2.0518064574801134sin(theta)^1.0267016242714626eta^(-0.2263696173867843) je  0.0375624885916007
