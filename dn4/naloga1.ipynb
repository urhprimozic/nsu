# %% [markdown]
# ## Predznanje
#
# - Namesto dveh značilk za temperaturo bom uvedel novo spremenljivko delta_t
# - poleg spremenljivke theta bom uvedel še cos(theta)
# - zdi se smiselno uvesti spremenljivko 1/izolacijski_indeks
#
# Enote nam v tem primeru ne pomagajo, saj je količina, ki nosi neko informacijo o enotah le temperatura. Enote izolacijskega indeksa so verjetno take, da se v enačbi lepo pokrajšajo v W. Ker enote indeksa niso podane, si z njimi ne moremo pomagati. Očitno je le, da se je treba delta_t pomnožiti z neko drugo enačbo, da je Celzija izniči.
#
# ## Algoritem - naiven poskus
# Pričakujem, da formula za toplotni tok posnema preproste oblike osnovnih formul pri toploti (Recimo Q=-kA deltaT). Zato bom poskusil z generiranjem vseh možnih enačb kratke oblike, ki posnemajo zgoraj izpeljana pravila. Formule bom generiral s pomočjo ProGeda, ker z gramatikami na enostaven način opišem željen prostor enačb.

# %%
import ProGED as pg
import pandas as pd
import numpy as np
from sklearn.preprocessing import PolynomialFeatures

# %%
# priprava podatkov
data = pd.read_csv('DN4_1_podatki.csv')
data['deltaT'] = data['Tw'] - data['Ta']
data['1_over_eta'] = 1 / data['eta']
proged_data = data.drop(columns=['Tw', 'Ta', 'eta'])
proged_data.head()
# Out:
#           Q     theta     deltaT  1_over_eta
# 0  1.711929  0.321921  42.217191    2.864645
# 1  0.067135  2.705824   8.535838    1.217925
# 2  0.034759  1.873776   3.654556    1.322609
# 3  0.417783  2.089589  12.586385    1.937483
# 4  1.667614  0.328350  34.837551   12.000908

# %% [markdown]
# Uporabil bom gramatiko, ki dela linearne izraze v produktih(kvocientih) spremenljivk đ. Prioritiziral bom enačbe z malo plusi (sledim klasičnih oblikam fizikalnih formul), prioritiziral bom spremenljivko sin(theta).

# %%
# priprava naivne gramatike
# grammar = "E -> E '+' 'c' '*' V [0.1] | 'c' '*' V [0.9]\n"
grammar = "V -> V '*' F [0.6]| 'c' '*' F [0.4]\n" #  | V '/' F [0.2] 
grammar += "F -> 'theta' [0.1] | 'cos' '(' 'theta'  ')' [0.3] | 'deltaT' [0.3] | '1_over_eta' [0.3]"

grammar = pg.GeneratorGrammar(grammar)

# %%
ED = pg.EqDisco(data=proged_data, 
                sample_size=500,
                lhs_vars=["Q"],
                rhs_vars=["theta", "deltaT", "1/eta"],
                strategy_settings = {"max_repeat":1000},
                generator = grammar,
                verbosity=1)

# %%
ED.generate_models()
# Out:
# [c*deltaT**2]
# [c*deltaT]
# [c*cos(theta)]
# [c*theta**3]
# [c*deltaT*cos(theta)]
# [c*deltaT*cos(theta)]
# [c*deltaT**2*theta]
# [c*deltaT**2*theta]
# [c*deltaT**2*theta]
# [c*deltaT**2*theta]
# [c*deltaT**2*cos(theta)**5]
# [c*cos(theta)**2]
# [c*theta]
# [c*deltaT/eta]
# [c*deltaT**4*theta*cos(theta)**3/eta]
# [c*deltaT*theta*cos(theta)/eta]
# [c*deltaT**2*cos(theta)/eta**2]
# [c*deltaT**2*cos(theta)/eta**2]
# [c*deltaT**2*cos(theta)/eta**2]
# [c*deltaT**2*cos(theta)/eta**2]
# [c*deltaT**2*cos(theta)/eta**2]
# [c*deltaT**3*cos(theta)/eta**3]
# [c*deltaT**3*cos(theta)/eta**3]
# [c*deltaT**3*cos(theta)/eta**3]
# [c*deltaT**3*cos(theta)/eta**3]
# [c*deltaT/eta**3]
# [c*deltaT/eta**3]
# [c*cos(theta)**2/eta**2]
# [c*cos(theta)**2/eta**2]
# [c*cos(theta)**2/eta**2]
# [c*cos(theta)**2/eta**2]
# [c*deltaT*cos(theta)/eta]
# [c*theta*cos(theta)**2]
# [c*theta*cos(theta)**2]
# [c*cos(theta)/eta]
# [c*cos(theta)/eta]
# [c*cos(theta)/eta]
# [c*cos(theta)/eta]
# [c*cos(theta)/eta]
# [c*deltaT**3*cos(theta)**6/eta**2]
# [c*deltaT**3*cos(theta)**6/eta**2]
# [c*cos(theta)**3]
# [c*cos(theta)**3]
# [c*cos(theta)**3]
# [c*cos(theta)**3]
# [c*cos(theta)**3]
# [c*cos(theta)**3]
# [c*cos(theta)**3]
# [c*deltaT**3*cos(theta)]
# [c*deltaT**3*cos(theta)]
# [c*deltaT*theta**3*cos(theta)**2/eta]
# [c*deltaT**2*theta*cos(theta)**3/eta]
# [c*deltaT**5*theta**2*cos(theta)/eta]
# [c*deltaT**2*cos(theta)/eta]
# [c*deltaT**2*cos(theta)/eta]
# [c*deltaT**2*cos(theta)/eta]
# [c*deltaT**2*cos(theta)/eta]
# [c*deltaT**2*cos(theta)/eta]
# [c*deltaT**2/eta]
# [c*deltaT**2/eta]
# [c*deltaT**2/eta]
# [c*deltaT**2/eta]
# [c*theta*cos(theta)**2/eta]
# [c*theta/eta]
# [c*deltaT*theta**2]
# [c*deltaT*theta**2]
# [c*deltaT*theta**2]
# [c*deltaT*theta**2]
# [c*deltaT*theta**2]
# [c*deltaT*cos(theta)/eta**2]
# [c*deltaT*cos(theta)/eta**2]
# [c*deltaT*cos(theta)/eta**2]
# [c*deltaT*cos(theta)/eta**2]
# [c*deltaT*cos(theta)/eta**2]
# [c*deltaT*cos(theta)**2]
# [c*deltaT*cos(theta)**2]
# [c*deltaT*cos(theta)**2]
# [c*deltaT*cos(theta)**2]
# [c*deltaT**2*cos(theta)**2/eta**2]
# [c*deltaT**2*theta*cos(theta)**4/eta**3]
# [c*deltaT**2*theta*cos(theta)**4/eta**3]
# [c*theta*cos(theta)]
# [c*theta*cos(theta)]
# [c*deltaT*cos(theta)**3]
# [c*deltaT*cos(theta)**3]
# [c*deltaT*cos(theta)**3]
# [c*deltaT*cos(theta)**3]
# [c*deltaT*cos(theta)**3]
# [c*deltaT*cos(theta)**3]
# [c*deltaT*cos(theta)**3]
# [c*deltaT*cos(theta)**3]
# [c*cos(theta)**2/eta]
# [c*deltaT*theta]
# [c*deltaT*theta]
# [c*deltaT*theta]
# [c*deltaT*theta]
# [c*deltaT*theta]
# [c*deltaT**2*theta*cos(theta)**3]
# [c*deltaT**2*theta*cos(theta)**3]
# [c*deltaT**2*theta*cos(theta)**3]
# [c*deltaT*cos(theta)**2/eta**4]
# [c*deltaT*theta/eta]
# [c*deltaT*theta*cos(theta)]
# [c*deltaT*theta*cos(theta)]
# [c*deltaT*theta*cos(theta)]
# [c*deltaT*cos(theta)**2/eta]
# [c*deltaT*cos(theta)**2/eta]
# [c*deltaT**2*cos(theta)**2/eta**3]
# [c*theta**2*cos(theta)**5]
# [c*theta**2*cos(theta)**5]
# [c*theta**2*cos(theta)**5]
# [c*theta*cos(theta)/eta**4]
# [c*theta*cos(theta)/eta**4]
# [c*deltaT*theta*cos(theta)**3/eta]
# [c*deltaT*theta*cos(theta)**3/eta]
# [c*deltaT*theta*cos(theta)**3/eta]
# [c*deltaT*theta*cos(theta)**3/eta]
# [c*deltaT*theta*cos(theta)**3/eta]
# [c*deltaT*theta*cos(theta)**3/eta]
# [c*deltaT*theta*cos(theta)**3/eta]
# [c*deltaT**2*cos(theta)]
# [c*deltaT**2*cos(theta)]
# [c*deltaT**2*cos(theta)]
# [c*deltaT**3*theta*cos(theta)**4/eta**2]
# [c*deltaT**3*theta*cos(theta)**4/eta**2]
# [c*deltaT**3*theta*cos(theta)**4/eta**2]
# [c*deltaT**3*theta*cos(theta)**4/eta**2]
# [c*deltaT**3*theta]
# [c*deltaT**3*theta]
# [c*deltaT**3*theta]
# [c*deltaT**3*theta]
# [c*deltaT**3*theta]
# [c*deltaT**3*theta]
# [c*deltaT**3*theta]
# [c*deltaT**3*theta]
# [c*deltaT**3*theta]
# [c*deltaT**3*theta]
# [c*deltaT**3*theta]
# [c*deltaT*cos(theta)**2/eta**2]
# [c*deltaT*cos(theta)**2/eta**2]
# [c*deltaT*cos(theta)**2/eta**2]
# [c*deltaT*cos(theta)**2/eta**2]
# [c*deltaT*cos(theta)**2/eta**2]
# [c*deltaT*cos(theta)**2/eta**2]
# [c*deltaT*cos(theta)**2/eta**2]
# [c*deltaT*theta**2/eta**2]
# [c*deltaT*theta**2/eta**2]
# [c*deltaT*theta**2/eta**2]
# [c*deltaT*theta**2/eta**2]
# [c*deltaT*theta**2/eta**2]
# [c*deltaT*theta**2/eta**2]
# [c*deltaT*theta**2/eta**2]
# [c*cos(theta)**3/eta]
# [c*cos(theta)**3/eta]
# [c*cos(theta)**3/eta]
# [c*cos(theta)**3/eta]
# [c*deltaT**2*cos(theta)**2/eta]
# [c*deltaT**2*cos(theta)**2/eta]
# [c*deltaT**2*cos(theta)**2/eta]
# [c*deltaT**2*cos(theta)**2/eta]
# [c*deltaT**2*cos(theta)**2/eta]
# [c*deltaT**2/eta**3]
# [c*deltaT**2/eta**3]
# [c*deltaT**2/eta**3]
# [c*deltaT**2/eta**3]
# [c*deltaT**2/eta**3]
# [c*deltaT**2*cos(theta)**2]
# [c*deltaT**2*cos(theta)**2]
# [c*deltaT**2*cos(theta)**2]
# [c*deltaT**2*cos(theta)**2]
# [c*deltaT**3*theta*cos(theta)/eta**3]
# [c*deltaT**3*theta*cos(theta)/eta**3]
# [c*deltaT**3*theta*cos(theta)/eta**3]
# [c*theta*cos(theta)**2/eta**2]
# [c*theta*cos(theta)**2/eta**2]
# [c*theta*cos(theta)**2/eta**2]
# [c*theta*cos(theta)**2/eta**2]
# [c*theta*cos(theta)/eta**2]
# [c*cos(theta)/eta**2]
# [c*deltaT**4*theta*cos(theta)**2/eta**5]
# [c*deltaT**4*theta*cos(theta)**2/eta**5]
# [c*deltaT**4*theta*cos(theta)**2/eta**5]
# [c*deltaT**4*theta*cos(theta)**2/eta**5]
# [c*deltaT**4*theta*cos(theta)**2/eta**5]
# [c*deltaT**4*theta*cos(theta)**2/eta**5]
# [c*deltaT**4*theta*cos(theta)**2/eta**5]
# [c*deltaT**4*theta*cos(theta)**2/eta**5]
# [c*deltaT**4*theta*cos(theta)**2/eta**5]
# [c*deltaT**4*theta*cos(theta)**2/eta**5]
# [c*deltaT**4*theta*cos(theta)**2/eta**5]
# [c*deltaT**4*theta*cos(theta)**2/eta**5]
# [c*deltaT**4*theta*cos(theta)**2/eta**5]
# [c*deltaT**4*theta*cos(theta)**2/eta**5]
# [c*theta*cos(theta)**3]
# [c*theta*cos(theta)**3]
# [c*theta*cos(theta)**3]
# [c*theta*cos(theta)**3]
# [c*theta*cos(theta)**3]
# [c*deltaT/eta**2]
# [c*deltaT/eta**2]
# [c*deltaT/eta**2]
# [c*deltaT*theta**2*cos(theta)**3/eta]
# [c*deltaT*theta**2*cos(theta)**3/eta]
# [c*deltaT*theta**2*cos(theta)**3/eta]
# [c*deltaT*theta**2*cos(theta)**3/eta]
# [c*deltaT*theta**2*cos(theta)**3/eta]
# [c*deltaT*theta**2*cos(theta)**3/eta]
# [c*deltaT*theta**2*cos(theta)**3/eta]
# [c*deltaT*theta**2*cos(theta)**3/eta]
# [c*deltaT*theta**2*cos(theta)**3/eta]
# [c*deltaT*theta**2*cos(theta)**3/eta]
# [c*deltaT*theta**2*cos(theta)**3/eta]
# [c*deltaT*theta**2*cos(theta)**3/eta]
# [c*deltaT*theta**2*cos(theta)**3/eta]
# [c*deltaT*theta**2*cos(theta)**3/eta]
# [c*deltaT*theta**2*cos(theta)**3/eta]
# [c*deltaT*theta**2*cos(theta)**3/eta]
# [c*deltaT*theta**2*cos(theta)**3/eta]
# [c*deltaT*theta**2*cos(theta)**3/eta]
# [c*deltaT*theta**2*cos(theta)**3/eta]
# [c*deltaT*theta**2*cos(theta)**3/eta]
# [c*theta/eta**2]
# [c*deltaT**3]
# [c*deltaT**3]
# [c*deltaT**3]
# [c*deltaT**3]
# [c*deltaT**3]
# [c*deltaT**3]
# [c*deltaT**3]
# [c*deltaT**3]
# [c*deltaT**3]
# [c*deltaT**3]
# [c*cos(theta)**4]
# [c*cos(theta)**4]
# [c*deltaT*theta*cos(theta)/eta**2]
# [c*deltaT*theta*cos(theta)/eta**2]
# [c*theta*cos(theta)**5]
# [c*theta*cos(theta)**5]
# [c*theta*cos(theta)**5]
# [c*theta*cos(theta)**5]
# [c*theta*cos(theta)**5]
# [c*theta*cos(theta)**5]
# [c*theta*cos(theta)**5]
# [c*theta*cos(theta)**5]
# [c*theta*cos(theta)**5]
# [c*theta*cos(theta)**5]
# [c*theta*cos(theta)**5]
# [c*theta*cos(theta)**5]
# [c*theta*cos(theta)**5]
# [c*theta*cos(theta)**5]
# [c*theta**2*cos(theta)/eta]
# [c*theta**2*cos(theta)/eta]
# [c*theta**2*cos(theta)/eta]
# [c*theta**2*cos(theta)/eta]
# [c*theta**2*cos(theta)/eta]
# [c*deltaT*cos(theta)/eta**3]
# [c*deltaT*cos(theta)/eta**3]
# [c*deltaT*cos(theta)/eta**3]
# [c*deltaT*cos(theta)/eta**3]
# [c*deltaT*cos(theta)/eta**3]
# [c*deltaT*cos(theta)/eta**3]
# [c*theta*cos(theta)/eta]
# [c*theta*cos(theta)/eta]
# [c*deltaT*theta**2*cos(theta)**3/eta**3]
# [c*deltaT*theta**2*cos(theta)**3/eta**3]
# [c*deltaT*theta**2*cos(theta)**3/eta**3]
# [c*deltaT*theta**2*cos(theta)**3/eta**3]
# [c*deltaT*theta**2*cos(theta)**3/eta**3]
# [c*deltaT*theta**2*cos(theta)**3/eta**3]
# [c*theta*cos(theta)**3/eta]
# [c*theta*cos(theta)**3/eta]
# [c*theta*cos(theta)**3/eta]
# [c*theta*cos(theta)**3/eta]
# [c*theta/eta**3]
# [c*theta/eta**3]
# [c*theta/eta**3]
# [c*theta*cos(theta)**3/eta**3]
# [c*theta*cos(theta)**3/eta**3]
# [c*theta*cos(theta)**3/eta**3]
# [c*theta*cos(theta)**3/eta**3]
# [c*theta*cos(theta)**3/eta**3]
# [c*theta*cos(theta)**5/eta]
# [c*theta*cos(theta)**5/eta]
# [c*theta*cos(theta)**5/eta]
# [c*deltaT*theta**2*cos(theta)**3/eta**5]
# [c*deltaT*theta**2*cos(theta)**3/eta**5]
# [c*deltaT*theta**2*cos(theta)**3/eta**5]
# [c*deltaT*theta**2*cos(theta)**3/eta**5]
# [c*deltaT*theta**2*cos(theta)**3/eta**5]
# [c*deltaT*theta**2*cos(theta)**3/eta**5]
# [c*deltaT*theta**2*cos(theta)**3/eta**5]
# [c*deltaT*theta**2*cos(theta)**3/eta**5]
# [c*deltaT*theta**2*cos(theta)**3/eta**5]
# [c*deltaT*theta/eta**3]
# [c*deltaT*theta/eta**3]
# [c*deltaT*theta/eta**3]
# [c*deltaT*theta/eta**3]
# [c*deltaT*theta/eta**3]
# [c*deltaT*theta/eta**3]
# [c*deltaT/eta**4]
# [c*deltaT**3*cos(theta)**2/eta**2]
# [c*deltaT**3*cos(theta)**2/eta**2]
# [c*deltaT**3*cos(theta)**2/eta**2]
# [c*deltaT**3*cos(theta)**2/eta**2]
# [c*deltaT**3*cos(theta)**2/eta**2]
# [c*deltaT**3*cos(theta)**2/eta**2]
# [c*deltaT**3*cos(theta)**2/eta**2]
# [c*deltaT**3*cos(theta)**2/eta**2]
# [c*deltaT**3*cos(theta)**2/eta**2]
# [c*deltaT**3*cos(theta)**2/eta**2]
# [c*deltaT**3*cos(theta)**2/eta**2]
# [c*deltaT**3*cos(theta)**2/eta**2]
# [c*deltaT**3*cos(theta)**2/eta**2]
# [c*deltaT**3*cos(theta)**2/eta**2]
# [c*deltaT**3*cos(theta)**2/eta**2]
# [c*deltaT**3*cos(theta)**2/eta**2]
# [c*deltaT**3*cos(theta)**2/eta**2]
# [c*deltaT**3*cos(theta)**2/eta**2]
# [c*deltaT**3*cos(theta)**2/eta**2]
# [c*deltaT**3*cos(theta)/eta]
# [c*deltaT**3*cos(theta)/eta]
# [c*deltaT**3*cos(theta)/eta]
# [c*deltaT**3*cos(theta)/eta]
# [c*deltaT**3*cos(theta)/eta]
# [c*deltaT**3*cos(theta)/eta]
# [c*deltaT**3*cos(theta)/eta]
# [c*deltaT**3*cos(theta)/eta]
# [c*deltaT**3*cos(theta)/eta]
# [c*deltaT**2*theta*cos(theta)**4/eta**2]
# [c*deltaT**2*theta*cos(theta)**4/eta**2]
# [c*deltaT**2*theta*cos(theta)**4/eta**2]
# [c*deltaT**2*theta*cos(theta)**4/eta**2]
# [c*deltaT**2*theta*cos(theta)**4/eta**2]
# [c*deltaT**2*theta*cos(theta)**4/eta**2]
# [c*deltaT**2*theta*cos(theta)**4/eta**2]
# [c*deltaT**2*theta*cos(theta)**4/eta**2]
# [c*deltaT**2*theta*cos(theta)**4/eta**2]
# [c*deltaT**2*theta*cos(theta)**4/eta**2]
# [c*deltaT**2*theta*cos(theta)**4/eta**2]
# [c*deltaT**2*theta*cos(theta)**4/eta**2]
# [c*deltaT**2*theta*cos(theta)**4/eta**2]
# [c*deltaT**2*theta*cos(theta)**4/eta**2]
# [c*deltaT**2*theta*cos(theta)**4/eta**2]
# [c*deltaT**2*theta*cos(theta)**4/eta**2]
# [c*deltaT**2*theta*cos(theta)**4/eta**2]
# [c*deltaT**2*theta*cos(theta)**4/eta**2]
# [c*deltaT**2*theta*cos(theta)**4/eta**2]
# [c*deltaT**2*theta*cos(theta)**4/eta**2]
# [c*deltaT**2*theta*cos(theta)**4/eta**2]
# [c*deltaT**2*theta*cos(theta)**4/eta**2]
# [c*deltaT**2*theta*cos(theta)**4/eta**2]
# [c*deltaT**2*theta*cos(theta)**4/eta**2]
# [c*deltaT**2*theta*cos(theta)**4/eta**2]
# [c*deltaT**3/eta**4]
# [c*deltaT**3/eta**4]
# [c*deltaT**3/eta**4]
# [c*deltaT**3/eta**4]
# [c*deltaT**3/eta**4]
# [c*deltaT**3/eta**4]
# [c*deltaT**3/eta**4]
# [c*deltaT**3/eta**4]
# [c*deltaT**3/eta**4]
# [c*deltaT**2*theta/eta**2]
# [c*deltaT**2*theta/eta**2]
# [c*deltaT**2*theta/eta**2]
# [c*deltaT*theta**2*cos(theta)]
# [c*deltaT*theta**2*cos(theta)]
# [c*deltaT*theta**2*cos(theta)]
# [c*deltaT*theta**2*cos(theta)]
# [c*deltaT*theta**2*cos(theta)]
# [c*deltaT*theta**2*cos(theta)]
# [c*deltaT*theta**2*cos(theta)]
# [c*deltaT*theta**2*cos(theta)]
# [c*deltaT*theta**2*cos(theta)]
# [c*deltaT*theta**2*cos(theta)]
# [c*deltaT*theta**2*cos(theta)]
# [c*deltaT*theta**2*cos(theta)]
# [c*deltaT*theta**2*cos(theta)]
# [c*deltaT*theta**2*cos(theta)]
# [c*deltaT*theta**2*cos(theta)]
# [c*deltaT*theta**2*cos(theta)]
# [c*deltaT*theta**2*cos(theta)]
# [c*deltaT*cos(theta)**4]
# [c*deltaT*cos(theta)**4]
# [c*deltaT*cos(theta)**4]
# [c*deltaT*cos(theta)**4]
# [c*deltaT*cos(theta)**4]
# [c*deltaT*cos(theta)**4/eta**3]
# [c*deltaT*cos(theta)**4/eta**3]
# [c*deltaT*cos(theta)**4/eta**3]
# [c*deltaT*cos(theta)**4/eta**3]
# [c*deltaT*cos(theta)**4/eta**3]
# [c*deltaT*theta/eta**2]
# [c*deltaT*theta/eta**2]
# [c*deltaT*theta**2*cos(theta)/eta]
# [c*deltaT*theta**2*cos(theta)/eta]
# [c*deltaT*theta**2*cos(theta)/eta]
# [c*deltaT*theta**2*cos(theta)/eta]
# [c*deltaT*theta**2*cos(theta)/eta]
# [c*deltaT*theta**2*cos(theta)/eta]
# [c*deltaT*theta**2*cos(theta)/eta]
# [c*deltaT*theta**2*cos(theta)/eta]
# [c*deltaT*theta**2*cos(theta)/eta]
# [c*deltaT*theta**2*cos(theta)/eta]
# [c*deltaT*theta**2*cos(theta)/eta]
# [c*deltaT*theta**2*cos(theta)/eta]
# [c*deltaT*theta**2*cos(theta)/eta]
# [c*deltaT*theta**2*cos(theta)/eta]
# [c*deltaT*theta**2*cos(theta)/eta]
# [c*deltaT**4*cos(theta)/eta**2]
# [c*deltaT**4*cos(theta)/eta**2]
# [c*deltaT**4*cos(theta)/eta**2]
# [c*deltaT**4*cos(theta)/eta**2]
# [c*deltaT**4*cos(theta)/eta**2]
# [c*deltaT**4*cos(theta)/eta**2]
# [c*deltaT**4*cos(theta)/eta**2]
# [c*deltaT**4*cos(theta)/eta**2]
# [c*deltaT**4*cos(theta)/eta**2]
# [c*deltaT**4*cos(theta)/eta**2]
# [c*deltaT**4*cos(theta)/eta**2]
# [c*deltaT**4*cos(theta)/eta**2]
# [c*deltaT**4*cos(theta)/eta**2]
# [c*deltaT*theta*cos(theta)**3/eta**2]
# [c*deltaT*theta*cos(theta)**3/eta**2]
# [c*deltaT*theta*cos(theta)**3/eta**2]
# [c*deltaT*theta*cos(theta)**3/eta**2]
# [c*deltaT*theta*cos(theta)**3/eta**2]
# [c*deltaT*theta*cos(theta)**3/eta**2]
# [c*deltaT*theta*cos(theta)**3/eta**2]
# [c*deltaT*theta*cos(theta)**3/eta**2]
# [c*deltaT*theta*cos(theta)**3/eta**2]
# [c*deltaT*theta*cos(theta)**3/eta**2]
# [c*deltaT*theta*cos(theta)**3/eta**2]
# [c*deltaT*theta*cos(theta)**3/eta**2]
# [c*deltaT*theta*cos(theta)**3/eta**2]
# [c*deltaT*theta*cos(theta)**3/eta**2]
# [c*deltaT*theta*cos(theta)**3/eta**2]
# [c*deltaT*theta*cos(theta)**3/eta**2]
# [c*deltaT*theta*cos(theta)**3/eta**2]
# [c*deltaT*theta*cos(theta)**3/eta**2]
# [c*deltaT*theta*cos(theta)**3/eta**2]
# [c*deltaT*theta*cos(theta)**3/eta**2]
# [c*deltaT*theta*cos(theta)**3/eta**2]
# [c*deltaT*theta*cos(theta)**3/eta**2]
# [c*deltaT*theta*cos(theta)**3/eta**2]
# [c*deltaT*theta*cos(theta)**3/eta**2]
# [c*deltaT*theta*cos(theta)**3/eta**2]
# [c*deltaT*theta*cos(theta)**3/eta**2]
# [c*deltaT*theta*cos(theta)**3/eta**2]
# [c*deltaT*theta*cos(theta)**3/eta**2]
# [c*deltaT*theta*cos(theta)**3/eta**2]
# [c*deltaT*theta*cos(theta)**3/eta**2]
# [c*deltaT*theta*cos(theta)**3/eta**2]
# [c*deltaT*theta*cos(theta)**3/eta**2]
# [c*deltaT*theta*cos(theta)**3/eta**2]
# [c*deltaT*theta*cos(theta)**3/eta**2]
# [c*deltaT*theta*cos(theta)**3/eta**2]
# [c*deltaT*theta*cos(theta)**3/eta**2]
# [c*deltaT*cos(theta)**4/eta]
# [c*deltaT*cos(theta)**4/eta]
# [c*deltaT*cos(theta)**4/eta]
# [c*deltaT*cos(theta)**4/eta]
# [c*deltaT*cos(theta)**4/eta]
# [c*cos(theta)**4/eta**2]
# [c*cos(theta)**4/eta**2]
# [c*cos(theta)**4/eta**2]
# [c*cos(theta)**4/eta**2]
# [c*cos(theta)**4/eta**2]
# [c*cos(theta)**4/eta**2]
# [c*cos(theta)/eta**4]
# [c*cos(theta)/eta**4]
# [c*cos(theta)/eta**4]
# [c*cos(theta)/eta**4]
# [c*cos(theta)/eta**4]
# [c*cos(theta)/eta**4]
# [c*cos(theta)/eta**4]
# [c*cos(theta)/eta**4]
# [c*deltaT**3/eta]
# [c*deltaT**3/eta]
# [c*deltaT*theta**2*cos(theta)**2/eta]
# [c*deltaT**3*theta*cos(theta)**2/eta**3]
# [c*deltaT**3*theta*cos(theta)**2/eta**3]
# [c*deltaT**3*theta*cos(theta)**2/eta**3]
# [c*deltaT**3*theta*cos(theta)**2/eta**3]
# [c*deltaT**3*theta*cos(theta)**2/eta**3]
# [c*deltaT**3*theta*cos(theta)**2/eta**3]
# [c*deltaT**3*theta*cos(theta)**2/eta**3]
# [c*deltaT**3*theta/eta]
# [c*deltaT**3*theta/eta]
# [c*deltaT**3*theta/eta]
# [c*deltaT**3*theta/eta]
# [c*deltaT**3*theta/eta]
# [c*deltaT**3*theta/eta]
# [c*deltaT**3*theta/eta]
# [c*deltaT**3*theta/eta]
# [c*deltaT**3*theta/eta]
# [c*deltaT**3*theta/eta]
# [c*deltaT**3*theta/eta]
# [c*deltaT**3*theta/eta]
# [c*deltaT**3*theta/eta]
# [c*deltaT**3*theta/eta]
# [c*deltaT**3*theta/eta]
# [c*deltaT**3*cos(theta)**2/eta**3]
# [c*deltaT**3*cos(theta)**2/eta**3]
# [c*deltaT**3*cos(theta)**2/eta**3]
# [c*deltaT*theta*cos(theta)**2]
# [c*deltaT*theta*cos(theta)**2]
# [c*deltaT*theta*cos(theta)**2]
# [c*deltaT*theta*cos(theta)**2]
# [c*deltaT*theta*cos(theta)**2]
# [c*deltaT*theta*cos(theta)**2]
# [c*deltaT*theta*cos(theta)**2]
# [c*deltaT*theta*cos(theta)**2]
# [c*deltaT*theta*cos(theta)**2]
# [c*deltaT*theta*cos(theta)**2]
# [c*deltaT*theta*cos(theta)**2/eta**5]
# [c*deltaT*theta*cos(theta)**2/eta**5]
# [c*deltaT*theta*cos(theta)**2/eta**5]
# [c*deltaT*theta*cos(theta)**2/eta**5]
# [c*deltaT*theta*cos(theta)**2/eta**5]
# [c*deltaT**3*theta**3*cos(theta)**2/eta**4]
# [c*deltaT**3*theta**3*cos(theta)**2/eta**4]
# [c*deltaT**3*theta**3*cos(theta)**2/eta**4]
# [c*deltaT**3*theta**3*cos(theta)**2/eta**4]
# [c*deltaT*theta**2*cos(theta)**2/eta**2]
# [c*deltaT*theta**2*cos(theta)**2/eta**2]
# [c*deltaT*theta**2*cos(theta)**2/eta**2]
# [c*deltaT*theta**2*cos(theta)**2/eta**2]
# [c*theta**2]
# [c*theta**2]
# [c*theta**2]
# [c*theta**2]
# [c*theta**2]
# [c*theta**2]
# [c*theta**2]
# [c*theta**2]
# [c*theta**2]
# [c*deltaT**2*theta*cos(theta)/eta**2]
# [c*deltaT**2*theta*cos(theta)/eta**2]
# [c*deltaT**2*theta*cos(theta)/eta**2]
# [c*deltaT**2*theta*cos(theta)/eta**2]
# [c*deltaT**2*theta*cos(theta)/eta**2]
# [c*deltaT**2*theta*cos(theta)/eta**2]
# [c*deltaT**4*cos(theta)/eta]
# [c*deltaT**4*cos(theta)/eta]
# [c*deltaT**4*cos(theta)/eta]
# [c*deltaT**4*cos(theta)/eta]
# [c*deltaT**4*cos(theta)/eta]
# [c*deltaT**4*cos(theta)/eta]
# [c*deltaT**4*cos(theta)/eta]
# [c*deltaT**4*cos(theta)/eta]
# [c*deltaT**4*cos(theta)/eta]
# [c*deltaT**4*cos(theta)/eta]
# [c*deltaT**4*cos(theta)/eta]
# [c*deltaT**4*cos(theta)/eta]
# [c*deltaT**4*cos(theta)/eta]
# [c*deltaT**4*cos(theta)/eta]
# [c*deltaT**4*cos(theta)/eta]
# [c*deltaT**4*cos(theta)/eta]
# [c*deltaT**4*cos(theta)/eta]
# [c*deltaT**4*cos(theta)/eta]
# [c*deltaT**4*cos(theta)/eta]
# [c*deltaT**4*cos(theta)/eta]
# [c*deltaT**4*cos(theta)/eta]
# [c*deltaT**4*cos(theta)/eta]
# [c*deltaT**4*cos(theta)/eta]
# [c*deltaT**4*cos(theta)/eta]
# [c*deltaT**4*cos(theta)/eta]
# [c*deltaT**4*cos(theta)/eta]
# [c*deltaT**4*cos(theta)/eta]
# [c*deltaT**4*cos(theta)/eta]
# [c*deltaT**4*cos(theta)/eta]
# [c*deltaT**4*cos(theta)/eta]
# [c*deltaT**4*cos(theta)/eta]
# [c*deltaT**4*cos(theta)/eta]
# [c*deltaT**4*cos(theta)/eta]
# [c*deltaT**4*cos(theta)/eta]
# [c*deltaT**4*cos(theta)/eta]
# [c*deltaT**4*cos(theta)/eta]
# [c*deltaT**4*cos(theta)/eta]
# [c*deltaT**4*cos(theta)/eta]
# [c*deltaT**4*cos(theta)/eta]
# [c*deltaT**4*cos(theta)/eta]
# [c*deltaT**4*cos(theta)/eta]
# [c*deltaT**4*cos(theta)/eta]
# [c*deltaT**4*cos(theta)/eta]
# [c*deltaT**3*theta*cos(theta)**3/eta**2]
# [c*deltaT**3*theta*cos(theta)**3/eta**2]
# [c*deltaT**3*theta*cos(theta)**3/eta**2]
# [c*deltaT**3*theta*cos(theta)**3/eta**2]
# [c*deltaT**3*theta*cos(theta)**3/eta**2]
# [c*deltaT**3*theta*cos(theta)**3/eta**2]
# [c*deltaT**3*theta*cos(theta)**3/eta**2]
# [c*deltaT**3*theta*cos(theta)**3/eta**2]
# [c*deltaT**3*theta*cos(theta)**3/eta**2]
# [c*deltaT**3*theta*cos(theta)**3/eta**2]
# [c*deltaT**3*theta*cos(theta)**3/eta**2]
# [c*deltaT**3*theta*cos(theta)**3/eta**2]
# [c*deltaT**3*theta*cos(theta)**3/eta**2]
# [c*deltaT**3*theta*cos(theta)**3/eta**2]
# [c*deltaT**3*theta*cos(theta)**3/eta**2]
# [c*deltaT**3*theta*cos(theta)**3/eta**2]
# [c*deltaT**3*theta*cos(theta)**3/eta**2]
# [c*deltaT**2*theta*cos(theta)**2/eta]
# [c*deltaT**2*theta*cos(theta)**2/eta]
# [c*deltaT**2*theta*cos(theta)**2/eta]
# [c*deltaT**2*theta*cos(theta)**2/eta]
# [c*deltaT**2*theta*cos(theta)**2/eta]
# [c*deltaT**2*theta*cos(theta)**2/eta]
# [c*deltaT**2*theta*cos(theta)**2/eta]
# [c*deltaT**2*theta*cos(theta)**2/eta]
# [c*deltaT**2*theta*cos(theta)**2/eta]
# [c*deltaT**2*theta*cos(theta)**2/eta]
# [c*deltaT**2*theta*cos(theta)**2/eta]
# [c*deltaT**2*theta*cos(theta)**2/eta]
# [c*deltaT**2*theta*cos(theta)**2/eta]
# [c*theta*cos(theta)**2/eta**4]
# [c*theta*cos(theta)**2/eta**4]
# [c*theta*cos(theta)**2/eta**4]
# [c*theta*cos(theta)**2/eta**4]
# [c*theta*cos(theta)**2/eta**4]
# [c*theta*cos(theta)**2/eta**4]
# [c*theta*cos(theta)**2/eta**4]
# [c*deltaT**5*theta**3*cos(theta)**5/eta]
# [c*deltaT**5*theta**3*cos(theta)**5/eta]
# [c*deltaT**5*theta**3*cos(theta)**5/eta]
# [c*deltaT**5*theta**3*cos(theta)**5/eta]
# [c*deltaT**5*theta**3*cos(theta)**5/eta]
# [c*deltaT**5*theta**3*cos(theta)**5/eta]
# [c*deltaT**5*theta**3*cos(theta)**5/eta]
# [c*deltaT**5*theta**3*cos(theta)**5/eta]
# [c*deltaT**5*theta**3*cos(theta)**5/eta]
# [c*deltaT**5*theta**3*cos(theta)**5/eta]
# [c*deltaT**2*cos(theta)**3/eta]
# [c*deltaT**2*cos(theta)**3/eta]
# [c*deltaT**2*cos(theta)**3/eta]
# [c*deltaT**2*cos(theta)**3/eta]
# [c*deltaT**2*cos(theta)**3/eta]
# [c*deltaT**2*cos(theta)**3/eta]
# [c*deltaT**2*cos(theta)**3/eta]
# [c*deltaT**2*cos(theta)**3/eta]
# [c*deltaT**2*cos(theta)**3/eta]
# [c*deltaT**2*cos(theta)**3/eta]
# [c*cos(theta)**3/eta**2]
# [c*deltaT**3*cos(theta)**2]
# [c*deltaT**3*cos(theta)**2]
# [c*deltaT**2*cos(theta)/eta**3]
# [c*deltaT**2*cos(theta)/eta**3]
# [c*deltaT**2*cos(theta)/eta**3]
# [c*deltaT**2*cos(theta)/eta**3]
# [c*deltaT**2*cos(theta)**3]
# [c*deltaT**3*theta*cos(theta)**3/eta]
# [c*deltaT**3*theta*cos(theta)**3/eta]
# [c*deltaT**3*theta*cos(theta)**3/eta]
# [c*deltaT**3*theta*cos(theta)**3/eta]
# [c*deltaT**3*theta*cos(theta)**3/eta]
# [c*deltaT**3*theta*cos(theta)**3/eta]
# [c*deltaT**3*theta*cos(theta)**3/eta]
# [c*deltaT**3*theta*cos(theta)**3/eta]
# [c*deltaT**3*theta*cos(theta)**3/eta]
# [c*deltaT**3*theta*cos(theta)**3/eta]
# [c*deltaT**3*theta*cos(theta)**3/eta]
# [c*deltaT**3*theta*cos(theta)**3/eta]
# [c*deltaT**3*theta*cos(theta)**3/eta]
# [c*deltaT**4*theta*cos(theta)**9/eta**5]
# [c*deltaT**4*theta*cos(theta)**9/eta**5]
# [c*deltaT**4*theta*cos(theta)**9/eta**5]
# [c*deltaT**4*theta*cos(theta)**9/eta**5]
# [c*deltaT**4*theta*cos(theta)**9/eta**5]
# [c*deltaT**4*theta*cos(theta)**9/eta**5]
# [c*deltaT**4*theta*cos(theta)**9/eta**5]
# [c*deltaT**4*theta*cos(theta)**9/eta**5]
# [c*deltaT**4*theta*cos(theta)**9/eta**5]
# [c*deltaT**4*theta*cos(theta)**9/eta**5]
# [c*deltaT**6*theta*cos(theta)**3/eta**2]
# [c*deltaT**6*theta*cos(theta)**3/eta**2]
# [c*deltaT**6*theta*cos(theta)**3/eta**2]
# [c*deltaT**6*theta*cos(theta)**3/eta**2]
# [c*deltaT**6*theta*cos(theta)**3/eta**2]
# [c*deltaT**6*theta*cos(theta)**3/eta**2]
# [c*deltaT**6*theta*cos(theta)**3/eta**2]
# [c*deltaT**6*theta*cos(theta)**3/eta**2]
# [c*deltaT**6*theta*cos(theta)**3/eta**2]
# [c*deltaT**6*theta*cos(theta)**3/eta**2]
# [c*deltaT**6*theta*cos(theta)**3/eta**2]
# [c*deltaT**6*theta*cos(theta)**3/eta**2]
# [c*deltaT**6*theta*cos(theta)**3/eta**2]
# [c*deltaT**6*theta*cos(theta)**3/eta**2]
# [c*deltaT**6*theta*cos(theta)**3/eta**2]
# [c*deltaT**6*theta*cos(theta)**3/eta**2]
# [c*deltaT**6*theta*cos(theta)**3/eta**2]
# [c*deltaT**6*theta*cos(theta)**3/eta**2]
# [c*deltaT**6*theta*cos(theta)**3/eta**2]
# [c*deltaT*cos(theta)**2/eta**3]
# [c*deltaT*cos(theta)**2/eta**3]
# [c*deltaT*cos(theta)**2/eta**3]
# [c*deltaT*cos(theta)**2/eta**3]
# [c*deltaT*cos(theta)**2/eta**3]
# [c*deltaT*cos(theta)**2/eta**3]
# [c*deltaT*cos(theta)**2/eta**3]
# [c*deltaT*cos(theta)**2/eta**3]
# [c*deltaT*cos(theta)**2/eta**3]
# [c*deltaT*cos(theta)**2/eta**3]
# [c*deltaT*cos(theta)**2/eta**3]
# [c*deltaT*cos(theta)**2/eta**3]
# [c*deltaT*cos(theta)**2/eta**3]
# [c*deltaT*cos(theta)**2/eta**3]
# [c*deltaT*cos(theta)**2/eta**3]
# [c*deltaT**4*theta*cos(theta)**2/eta]
# [c*deltaT**4*theta*cos(theta)**2/eta]
# [c*deltaT**4*theta*cos(theta)**2/eta]
# [c*deltaT**4*theta*cos(theta)**2/eta]
# [c*deltaT*cos(theta)**3/eta**2]
# [c*deltaT*cos(theta)**3/eta**2]
# [c*deltaT*cos(theta)**3/eta**2]
# [c*deltaT*cos(theta)**3/eta**2]
# [c*deltaT*cos(theta)**3/eta**2]
# [c*deltaT*cos(theta)**3/eta**2]
# [c*deltaT*cos(theta)**3/eta**2]
# [c*deltaT**3*theta*cos(theta)/eta]
# [c*deltaT**3*theta*cos(theta)/eta]
# [c*deltaT**6*theta**2*cos(theta)/eta]
# [c*deltaT**6*theta**2*cos(theta)/eta]
# [c*deltaT**6*theta**2*cos(theta)/eta]
# [c*deltaT**6*theta**2*cos(theta)/eta]
# [c*deltaT**6*theta**2*cos(theta)/eta]
# [c*deltaT**6*theta**2*cos(theta)/eta]
# [c*deltaT**6*theta**2*cos(theta)/eta]
# [c*deltaT**6*theta**2*cos(theta)/eta]
# [c*deltaT**6*theta**2*cos(theta)/eta]
# [c*deltaT**6*theta**2*cos(theta)/eta]
# [c*deltaT**6*theta**2*cos(theta)/eta]
# [c*deltaT**6*theta**2*cos(theta)/eta]
# [c*deltaT**6*theta**2*cos(theta)/eta]
# [c*deltaT**6*theta**2*cos(theta)/eta]
# [c*deltaT**6*theta**2*cos(theta)/eta]
# [c*deltaT**6*theta**2*cos(theta)/eta]
# [c*deltaT**6*theta**2*cos(theta)/eta]
# [c*deltaT**6*theta**2*cos(theta)/eta]
# [c*deltaT**6*theta**2*cos(theta)/eta]
# [c*deltaT**6*theta**2*cos(theta)/eta]
# [c*deltaT**6*theta**2*cos(theta)/eta]
# [c*deltaT**6*theta**2*cos(theta)/eta]
# [c*deltaT**6*theta**2*cos(theta)/eta]
# [c*deltaT*theta**2/eta]
# [c*deltaT*theta**2/eta]
# [c*deltaT*theta**2/eta]
# [c*deltaT*theta**2/eta]
# [c*deltaT**6*cos(theta)**2/eta**3]
# [c*deltaT**6*cos(theta)**2/eta**3]
# [c*deltaT**6*cos(theta)**2/eta**3]
# [c*deltaT**2*theta/eta]
# [c*deltaT**2*theta/eta]
# [c*deltaT**2*theta/eta]
# [c*deltaT**2*theta/eta]
# [c*deltaT**2*theta/eta]
# [c*deltaT**2*theta**2*cos(theta)/eta**3]
# [c*deltaT**2*theta**2*cos(theta)/eta**3]
# [c*deltaT**2*theta**2*cos(theta)/eta**3]
# [c*deltaT**2*theta**2*cos(theta)/eta**3]
# [c*deltaT**2*theta**2*cos(theta)/eta**3]
# [c*deltaT**2*theta**2*cos(theta)/eta**3]
# [c*deltaT**2*theta**2*cos(theta)/eta**3]
# [c*deltaT**2*theta**2*cos(theta)/eta**3]
# [c*deltaT**2*theta**2*cos(theta)/eta**3]
# [c*deltaT**2*theta**2*cos(theta)/eta**3]
# [c*deltaT**2*theta**2*cos(theta)/eta**3]
# [c*deltaT**2*theta**2*cos(theta)/eta**3]
# [c*deltaT**2*theta*cos(theta)**2]
# [c*deltaT**2*theta*cos(theta)**2]
# [c*deltaT**2*theta*cos(theta)**2]
# [c*deltaT**2*theta*cos(theta)**2]
# [c*deltaT**2*theta*cos(theta)**2]
# [c*deltaT**2*theta*cos(theta)**2]
# [c*deltaT**2*theta*cos(theta)**2]
# [c*deltaT**2*theta*cos(theta)**2]
# [c*deltaT**2*theta*cos(theta)**2]
# [c*deltaT**2*theta*cos(theta)**2]
# [c*deltaT**2*theta*cos(theta)**2]
# [c*deltaT**2*theta*cos(theta)**2]
# [c*deltaT**2*theta*cos(theta)**2]
# [c*deltaT**2*cos(theta)**3/eta**2]
# [c*deltaT**2*cos(theta)**3/eta**2]
# [c*deltaT**2*cos(theta)**3/eta**2]
# [c*deltaT**2*cos(theta)**3/eta**2]
# [c*deltaT**2*cos(theta)**3/eta**2]
# [c*deltaT**2*theta*cos(theta)**2/eta**3]
# [c*deltaT**2*theta*cos(theta)**2/eta**3]
# [c*deltaT**2*theta*cos(theta)**2/eta**3]
# [c*deltaT**2*theta*cos(theta)**2/eta**3]
# [c*deltaT**3*theta**2*cos(theta)**2/eta]
# [c*deltaT**3*theta**2*cos(theta)**2/eta]
# [c*deltaT**3*theta**2*cos(theta)**2/eta]
# [c*deltaT**3*theta**2*cos(theta)**2/eta]
# [c*deltaT**3*theta**2*cos(theta)**2/eta]
# [c*cos(theta)/eta**5]
# [c*cos(theta)/eta**5]
# [c*cos(theta)/eta**5]
# [c*cos(theta)/eta**5]
# [c*cos(theta)/eta**5]
# [c*cos(theta)/eta**5]
# [c*deltaT**2*cos(theta)**3/eta**3]
# [c*deltaT**2*cos(theta)**3/eta**3]
# [c*deltaT**2*cos(theta)**3/eta**3]
# [c*deltaT**2*cos(theta)**3/eta**3]
# [c*deltaT**2*cos(theta)**3/eta**3]
# [c*deltaT**2*cos(theta)**3/eta**3]
# [c*deltaT**2*cos(theta)**3/eta**3]
# [c*deltaT**2*cos(theta)**3/eta**3]
# [c*deltaT**2*cos(theta)**3/eta**3]
# [c*deltaT**2*cos(theta)**3/eta**3]
# [c*deltaT**2*cos(theta)**3/eta**3]
# [c*deltaT**2*cos(theta)**3/eta**3]
# [c*deltaT**2*cos(theta)**3/eta**3]
# [c*deltaT**2*cos(theta)**3/eta**3]
# [c*deltaT**2*cos(theta)**3/eta**3]
# [c*cos(theta)**4/eta]
# [c*cos(theta)**4/eta]
# [c*cos(theta)**4/eta]
# [c*cos(theta)**4/eta]
# [c*cos(theta)**4/eta]
# [c*deltaT**2*theta*cos(theta)]
# [c*deltaT**2*theta*cos(theta)]
# [c*deltaT**2*theta*cos(theta)]
# [c*deltaT**2*theta*cos(theta)]
# [c*deltaT**2*theta*cos(theta)]
# [c*deltaT**2*theta*cos(theta)]
# [c*deltaT**3*cos(theta)**2/eta]
# [c*deltaT**3*cos(theta)**2/eta]
# [c*deltaT**3*cos(theta)**2/eta]
# [c*deltaT**3*cos(theta)**2/eta]
# [c*deltaT**3*cos(theta)**2/eta]
# [c*deltaT**3*cos(theta)**2/eta]
# [c*deltaT**3*cos(theta)**2/eta]
# [c*deltaT**3*cos(theta)**2/eta]
# [c*deltaT**3*cos(theta)**2/eta]
# [c*deltaT**3*cos(theta)**2/eta]
# [c*deltaT**3*cos(theta)**2/eta]
# [c*deltaT**3*cos(theta)**2/eta]
# [c*theta**2*cos(theta)**2/eta**3]
# [c*theta**2*cos(theta)**2/eta**3]
# [c*theta**2*cos(theta)**2/eta**3]
# [c*theta**2*cos(theta)**2/eta**3]
# [c*theta*cos(theta)**4/eta]
# [c*theta*cos(theta)**4/eta]
# [c*theta*cos(theta)**4/eta]
# [c*theta*cos(theta)**4/eta]
# [c*theta*cos(theta)**4/eta]
# [c*theta*cos(theta)**4/eta]
# [c*theta*cos(theta)**4/eta]
# [c*theta*cos(theta)**4/eta]
# [c*theta*cos(theta)**4/eta]
# [c*deltaT**2*theta*cos(theta)**2/eta**2]
# [c*deltaT**2*theta*cos(theta)**2/eta**2]
# [c*deltaT**2*theta*cos(theta)**2/eta**2]
# [c*deltaT**2*theta*cos(theta)**2/eta**2]
# [c*deltaT**2*theta*cos(theta)**2/eta**2]
# [c*deltaT**2*theta*cos(theta)**2/eta**2]
# [c*deltaT**2*theta*cos(theta)**2/eta**2]
# [c*deltaT**2*theta*cos(theta)**2/eta**2]
# [c*deltaT**2*theta*cos(theta)**2/eta**2]
# [c*deltaT**2*theta*cos(theta)**2/eta**2]
# [c*deltaT**2*theta*cos(theta)**2/eta**2]
# [c*deltaT**2*theta*cos(theta)**2/eta**2]
# [c*deltaT**2*theta*cos(theta)**2/eta**2]
# [c*deltaT**2*theta*cos(theta)**2/eta**2]
# [c*deltaT**2*theta*cos(theta)**2/eta**2]
# [c*deltaT**2*theta*cos(theta)**2/eta**2]
# [c*deltaT**2*theta*cos(theta)**2/eta**2]
# [c*deltaT**2*theta*cos(theta)**2/eta**2]
# [c*deltaT**2*theta*cos(theta)**2/eta**2]
# [c*deltaT**2*theta*cos(theta)**2/eta**2]
# [c*deltaT**2*theta*cos(theta)**2/eta**2]
# [c*deltaT**2*theta*cos(theta)**2/eta**2]
# [c*deltaT**2*theta*cos(theta)**2/eta**2]
# [c*deltaT**2*theta*cos(theta)**2/eta**2]
# [c*deltaT**2*theta*cos(theta)**2/eta**2]
# [c*deltaT**2*theta*cos(theta)**2/eta**2]
# [c*deltaT**2*theta*cos(theta)**2/eta**2]
# [c*deltaT**2*theta*cos(theta)**2/eta**2]
# [c*deltaT**2*theta*cos(theta)**2/eta**2]
# [c*deltaT**2*theta*cos(theta)**2/eta**2]
# [c*deltaT**2*theta*cos(theta)**2/eta**2]
# [c*deltaT**2*theta*cos(theta)**2/eta**2]
# [c*deltaT**2*theta*cos(theta)**2/eta**2]
# [c*deltaT**2*theta*cos(theta)**2/eta**2]
# [c*deltaT**2*theta*cos(theta)**2/eta**2]
# [c*deltaT*theta*cos(theta)**2/eta**2]
# [c*deltaT*theta*cos(theta)**2/eta**2]
# [c*deltaT*theta*cos(theta)**2/eta**2]
# [c*deltaT**4*theta]
# [c*deltaT**4*theta]
# [c*deltaT**4*theta]
# [c*deltaT**4*theta]
# [c*theta*cos(theta)/eta**3]
# [c*theta*cos(theta)/eta**3]
# [c*theta*cos(theta)/eta**3]
# [c*theta*cos(theta)/eta**3]
# [c*theta*cos(theta)/eta**3]
# [c*theta*cos(theta)/eta**3]
# [c*theta*cos(theta)/eta**3]
# [c*theta*cos(theta)/eta**3]
# [c*theta*cos(theta)/eta**3]
# [c*theta*cos(theta)/eta**3]
# [c*theta*cos(theta)/eta**3]
# [c*theta*cos(theta)/eta**3]
# [c*theta*cos(theta)/eta**3]
# [c*theta*cos(theta)/eta**3]
# [c*theta*cos(theta)/eta**3]
# [c*theta*cos(theta)/eta**3]
# [c*theta*cos(theta)/eta**3]
# [c*theta*cos(theta)/eta**3]
# [c*theta*cos(theta)/eta**3]
# [c*theta*cos(theta)/eta**3]
# [c*theta*cos(theta)/eta**3]
# [c*theta*cos(theta)/eta**3]
# [c*theta*cos(theta)/eta**3]
# [c*theta*cos(theta)/eta**3]
# [c*theta*cos(theta)/eta**3]
# [c*theta*cos(theta)/eta**3]
# [c*theta*cos(theta)/eta**3]
# [c*theta*cos(theta)/eta**3]
# [c*theta*cos(theta)/eta**3]
# [c*theta*cos(theta)/eta**3]
# [c*theta*cos(theta)/eta**3]
# [c*theta*cos(theta)/eta**3]
# [c*theta*cos(theta)/eta**3]
# [c*theta*cos(theta)/eta**3]
# [c*theta*cos(theta)/eta**3]
# [c*theta*cos(theta)/eta**3]
# [c*theta*cos(theta)/eta**3]
# [c*theta*cos(theta)/eta**3]
# [c*theta*cos(theta)/eta**3]
# [c*theta*cos(theta)/eta**3]
# [c*theta*cos(theta)/eta**3]
# [c*theta*cos(theta)/eta**3]
# [c*deltaT**3/eta**2]
# [c*deltaT/eta**5]
# [c*deltaT/eta**5]
# [c*deltaT**5*theta*cos(theta)**2]
# [c*deltaT**5*theta*cos(theta)**2]
# [c*deltaT**5*theta*cos(theta)**2]
# [c*deltaT**5*theta*cos(theta)**2]
# [c*deltaT**5*theta*cos(theta)**2]
# [c*deltaT**5*theta*cos(theta)**2]
# [c*deltaT**5*theta*cos(theta)**2]
# [c*deltaT**5*theta*cos(theta)**2]
# [c*deltaT**5*theta*cos(theta)**2]
# [c*deltaT**5*theta*cos(theta)**2]
# [c*deltaT**5*theta*cos(theta)**2]
# [c*deltaT**5*theta*cos(theta)**2]
# [c*deltaT**5*theta*cos(theta)**2]
# [c*deltaT**5*theta*cos(theta)**2]
# [c*deltaT**5*theta*cos(theta)**2]
# [c*deltaT**5*theta*cos(theta)**2]
# [c*deltaT**5*theta*cos(theta)**2]
# [c*deltaT**5*theta*cos(theta)**2]
# [c*deltaT**5*theta*cos(theta)**2]
# [c*deltaT**5*theta*cos(theta)**2]
# [c*deltaT**5*theta*cos(theta)**2]
# [c*deltaT**5*theta*cos(theta)**2]
# [c*deltaT**5*theta*cos(theta)**2]
# [c*deltaT*theta**2*cos(theta)**4]
# [c*deltaT*theta**2*cos(theta)**4]
# [c*deltaT*theta**2*cos(theta)**4]
# [c*deltaT*theta**2*cos(theta)**4]
# [c*deltaT*theta**2*cos(theta)**4]
# [c*deltaT*theta**2*cos(theta)**4]
# [c*deltaT*theta**2*cos(theta)**4]
# [c*deltaT*theta**2*cos(theta)**4]
# [c*deltaT*theta**2*cos(theta)**4]
# [c*deltaT*theta**2*cos(theta)**4]
# [c*deltaT*theta**2*cos(theta)**4]
# [c*deltaT*theta**2*cos(theta)**4]
# [c*deltaT*theta**2*cos(theta)**4]
# [c*deltaT*theta**2*cos(theta)**4]
# [c*deltaT*theta**2*cos(theta)**4]
# [c*deltaT*theta**2*cos(theta)**4]
# [c*deltaT*theta**2*cos(theta)**4]
# [c*deltaT*theta**2*cos(theta)**4]
# [c*deltaT*theta**2*cos(theta)**4]
# [c*deltaT*theta**2*cos(theta)**4]
# [c*deltaT*theta**2*cos(theta)**4]
# [c*deltaT**2*theta**2*cos(theta)**3/eta**2]
# [c*deltaT**2*theta**2*cos(theta)**3/eta**2]
# [c*deltaT**2*theta**2*cos(theta)**3/eta**2]
# [c*deltaT**2*theta**2*cos(theta)**3/eta**2]
# [c*deltaT**2*theta**2*cos(theta)**3/eta**2]
# [c*deltaT**2*theta**2*cos(theta)**3/eta**2]
# [c*deltaT**2*theta**2*cos(theta)**3/eta**2]
# [c*deltaT**2*theta**2*cos(theta)**3/eta**2]
# [c*deltaT**2*theta**2*cos(theta)**3/eta**2]
# [c*deltaT**2*theta**2*cos(theta)**3/eta**2]
# [c*deltaT**2*cos(theta)**3/eta**4]
# [c*deltaT**2*cos(theta)**3/eta**4]
# [c*deltaT**2*cos(theta)**3/eta**4]
# [c*deltaT**2*cos(theta)**3/eta**4]
# [c*deltaT**2*cos(theta)**3/eta**4]
# [c*deltaT**2*cos(theta)**3/eta**4]
# [c*deltaT**2*cos(theta)**3/eta**4]
# [c*deltaT**2*cos(theta)**3/eta**4]
# [c*deltaT**2*cos(theta)**3/eta**4]
# [c*deltaT**2*cos(theta)**3/eta**4]
# [c*deltaT**2*cos(theta)**3/eta**4]
# [c*deltaT**2*cos(theta)**3/eta**4]
# [c*deltaT**2*cos(theta)**3/eta**4]
# [c*deltaT**2*cos(theta)**3/eta**4]
# [c*deltaT**2*cos(theta)**3/eta**4]
# [c*theta**2*cos(theta)**3/eta**2]
# [c*theta**2*cos(theta)**3/eta**2]
# [c*theta**2*cos(theta)**3/eta**2]
# [c*theta**2*cos(theta)**3/eta**2]
# [c*theta**2*cos(theta)**3/eta**2]
# [c*theta**2*cos(theta)**3/eta**2]
# [c*theta**2*cos(theta)**3/eta**2]
# [c*theta**2*cos(theta)**3/eta**2]
# [c*theta**2*cos(theta)**3/eta**2]
# [c*theta**2*cos(theta)**3/eta**2]
# [c*theta**2*cos(theta)**3/eta**2]
# [c*theta**2*cos(theta)**3/eta**2]
# [c*theta**2*cos(theta)**3/eta**2]
# [c*theta**2*cos(theta)**3/eta**2]
# [c*theta**2*cos(theta)**3/eta**2]
# [c*theta**2*cos(theta)**3/eta**2]
# [c*theta**2*cos(theta)**3/eta**2]
# [c*theta**2*cos(theta)**3/eta**2]
# [c*theta**2*cos(theta)**3/eta**2]
# [c*theta**2*cos(theta)**3/eta**2]
# [c*theta**2*cos(theta)**3/eta**2]
# [c*theta**2*cos(theta)**3/eta**2]
# [c*theta**2*cos(theta)**3/eta**2]
# [c*theta**2*cos(theta)**3/eta**2]
# [c*theta**2*cos(theta)**3/eta**2]
# [c*theta**2*cos(theta)**3/eta**2]
# [c*theta**2*cos(theta)**3/eta**2]
# [c*theta**2*cos(theta)**3/eta**2]
# [c*theta**2*cos(theta)**3/eta**2]
# [c*theta/eta**4]
# [c*theta/eta**4]
# [c*theta/eta**4]
# [c*theta/eta**4]
# [c*theta/eta**4]
# [c*theta/eta**4]
# [c*theta/eta**4]
# [c*theta/eta**4]
# [c*theta/eta**4]
# [c*theta/eta**4]
# [c*theta/eta**4]
# [c*theta/eta**4]
# [c*theta/eta**4]
# [c*theta/eta**4]
# [c*deltaT**6*cos(theta)/eta]
# [c*deltaT**6*cos(theta)/eta]
# [c*deltaT**6*cos(theta)/eta]
# [c*deltaT**6*cos(theta)/eta]
# [c*deltaT**6*cos(theta)/eta]
# [c*deltaT**6*cos(theta)/eta]
# [c*deltaT**6*cos(theta)/eta]
# [c*deltaT**6*cos(theta)/eta]
# [c*deltaT**6*cos(theta)/eta]
# [c*deltaT**6*cos(theta)/eta]
# [c*deltaT**6*cos(theta)/eta]
# [c*deltaT**6*cos(theta)/eta]
# [c*deltaT**6*cos(theta)/eta]
# [c*deltaT**6*cos(theta)/eta]
# [c*deltaT**6*cos(theta)/eta]
# [c*deltaT**6*cos(theta)/eta]
# [c*deltaT*cos(theta)**5/eta**2]
# [c*deltaT*cos(theta)**5/eta**2]
# [c*deltaT*cos(theta)**5/eta**2]
# [c*deltaT*cos(theta)**5/eta**2]
# [c*deltaT*cos(theta)**5/eta**2]
# [c*deltaT*cos(theta)**5/eta**2]
# [c*deltaT**2*theta**2/eta]
# [c*deltaT**2*theta**2/eta]
# [c*deltaT**2*theta**2/eta]
# [c*deltaT**2*theta**2/eta]
# [c*deltaT**2*theta**2/eta]
# [c*deltaT**2*theta**2/eta]
# [c*deltaT**2*theta**2/eta]
# [c*deltaT**2*theta**2/eta]
# [c*deltaT**2*theta**2/eta]
# [c*theta**2*cos(theta)]
# [c*theta**2*cos(theta)]
# [c*theta**2*cos(theta)]
# [c*theta**2*cos(theta)]
# [c*theta**2*cos(theta)]
# [c*theta**2*cos(theta)]
# [c*theta**2*cos(theta)]
# [c*theta**2*cos(theta)]
# [c*theta**2*cos(theta)]
# [c*theta**2*cos(theta)]
# [c*theta**2*cos(theta)]
# [c*theta**2*cos(theta)]
# [c*theta**2*cos(theta)]
# [c*theta**2*cos(theta)]
# [c*deltaT**2*theta**2*cos(theta)**2/eta**3]
# [c*deltaT**2*theta**2*cos(theta)**2/eta**3]
# [c*deltaT**2*theta**2*cos(theta)**2/eta**3]
# [c*deltaT**2*theta**2*cos(theta)**2/eta**3]
# [c*deltaT**2*theta**2*cos(theta)**2/eta**3]
# [c*deltaT**2*theta**2*cos(theta)**2/eta**3]
# [c*deltaT**2*theta**2*cos(theta)**2/eta**3]
# [c*deltaT**2*theta**2*cos(theta)**2/eta**3]
# [c*deltaT*theta/eta**5]
# [c*deltaT*theta/eta**5]
# [c*deltaT*theta/eta**5]
# [c*deltaT*theta/eta**5]
# [c*deltaT*theta/eta**5]
# [c*theta**3*cos(theta)/eta]
# [c*theta**3*cos(theta)/eta]
# [c*theta**3*cos(theta)/eta]
# [c*theta**3*cos(theta)/eta]
# [c*theta**3*cos(theta)/eta]
# [c*theta**3*cos(theta)/eta]
# [c*theta**3*cos(theta)/eta]
# [c*theta**3*cos(theta)/eta]
# [c*theta**3*cos(theta)/eta]
# [c*theta**3*cos(theta)/eta]
# [c*theta**3*cos(theta)/eta]
# [c*theta**3*cos(theta)/eta]
# [c*theta**3*cos(theta)/eta]
# [c*theta**3*cos(theta)/eta]
# [c*theta**3*cos(theta)/eta]
# [c*theta**3*cos(theta)/eta]
# [c*theta**3*cos(theta)/eta]
# [c*theta**3*cos(theta)/eta]
# [c*theta**3*cos(theta)/eta]
# [c*theta**3*cos(theta)/eta]
# [c*theta**3*cos(theta)/eta]
# [c*theta**3*cos(theta)/eta]
# [c*theta**3*cos(theta)/eta]
# [c*theta**3*cos(theta)/eta]
# [c*theta**3*cos(theta)/eta]
# [c*theta**3*cos(theta)/eta]
# [c*theta**3*cos(theta)/eta]
# [c*deltaT**4*cos(theta)**2/eta]
# [c*deltaT**4*cos(theta)**2/eta]
# [c*deltaT**4*cos(theta)**2/eta]
# [c*deltaT**4*cos(theta)**2/eta]
# [c*deltaT**4*cos(theta)**2/eta]
# [c*deltaT**4*cos(theta)**2/eta]
# [c*deltaT**4*cos(theta)**2/eta]
# [c*deltaT**4*cos(theta)**2/eta]
# [c*deltaT**4*cos(theta)**2/eta]
# [c*deltaT**4*cos(theta)**2/eta]
# [c*deltaT**4*cos(theta)**2/eta]
# [c*deltaT**4*cos(theta)**2/eta]
# [c*deltaT**4*cos(theta)**2/eta]
# [c*deltaT**4*cos(theta)**2/eta]
# [c*theta**2*cos(theta)/eta**2]
# [c*theta**2*cos(theta)/eta**2]
# [c*deltaT*theta**2*cos(theta)**3]
# [c*deltaT**5*cos(theta)**5/eta**3]
# [c*deltaT**5*cos(theta)**5/eta**3]
# [c*deltaT**5*cos(theta)**5/eta**3]
# [c*deltaT**5*cos(theta)**5/eta**3]
# [c*deltaT**5*cos(theta)**5/eta**3]
# [c*deltaT**5*cos(theta)**5/eta**3]
# [c*deltaT**5*cos(theta)**5/eta**3]
# [c*deltaT**5*cos(theta)**5/eta**3]
# [c*deltaT**5*cos(theta)**5/eta**3]
# [c*deltaT**5*cos(theta)**5/eta**3]
# [c*deltaT*theta*cos(theta)**2/eta]
# [c*deltaT*theta*cos(theta)**2/eta]
# [c*deltaT*theta*cos(theta)**2/eta]
# [c*deltaT*theta*cos(theta)**2/eta]
# [c*deltaT*theta*cos(theta)**2/eta]
# [c*deltaT*theta*cos(theta)**2/eta]
# [c*deltaT*theta*cos(theta)**2/eta]
# [c*deltaT*theta*cos(theta)**2/eta]
# [c*deltaT*theta*cos(theta)**2/eta]
# [c*theta**2*cos(theta)**3]
# [c*theta**2*cos(theta)**3]
# [c*theta**2*cos(theta)**3]
# [c*theta**2*cos(theta)**3]
# [c*theta**2*cos(theta)**3]
# [c*theta**2*cos(theta)**3]
# [c*theta**2*cos(theta)**3]
# [c*theta**2*cos(theta)**3]
# [c*theta**2*cos(theta)**3]
# [c*theta**2*cos(theta)**3]
# [c*theta**2*cos(theta)**3]
# [c*theta**2*cos(theta)**3]
# [c*theta**2*cos(theta)**3]
# [c*theta**2*cos(theta)**3]
# [c*theta**2*cos(theta)**3]
# [c*theta**2*cos(theta)**3]
# [c*theta**2*cos(theta)**3]
# [c*theta**2*cos(theta)**3]
# [c*theta**2*cos(theta)**3]
# [c*theta**2*cos(theta)**3]
# [c*theta**2*cos(theta)**3]
# [c*theta**2*cos(theta)**3]
# [c*theta**2*cos(theta)**3]
# [c*theta**2*cos(theta)**3]
# [c*theta**2*cos(theta)**3]
# [c*theta**2*cos(theta)**3]
# [c*theta**2*cos(theta)**3]
# [c*theta**2*cos(theta)**3]
# [c*theta**2*cos(theta)**3]
# [c*theta**2*cos(theta)**3]
# [c*theta**2*cos(theta)**3]
# [c*theta**2*cos(theta)**3]
# [c*theta**2*cos(theta)**3]
# [c*theta**2*cos(theta)**3]
# [c*theta**2*cos(theta)**3]
# [c*theta**2*cos(theta)**3]
# [c*cos(theta)**2/eta**3]
# [c*cos(theta)**2/eta**3]
# [c*cos(theta)**2/eta**3]
# [c*cos(theta)**2/eta**3]
# [c*cos(theta)**2/eta**3]
# [c*cos(theta)**2/eta**3]
# [c*cos(theta)**2/eta**3]
# [c*cos(theta)**2/eta**3]
# [c*cos(theta)**2/eta**3]
# [c*cos(theta)**2/eta**3]
# [c*cos(theta)**2/eta**3]
# [c*cos(theta)**2/eta**3]
# [c*cos(theta)**2/eta**3]
# [c*cos(theta)**2/eta**3]
# [c*cos(theta)**2/eta**3]
# [c*cos(theta)**2/eta**3]
# [c*cos(theta)**2/eta**3]
# [c*cos(theta)**2/eta**3]
# [c*cos(theta)**2/eta**3]
# [c*cos(theta)**2/eta**3]
# [c*cos(theta)**2/eta**3]
# [c*cos(theta)**2/eta**3]
# [c*cos(theta)**2/eta**3]
# [c*cos(theta)**2/eta**3]
# [c*cos(theta)**2/eta**3]
# [c*cos(theta)**2/eta**3]
# [c*cos(theta)**2/eta**3]
# [c*cos(theta)**2/eta**3]
# [c*cos(theta)**2/eta**3]
# [c*cos(theta)**2/eta**3]
# [c*cos(theta)**2/eta**3]
# [c*cos(theta)**2/eta**3]
# [c*cos(theta)**2/eta**3]
# [c*cos(theta)**2/eta**3]
# [c*cos(theta)**2/eta**3]
# [c*cos(theta)**2/eta**3]
# [c*deltaT**3*theta*cos(theta)]
# [c*deltaT**3*theta*cos(theta)]
# [c*deltaT**3*theta*cos(theta)]
# [c*deltaT**3*theta*cos(theta)]
# [c*deltaT**2/eta**2]
# [c*deltaT**2/eta**2]
# [c*deltaT**2/eta**2]
# [c*deltaT**2/eta**2]
# [c*deltaT**2/eta**2]
# [c*deltaT**2/eta**2]
# [c*deltaT**2/eta**2]
# [c*deltaT**2/eta**2]
# [c*deltaT**2/eta**2]
# [c*deltaT**2/eta**2]
# [c*deltaT**2/eta**2]
# [c*deltaT**2/eta**2]
# [c*deltaT**2/eta**2]
# [c*deltaT**2/eta**2]
# [c*deltaT**2/eta**2]
# [c*deltaT**2/eta**2]
# [c*deltaT**3*cos(theta)/eta**6]
# [c*deltaT**3*cos(theta)/eta**6]
# [c*deltaT**3*cos(theta)/eta**6]
# [c*deltaT**3*cos(theta)/eta**6]
# [c*deltaT**3*cos(theta)/eta**6]
# [c*deltaT**3*cos(theta)/eta**6]
# [c*deltaT**3*cos(theta)/eta**6]
# [c*deltaT**4*theta/eta**2]
# [c*deltaT**4*theta/eta**2]
# [c*deltaT**4*theta/eta**2]
# [c*deltaT**4*theta/eta**2]
# [c*deltaT**4*theta/eta**2]
# [c*deltaT**4*theta/eta**2]
# [c*deltaT**4*theta**2*cos(theta)**3/eta**2]
# [c*deltaT**4*theta**2*cos(theta)**3/eta**2]
# [c*deltaT**4*theta**2*cos(theta)**3/eta**2]
# [c*deltaT**4*theta**2*cos(theta)**3/eta**2]
# [c*deltaT**4*theta**2*cos(theta)**3/eta**2]
# [c*deltaT**4*theta**2*cos(theta)**3/eta**2]
# [c*deltaT**4*theta**2*cos(theta)**3/eta**2]
# [c*deltaT**4*theta**2*cos(theta)**3/eta**2]
# [c*deltaT**4*theta**2*cos(theta)**3/eta**2]
# [c*deltaT**4*theta**2*cos(theta)**3/eta**2]
# [c*deltaT**4*theta**2*cos(theta)**3/eta**2]
# [c*deltaT**4*theta**2*cos(theta)**3/eta**2]
# [c*theta**2/eta]
# [c*theta**2/eta]
# [c*theta**2/eta]
# [c*theta**2/eta]
# [c*theta**2/eta]
# [c*theta**2/eta]
# [c*theta**2/eta]
# [c*theta**2/eta]
# [c*theta**2/eta]
# [c*cos(theta)/eta**3]
# [c*cos(theta)/eta**3]
# [c*cos(theta)/eta**3]
# [c*cos(theta)/eta**3]
# [c*cos(theta)/eta**3]
# [c*cos(theta)/eta**3]
# [c*cos(theta)/eta**3]
# [c*cos(theta)/eta**3]
# [c*cos(theta)/eta**3]
# [c*deltaT**2*theta**2*cos(theta)]
# [c*deltaT**2*theta**2*cos(theta)]
# [c*deltaT**2*theta**2*cos(theta)]
# [c*deltaT**2*theta**2*cos(theta)]
# [c*deltaT**2*theta**2*cos(theta)]
# [c*deltaT**2*theta**2*cos(theta)]
# [c*theta**2*cos(theta)**2/eta**2]
# [c*theta**2*cos(theta)**2/eta**2]
# [c*theta**2*cos(theta)**2/eta**2]
# [c*theta**2*cos(theta)**2/eta**2]
# [c*theta**2*cos(theta)**2/eta**2]
# [c*theta**2*cos(theta)**2/eta**2]
# [c*theta**2*cos(theta)**2/eta**2]
# [c*theta**2*cos(theta)**2/eta**2]
# [c*theta**2*cos(theta)**2/eta**2]
# [c*theta**2*cos(theta)**2/eta**2]
# [c*theta**2*cos(theta)**2/eta**2]
# [c*theta**2*cos(theta)**2/eta**2]
# [c*theta**2*cos(theta)**2/eta**2]
# [c*theta**2*cos(theta)**2/eta**2]
# [c*theta**2*cos(theta)**2/eta**2]
# [c*theta**2*cos(theta)**2/eta**2]
# [c*theta**2*cos(theta)**2/eta**2]
# [c*theta**2*cos(theta)**2/eta**2]
# [c*deltaT*theta*cos(theta)/eta**3]
# [c*deltaT*theta*cos(theta)/eta**3]
# [c*deltaT*theta*cos(theta)/eta**3]
# [c*deltaT*theta*cos(theta)/eta**3]
# [c*deltaT*theta*cos(theta)/eta**3]
# [c*deltaT*theta*cos(theta)/eta**3]
# [c*deltaT**3*theta*cos(theta)**4/eta]
# [c*deltaT**3*theta*cos(theta)**4/eta]
# [c*deltaT**3*theta*cos(theta)**4/eta]
# [c*deltaT**3*theta*cos(theta)**4/eta]
# [c*deltaT**4*cos(theta)/eta**3]
# [c*deltaT**4*cos(theta)/eta**3]
# [c*deltaT**4*cos(theta)/eta**3]
# [c*deltaT**4*cos(theta)/eta**3]
# [c*deltaT**4*cos(theta)/eta**3]
# [c*deltaT**4*cos(theta)/eta**3]
# [c*deltaT**4*cos(theta)/eta**3]
# [c*deltaT**4*cos(theta)/eta**3]
# [c*deltaT**4*cos(theta)/eta**3]
# [c*deltaT**4*cos(theta)/eta**3]
# [c*deltaT**4*cos(theta)/eta**3]
# [c*deltaT**3*cos(theta)/eta**2]
# [c*deltaT**3*cos(theta)/eta**2]
# [c*deltaT**3*cos(theta)/eta**2]
# [c*deltaT**3*cos(theta)/eta**2]
# [c*deltaT**3*cos(theta)/eta**2]
# [c*deltaT**3*cos(theta)/eta**2]
# [c*deltaT**3*cos(theta)/eta**2]
# [c*deltaT**3*cos(theta)/eta**2]
# [c*deltaT**3*cos(theta)/eta**2]
# [c*deltaT**3*cos(theta)/eta**2]
# [c*deltaT**3*cos(theta)/eta**2]
# [c*deltaT**5*cos(theta)/eta**2]
# [c*deltaT**5*cos(theta)/eta**2]
# [c*deltaT**5*cos(theta)/eta**2]
# [c*deltaT**5*cos(theta)/eta**2]
# [c*deltaT**5*cos(theta)/eta**2]
# [c*deltaT**5*cos(theta)/eta**2]
# [c*deltaT**5*cos(theta)/eta**2]
# [c*deltaT**5*cos(theta)/eta**2]
# [c*deltaT**5*cos(theta)/eta**2]
# [c*deltaT**5*cos(theta)/eta**2]
# [c*deltaT**5*cos(theta)/eta**2]
# [c*deltaT**5*cos(theta)/eta**2]
# [c*deltaT**5*cos(theta)/eta**2]
# [c*deltaT**5*cos(theta)/eta**2]
# [c*deltaT**5*cos(theta)/eta**2]
# [c*deltaT**5*cos(theta)/eta**2]
# [c*deltaT**5*cos(theta)/eta**2]
# [c*deltaT**5*cos(theta)/eta**2]
# [c*deltaT**5*cos(theta)/eta**2]
# [c*deltaT**5*cos(theta)**2/eta**2]
# [c*deltaT**5*cos(theta)**2/eta**2]
# [c*deltaT**5*cos(theta)**2/eta**2]
# [c*deltaT**5*cos(theta)**2/eta**2]
# [c*deltaT**5*cos(theta)**2/eta**2]
# [c*deltaT**5*cos(theta)**2/eta**2]
# [c*deltaT**5*cos(theta)**2/eta**2]
# [c*deltaT**5*cos(theta)**2/eta**2]
# [c*deltaT**5*cos(theta)**2/eta**2]
# [c*deltaT**5*cos(theta)**2/eta**2]
# [c*deltaT**5*cos(theta)**2/eta**2]
# [c*deltaT**5*cos(theta)**2/eta**2]
# [c*deltaT**5*cos(theta)**2/eta**2]
# [c*deltaT**5*cos(theta)**2/eta**2]
# [c*deltaT**5*cos(theta)**2/eta**2]
# [c*deltaT**5*cos(theta)**2/eta**2]
# [c*deltaT**5*cos(theta)**2/eta**2]
# [c*deltaT**5*cos(theta)**2/eta**2]
# [c*deltaT**5*cos(theta)**2/eta**2]
# [c*deltaT**5*cos(theta)**2/eta**2]
# [c*deltaT**5*cos(theta)**2/eta**2]
# [c*deltaT**5*cos(theta)**2/eta**2]
# [c*deltaT**5*cos(theta)**2/eta**2]
# [c*deltaT**5*cos(theta)**2/eta**2]
# [c*deltaT**5*cos(theta)**2/eta**2]
# [c*deltaT**5*cos(theta)**2/eta**2]
# [c*deltaT**5*cos(theta)**2/eta**2]
# [c*deltaT**5*cos(theta)**2/eta**2]
# [c*deltaT**5*cos(theta)**2/eta**2]
# [c*deltaT**5*cos(theta)**2/eta**2]
# [c*deltaT**5*cos(theta)**2/eta**2]
# [c*deltaT**5*cos(theta)**2/eta**2]
# [c*deltaT**5*cos(theta)**2/eta**2]
# [c*deltaT**5*cos(theta)**2/eta**2]
# [c*deltaT**5*cos(theta)**2/eta**2]
# [c*deltaT**5*cos(theta)**2/eta**2]
# [c*deltaT**5*cos(theta)**2/eta**2]
# [c*deltaT**5*cos(theta)**2/eta**2]
# [c*deltaT**5*cos(theta)**2/eta**2]
# [c*deltaT**2*theta**2*cos(theta)**2/eta]
# [c*deltaT**2*theta**2*cos(theta)**2/eta]
# [c*deltaT**2*theta**2*cos(theta)**2/eta]
# [c*deltaT**2*theta**2*cos(theta)**2/eta]
# [c*deltaT**2*theta**2*cos(theta)**2/eta]
# [c*deltaT**2*theta**2*cos(theta)**2/eta]
# [c*deltaT**2*theta**2*cos(theta)**2/eta]
# [c*deltaT**2*theta**2*cos(theta)**2/eta]
# [c*deltaT**2*theta**2*cos(theta)**2/eta]
# [c*deltaT**2*theta**2*cos(theta)**2/eta]
# [c*deltaT**2*theta**2*cos(theta)**2/eta]
# [c*deltaT**2*theta**2*cos(theta)**2/eta]
# [c*deltaT**2*theta**2*cos(theta)**2/eta]
# [c*deltaT**2*theta**2*cos(theta)**2/eta]
# [c*deltaT**2*theta**2*cos(theta)**2/eta]
# [c*deltaT**2*theta**2*cos(theta)**2/eta]
# [c*deltaT**2*theta**2*cos(theta)**2/eta]
# [c*deltaT**2*theta**2*cos(theta)**2/eta]
# [c*deltaT**2*theta**2*cos(theta)**2/eta]
# [c*deltaT**2*theta**2*cos(theta)**2/eta]
# [c*deltaT**2*theta**2*cos(theta)**2/eta]
# [c*deltaT**2*theta**2*cos(theta)**2/eta]
# [c*deltaT**2*theta**2*cos(theta)**2/eta]
# [c*deltaT**2*theta**2*cos(theta)**2/eta]
# [c*deltaT**2*theta**2*cos(theta)**2/eta]
# [c*deltaT**2*theta**2*cos(theta)**2/eta]
# [c*deltaT**2*theta**2*cos(theta)**2/eta]
# [c*deltaT**2*theta**2*cos(theta)**2/eta]
# [c*deltaT**2*theta**2*cos(theta)**2/eta]
# [c*deltaT**2*theta**2*cos(theta)**2/eta]
# [c*deltaT**2*theta**2*cos(theta)**2/eta]
# [c*deltaT**2*theta**2*cos(theta)**2/eta]
# [c*deltaT**2*theta**2*cos(theta)**2/eta]
# [c*deltaT**2*theta**2*cos(theta)**2/eta]
# [c*deltaT**2*theta**2*cos(theta)**2/eta]
# [c*deltaT**2*theta**2*cos(theta)**2/eta]
# [c*deltaT**2*theta**2*cos(theta)**2/eta]
# [c*deltaT**2*theta**2*cos(theta)**2/eta]
# [c*deltaT**2*theta**2*cos(theta)**2/eta]
# [c*deltaT**2*theta**2*cos(theta)**2/eta]
# [c*deltaT**2*theta**2*cos(theta)**2/eta]
# [c*deltaT**2*theta**2*cos(theta)**2/eta]
# [c*deltaT**2*theta**2*cos(theta)**2/eta]
# [c*deltaT**2*theta**2*cos(theta)**2/eta]
# [c*deltaT**2*theta**2*cos(theta)**2/eta]
# [c*deltaT**2*theta**2*cos(theta)**2/eta]
# [c*deltaT**2*theta**2*cos(theta)**2/eta]
# [c*deltaT**2*theta**2*cos(theta)**2/eta]
# [c*deltaT**2*theta**2*cos(theta)**2/eta]
# [c*deltaT**2*theta**2*cos(theta)**2/eta]
# [c*deltaT**2*theta**2*cos(theta)**2/eta]
# [c*deltaT**2*theta**2*cos(theta)**2/eta**2]
# [c*deltaT**2*theta**2*cos(theta)**2/eta**2]
# [c*deltaT**2*theta**2*cos(theta)**2/eta**2]
# [c*deltaT**2*theta**2*cos(theta)**2/eta**2]
# [c*deltaT**2*theta**2*cos(theta)**2/eta**2]
# [c*deltaT**2*theta**2*cos(theta)**2/eta**2]
# [c*deltaT*cos(theta)**3/eta]
# [c*deltaT*cos(theta)**3/eta]
# [c*deltaT*cos(theta)**3/eta]
# [c*theta*cos(theta)/eta**5]
# [c*theta*cos(theta)/eta**5]
# [c*theta*cos(theta)/eta**5]
# [c*theta*cos(theta)/eta**5]
# [c*theta*cos(theta)/eta**5]
# [c*theta*cos(theta)/eta**5]
# [c*theta*cos(theta)/eta**5]
# [c*theta*cos(theta)/eta**5]
# [c*theta*cos(theta)/eta**5]
# [c*theta*cos(theta)/eta**5]
# [c*theta*cos(theta)/eta**5]
# [c*theta*cos(theta)/eta**5]
# [c*theta*cos(theta)/eta**5]
# [c*theta*cos(theta)/eta**5]
# [c*theta*cos(theta)/eta**5]
# [c*theta*cos(theta)/eta**5]
# [c*theta*cos(theta)/eta**5]
# [c*theta*cos(theta)/eta**5]
# [c*theta*cos(theta)/eta**5]
# [c*deltaT*theta*cos(theta)**3/eta**3]
# [c*deltaT**4*cos(theta)/eta**4]
# [c*deltaT**4*cos(theta)/eta**4]
# [c*deltaT**4*cos(theta)/eta**4]
# [c*deltaT**4*cos(theta)/eta**4]
# [c*deltaT**4*cos(theta)/eta**4]
# [c*deltaT**4*cos(theta)/eta**4]
# [c*deltaT**4*cos(theta)/eta**4]
# [c*cos(theta)**3/eta**3]
# [c*cos(theta)**3/eta**3]
# [c*cos(theta)**3/eta**3]
# [c*cos(theta)**3/eta**3]
# [c*cos(theta)**3/eta**3]
# [c*cos(theta)**3/eta**3]
# [c*cos(theta)**3/eta**3]
# [c*cos(theta)**3/eta**3]
# [c*cos(theta)**3/eta**3]
# [c*cos(theta)**3/eta**3]
# ...
# -> [c*deltaT**4*theta*cos(theta)**3], p = 2.448880127999999e-07
# -> [c*deltaT**3*theta**3*cos(theta)/eta**3], p = 8.815968460799998e-10
# -> [c*deltaT**4*cos(theta)**2/eta**4], p = 4.760622968831997e-08
# -> [c*deltaT**3*cos(theta)**3], p = 0.00020407334399999996
# -> [c*deltaT**2*theta*cos(theta)/eta**7], p = 1.4281868906495992e-09
# -> [c*deltaT*theta**3/eta**5], p = 9.795520512e-09
# -> [c*deltaT**3*theta/eta**3], p = 5.441955839999999e-06
# -> [c*deltaT**3*theta/eta**5], p = 8.815968460799997e-08
# -> [c*deltaT**2*theta*cos(theta)/eta**3], p = 9.523422719999997e-06
# -> [c*deltaT*theta**2*cos(theta)/eta**2], p = 1.7635967999999998e-05
# -> [c*deltaT**3*theta**2*cos(theta)**4/eta], p = 5.289581076479998e-09
# -> [c*deltaT**2*theta**2/eta**3], p = 4.5349631999999997e-07
# -> [c*deltaT**4*theta**2*cos(theta)**2/eta**2], p = 2.644790538239998e-09
# -> [c*deltaT**2*theta**3*cos(theta)**2/eta], p = 2.720977919999999e-08
# -> [c*deltaT**2*cos(theta)**4/eta], p = 2.8570268159999983e-05
# -> [c*deltaT*theta**2*cos(theta)**5/eta**2], p = 5.289581076479998e-09
# -> [c*deltaT**3*theta**2/eta], p = 5.038848e-06
# -> [c*deltaT**3*cos(theta)/eta**4], p = 2.203992115199999e-06
# -> [c*deltaT**5*theta/eta**2], p = 4.897760255999998e-07
# -> [c*deltaT**2*theta**2*cos(theta)**4/eta**5], p = 1.542441841901567e-11
# -> [c*deltaT**5*theta*cos(theta)**4/eta**6], p = 2.698656246590981e-13
# -> [c*deltaT**5*cos(theta)/eta**3], p = 5.289581076479997e-07
# -> [c*deltaT*cos(theta)**7/eta], p = 1.3223952691199992e-07
# -> [c*deltaT*cos(theta)**5/eta**4], p = 2.3803114844159985e-08
# -> [c*cos(theta)**2/eta**4], p = 9.069926399999997e-05
# -> [c*deltaT**3*theta**4*cos(theta)/eta**2], p = 2.938656153599999e-10
# -> [c*deltaT*theta**3*cos(theta)**2], p = 1.679616e-06
# -> [c*deltaT**2/eta**6], p = 7.346640383999997e-07
# -> [c*deltaT**2/eta**4], p = 9.069926399999997e-05
# -> [c*deltaT**3*cos(theta)**2/eta**4], p = 3.9671858073599974e-07
# -> [c*deltaT**3*theta**2*cos(theta)**2], p = 4.5349631999999986e-07
# -> [c*deltaT**5*theta*cos(theta)], p = 4.081466879999999e-06
# -> [c*deltaT**3*theta**2*cos(theta)/eta**3], p = 1.4693280767999997e-08
# -> [c*deltaT**2*cos(theta)**2/eta**4], p = 2.9386561535999988e-06
# -> [c*deltaT**5*theta*cos(theta)/eta], p = 7.346640383999998e-07
# -> [c*deltaT**4*theta**2*cos(theta)**4], p = 2.6447905382399986e-09
# -> [c*deltaT**2*theta*cos(theta)**4/eta], p = 1.2244400639999995e-06
# -> [c*deltaT**3*cos(theta)**3/eta**2], p = 4.407984230399998e-06
# -> [c*deltaT**3*theta*cos(theta)**2/eta**2], p = 1.2244400639999995e-06
# -> [c*deltaT*theta*cos(theta)**3/eta**6], p = 1.4281868906495992e-09
# -> [c*cos(theta)**6/eta], p = 4.081466879999998e-06
# -> [c*deltaT**2*theta**2*cos(theta)**5/eta**2], p = 4.760622968831998e-10
# -> [c*deltaT**2*cos(theta)/eta**4], p = 4.081466879999997e-05
# -> [c*deltaT**5*cos(theta)**2/eta], p = 1.4693280767999994e-06
# -> [c*deltaT**2*cos(theta)**3/eta**5], p = 4.760622968831997e-08
# -> [c*theta*cos(theta)**3/eta**2], p = 3.0233087999999994e-05
# -> [c*theta**3/eta**4], p = 1.5116544e-07
# -> [c*deltaT**3*theta**2*cos(theta)**4], p = 1.4693280767999992e-08
# -> [c*deltaT**6*theta**8*cos(theta)**8/eta**2], p = 1.3598118630822476e-22
# -> [c*deltaT**4*cos(theta)**2], p = 6.802444799999997e-05
# -> [c*cos(theta)**4/eta**5], p = 1.3223952691199992e-07
# -> [c*theta**2/eta**3], p = 6.9984e-05
# -> [c*deltaT**3*theta**2*cos(theta)/eta**2], p = 8.162933759999998e-08
# -> [c*deltaT**2*cos(theta)**4/eta**2], p = 5.142648268799998e-06
# -> [c*theta**3*cos(theta)**3/eta], p = 1.5116544e-07
# -> [c*deltaT**2*theta/eta**5], p = 2.448880127999999e-07
# -> [c*deltaT**2*theta*cos(theta)**3/eta**4], p = 2.3803114844159988e-08
# -> [c*deltaT**2*theta**4*cos(theta)**2/eta**2], p = 2.9386561535999996e-10
# -> [c*deltaT**3*theta**2*cos(theta)**2/eta**4], p = 4.760622968831998e-10
# -> [c*deltaT**4*theta*cos(theta)**6/eta**4], p = 1.4992534703283229e-12
# -> [c*deltaT**3*theta**2/eta**3], p = 8.162933759999998e-08
# -> [c*deltaT*theta**2*cos(theta)**3/eta**2], p = 8.162933759999996e-08
# -> [c*deltaT**3*theta*cos(theta)**7/eta**4], p = 1.4992534703283229e-12
# -> [c*cos(theta)**4/eta**3], p = 1.2244400639999995e-05
# -> [c*deltaT**4], p = 0.0006998399999999999
# -> [c*deltaT**3*theta**3/eta], p = 1.5116543999999997e-07
# -> [c*deltaT**4*theta*cos(theta)/eta**2], p = 4.897760255999998e-07
# -> [c*theta*cos(theta)**6/eta**3], p = 1.5868743229439992e-08
# -> [c*deltaT**4*cos(theta)**5/eta**4], p = 2.77639531542282e-10
# -> [c*deltaT**2*theta*cos(theta)**3/eta**2], p = 1.2244400639999995e-06
# -> [c*deltaT**4*theta/eta**5], p = 7.934371614719996e-09
# -> [c*deltaT**5*theta**3*cos(theta)/eta**3], p = 2.856373781299198e-11
# -> [c*theta**3*cos(theta)**2], p = 4.6656e-06
# -> [c*deltaT**6*theta**2*cos(theta)**2/eta], p = 4.760622968831999e-10
# -> [c*deltaT**3*theta**2*cos(theta)**3/eta**2], p = 5.289581076479998e-09
# -> [c*theta*cos(theta)**6/eta], p = 2.448880127999999e-07
# -> [c*deltaT**3*theta*cos(theta)**6], p = 7.934371614719996e-09
# -> [c*deltaT**3*cos(theta)**4/eta**5], p = 1.5424418419015667e-09
# -> [c*deltaT**6*cos(theta)/eta**2], p = 1.3223952691199992e-07
# -> [c*deltaT**3*theta*cos(theta)**5/eta**4], p = 4.627325525704701e-11
# -> [c*cos(theta)**4/eta**4], p = 7.346640383999997e-07
# -> [c*deltaT**2/eta**5], p = 4.081466879999998e-06
# -> [c*deltaT*theta**2/eta**3], p = 2.519424e-06
# -> [c*deltaT**5*cos(theta)**4/eta**3], p = 7.712209209507833e-10
# -> [c*deltaT*theta*cos(theta)**5], p = 1.3604889599999997e-06
# -> [c*deltaT**7*cos(theta)], p = 7.346640383999997e-07
# -> [c*deltaT*cos(theta)**3/eta**3], p = 2.040733439999999e-05
# -> [c*deltaT*theta/eta**4], p = 1.5116543999999997e-05
# -> [c*theta/eta**5], p = 1.5116543999999997e-05
# -> [c*deltaT**2*theta**2*cos(theta)/eta**2], p = 2.2674815999999992e-06
# -> [c*deltaT**4*theta/eta], p = 1.5116543999999997e-05
# -> [c*deltaT*theta**2*cos(theta)**2/eta**6], p = 4.760622968831997e-10
# -> [c*deltaT*cos(theta)**5/eta**3], p = 2.6447905382399985e-07
# -> [c*deltaT**2*theta**2*cos(theta)/eta], p = 7.558271999999999e-06
# -> [c*deltaT**3*theta**2*cos(theta)/eta], p = 9.069926399999998e-07
# -> [c*deltaT**5*theta**2*cos(theta)**5/eta**6], p = 2.914548746318259e-15
# -> [c*deltaT**3/eta**6], p = 1.3223952691199992e-07
# -> [c*deltaT**6*cos(theta)**3/eta], p = 2.3803114844159985e-08
# -> [c*deltaT**2*cos(theta)/eta**5], p = 7.346640383999997e-07
# -> [c*deltaT*theta**2*cos(theta)**4/eta**5], p = 8.569121343897596e-11
# -> [c*deltaT**4*theta**2/eta], p = 4.5349631999999986e-07
# -> [c*deltaT*theta*cos(theta)**4/eta**3], p = 4.4079842303999983e-08
# -> [c*deltaT**5], p = 0.00012597119999999996
# -> [c*deltaT**5*theta**2], p = 4.5349631999999986e-07
# -> [c*deltaT**6/eta**2], p = 7.346640383999997e-07
# -> [c*deltaT**3*theta**2], p = 4.1990400000000004e-05
# -> [c*deltaT*theta**2*cos(theta)**5], p = 8.162933759999998e-08
# -> [c*deltaT**3*theta**3*cos(theta)**3/eta**3], p = 2.856373781299199e-11
# -> [c*deltaT**2*cos(theta)**4/eta**4], p = 2.3803114844159985e-08
# -> [c*deltaT**5/eta], p = 2.2674815999999992e-05
# -> [c*deltaT**3*theta**2*cos(theta)**5/eta**4], p = 2.7763953154228204e-12
# -> [c*deltaT/eta**7], p = 7.346640383999997e-07
# -> [c*deltaT*theta*cos(theta)**3/eta**4], p = 8.815968460799997e-08
# -> [c*deltaT**6*theta*cos(theta)**2/eta**2], p = 2.8563737812991984e-09
# -> [c*deltaT**3*theta**3*cos(theta)/eta**2], p = 4.897760255999999e-09
# -> [c*deltaT**5*theta*cos(theta)**2/eta], p = 8.815968460799997e-08
# -> [c*deltaT**2*theta/eta**4], p = 1.3604889599999997e-06
# -> [c*deltaT**5*cos(theta)**6/eta**3], p = 2.498755783880538e-11
# -> [c*deltaT**4*cos(theta)**3/eta], p = 2.203992115199999e-06
# -> [c*theta**3*cos(theta)], p = 7.776000000000001e-05
# -> [c*deltaT**2*theta*cos(theta)**7/eta**2], p = 2.570736403169278e-10
# -> [c*deltaT**2*theta*cos(theta)/eta**4], p = 9.795520511999997e-07
# -> [c*deltaT**3*cos(theta)/eta**5], p = 1.3223952691199992e-07
# -> [c*deltaT**4/eta**2], p = 9.069926399999997e-05
# -> [c*deltaT*theta**2*cos(theta)/eta**4], p = 8.16293376e-08
# -> [c*deltaT**2*cos(theta)**2/eta**5], p = 5.289581076479997e-07
# -> [c*deltaT**3*theta**3*cos(theta)**3/eta**4], p = 5.1414728063385565e-12
# -> [c*deltaT**3*theta*cos(theta)**5/eta**2], p = 1.4281868906495992e-09
# -> [c*deltaT**2*theta**2*cos(theta)**5/eta], p = 2.644790538239998e-09
# -> [c*cos(theta)**5/eta**5], p = 2.3803114844159985e-08
# -> [c*deltaT**2*theta**2*cos(theta)/eta**4], p = 2.9386561535999987e-08
# -> [c*deltaT**5*cos(theta)**4/eta**7], p = 8.095968739772942e-13
# -> [c*deltaT**5*theta*cos(theta)**5/eta**6], p = 4.857581243863765e-14
# -> [c*deltaT**4*cos(theta)**5/eta**2], p = 8.569121343897593e-09
# -> [c*deltaT**4*theta**2*cos(theta)], p = 4.5349631999999986e-07
# -> [c*deltaT*cos(theta)/eta**5], p = 8.162933759999996e-06
# -> [c*deltaT**2*theta**2*cos(theta)**4/eta**3], p = 9.521245937663996e-10
# -> [c*deltaT**5*theta*cos(theta)/eta**2], p = 4.4079842303999983e-08
# -> [c*deltaT**4*theta*cos(theta)**5/eta], p = 1.4281868906495992e-09
# -> [c*deltaT*theta*cos(theta)**4/eta], p = 5.441955839999998e-06
# -> [c*deltaT**5*cos(theta)**3/eta**3], p = 4.284560671948796e-09
# -> [c*cos(theta)/eta**6], p = 4.081466879999998e-06
# -> [c*deltaT*cos(theta)**6/eta**2], p = 1.3223952691199992e-07
# -> [c*deltaT**3*theta*cos(theta)/eta**2], p = 6.8024447999999985e-06
# -> [c*theta**3/eta], p = 5.1840000000000005e-05
# -> [c*deltaT**3*theta*cos(theta)**3/eta**4], p = 1.4281868906495992e-09
# -> [c*deltaT**3*theta*cos(theta)**2/eta**6], p = 5.141472806338557e-10
# -> [c*deltaT*theta**3*cos(theta)/eta], p = 1.679616e-06
# -> [c*deltaT**5*cos(theta)], p = 0.00011337407999999997
# -> [c*theta**2*cos(theta)**2], p = 0.00015552000000000003
# -> [c*deltaT**5*theta*cos(theta)**2/eta**4], p = 2.570736403169278e-10
# -> [c*deltaT**4*cos(theta)**3], p = 4.081466879999998e-06
# -> [c*deltaT**2*theta**2*cos(theta)**3/eta**7], p = 2.7763953154228208e-12
# -> [c*theta**2*cos(theta)**3/eta], p = 2.5194239999999994e-06
# -> [c*theta*cos(theta)**7/eta**2], p = 7.934371614719996e-09
# -> [c*theta**3/eta**2], p = 4.665600000000001e-06
# -> [c*deltaT*theta*cos(theta)**4/eta**4], p = 7.934371614719996e-09
# -> [c*deltaT**4*theta**2*cos(theta)**2/eta], p = 4.407984230399999e-08
# -> [c*deltaT**3*theta*cos(theta)/eta**4], p = 8.815968460799997e-08
# -> [c*deltaT**5*cos(theta)/eta**4], p = 2.3803114844159985e-08
# -> [c*deltaT**4*theta**2*cos(theta)**2], p = 8.162933759999996e-08
# -> [c*deltaT**2*theta**3*cos(theta)/eta**3], p = 4.897760256e-09
# -> [c*deltaT**3*theta**3*cos(theta)**2/eta], p = 4.897760255999998e-09
# -> [c*deltaT*theta**2*cos(theta)**5/eta**6], p = 2.776395315422821e-12
# -> [c*deltaT*theta**2*cos(theta)**4/eta], p = 8.162933759999996e-08
# -> [c*deltaT**6*theta**3*cos(theta)**4/eta**2], p = 1.6658371892536922e-13
# -> [c*deltaT*theta**2*cos(theta)**2/eta**5], p = 2.64479053824e-09
# -> [c*deltaT**5*cos(theta)/eta], p = 8.162933759999996e-06
# -> [c*deltaT**2*theta**2*cos(theta)**5/eta**4], p = 1.542441841901567e-11
# -> [c*deltaT**5/eta**2], p = 4.081466879999998e-06
# -> [c*cos(theta)**5], p = 0.00012597119999999996
# -> [c*deltaT*theta*cos(theta)/eta**5], p = 2.448880127999999e-07
# -> [c*deltaT*theta**3*cos(theta)**2/eta**2], p = 2.7209779199999993e-08
# -> [c*deltaT**4*theta/eta**4], p = 4.4079842303999983e-08
# -> [c*deltaT**2*theta*cos(theta)**4/eta**4], p = 1.4281868906495992e-09
# -> [c*deltaT**5/eta**5], p = 2.3803114844159985e-08
# -> [c*deltaT**3/eta**3], p = 2.2674815999999992e-05
# -> [c*deltaT**3*theta**3*cos(theta)**3/eta], p = 8.815968460799999e-10
# -> [c*deltaT**5*cos(theta)/eta**5], p = 4.284560671948796e-09
# -> [c*deltaT**4*theta*cos(theta)], p = 2.2674815999999996e-05
# -> [c*deltaT**4*theta**2*cos(theta)/eta**2], p = 2.9386561535999993e-08
# -> [c*deltaT**3*theta*cos(theta)**2/eta**4], p = 7.934371614719996e-09
# -> [c*deltaT**4*theta*cos(theta)**2/eta**4], p = 1.4281868906495992e-09
# -> [c*deltaT*theta*cos(theta)**5/eta**3], p = 1.5868743229439992e-08
# -> [c*deltaT**5*cos(theta)**4/eta**2], p = 4.284560671948796e-09
# -> [c*theta**2*cos(theta)/eta**5], p = 8.162933759999997e-08
# -> [c*deltaT**3*theta*cos(theta)**4/eta**6], p = 8.32918594626846e-12
# -> [c*deltaT*cos(theta)**2/eta**7], p = 2.3803114844159985e-08
# -> [c*deltaT**4*theta**3*cos(theta)/eta**3], p = 1.5868743229439995e-10
# -> [c*deltaT**4*theta**2*cos(theta)**5/eta**4], p = 4.997511567761076e-13
# -> [c*deltaT**3*cos(theta)**3/eta**4], p = 2.3803114844159985e-08
# -> [c*deltaT*cos(theta)**6/eta**3], p = 2.3803114844159985e-08
# -> [c*deltaT**7*theta*cos(theta)/eta**4], p = 4.627325525704701e-11
# -> [c*deltaT**6*cos(theta)**2/eta], p = 1.3223952691199992e-07
# -> [c*deltaT**2*theta*cos(theta)**6/eta**3], p = 2.570736403169278e-10
# -> [c*deltaT**3*theta*cos(theta)**3], p = 1.3604889599999997e-06
# -> [c*deltaT**3*cos(theta)**5/eta], p = 1.3223952691199992e-07
# -> [c*deltaT*theta**2*cos(theta)/eta**6], p = 2.64479053824e-09
# -> [c*deltaT**8*theta**2*cos(theta)**3/eta**3], p = 8.995520821969936e-14
# -> [c*deltaT**4*theta*cos(theta)/eta**5], p = 1.4281868906495992e-09
# -> [c*deltaT**3*theta*cos(theta)**3/eta**5], p = 2.570736403169278e-10
# -> [c*deltaT**5*theta*cos(theta)**3/eta**2], p = 1.428186890649599e-09
# -> [c*deltaT**4*theta**2*cos(theta)**3], p = 2.9386561535999987e-08
# -> [c*deltaT**5*theta], p = 7.558271999999998e-06
# -> [c*deltaT**3*theta*cos(theta)**4], p = 2.448880127999999e-07
# -> [c*deltaT**2*theta**2*cos(theta)**3/eta], p = 8.16293376e-08
# -> [c*cos(theta)**5/eta**2], p = 4.081466879999998e-06
# -> [c*theta**3*cos(theta)**2/eta], p = 8.398079999999999e-07
# -> [c*deltaT*cos(theta)**3/eta**5], p = 2.6447905382399985e-07
# -> [c*deltaT**4*cos(theta)**3/eta**5], p = 7.712209209507833e-10
# -> [c*deltaT**3*theta**2*cos(theta)**3/eta**3], p = 4.760622968831999e-10
# -> [c*deltaT**6*theta*cos(theta)**3/eta**3], p = 4.627325525704701e-11
# -> [c*deltaT*theta**3*cos(theta)], p = 4.6656000000000015e-06
# -> [c*deltaT**4*cos(theta)**4/eta], p = 1.3223952691199992e-07
# -> [c*deltaT**4*theta**5*cos(theta)**3/eta], p = 5.7127475625984e-13
# -> [c*deltaT**3*cos(theta)**4], p = 4.081466879999998e-06
# -> [c*deltaT*theta**3/eta**2], p = 8.398080000000001e-07
# -> [c*cos(theta)**3/eta**5], p = 7.346640383999997e-07
# -> [c*theta**3*cos(theta)**3], p = 8.398079999999999e-07
# -> [c*deltaT**4*cos(theta)**3/eta**3], p = 2.3803114844159985e-08
# -> [c*deltaT**2*theta**3/eta], p = 8.398079999999999e-07
# -> [c*deltaT**5*cos(theta)**4/eta], p = 2.3803114844159985e-08
# -> [c*theta*cos(theta)**4/eta**3], p = 4.897760255999998e-07
# -> [c*deltaT**4*cos(theta)**4/eta**3], p = 4.284560671948796e-09
# -> [c*deltaT**2*theta**2*cos(theta)**3/eta**5], p = 8.569121343897596e-11
# -> [c*deltaT*theta*cos(theta)**2/eta**4], p = 2.448880127999999e-07
# -> [c*deltaT**5*theta*cos(theta)**2/eta**2], p = 7.934371614719996e-09
# -> [c*deltaT**9*theta**4*cos(theta)**2/eta**3], p = 3.238387495909177e-16
# -> [c*theta*cos(theta)**5/eta**2], p = 2.448880127999999e-07
# -> [c*deltaT**6*cos(theta)**4/eta**6], p = 8.095968739772942e-13
# -> [c*deltaT**5*cos(theta)**3/eta**4], p = 7.712209209507833e-10
# -> [c*theta*cos(theta)**3/eta**4], p = 2.448880127999999e-07
# -> [c*deltaT*theta**3*cos(theta)/eta**2], p = 1.5116544e-07
# -> [c*deltaT*theta**2*cos(theta)**2/eta**3], p = 8.162933759999996e-08
# -> [c*deltaT**5*theta**2*cos(theta)/eta**3], p = 4.760622968831997e-10
# -> [c*deltaT**5*theta**2*cos(theta)**5], p = 8.569121343897597e-11
# -> [c*deltaT*cos(theta)**2/eta**5], p = 7.346640383999997e-07
# -> [c*theta**2*cos(theta)**4/eta], p = 4.5349631999999997e-07
# -> [c*deltaT**4*cos(theta)**2/eta**3], p = 1.3223952691199992e-07
# -> [c*deltaT*cos(theta)**4/eta**4], p = 1.3223952691199992e-07
# -> [c*deltaT**3*theta**3*cos(theta)**2], p = 2.7209779199999993e-08
# -> [c*deltaT**2*cos(theta)**6/eta], p = 1.3223952691199992e-07
# -> [c*deltaT**6*theta*cos(theta)**4/eta**5], p = 2.698656246590981e-13
# -> [c*deltaT**2*theta*cos(theta)**8/eta**3], p = 8.32918594626846e-12
# -> [c*deltaT**4*theta**3*cos(theta)/eta**2], p = 8.815968460799998e-10
# -> [c*deltaT**4*cos(theta)**4/eta**2], p = 2.3803114844159985e-08
# -> [c*deltaT**4*theta*cos(theta)**2], p = 1.3604889599999997e-06
# -> [c*deltaT*theta*cos(theta)/eta**8], p = 1.4281868906495992e-09
# -> [c*deltaT**2*theta**3*cos(theta)**4/eta**3], p = 2.856373781299198e-11
# -> [c*deltaT**6], p = 2.2674815999999992e-05

# %%
ED.fit_models()
# Out:
# ModelBox: 500 models
# -> [0.00208863155644536*deltaT**2], p = 0.021599999999999998, error = 0.6556113356661527, time = 0.47377610206604004
# -> [0.0563767583856052*deltaT], p = 0.12, error = 0.7560964680393287, time = 0.07455921173095703
# -> [0.0161840936823956*cos(theta)], p = 0.12, error = 1.2713405897993268, time = 0.02468419075012207
# -> [0.0306150350590362*theta**3], p = 0.00014400000000000003, error = 1.2226484279777616, time = 0.07267022132873535
# -> [0.00240772519430417*deltaT*cos(theta)], p = 0.043199999999999995, error = 1.2710289378107122, time = 0.06153106689453125
# -> [0.00107152571936803*deltaT**2*theta], p = 0.003888, error = 0.8261948614369855, time = 0.11239504814147949
# -> [0.000133668137037507*deltaT**2*cos(theta)**5], p = 4.081466879999998e-06, error = 1.2709217131383665, time = 0.11789917945861816
# -> [0.571913943307724*cos(theta)**2], p = 0.021599999999999998, error = 1.2221660655705235, time = 0.04433798789978027
# -> [0.337834861309631*theta], p = 0.04000000000000001, error = 1.1213145900644064, time = 0.04524421691894531
# -> [0.0563766943779855*deltaT], p = 0.043199999999999995, error = 0.7560964680404827, time = 0.08467292785644531
# -> [-2.62096641996853e-7*deltaT**4*theta*cos(theta)**3], p = 2.2039921151999992e-07, error = 1.2600208222111415, time = 0.9265999794006348
# -> [-0.0107751566382442*deltaT*theta*cos(theta)], p = 0.005598719999999996, error = 1.2450644206056891, time = 0.10278630256652832
# -> [0.000129774678253197*deltaT**2*cos(theta)], p = 0.003275251199999999, error = 1.2705157011100998, time = 0.16011404991149902
# -> [1.08747403186772e-5*deltaT**3*cos(theta)], p = 3.6733201919999976e-05, error = 1.2726387470819005, time = 0.4990103244781494
# -> [0.0563762371572026*deltaT], p = 0.0027993599999999994, error = 0.7560964681005302, time = 0.24956631660461426
# -> [0.571913617470455*cos(theta)**2], p = 0.004199039999999999, error = 1.2221660655705417, time = 0.13701796531677246
# -> [0.00240772909288497*deltaT*cos(theta)], p = 0.023327999999999995, error = 1.2710289378107087, time = 0.07452821731567383
# -> [0.232202284949499*theta*cos(theta)**2], p = 0.003888, error = 1.240795825238186, time = 0.044960737228393555
# -> [0.0161842448858353*cos(theta)], p = 0.043199999999999995, error = 1.2713405897993275, time = 0.06659913063049316
# -> [3.26904827987016e-5*deltaT**3*cos(theta)**6], p = 4.284560671948796e-09, error = 1.23924831445045, time = 0.21625804901123047
# -> [0.013710641330204*cos(theta)**3], p = 0.003887999999999999, error = 1.2713689888113975, time = 0.029831886291503906
# -> [4.48418438913569e-6*deltaT**3*cos(theta)], p = 0.0027993599999999994, error = 1.270168201295556, time = 0.36318087577819824
# -> [0.00151605346513364*deltaT*theta**3*cos(theta)**2], p = 3.0233088e-07, error = 1.2449231083189203, time = 0.23081326484680176
# -> [-0.000355040463747588*deltaT**2*theta*cos(theta)**3], p = 1.0883911679999998e-05, error = 1.2560216981019996, time = 0.19045615196228027
# -> [-6.6424873411722e-9*deltaT**5*theta**2*cos(theta)], p = 1.4693280768e-08, error = 1.2572234078642803, time = 0.7677369117736816
# -> [0.000129772929592545*deltaT**2*cos(theta)], p = 0.00839808, error = 1.270515701110346, time = 0.19392085075378418
# -> [0.00208863635853096*deltaT**2], p = 0.011663999999999997, error = 0.6556113356560924, time = 0.15433311462402344
# -> [0.232200993431604*theta*cos(theta)**2], p = 0.002799359999999999, error = 1.2407958252391473, time = 0.11580848693847656
# -> [0.337836290601069*theta], p = 0.0144, error = 1.121314590067094, time = 0.07097554206848145
# -> [0.00880594685403944*deltaT*theta**2], p = 0.0012960000000000003, error = 1.0751775558156844, time = 0.08689498901367188
# -> [0.00240982244258237*deltaT*cos(theta)], p = 0.00839808, error = 1.2710289380839164, time = 0.1472938060760498
# -> [0.0483984208589442*deltaT*cos(theta)**2], p = 0.011663999999999997, error = 1.157022488314413, time = 0.06453227996826172
# -> [0.00173361411283711*deltaT**2*cos(theta)**2], p = 0.0006802444799999995, error = 1.1473408305234873, time = 0.2010786533355713
# -> [0.000542697707695333*deltaT**2*theta*cos(theta)**4], p = 1.5868743229439992e-08, error = 1.238751625640149, time = 0.0991678237915039
# -> [-0.132555207150282*theta*cos(theta)], p = 0.0144, error = 1.2588507174561059, time = 0.03367424011230469
# -> [0.00234712800050864*deltaT*cos(theta)**3], p = 0.0027993599999999994, error = 1.2711787274546729, time = 0.045156002044677734
# -> [0.571057547617731*cos(theta)**2], p = 0.011663999999999997, error = 1.2221661781768394, time = 0.20609712600708008
# -> [0.0278328276903663*deltaT*theta], p = 0.0144, error = 0.9051018447029932, time = 0.0635230541229248
# -> [-0.000355049378216458*deltaT**2*theta*cos(theta)**3], p = 6.0466175999999974e-05, error = 1.2560216981085448, time = 0.13336706161499023
# -> [0.0483984257465901*deltaT*cos(theta)**2], p = 2.4488801279999986e-05, error = 1.1570224883144102, time = 0.1344306468963623
# -> [0.0278328327039401*deltaT*theta], p = 0.007776, error = 0.905101844702965, time = 0.115478515625
# -> [-0.0107751631224502*deltaT*theta*cos(theta)], p = 0.007776, error = 1.2450644206057018, time = 0.09451746940612793
# -> [0.0483982021178319*deltaT*cos(theta)**2], p = 0.00839808, error = 1.1570224883170321, time = 0.08162307739257812
# -> [0.00173361786321402*deltaT**2*cos(theta)**2], p = 7.754787071999995e-05, error = 1.147340830522932, time = 0.07249760627746582
# -> [-0.0407054414267307*theta**2*cos(theta)**5], p = 4.5349631999999986e-07, error = 1.2659882718277278, time = 0.061980247497558594
# -> [-0.13256951276613*theta*cos(theta)], p = 3.023308799999999e-05, error = 1.2588507176058281, time = 0.17463898658752441
# -> [-0.0100557460126825*deltaT*theta*cos(theta)**3], p = 0.00012093235199999994, error = 1.2561842419336122, time = 0.12323355674743652
# -> [0.000129767610015106*deltaT**2*cos(theta)], p = 0.011663999999999997, error = 1.2705157011130523, time = 0.11362957954406738
# -> [1.57299208284134e-5*deltaT**3*theta*cos(theta)**4], p = 1.5868743229439992e-08, error = 1.2411682772143813, time = 0.10889577865600586
# -> [3.19682828265108e-5*deltaT**3*theta], p = 0.00093312, error = 0.8310185387995156, time = 0.33246350288391113
# -> [0.0483984295404253*deltaT*cos(theta)**2], p = 0.002897337599999999, error = 1.15702248831441, time = 0.07940363883972168
# -> [0.00880596149006366*deltaT*theta**2], p = 0.00011197439999999998, error = 1.0751775558156695, time = 0.11018514633178711
# -> [0.0137889871782468*cos(theta)**3], p = 0.0027993599999999994, error = 1.2713689895668017, time = 0.11168122291564941
# -> [0.00173361687878138*deltaT**2*cos(theta)**2], p = 0.003401222399999999, error = 1.1473408305229593, time = 0.15260052680969238
# -> [0.00208863907710713*deltaT**2], p = 0.0011337407999999997, error = 0.6556113356546384, time = 0.13623666763305664
# -> [0.00173361023857601*deltaT**2*cos(theta)**2], p = 0.004199039999999999, error = 1.1473408305253463, time = 0.1000521183013916
# -> [-1.16771148785761e-5*deltaT**3*theta*cos(theta)], p = 2.203992115199999e-06, error = 1.245441159300738, time = 0.17133593559265137
# -> [0.232176253639944*theta*cos(theta)**2], p = 0.0007138368000000001, error = 1.2407958256275102, time = 1.7449862957000732
# -> [-0.132616628803914*theta*cos(theta)], p = 0.002799359999999999, error = 1.258850720174815, time = 0.10362362861633301
# -> [0.00919656267250297*cos(theta)], p = 0.011663999999999997, error = 1.2713501889745513, time = 0.2303311824798584
# -> [5.82270712569539e-7*deltaT**4*theta*cos(theta)**2], p = 2.570736403169278e-10, error = 1.2062174277622435, time = 0.2343277931213379
# -> [-0.122268078966686*theta*cos(theta)**3], p = 0.00093312, error = 1.2642134138894776, time = 0.054100990295410156
# -> [0.0563767656281103*deltaT], p = 0.011663999999999997, error = 0.7560964680393103, time = 0.11137104034423828
# -> [-0.00393754656774126*deltaT*theta**2*cos(theta)**3], p = 1.8139852799999997e-06, error = 1.2523184611836498, time = 0.15427899360656738
# -> [0.337832880348904*theta], p = 0.003888, error = 1.1213145900701593, time = 0.10165524482727051
# -> [5.94389597782609e-5*deltaT**3], p = 0.003887999999999999, error = 0.6986822321681855, time = 0.312847375869751
# -> [0.466082255124952*cos(theta)**4], p = 0.0006998399999999999, error = 1.2478732458649655, time = 0.030464649200439453
# -> [-0.0107751596521064*deltaT*theta*cos(theta)], p = 0.0010917504, error = 1.2450644206056924, time = 0.13559961318969727
# -> [-0.108897585163675*theta*cos(theta)**5], p = 7.5582719999999985e-06, error = 1.266808481752868, time = 0.04782605171203613
# -> [-0.057863107174909*theta**2*cos(theta)], p = 0.0007776, error = 1.253899168968321, time = 0.05495715141296387
# -> [0.00240773297270072*deltaT*cos(theta)], p = 0.0022674815999999993, error = 1.2710289378107071, time = 0.1196749210357666
# -> [-0.132577011889583*theta*cos(theta)], p = 0.007776, error = 1.2588507178016066, time = 0.11753296852111816
# -> [-0.00393758241978674*deltaT*theta**2*cos(theta)**3], p = 1.4693280767999992e-08, error = 1.2523184611849252, time = 0.10259079933166504
# -> [-0.122281122996837*theta*cos(theta)**3], p = 0.0005458751999999999, error = 1.2642134139715366, time = 0.12130069732666016
# -> [0.337832348319425*theta], p = 0.00093312, error = 1.1213145900735801, time = 0.42931580543518066
# -> [1.53653856279823e-5*theta*cos(theta)**3], p = 4.081466879999999e-06, error = 1.271393882492693, time = 0.14300084114074707
# -> [-0.108963775199833*theta*cos(theta)**5], p = 1.3604889599999995e-06, error = 1.2668084834496924, time = 0.12244200706481934
# -> [3.17652312362127e-6*deltaT*theta**2*cos(theta)**3], p = 4.760622968831998e-10, error = 1.271422638669311, time = 0.15970540046691895
# -> [0.0278327580336189*deltaT*theta], p = 0.00029393279999999995, error = 0.905101844706342, time = 0.1705036163330078
# -> [-7.37788408858638e-7*deltaT], p = 0.0005038847999999999, error = 1.2714028371429649, time = 0.21809172630310059
# -> [4.78045274872023e-5*deltaT**3*cos(theta)**2], p = 6.938493695999995e-05, error = 1.1602933687158465, time = 0.6456193923950195
# -> [4.49346605963745e-6*deltaT**3*cos(theta)], p = 0.0022674815999999993, error = 1.2701681981662944, time = 0.2234952449798584
# -> [0.000542697499109324*deltaT**2*theta*cos(theta)**4], p = 2.644790538239999e-07, error = 1.2387516256401634, time = 0.6315693855285645
# -> [5.94461538213838e-5*deltaT**3], p = 8.162933759999996e-06, error = 0.6986822195323327, time = 0.4069530963897705
# -> [0.00107153226420725*deltaT**2*theta], p = 0.0005038848000000001, error = 0.826194861410057, time = 0.17714715003967285
# -> [-0.00477133034066133*deltaT*theta**2*cos(theta)], p = 0.00054432, error = 1.2335655982831175, time = 0.1021418571472168
# -> [0.0396702482483738*deltaT*cos(theta)**4], p = 0.0003779135999999999, error = 1.217002181128412, time = 0.06552529335021973
# -> [0.0396702334472325*deltaT*cos(theta)**4], p = 1.4693280767999994e-06, error = 1.2170021811284275, time = 0.1256272792816162
# -> [0.0278328337513366*deltaT*theta], p = 0.0025660799999999992, error = 0.9051018447029626, time = 0.0626990795135498
# -> [-0.00477132841380202*deltaT*theta**2*cos(theta)], p = 0.00019595520000000006, error = 1.2335655982830753, time = 0.14451026916503906
# -> [1.2192620816524e-7*deltaT**4*cos(theta)], p = 2.4488801279999986e-05, error = 1.2701488035232011, time = 0.8805022239685059
# -> [-0.0100558410232669*deltaT*theta*cos(theta)**3], p = 1.3604889599999995e-05, error = 1.256184241932248, time = 0.09487175941467285
# -> [0.0396702996321957*deltaT*cos(theta)**4], p = 0.00015872371199999997, error = 1.2170021811284784, time = 0.1016077995300293
# -> [0.466597661289957*cos(theta)**4], p = 9.069926399999997e-05, error = 1.2478732738733491, time = 0.4729189872741699
# -> [0.00318174085639383*cos(theta)], p = 0.0006298559999999998, error = 1.2713738268591694, time = 0.009277582168579102
# -> [5.9445482033753e-5*deltaT**3], p = 0.0027993599999999994, error = 0.6986822197111621, time = 0.5481963157653809
# -> [0.00525414772970997*deltaT*theta**2*cos(theta)**2], p = 1.259712e-05, error = 1.232816426682681, time = 0.15807366371154785
# -> [2.13720054699494e-5*deltaT**3*theta*cos(theta)**2], p = 3.085588961279999e-07, error = 1.2003780111012485, time = 0.1449446678161621
# -> [3.19747588255132e-5*deltaT**3*theta], p = 0.0005458752, error = 0.8310185090753411, time = 0.19853830337524414
# -> [4.7804709736754e-5*deltaT**3*cos(theta)**2], p = 8.081304422399997e-06, error = 1.1602933687143164, time = 0.12094807624816895
# -> [0.0195369081528188*deltaT*theta*cos(theta)**2], p = 0.0025660799999999992, error = 1.2026133259623746, time = 0.09122729301452637
# -> [0.0195370170368626*deltaT*theta*cos(theta)**2], p = 4.4079842303999983e-08, error = 1.2026133259643155, time = 0.08042693138122559
# -> [1.55472858244343e-6*deltaT**3*theta**3*cos(theta)**2], p = 2.856373781299198e-11, error = 1.246178014859279, time = 0.1519927978515625
# -> [0.00525433337466466*deltaT*theta**2*cos(theta)**2], p = 3.1744742399999987e-06, error = 1.2328164267304562, time = 0.07374691963195801
# -> [0.105920890501518*theta**2], p = 0.0024000000000000007, error = 1.1872487788822723, time = 0.0688469409942627
# -> [-0.000395813375250531*deltaT**2*theta*cos(theta)], p = 0.00014360716799999995, error = 1.2435122300300256, time = 0.1555635929107666
# -> [1.2291952120713e-7*deltaT**4*cos(theta)], p = 0.00015872371199999997, error = 1.270148867322231, time = 0.5989258289337158
# -> [-1.00185044424651e-5*deltaT**3*theta*cos(theta)**3], p = 2.644790538239999e-07, error = 1.258031141252508, time = 0.29631996154785156
# -> [0.00072353325808523*deltaT**2*theta*cos(theta)**2], p = 0.000196515072, error = 1.1959635737777716, time = 0.7779834270477295
# -> [-9.38875077254852e-5*theta*cos(theta)**2], p = 4.081466879999999e-06, error = 1.2714165324612003, time = 0.13013482093811035
# -> [2.81557975475201e-10*deltaT**5*theta**3*cos(theta)**5], p = 9.254651051409403e-13, error = 1.2785569780672543, time = 0.8557851314544678
# -> [0.000137293181339206*deltaT**2*cos(theta)**3], p = 0.0003854718719999998, error = 1.270770210510755, time = 0.16965961456298828
# -> [-0.00737464827270625*cos(theta)**3], p = 0.0010077695999999997, error = 1.2714236081013477, time = 0.21629977226257324
# -> [4.78039539968588e-5*deltaT**3*cos(theta)**2], p = 0.0010077695999999997, error = 1.1602933687427404, time = 0.44678378105163574
# -> [0.000129800475352201*deltaT**2*cos(theta)], p = 0.0003854718719999998, error = 1.2705157011434574, time = 0.09191155433654785
# -> [0.000137288221451811*deltaT**2*cos(theta)**3], p = 0.0012597119999999996, error = 1.2707702105123821, time = 0.09501123428344727
# -> [-1.00162780238162e-5*deltaT**3*theta*cos(theta)**3], p = 4.897760255999998e-07, error = 1.2580311405974018, time = 0.8136019706726074
# -> [-1.83141942247109e-7*deltaT**4*theta*cos(theta)**9], p = 1.5738563230118595e-15, error = 1.2674091459045858, time = 0.5271317958831787
# -> [-3.98329177443408e-10*deltaT**6*theta*cos(theta)**3], p = 5.141472806338557e-10, error = 1.279255587201499, time = 0.845634937286377
# -> [0.0483990186638962*deltaT*cos(theta)**2], p = 0.00040814668799999976, error = 1.157022488332266, time = 0.12558221817016602
# -> [5.81895713839896e-7*deltaT**4*theta*cos(theta)**2], p = 9.795520511999997e-07, error = 1.2062174563773504, time = 0.6812131404876709
# -> [0.00233851532090382*deltaT*cos(theta)**3], p = 0.00043082150399999974, error = 1.2711787303290254, time = 0.18764257431030273
# -> [-1.16767158075982e-5*deltaT**3*theta*cos(theta)], p = 0.00012849062399999993, error = 1.245441159333641, time = 1.1013269424438477
# -> [-1.7678137665517*deltaT**6*theta**2*cos(theta)], p = 2.6447905382399986e-09, error = 5090715121.187462, time = 0.46107912063598633
# -> [0.0088059576661676*deltaT*theta**2], p = 0.00054432, error = 1.0751775558155592, time = 0.1486973762512207
# -> [7.8588953945299e-10*deltaT**6*cos(theta)**2], p = 4.284560671948796e-09, error = 1.2087268915887757, time = 0.7011735439300537
# -> [0.00107153473829284*deltaT**2*theta], p = 0.002799359999999999, error = 0.8261948614108604, time = 0.20613360404968262
# -> [-0.00017513604390286*deltaT**2*theta**2*cos(theta)], p = 3.265173504e-07, error = 1.230788424651062, time = 0.22242331504821777
# -> [0.000723512435680174*deltaT**2*theta*cos(theta)**2], p = 0.0003359232, error = 1.1959635737590697, time = 0.37844133377075195
# -> [0.000137295580266489*deltaT**2*cos(theta)**3], p = 8.979227135999994e-05, error = 1.2707702105105507, time = 0.10904788970947266
# -> [0.000723486891265176*deltaT**2*theta*cos(theta)**2], p = 1.7142160895999992e-06, error = 1.1959635739121708, time = 0.10623764991760254
# -> [5.53313439641684e-6*deltaT**3*theta**2*cos(theta)**2], p = 2.4488801279999997e-07, error = 1.233602336277309, time = 0.6030008792877197
# -> [0.000158233549923783*cos(theta)], p = 6.802444799999997e-05, error = 1.2713910812267022, time = 0.009822368621826172
# -> [0.000137306442954696*deltaT**2*cos(theta)**3], p = 4.407984230399998e-06, error = 1.2707702105143786, time = 0.1057584285736084
# -> [0.464735279146232*cos(theta)**4], p = 0.0006298559999999998, error = 1.247873446809309, time = 0.17972517013549805
# -> [-0.000395820731385794*deltaT**2*theta*cos(theta)], p = 0.002799359999999999, error = 1.2435122300400132, time = 0.12024593353271484
# -> [4.78052821759215e-5*deltaT**3*cos(theta)**2], p = 0.0003854718719999998, error = 1.160293368731518, time = 0.6328861713409424
# -> [0.063122062452872*theta**2*cos(theta)**2], p = 9.069926399999999e-07, error = 1.2538331004790368, time = 0.29976892471313477
# -> [0.179352185690768*theta*cos(theta)**4], p = 3.0233087999999994e-05, error = 1.2576516759016878, time = 0.06437897682189941
# -> [0.000723519093332049*deltaT**2*theta*cos(theta)**2], p = 2.993075711999998e-05, error = 1.1959635737510326, time = 0.11027979850769043
# -> [0.0195369759728838*deltaT*theta*cos(theta)**2], p = 0.00015872371199999997, error = 1.2026133259630674, time = 0.06894779205322266
# -> [8.41734576841426e-7*deltaT**4*theta], p = 0.0001679616, error = 0.8657932345588056, time = 0.47235608100891113
# -> [-0.132614372118649*theta*cos(theta)], p = 0.0005458752, error = 1.2588507199791537, time = 0.5734686851501465
# -> [5.94459224418454e-5*deltaT**3], p = 0.0011337407999999997, error = 0.6986822195706428, time = 0.4775826930999756
# -> [0.056376768155119*deltaT], p = 4.5349631999999984e-05, error = 0.7560964680393093, time = 0.1765289306640625
# -> [1.55652600117882e-8*deltaT**5*theta*cos(theta)**2], p = 4.897760255999998e-07, error = 1.2110712869377847, time = 0.4876532554626465
# -> [0.00405268372148521*deltaT*theta**2*cos(theta)**4], p = 4.5349631999999986e-07, error = 1.2529471449303022, time = 0.06799697875976562
# -> [-0.000139662115247912*deltaT**2*theta**2*cos(theta)**3], p = 1.4693280767999992e-08, error = 1.2516447878488717, time = 0.26888251304626465
# -> [0.000139751436516603*deltaT**2*cos(theta)**3], p = 6.611976345599996e-07, error = 1.2707704095171422, time = 0.1515192985534668
# -> [-0.0475582936745922*theta**2*cos(theta)**3], p = 1.3604889599999997e-06, error = 1.262557677672378, time = 0.1036219596862793
# -> [0.337834910154701*theta], p = 0.0001679616, error = 1.1213145900644037, time = 0.14217543601989746
# -> [-6.21805018554926e-10*deltaT**6*cos(theta)], p = 7.346640383999997e-07, error = 1.3608237082321646, time = 0.7409181594848633
# -> [0.00248561581100742*deltaT*cos(theta)**5], p = 3.6733201919999983e-06, error = 1.2712041694376044, time = 0.08136391639709473
# -> [0.000337480921573652*deltaT**2*theta**2], p = 4.19904e-05, error = 1.040875742383856, time = 0.2334754467010498
# -> [-0.0578708606707359*theta**2*cos(theta)], p = 0.0012960000000000003, error = 1.253899168652706, time = 0.07781529426574707
# -> [0.000190294075963758*deltaT**2*theta**2*cos(theta)**2], p = 5.8773123071999987e-08, error = 1.2303554857021248, time = 0.09882044792175293
# -> [4.14506159151532e-7*deltaT*theta], p = 4.081466879999999e-06, error = 1.2713827447342063, time = 0.1624448299407959
# -> [-0.0195218653030124*theta**3*cos(theta)], p = 4.6656000000000015e-06, error = 1.2556840707526675, time = 0.10820221900939941
# -> [1.18367945436406e-6*deltaT**4*cos(theta)**2], p = 4.489613567999997e-05, error = 1.1771864139044517, time = 0.8895089626312256
# -> [-0.0578775082155724*theta**2*cos(theta)], p = 8.39808e-05, error = 1.2538991688856294, time = 0.08856630325317383
# -> [-0.00393755760255523*deltaT*theta**2*cos(theta)**3], p = 1.2597119999999998e-05, error = 1.2523184611837028, time = 0.10369729995727539
# -> [4.01324008089573e-9*deltaT**5*cos(theta)**5], p = 1.38819765771141e-10, error = 1.270144213985048, time = 0.634443998336792
# -> [0.0195369143773195*deltaT*theta*cos(theta)**2], p = 0.0012177215999999997, error = 1.202613325962367, time = 0.11513209342956543
# -> [-0.047656307302812*theta**2*cos(theta)**3], p = 2.7993599999999996e-05, error = 1.2625576401280199, time = 0.07516980171203613
# -> [0.571909528411484*cos(theta)**2], p = 0.0010077695999999997, error = 1.2221660655735442, time = 0.13216710090637207
# -> [-1.16766631280016e-5*deltaT**3*theta*cos(theta)], p = 0.00029393279999999995, error = 1.245441159342561, time = 0.41968369483947754
# -> [0.0020886386913216*deltaT**2], p = 0.004199039999999999, error = 0.655611335654658, time = 0.12546396255493164
# -> [4.49922990929421e-6*deltaT**3*cos(theta)], p = 2.3803114844159985e-08, error = 1.2701682014864544, time = 0.19174528121948242
# -> [8.42656521403457e-7*deltaT**4*theta], p = 2.7209779199999994e-06, error = 0.8657925098569843, time = 0.45594167709350586
# -> [-1.06617746731296e-7*deltaT**4*theta**2*cos(theta)**3], p = 4.760622968831996e-10, error = 1.255673583363637, time = 0.767228364944458
# -> [0.105919610660178*theta**2], p = 0.0012960000000000003, error = 1.18724877889515, time = 0.06946611404418945
# -> [-0.0032528187165571*cos(theta)], p = 0.0027993599999999994, error = 1.271414861751035, time = 0.1995534896850586
# -> [-0.000175142850511098*deltaT**2*theta**2*cos(theta)], p = 4.19904e-05, error = 1.230788424725201, time = 0.11828112602233887
# -> [0.063156083474205*theta**2*cos(theta)**2], p = 1.0077695999999997e-05, error = 1.2538331086345293, time = 0.21001195907592773
# -> [-0.0107751566293446*deltaT*theta*cos(theta)], p = 7.558271999999996e-05, error = 1.2450644206056891, time = 0.10547828674316406
# -> [1.57290149738753e-5*deltaT**3*theta*cos(theta)**4], p = 8.815968460799997e-08, error = 1.2411682773402664, time = 0.2364041805267334
# -> [1.22021106967872e-7*deltaT**4*cos(theta)], p = 2.9386561535999988e-06, error = 1.2701488024976506, time = 0.5273189544677734
# -> [4.49106152249227e-6*deltaT**3*cos(theta)], p = 0.00034012223999999985, error = 1.2701681979733113, time = 0.7376677989959717
# -> [2.84057326502875e-9*deltaT**5*cos(theta)], p = 7.346640383999997e-07, error = 1.2703800833665702, time = 0.6983442306518555
# -> [2.6096489671248e-8*deltaT**5*cos(theta)**2], p = 3.9671858073599974e-07, error = 1.1926649085072698, time = 0.8002786636352539
# -> [0.000190287933951676*deltaT**2*theta**2*cos(theta)**2], p = 2.2674815999999996e-06, error = 1.2303554857457786, time = 0.24799895286560059
# -> [0.000190291189208794*deltaT**2*theta**2*cos(theta)**2], p = 3.2651735039999994e-07, error = 1.2303554857118153, time = 0.19884967803955078
# -> [0.00234717492718522*deltaT*cos(theta)**3], p = 0.0020155391999999994, error = 1.271178727454751, time = 0.11863374710083008
# -> [-5.32926372299525e-5*theta*cos(theta)], p = 1.3604889599999997e-06, error = 1.2713820506086595, time = 0.010669469833374023
# -> [-0.0100295157321193*deltaT*theta*cos(theta)**3], p = 4.897760255999998e-07, error = 1.2561843467889955, time = 0.6033351421356201
# -> [1.22015611825578e-7*deltaT**4*cos(theta)], p = 2.6447905382399985e-07, error = 1.2701488025160033, time = 0.2649552822113037
# -> [-0.00234590266137016*cos(theta)**3], p = 4.5349631999999984e-05, error = 1.2714006621689786, time = 0.011650800704956055
# -> [-0.000395814197485768*deltaT**2*theta*cos(theta)], p = 0.0009237888000000002, error = 1.2435122300301753, time = 0.5842430591583252
# -> [0.000190286638811733*deltaT**2*theta**2*cos(theta)**2], p = 5.0388479999999996e-06, error = 1.230355485766081, time = 0.1323552131652832
# -> [-0.0100558484165926*deltaT*theta*cos(theta)**3], p = 0.00037791359999999995, error = 1.2561842419322564, time = 0.07385659217834473
# -> [-0.00031145038059214*deltaT**2*theta*cos(theta)**5], p = 1.5868743229439992e-08, error = 1.2615458191920204, time = 0.12521958351135254
# -> [0.0631120079151535*theta**2*cos(theta)**2], p = 6.9984e-05, error = 1.2538331000360445, time = 0.11107611656188965
# -> [-0.000355038272012025*deltaT**2*theta*cos(theta)**3], p = 1.3223952691199995e-07, error = 1.2560216981033767, time = 0.16598105430603027
# -> [0.0195369133628141*deltaT*theta*cos(theta)**2], p = 1.3604889599999995e-05, error = 1.2026133259623673, time = 0.11704301834106445
# -> [1.20746243089582e-7*deltaT**4*cos(theta)], p = 0.0005038847999999999, error = 1.270148941913098, time = 0.47252535820007324
# -> [0.000137597535469738*deltaT**2*cos(theta)**3], p = 4.284560671948796e-09, error = 1.2707702135174248, time = 0.16515874862670898
# -> [-3.19418791529574e-7*deltaT**4*theta*cos(theta)], p = 6.8024447999999985e-06, error = 1.2471764855530207, time = 0.7688825130462646
# -> [-8.58839872426049e-9*deltaT**5*theta*cos(theta)], p = 1.5868743229439992e-08, error = 1.2479054154254248, time = 0.8143818378448486
# -> [0.0150720886876147*deltaT*theta*cos(theta)**4], p = 3.023308799999999e-05, error = 1.2408071545715673, time = 0.07346367835998535
# -> [5.39867737348945e-5*deltaT**2*theta**3*cos(theta)**2], p = 9.795520511999997e-09, error = 1.2437260675379607, time = 0.25478219985961914
# -> [3.80578473503205e-5*deltaT**3*cos(theta)**4], p = 1.4693280767999994e-06, error = 1.2193871629669308, time = 0.4039950370788574
# -> [2.13775693026255e-5*deltaT**3*theta*cos(theta)**2], p = 8.162933759999998e-06, error = 1.200378016062847, time = 0.5642530918121338
# -> [0.03967879271191*deltaT*cos(theta)**4], p = 2.4488801279999986e-05, error = 1.2170021837035805, time = 0.10170364379882812
# -> [0.00140152255804083*deltaT**2*cos(theta)**4], p = 1.3223952691199992e-07, error = 1.212958973382647, time = 0.36928868293762207
# -> [0.00248559814292396*deltaT*cos(theta)**5], p = 2.4488801279999986e-05, error = 1.2712041694375902, time = 0.11947035789489746
# -> [0.000133668455535941*deltaT**2*cos(theta)**5], p = 2.3803114844159985e-08, error = 1.2709217131382442, time = 0.22690105438232422
# -> [0.0150721705494416*deltaT*theta*cos(theta)**4], p = 1.2244400639999995e-06, error = 1.2408071545723076, time = 0.11723446846008301
# -> [5.82293475888147e-7*deltaT**4*theta*cos(theta)**2], p = 1.5868743229439992e-08, error = 1.206217427812781, time = 0.21459221839904785
# -> [-3.20306956291392e-7*deltaT**4*theta*cos(theta)], p = 7.934371614719996e-09, error = 1.2471762994899636, time = 0.21620678901672363
# -> [0.105921499452103*theta**2], p = 0.00038880000000000007, error = 1.187248778885077, time = 0.057528018951416016
# -> [1.49483545603178e-6*deltaT**4], p = 0.0003779135999999999, error = 0.7784323761954633, time = 0.8028390407562256
# -> [0.00140150772037015*deltaT**2*cos(theta)**4], p = 0.00015872371199999997, error = 1.212958973381131, time = 0.42635321617126465
# -> [-0.000354940848406514*deltaT**2*theta*cos(theta)**3], p = 4.284560671948797e-09, error = 1.256021699355185, time = 0.29363226890563965
# -> [5.25739638050009e-6*deltaT**3*cos(theta)**3], p = 4.081466879999997e-05, error = 1.270297858287882, time = 0.264479398727417
# -> [0.00107153185935988*deltaT**2*theta], p = 3.0233087999999994e-05, error = 0.8261948614104992, time = 0.08094310760498047
# -> [0.179350601744171*theta*cos(theta)**4], p = 0.0001259712, error = 1.2576516759006375, time = 0.047187089920043945
# -> [-2.39519438212173e-6*theta*cos(theta)**2], p = 5.290790399999998e-05, error = 1.2713927068090665, time = 0.23102116584777832
# -> [-1.00162678451682e-5*deltaT**3*theta*cos(theta)**3], p = 2.3803114844159988e-08, error = 1.2580311405974547, time = 0.12906622886657715
# -> [0.000133673327470303*deltaT**2*cos(theta)**5], p = 1.4693280767999994e-06, error = 1.2709217131370398, time = 0.15703535079956055
# -> [0.00336868150263276*deltaT*theta**2*cos(theta)**6], p = 2.6447905382399994e-09, error = 1.2602686109621706, time = 0.1605510711669922
# -> [0.00254866030055251*deltaT*theta**3], p = 2.5920000000000003e-05, error = 1.1606701454807253, time = 0.11870741844177246
# -> [5.81422955973388e-7*deltaT**4*theta*cos(theta)**2], p = 8.815968460799997e-08, error = 1.2062175715760368, time = 0.5750408172607422
# -> [-0.0579183744406023*theta**2*cos(theta)], p = 5.0388479999999996e-06, error = 1.2538991805303532, time = 0.5210573673248291
# -> [1.18253980988274e-6*deltaT**4*cos(theta)**2], p = 3.6733201919999983e-06, error = 1.1771863522008519, time = 0.7757213115692139
# -> [3.80560984848885e-5*deltaT**3*cos(theta)**4], p = 3.9671858073599974e-07, error = 1.2193871628696127, time = 0.1690075397491455
# -> [0.0183820861668341*theta**3*cos(theta)**2], p = 2.72097792e-08, error = 1.2591859155283631, time = 0.2632319927215576
# -> [0.00525414243835567*deltaT*theta**2*cos(theta)**2], p = 9.797759999999999e-05, error = 1.232816426682753, time = 0.1015007495880127
# -> [5.25902412556023e-6*deltaT**3*cos(theta)**3], p = 3.9671858073599974e-07, error = 1.2702978581914905, time = 0.21909785270690918
# -> [-0.000139668336465084*deltaT**2*theta**2*cos(theta)**3], p = 9.069926399999997e-07, error = 1.251644787903973, time = 0.12462735176086426
# -> [0.000337471730931849*deltaT**2*theta**2], p = 0.00031104000000000006, error = 1.0408757424652206, time = 0.441225528717041
# -> [0.000190274297143161*deltaT**2*theta**2*cos(theta)**2], p = 2.6447905382399994e-09, error = 1.2303554861534545, time = 0.14177417755126953
# -> [-1.08386308367099e-5*deltaT*cos(theta)], p = 7.346640383999997e-07, error = 1.27139535954249, time = 0.011526823043823242
# -> [-1.41287169691924e-7*deltaT**4*theta**2*cos(theta)], p = 8.162933759999998e-08, error = 1.236079081801505, time = 0.9030466079711914
# -> [3.19750374918694e-5*deltaT**3*theta], p = 4.5349631999999984e-05, error = 0.8310185088218142, time = 0.579827070236206
# -> [0.000723519794067829*deltaT**2*theta*cos(theta)**2], p = 1.3223952691199995e-07, error = 1.195963573750953, time = 0.10967350006103516
# -> [1.63237447470884e-7*deltaT**4*cos(theta)**3], p = 6.611976345599996e-07, error = 1.2699009980222622, time = 0.26538991928100586
# -> [-0.0107770670142362*deltaT*theta*cos(theta)], p = 5.441955839999999e-06, error = 1.2450644214428714, time = 0.4915328025817871
# -> [0.000337477945762003*deltaT**2*theta**2], p = 1.2597119999999996e-05, error = 1.0408757423686237, time = 0.14945387840270996
# -> [5.75479415760415e-6*deltaT**3*theta**2*cos(theta)**2], p = 1.3223952691199996e-08, error = 1.2336628235114735, time = 0.46291017532348633
# -> [-4.12065969301565e-9*deltaT**4*theta**5*cos(theta)], p = 1.8509302102818806e-14, error = 1.253429550343812, time = 0.6578538417816162
# -> [4.24577418369809e-7*deltaT**4*theta*cos(theta)**4], p = 1.5868743229439992e-08, error = 1.2439459216188604, time = 0.7709391117095947
# -> [9.27250215506572e-7*deltaT**4*cos(theta)**4], p = 7.712209209507833e-10, error = 1.2275985559337856, time = 0.1902322769165039
# -> [1.49618259565861e-6*deltaT**4], p = 1.2244400639999995e-05, error = 0.7784327736118843, time = 0.36876773834228516
# -> [0.00242548954013918*deltaT*cos(theta)], p = 0.00022674815999999996, error = 1.271028957561494, time = 0.1272258758544922
# -> [-0.00477288536616385*deltaT*theta**2*cos(theta)], p = 1.3604889599999997e-06, error = 1.2335656024016541, time = 0.5501153469085693
# -> [0.0165695353561545*cos(theta)**5], p = 4.5349631999999984e-05, error = 1.2713655929101162, time = 0.08665132522583008
# -> [2.13645513317989e-5*deltaT**3*theta*cos(theta)**2], p = 7.558271999999996e-05, error = 1.200378019986933, time = 0.13814306259155273
# -> [-0.000139659528014332*deltaT**2*theta**2*cos(theta)**3], p = 2.644790538239998e-09, error = 1.251644787849211, time = 0.7761435508728027
# -> [-7.82864722727673e-11*deltaT**6*theta**3*cos(theta)**2], p = 9.254651051409401e-13, error = 1.5020296811598781, time = 0.8398847579956055
# -> [0.000542690459265324*deltaT**2*theta*cos(theta)**4], p = 8.162933759999998e-06, error = 1.2387516256463778, time = 0.14655613899230957
# -> [-2.69457064853692e-7*deltaT**4*theta*cos(theta)**3], p = 2.448880127999999e-07, error = 1.2600300575110646, time = 0.33806610107421875
# -> [-1.81902694596276e-6*deltaT**3*theta**3*cos(theta)], p = 8.815968460799998e-10, error = 1.2381557826625615, time = 0.5808923244476318
# -> [1.1826688362414e-6*deltaT**4*cos(theta)**2], p = 4.760622968831997e-08, error = 1.1771863500536641, time = 0.855604887008667
# -> [5.2515077181481e-6*deltaT**3*cos(theta)**3], p = 0.00020407334399999996, error = 1.2702978603885433, time = 0.15588092803955078
# -> [3.53287593415517e-8*deltaT**2*theta*cos(theta)], p = 1.4281868906495992e-09, error = 1.271397005730175, time = 0.13638806343078613
# -> [0.00254862997786428*deltaT*theta**3], p = 9.795520512e-09, error = 1.1606701455052428, time = 0.09664106369018555
# -> [3.1979781778041e-5*deltaT**3*theta], p = 5.441955839999999e-06, error = 0.8310185174888817, time = 0.32642626762390137
# -> [3.19757323201155e-5*deltaT**3*theta], p = 8.815968460799997e-08, error = 0.8310185085581944, time = 0.08869314193725586
# -> [-0.000395813795341284*deltaT**2*theta*cos(theta)], p = 9.523422719999997e-06, error = 1.2435122300300716, time = 0.6035034656524658
# -> [-0.00477132116432083*deltaT*theta**2*cos(theta)], p = 1.7635967999999998e-05, error = 1.2335655982830287, time = 0.12172055244445801
# -> [4.11528203182027e-6*deltaT**3*theta**2*cos(theta)**4], p = 5.289581076479998e-09, error = 1.2538496357514934, time = 0.7553040981292725
# -> [0.000337478279257688*deltaT**2*theta**2], p = 4.5349631999999997e-07, error = 1.0408757423683497, time = 0.10827398300170898
# -> [1.49186093126015e-7*deltaT**4*theta**2*cos(theta)**2], p = 2.644790538239998e-09, error = 1.2372560365292458, time = 0.8024861812591553
# -> [5.3994475502119e-5*deltaT**2*theta**3*cos(theta)**2], p = 2.720977919999999e-08, error = 1.2437260675799322, time = 0.2592356204986572
# -> [0.00140151452084344*deltaT**2*cos(theta)**4], p = 2.8570268159999983e-05, error = 1.2129589733801607, time = 0.18565630912780762
# -> [-0.00334396218748337*deltaT*theta**2*cos(theta)**5], p = 5.289581076479998e-09, error = 1.259747132264414, time = 0.12686371803283691
# -> [1.02050956654708e-5*deltaT**3*theta**2], p = 5.038848e-06, error = 1.0413954654242106, time = 0.6043694019317627
# -> [4.49158674820952e-6*deltaT**3*cos(theta)], p = 2.203992115199999e-06, error = 1.2701681979555557, time = 0.10265135765075684
# -> [2.03321771121327e-8*deltaT**5*theta], p = 4.897760255999998e-07, error = 0.9055576678659414, time = 0.7485008239746094
# -> [0.000143358726931819*deltaT**2*theta**2*cos(theta)**4], p = 1.542441841901567e-11, error = 1.252148921393212, time = 0.6118206977844238
# -> [-6.1510091633933e-11*deltaT**5*theta*cos(theta)**4], p = 2.698656246590981e-13, error = 1.2716685217890302, time = 0.41192126274108887
# -> [2.85700908325218e-9*deltaT**5*cos(theta)], p = 5.289581076479997e-07, error = 1.2703801495244447, time = 0.2694284915924072
# -> [0.00277390496904627*deltaT*cos(theta)**7], p = 1.3223952691199992e-07, error = 1.2711928427885162, time = 0.08155322074890137
# -> [0.0025834960620293*deltaT*cos(theta)**5], p = 2.3803114844159985e-08, error = 1.2712044609898183, time = 0.011680841445922852
# -> [-0.000118935856405135*cos(theta)**2], p = 9.069926399999997e-05, error = 1.271412162953509, time = 0.14732789993286133
# -> [-5.1644228183198e-7*deltaT**3*theta**4*cos(theta)], p = 2.938656153599999e-10, error = 1.2452719621226676, time = 1.1911208629608154
# -> [0.0015160547797861*deltaT*theta**3*cos(theta)**2], p = 1.679616e-06, error = 1.2449231083187287, time = 0.417316198348999
# -> [0.00208863902930273*deltaT**2], p = 7.346640383999997e-07, error = 0.6556113356546375, time = 0.07729029655456543
# -> [0.00208864739077564*deltaT**2], p = 9.069926399999997e-05, error = 0.6556113356692183, time = 0.35634922981262207
# -> [4.78046995212133e-5*deltaT**3*cos(theta)**2], p = 3.9671858073599974e-07, error = 1.1602933687143127, time = 0.08314871788024902
# -> [5.52756559012127e-6*deltaT**3*theta**2*cos(theta)**2], p = 4.5349631999999986e-07, error = 1.2336024013638411, time = 0.15909790992736816
# -> [-9.77909713735388e-9*deltaT**5*theta*cos(theta)], p = 4.081466879999999e-06, error = 1.2483609777686635, time = 0.6026694774627686
# -> [-5.16704821305198e-6*deltaT**3*theta**2*cos(theta)], p = 1.4693280767999997e-08, error = 1.2333503196299371, time = 0.24963092803955078
# -> [0.00173375211220218*deltaT**2*cos(theta)**2], p = 2.9386561535999988e-06, error = 1.1473408313090792, time = 0.5897581577301025
# -> [-8.50165461278636e-9*deltaT**5*theta*cos(theta)], p = 7.346640383999998e-07, error = 1.2479078366579655, time = 0.8227977752685547
# -> [1.09643483075536e-7*deltaT**4*theta**2*cos(theta)**4], p = 2.6447905382399986e-09, error = 1.2556605215123156, time = 0.5203969478607178
# -> [0.000542695109697566*deltaT**2*theta*cos(theta)**4], p = 1.2244400639999995e-06, error = 1.238751625641025, time = 0.5377147197723389
# -> [5.25885648375018e-6*deltaT**3*cos(theta)**3], p = 4.407984230399998e-06, error = 1.2702978581917292, time = 0.12056398391723633
# -> [2.1371712754021e-5*deltaT**3*theta*cos(theta)**2], p = 1.2244400639999995e-06, error = 1.2003780111146278, time = 0.14695453643798828
# -> [-0.0100558660410399*deltaT*theta*cos(theta)**3], p = 1.4281868906495992e-09, error = 1.256184241932343, time = 0.16025400161743164
# -> [0.402403498702091*cos(theta)**6], p = 4.081466879999998e-06, error = 1.257054462318996, time = 0.12138843536376953
# -> [-0.000117043697753348*deltaT**2*theta**2*cos(theta)**5], p = 4.760622968831998e-10, error = 1.259369992152178, time = 0.11632418632507324
# -> [0.000130183664233591*deltaT**2*cos(theta)], p = 4.081466879999997e-05, error = 1.2705157097969049, time = 0.1815636157989502
# -> [2.78229024909895e-8*deltaT**5*cos(theta)**2], p = 1.4693280767999994e-06, error = 1.1923612389336613, time = 0.9876918792724609
# -> [0.000137296037018733*deltaT**2*cos(theta)**3], p = 4.760622968831997e-08, error = 1.2707702105105547, time = 0.661585807800293
# -> [-0.121933102997601*theta*cos(theta)**3], p = 3.0233087999999994e-05, error = 1.2642134679214672, time = 0.4549117088317871
# -> [0.0306151516910794*theta**3], p = 1.5116544e-07, error = 1.222648427978136, time = 0.1714019775390625
# -> [4.10644597232503e-6*deltaT**3*theta**2*cos(theta)**4], p = 1.4693280767999992e-08, error = 1.2538496366919276, time = 0.4919905662536621
# -> [-2.62074305611935e-10*deltaT**6*theta**8*cos(theta)**8], p = 1.3598118630822476e-22, error = 455.84781433469345, time = 0.8218021392822266
# -> [1.18202342966837e-6*deltaT**4*cos(theta)**2], p = 6.802444799999997e-05, error = 1.1771863841369752, time = 0.6059696674346924
# -> [0.466087274350146*cos(theta)**4], p = 1.3223952691199992e-07, error = 1.2478732458577702, time = 0.15808367729187012
# -> [0.105924402126065*theta**2], p = 6.9984e-05, error = 1.1872487789776027, time = 0.07894325256347656
# -> [-5.16730619545936e-6*deltaT**3*theta**2*cos(theta)], p = 8.162933759999998e-08, error = 1.2333503197784175, time = 0.23374271392822266
# -> [0.00140151417904994*deltaT**2*cos(theta)**4], p = 5.142648268799998e-06, error = 1.2129589733801422, time = 0.10666370391845703
# -> [-0.0154331523017005*theta**3*cos(theta)**3], p = 1.5116544e-07, error = 1.263609496169181, time = 0.129072904586792
# -> [0.0010715324799342*deltaT**2*theta], p = 2.448880127999999e-07, error = 0.8261948614098873, time = 0.12871360778808594
# -> [-0.000355030548565845*deltaT**2*theta*cos(theta)**3], p = 2.3803114844159988e-08, error = 1.256021698117624, time = 0.12472820281982422
# -> [1.57685777223997e-5*deltaT**2*theta**4*cos(theta)**2], p = 2.9386561535999996e-10, error = 1.2511067755121266, time = 0.7220101356506348
# -> [5.535013281095e-6*deltaT**3*theta**2*cos(theta)**2], p = 4.760622968831998e-10, error = 1.2336023318425329, time = 0.1144258975982666
# -> [3.42983694200375e-7*deltaT**4*theta*cos(theta)**6], p = 1.4992534703283229e-12, error = 1.2555854615336948, time = 0.7484018802642822
# -> [1.02058798704117e-5*deltaT**3*theta**2], p = 8.162933759999998e-08, error = 1.0413954638645866, time = 0.15144991874694824
# -> [-0.00393756888923107*deltaT*theta**2*cos(theta)**3], p = 8.162933759999996e-08, error = 1.2523184611840694, time = 0.10269451141357422
# -> [6.89920781261311e-7*deltaT**3*theta*cos(theta)**7], p = 1.4992534703283229e-12, error = 1.2725162006488986, time = 0.35485339164733887
# -> [0.466132185862207*cos(theta)**4], p = 1.2244400639999995e-05, error = 1.2478732460384463, time = 0.4988694190979004
# -> [1.4887545953565e-6*deltaT**4], p = 0.0006998399999999999, error = 0.7784436991111419, time = 0.30768465995788574
# -> [2.88701655242729e-6*deltaT**3*theta**3], p = 1.5116543999999997e-07, error = 1.1475132609342908, time = 1.1323986053466797
# -> [-3.2148493761238e-7*deltaT**4*theta*cos(theta)], p = 4.897760255999998e-07, error = 1.2471766327735316, time = 0.8530361652374268
# -> [0.149438230316824*theta*cos(theta)**6], p = 1.5868743229439992e-08, error = 1.263423492772842, time = 0.0832524299621582
# -> [1.50969793584833e-7*deltaT**4*cos(theta)**5], p = 2.77639531542282e-10, error = 1.2703447531130767, time = 0.25293874740600586
# -> [-0.000355042296696084*deltaT**2*theta*cos(theta)**3], p = 1.2244400639999995e-06, error = 1.2560216981017531, time = 0.17717385292053223
# -> [8.42748596878436e-7*deltaT**4*theta], p = 7.934371614719996e-09, error = 0.86579250328932, time = 0.602914571762085
# -> [-1.16059946006453e-9*deltaT**5*theta**3*cos(theta)], p = 2.856373781299198e-11, error = 1.2427357491457918, time = 0.911707878112793
# -> [0.018383796817039*theta**3*cos(theta)**2], p = 4.6656e-06, error = 1.2591859154212086, time = 0.06107521057128906
# -> [-3.25361196711076*deltaT**6*theta**2*cos(theta)**2], p = 4.760622968831999e-10, error = 8679435088.77745, time = 0.768549919128418
# -> [-3.99481039637678e-6*deltaT**3*theta**2*cos(theta)**3], p = 5.289581076479998e-09, error = 1.2536210630027729, time = 0.7419042587280273
# -> [0.149417015559836*theta*cos(theta)**6], p = 2.448880127999999e-07, error = 1.2634234920792586, time = 0.09267520904541016
# -> [1.27183854943698e-5*deltaT**3*theta*cos(theta)**6], p = 7.934371614719996e-09, error = 1.2540896359705929, time = 0.14354205131530762
# -> [3.80568083105444e-5*deltaT**3*cos(theta)**4], p = 1.5424418419015667e-09, error = 1.2193871628820636, time = 0.0974431037902832
# -> [-5.82903386757549e-9*deltaT**6*cos(theta)], p = 1.3223952691199992e-07, error = 4.405748904904696, time = 0.7305927276611328
# -> [-8.75210650696837e-6*deltaT**3*theta*cos(theta)**5], p = 4.627325525704701e-11, error = 1.2627539750340162, time = 0.6413624286651611
# -> [-8.32333670143773e-6*cos(theta)**4], p = 7.346640383999997e-07, error = 1.271392915417323, time = 0.13585424423217773
# -> [0.00208862942320701*deltaT**2], p = 4.081466879999998e-06, error = 0.655611335673691, time = 0.4333994388580322
# -> [0.00880555824324086*deltaT*theta**2], p = 2.519424e-06, error = 1.07517755624878, time = 0.3183631896972656
# -> [2.15464495029376e-8*deltaT**5*cos(theta)**4], p = 7.712209209507833e-10, error = 1.235039004695753, time = 0.7583966255187988
# -> [-0.00894314748159531*deltaT*theta*cos(theta)**5], p = 1.3604889599999997e-06, error = 1.2616437591106726, time = 0.07422971725463867
# -> [-2.75980749364635e-9*deltaT**7*cos(theta)], p = 7.346640383999997e-07, error = 80.82905158037359, time = 0.48626112937927246
# -> [0.00241034281106214*deltaT*cos(theta)**3], p = 2.040733439999999e-05, error = 1.2711788822213006, time = 0.21264243125915527
# -> [9.26549057240718e-7*deltaT*theta], p = 1.5116543999999997e-05, error = 1.2713712089559541, time = 0.22701072692871094
# -> [-2.30213135585046e-5*theta], p = 1.5116543999999997e-05, error = 1.2714113301738148, time = 0.13835573196411133
# -> [-0.000175135443584678*deltaT**2*theta**2*cos(theta)], p = 2.2674815999999992e-06, error = 1.2307884246505065, time = 0.6729698181152344
# -> [8.42229885045036e-7*deltaT**4*theta], p = 1.5116543999999997e-05, error = 0.8657926962721723, time = 0.6751487255096436
# -> [0.0052541876953223*deltaT*theta**2*cos(theta)**2], p = 4.760622968831997e-10, error = 1.232816426684703, time = 0.17734074592590332
# -> [0.000182094862511574*deltaT*cos(theta)**5], p = 2.6447905382399985e-07, error = 1.2713655602541467, time = 0.21811938285827637
# -> [-0.000175136779654386*deltaT**2*theta**2*cos(theta)], p = 7.558271999999999e-06, error = 1.2307884246530656, time = 0.2089099884033203
# -> [-5.16641513615113e-6*deltaT**3*theta**2*cos(theta)], p = 9.069926399999998e-07, error = 1.2333503200817741, time = 0.24235248565673828
# -> [-2.31118114742601e-9*deltaT**5*theta**2*cos(theta)**5], p = 2.914548746318259e-15, error = 1.2626420155504137, time = 0.397829532623291
# -> [-6.71239510249193e-9*deltaT**3], p = 1.3223952691199992e-07, error = 1.2714922899758272, time = 0.3500659465789795
# -> [2.44287409434043e-9*deltaT**6*cos(theta)**3], p = 2.3803114844159985e-08, error = 1.8852683955556293, time = 0.8372671604156494
# -> [0.000129772788499861*deltaT**2*cos(theta)], p = 7.346640383999997e-07, error = 1.2705157011103798, time = 0.23960113525390625
# -> [-2.90534941270319e-6*deltaT*theta**2*cos(theta)**4], p = 8.569121343897596e-11, error = 1.2714183466225615, time = 0.16561317443847656
# -> [2.79906692852472e-7*deltaT**4*theta**2], p = 4.5349631999999986e-07, error = 1.050423164604736, time = 0.5547425746917725
# -> [0.0150721725624752*deltaT*theta*cos(theta)**4], p = 4.4079842303999983e-08, error = 1.240807154572349, time = 0.13799381256103516
# -> [2.82815094127803e-8*deltaT**5], p = 0.00012597119999999996, error = 0.8721096445723943, time = 0.4053976535797119
# -> [1.12058729622617e-10*deltaT**5*theta**2], p = 4.5349631999999986e-07, error = 1.2653856142320272, time = 0.45053768157958984
# -> [2.91107505300232e-10*deltaT**6], p = 7.346640383999997e-07, error = 1.0718835835160119, time = 0.6635427474975586
# -> [1.01984428941089e-5*deltaT**3*theta**2], p = 4.1990400000000004e-05, error = 1.0413955999685198, time = 0.5533328056335449
# -> [-0.0033439738856119*deltaT*theta**2*cos(theta)**5], p = 8.162933759999998e-08, error = 1.2597471322643712, time = 0.08487749099731445
# -> [-1.27249581184499e-6*deltaT**3*theta**3*cos(theta)**3], p = 2.856373781299199e-11, error = 1.2557427198087314, time = 0.2268359661102295
# -> [0.00140150775097409*deltaT**2*cos(theta)**4], p = 2.3803114844159985e-08, error = 1.2129589733811204, time = 0.11663627624511719
# -> [3.59960265502859e-8*deltaT**5], p = 2.2674815999999992e-05, error = 0.8522324454582272, time = 0.6237573623657227
# -> [-3.33542198787237e-6*deltaT**3*theta**2*cos(theta)**5], p = 2.7763953154228204e-12, error = 1.260497970704771, time = 0.07926511764526367
# -> [0.0563767737072814*deltaT], p = 7.346640383999997e-07, error = 0.7560964680393166, time = 0.4124901294708252
# -> [-0.0100525319072851*deltaT*theta*cos(theta)**3], p = 8.815968460799997e-08, error = 1.2561842435890183, time = 0.18173623085021973
# -> [-2.01413806087628e-9*deltaT**6*theta*cos(theta)**2], p = 2.8563737812991984e-09, error = 2.5803374631282767, time = 0.8529753684997559
# -> [-1.69659124040352e-6*deltaT**3*theta**3*cos(theta)], p = 4.897760255999999e-09, error = 1.2379794989450679, time = 0.9698917865753174
# -> [1.53224320052037e-8*deltaT**5*theta*cos(theta)**2], p = 8.815968460799997e-08, error = 1.2110586073873284, time = 0.9241063594818115
# -> [0.00107153882692574*deltaT**2*theta], p = 1.3604889599999997e-06, error = 0.8261948614253952, time = 0.5652663707733154
# -> [1.83250913719839e-8*deltaT**5*cos(theta)**6], p = 2.498755783880538e-11, error = 1.2486875752768651, time = 0.6629247665405273
# -> [1.62431647094653e-7*deltaT**4*cos(theta)**3], p = 2.203992115199999e-06, error = 1.2699010503946415, time = 0.25567054748535156
# -> [-0.0195218702051994*theta**3*cos(theta)], p = 7.776000000000001e-05, error = 1.2556840707526695, time = 0.05991816520690918
# -> [-0.000274163143966241*deltaT**2*theta*cos(theta)**7], p = 2.570736403169278e-10, error = 1.2646091729918878, time = 0.1743760108947754
# -> [-0.000395821436354785*deltaT**2*theta*cos(theta)], p = 9.795520511999997e-07, error = 1.243512230041993, time = 0.13448810577392578
# ...
# -> [-0.00017513544335319*deltaT**2*theta**2*cos(theta)], p = 2.9386561535999987e-08, error = 1.2307884246505065, time = 0.1378169059753418
# -> [2.14341823356449e-8*deltaT**5*cos(theta)**4], p = 8.095968739772942e-13, error = 1.23503799215091, time = 0.16062521934509277
# -> [-5.83184665265006e-9*deltaT**5*theta*cos(theta)**5], p = 4.857581243863765e-14, error = 1.264953262728533, time = 0.13928866386413574
# -> [1.50865442701132e-7*deltaT**4*cos(theta)**5], p = 8.569121343897593e-09, error = 1.2703447537370607, time = 0.24437236785888672
# -> [-1.41745542318227e-7*deltaT**4*theta**2*cos(theta)], p = 4.5349631999999986e-07, error = 1.236078991702379, time = 0.5438065528869629
# -> [-4.37432468045861e-5*deltaT*cos(theta)], p = 8.162933759999996e-06, error = 1.2714053961942648, time = 0.12339997291564941
# -> [0.000143364574791193*deltaT**2*theta**2*cos(theta)**4], p = 9.521245937663996e-10, error = 1.252148921364296, time = 0.20571660995483398
# -> [-9.43600840302263e-9*deltaT**5*theta*cos(theta)], p = 4.4079842303999983e-08, error = 1.2481362817064352, time = 0.7810521125793457
# -> [-2.27508876128868e-7*deltaT**4*theta*cos(theta)**5], p = 1.4281868906495992e-09, error = 1.2639623231888388, time = 0.9046134948730469
# -> [0.0150720983202869*deltaT*theta*cos(theta)**4], p = 5.441955839999998e-06, error = 1.2408071545715595, time = 0.09521722793579102
# -> [4.52310443272756e-9*deltaT**5*cos(theta)**3], p = 4.284560671948796e-09, error = 1.2696285705067105, time = 0.9815816879272461
# -> [-3.27125460954079e-5*cos(theta)], p = 4.081466879999998e-06, error = 1.2713922915631448, time = 0.011257171630859375
# -> [0.0342881664041476*deltaT*cos(theta)**6], p = 1.3223952691199992e-07, error = 1.2381724834920447, time = 0.4363572597503662
# -> [-1.16780526520673e-5*deltaT**3*theta*cos(theta)], p = 6.8024447999999985e-06, error = 1.2454411594644994, time = 0.6728274822235107
# -> [0.030615063332727*theta**3], p = 5.1840000000000005e-05, error = 1.2226484279777199, time = 0.07279062271118164
# -> [-1.01127993065388e-5*deltaT**3*theta*cos(theta)**3], p = 1.4281868906495992e-09, error = 1.258032387522155, time = 0.35777759552001953
# -> [-6.32442052344032e-10*deltaT**3*theta*cos(theta)**2], p = 5.141472806338557e-10, error = 1.2713961687779451, time = 0.23151445388793945
# -> [-0.00160806562886025*deltaT*theta**3*cos(theta)], p = 1.679616e-06, error = 1.237380009508962, time = 0.08792924880981445
# -> [1.51437123867709e-9*deltaT**5*cos(theta)], p = 0.00011337407999999997, error = 1.2705993633994084, time = 0.5103702545166016
# -> [0.0631118257421815*theta**2*cos(theta)**2], p = 0.00015552000000000003, error = 1.2538331000362968, time = 0.030112743377685547
# -> [1.53439004428587e-8*deltaT**5*theta*cos(theta)**2], p = 2.570736403169278e-10, error = 1.2110584803151803, time = 0.9756729602813721
# -> [1.5596880102074e-7*deltaT**4*cos(theta)**3], p = 4.081466879999998e-06, error = 1.2699040949285443, time = 0.341447114944458
# -> [6.99948352556322e-8*deltaT**2*theta**2*cos(theta)**3], p = 2.7763953154228208e-12, error = 1.2714117280276767, time = 0.2116401195526123
# -> [-0.0476563458737019*theta**2*cos(theta)**3], p = 2.5194239999999994e-06, error = 1.262557640128008, time = 0.12347197532653809
# -> [-0.0973709431832689*theta*cos(theta)**7], p = 7.934371614719996e-09, error = 1.2682378557775509, time = 0.08737468719482422
# -> [0.0306150585754282*theta**3], p = 4.665600000000001e-06, error = 1.222648427977721, time = 0.140364408493042
# -> [0.0150720513664462*deltaT*theta*cos(theta)**4], p = 7.934371614719996e-09, error = 1.2408071545718362, time = 0.18222594261169434
# -> [1.49327542498707e-7*deltaT**4*theta**2*cos(theta)**2], p = 4.407984230399999e-08, error = 1.237255962121097, time = 0.8698103427886963
# -> [-1.16769876336808e-5*deltaT**3*theta*cos(theta)], p = 8.815968460799997e-08, error = 1.2454411593045778, time = 0.08424067497253418
# -> [2.83026552884565e-9*deltaT**5*cos(theta)], p = 2.3803114844159985e-08, error = 1.270380076652883, time = 1.0715916156768799
# -> [1.41976179932555e-7*deltaT**4*theta**2*cos(theta)**2], p = 8.162933759999996e-08, error = 1.2373419761552726, time = 0.5016911029815674
# -> [-5.81279185764717e-5*deltaT**2*theta**3*cos(theta)], p = 4.897760256e-09, error = 1.2353404278973605, time = 0.1409001350402832
# -> [1.55806085682516e-6*deltaT**3*theta**3*cos(theta)**2], p = 4.897760255999998e-09, error = 1.2461781317736214, time = 0.755357027053833
# -> [-0.00334393926187492*deltaT*theta**2*cos(theta)**5], p = 2.776395315422821e-12, error = 1.2597471322653286, time = 0.06380748748779297
# -> [0.00405272280056574*deltaT*theta**2*cos(theta)**4], p = 8.162933759999996e-08, error = 1.2529471449313716, time = 0.12189841270446777
# -> [-7.24120034309647e-10*deltaT**6*theta**3*cos(theta)**4], p = 1.6658371892536922e-13, error = 5.614913715453504, time = 0.6928966045379639
# -> [0.00525382741387347*deltaT*theta**2*cos(theta)**2], p = 2.64479053824e-09, error = 1.232816426830258, time = 0.49576258659362793
# -> [5.04307059579421e-9*deltaT**5*cos(theta)], p = 8.162933759999996e-06, error = 1.2709962220545024, time = 0.7864224910736084
# -> [-0.000117084018995252*deltaT**2*theta**2*cos(theta)**5], p = 1.542441841901567e-11, error = 1.25936999358626, time = 0.17172598838806152
# -> [3.51082054016197e-8*deltaT**5], p = 4.081466879999998e-06, error = 0.8519960697614405, time = 0.4731748104095459
# -> [0.0165847824034252*cos(theta)**5], p = 0.00012597119999999996, error = 1.2713655928789345, time = 0.044486045837402344
# -> [-0.0107764897394591*deltaT*theta*cos(theta)], p = 2.448880127999999e-07, error = 1.2450644210135418, time = 0.18390965461730957
# -> [0.00151605990658728*deltaT*theta**3*cos(theta)**2], p = 2.7209779199999993e-08, error = 1.2449231083183654, time = 0.16018939018249512
# -> [8.42753757447995e-7*deltaT**4*theta], p = 4.4079842303999983e-08, error = 0.8657925032749086, time = 0.6828017234802246
# -> [0.00054269774871395*deltaT**2*theta*cos(theta)**4], p = 1.4281868906495992e-09, error = 1.2387516256401474, time = 0.1092529296875
# -> [3.52356175246622e-8*deltaT**5], p = 2.3803114844159985e-08, error = 0.8519892137967565, time = 0.20656251907348633
# -> [5.94461357166248e-5*deltaT**3], p = 2.2674815999999992e-05, error = 0.698682219534448, time = 0.4731271266937256
# -> [-1.27117601831988e-6*deltaT**3*theta**3*cos(theta)**3], p = 8.815968460799999e-10, error = 1.255742738168476, time = 0.9887094497680664
# -> [-8.00084551487675e-10*deltaT**5*cos(theta)], p = 4.284560671948796e-09, error = 1.2720440289836275, time = 0.4430656433105469
# -> [-3.20837278042485e-7*deltaT**4*theta*cos(theta)], p = 2.2674815999999996e-05, error = 1.247176367674855, time = 0.5762977600097656
# -> [-1.41655645988262e-7*deltaT**4*theta**2*cos(theta)], p = 2.9386561535999993e-08, error = 1.2360789501760623, time = 0.7202301025390625
# -> [2.13721089343624e-5*deltaT**3*theta*cos(theta)**2], p = 7.934371614719996e-09, error = 1.2003780111030808, time = 0.0481870174407959
# -> [5.82272471607209e-7*deltaT**4*theta*cos(theta)**2], p = 1.4281868906495992e-09, error = 1.2062174277588544, time = 1.0347959995269775
# -> [-0.00894488734006695*deltaT*theta*cos(theta)**5], p = 1.5868743229439992e-08, error = 1.261643759484425, time = 0.09973835945129395
# -> [2.12985237541087e-8*deltaT**5*cos(theta)**4], p = 4.284560671948796e-09, error = 1.2350394692020472, time = 0.60325026512146
# -> [-0.0578708897495199*theta**2*cos(theta)], p = 8.162933759999997e-08, error = 1.2538991686527123, time = 0.2122783660888672
# -> [3.34517766374613e-9*deltaT**3*theta*cos(theta)**4], p = 8.32918594626846e-12, error = 1.2713793823723452, time = 0.3077974319458008
# -> [1.5068211827449e-6*deltaT*cos(theta)**2], p = 2.3803114844159985e-08, error = 1.2713852820990708, time = 0.011301517486572266
# -> [-4.61150596383335e-8*deltaT**4*theta**3*cos(theta)], p = 1.5868743229439995e-10, error = 1.2407353323237278, time = 0.7218263149261475
# -> [-8.89418677275577e-8*deltaT**4*theta**2*cos(theta)**5], p = 4.997511567761076e-13, error = 1.2616719161947012, time = 0.6330733299255371
# -> [5.25895421726295e-6*deltaT**3*cos(theta)**3], p = 2.3803114844159985e-08, error = 1.2702978581913198, time = 0.11861968040466309
# -> [0.0342967441309747*deltaT*cos(theta)**6], p = 2.3803114844159985e-08, error = 1.2381724819012623, time = 0.5039899349212646
# -> [-7.9263066489697e-12*deltaT**7*theta*cos(theta)], p = 4.627325525704701e-11, error = 1.2486425162449613, time = 0.8165953159332275
# -> [7.89853843363793e-10*deltaT**6*cos(theta)**2], p = 1.3223952691199992e-07, error = 1.2089313433899465, time = 0.9743225574493408
# -> [0.000441633924856245*deltaT**2*theta*cos(theta)**6], p = 2.570736403169278e-10, error = 1.2527475727409179, time = 0.12175893783569336
# -> [-1.0023742930297e-5*deltaT**3*theta*cos(theta)**3], p = 1.3604889599999997e-06, error = 1.258031148029336, time = 0.14872193336486816
# -> [4.92791213701552e-6*deltaT**3*cos(theta)**5], p = 1.3223952691199992e-07, error = 1.2706128536342856, time = 0.5904860496520996
# -> [-0.00477139084360676*deltaT*theta**2*cos(theta)], p = 2.64479053824e-09, error = 1.2335655982908138, time = 0.15929651260375977
# -> [0.0424301573151458*deltaT**8*theta**2*cos(theta)**3], p = 8.995520821969936e-14, error = 156997691196.52188, time = 0.6694610118865967
# -> [-3.20302441010065e-7*deltaT**4*theta*cos(theta)], p = 1.4281868906495992e-09, error = 1.2471762994849682, time = 0.1195378303527832
# -> [-1.00162934479443e-5*deltaT**3*theta*cos(theta)**3], p = 2.570736403169278e-10, error = 1.2580311405973745, time = 0.08959078788757324
# -> [-6.84502896715418e-9*deltaT**5*theta*cos(theta)**3], p = 1.428186890649599e-09, error = 1.261603139498389, time = 0.7798140048980713
# -> [-1.13892240150995e-7*deltaT**4*theta**2*cos(theta)**3], p = 2.9386561535999987e-08, error = 1.2557510062893165, time = 0.6777687072753906
# -> [1.50773615784068e-8*deltaT**5*theta], p = 7.558271999999998e-06, error = 0.9373350839467932, time = 0.4160423278808594
# -> [1.57225793261263e-5*deltaT**3*theta*cos(theta)**4], p = 2.448880127999999e-07, error = 1.2411682840761018, time = 0.16060638427734375
# -> [-0.000139664766685732*deltaT**2*theta**2*cos(theta)**3], p = 8.16293376e-08, error = 1.2516447878626973, time = 0.220703125
# -> [0.0250713328261428*cos(theta)**5], p = 4.081466879999998e-06, error = 1.2713725218607546, time = 0.1496448516845703
# -> [0.0183853394188805*theta**3*cos(theta)**2], p = 8.398079999999999e-07, error = 1.2591859155067098, time = 0.06694173812866211
# -> [0.00237560658783628*deltaT*cos(theta)**3], p = 2.6447905382399985e-07, error = 1.271178758862928, time = 0.13527321815490723
# -> [1.63414553283771e-7*deltaT**4*cos(theta)**3], p = 7.712209209507833e-10, error = 1.2699009962369165, time = 0.10936379432678223
# -> [-3.99481235821911e-6*deltaT**3*theta**2*cos(theta)**3], p = 4.760622968831999e-10, error = 1.2536210630029063, time = 0.14452195167541504
# -> [-1.18668624951457e-10*deltaT**6*theta*cos(theta)**3], p = 4.627325525704701e-11, error = 1.263508413195613, time = 0.8981945514678955
# -> [-0.00160807364398455*deltaT*theta**3*cos(theta)], p = 4.6656000000000015e-06, error = 1.2373800095096432, time = 0.11321258544921875
# -> [9.28306703157518e-7*deltaT**4*cos(theta)**4], p = 1.3223952691199992e-07, error = 1.2275986127556386, time = 0.5576493740081787
# -> [-3.08100012615969e-9*deltaT**4*theta**5*cos(theta)**3], p = 5.7127475625984e-13, error = 1.2620945037387803, time = 1.0981781482696533
# -> [3.80487636754332e-5*deltaT**3*cos(theta)**4], p = 4.081466879999998e-06, error = 1.2193871649049284, time = 0.11365461349487305
# -> [0.00254866506915*deltaT*theta**3], p = 8.398080000000001e-07, error = 1.1606701454798578, time = 0.17750859260559082
# -> [9.63939453356012e-5*cos(theta)**3], p = 7.346640383999997e-07, error = 1.2713917596013713, time = 0.01092386245727539
# -> [-0.0154331650202278*theta**3*cos(theta)**3], p = 8.398079999999999e-07, error = 1.263609496169185, time = 0.037288665771484375
# -> [1.63370163866696e-7*deltaT**4*cos(theta)**3], p = 2.3803114844159985e-08, error = 1.2699009963552585, time = 0.7114686965942383
# -> [9.58466322584901e-5*deltaT**2*theta**3], p = 8.398079999999999e-07, error = 1.14571089340768, time = 0.2248401641845703
# -> [2.16544652746762e-8*deltaT**5*cos(theta)**4], p = 2.3803114844159985e-08, error = 1.2350418894219608, time = 0.7778353691101074
# -> [0.179335970625687*theta*cos(theta)**4], p = 4.897760255999998e-07, error = 1.2576516759928325, time = 0.14841628074645996
# -> [9.27215943242389e-7*deltaT**4*cos(theta)**4], p = 4.284560671948796e-09, error = 1.227598556028511, time = 0.6271345615386963
# -> [-0.00013965990569231*deltaT**2*theta**2*cos(theta)**3], p = 8.569121343897596e-11, error = 1.25164478784831, time = 0.14997625350952148
# -> [0.0195363651346209*deltaT*theta*cos(theta)**2], p = 2.448880127999999e-07, error = 1.2026133260183078, time = 0.17437410354614258
# -> [1.51630067874285e-8*deltaT**5*theta*cos(theta)**2], p = 7.934371614719996e-09, error = 1.2110671249631062, time = 0.7221851348876953
# -> [0.00349595810194588*deltaT**9*theta**4*cos(theta)**2], p = 3.238387495909177e-16, error = 4492060141981.221, time = 0.8725330829620361
# -> [-0.109203103274915*theta*cos(theta)**5], p = 2.448880127999999e-07, error = 1.2668085178980286, time = 0.09993505477905273
# -> [4.80584928621795e-10*deltaT**6*cos(theta)**4], p = 8.095968739772942e-13, error = 1.2412527236463302, time = 0.5708727836608887
# -> [7.82344693516802e-9*deltaT**5*cos(theta)**3], p = 7.712209209507833e-10, error = 1.2705704034980787, time = 0.49697303771972656
# -> [-0.122267748438113*theta*cos(theta)**3], p = 2.448880127999999e-07, error = 1.2642134138895271, time = 0.11041522026062012
# -> [-0.00160806799633889*deltaT*theta**3*cos(theta)], p = 1.5116544e-07, error = 1.2373800095089849, time = 0.14301323890686035
# -> [0.00525563246644388*deltaT*theta**2*cos(theta)**2], p = 8.162933759999996e-08, error = 1.2328164298021844, time = 0.47313499450683594
# -> [-6.36392150609073e-9*deltaT**5*theta**2*cos(theta)], p = 4.760622968831997e-10, error = 1.2536520949019963, time = 0.6193869113922119
# -> [-3.26490548287692e-9*deltaT**5*theta**2*cos(theta)**5], p = 8.569121343897597e-11, error = 1.2641502095762038, time = 0.5952262878417969
# -> [-4.43929719332509e-6*deltaT*cos(theta)**2], p = 7.346640383999997e-07, error = 1.2714121211465286, time = 0.23899364471435547
# -> [0.0489570078952292*theta**2*cos(theta)**4], p = 4.5349631999999997e-07, error = 1.2629198851723664, time = 0.1134488582611084
# -> [1.33682054941385e-6*deltaT**4*cos(theta)**2], p = 1.3223952691199992e-07, error = 1.178848362301469, time = 0.4715869426727295
# -> [5.47584907220495e-6*deltaT*cos(theta)**4], p = 1.3223952691199992e-07, error = 1.2713773899732914, time = 0.23713994026184082
# -> [1.54727922260629e-6*deltaT**3*theta**3*cos(theta)**2], p = 2.7209779199999993e-08, error = 1.2461785997633785, time = 0.15973281860351562
# -> [0.00120714582701069*deltaT**2*cos(theta)**6], p = 1.3223952691199992e-07, error = 1.2355443827086663, time = 0.11968350410461426
# -> [2.8645432599241e-10*deltaT**6*theta*cos(theta)**4], p = 2.698656246590981e-13, error = 1.2480574440981094, time = 0.948887825012207
# -> [0.000375571619246743*deltaT**2*theta*cos(theta)**8], p = 8.32918594626846e-12, error = 1.2591910994305435, time = 0.1972367763519287
# -> [-4.62741358536173e-8*deltaT**4*theta**3*cos(theta)], p = 8.815968460799998e-10, error = 1.2407355655866739, time = 0.8239648342132568
# -> [9.238744033115e-7*deltaT**4*cos(theta)**4], p = 2.3803114844159985e-08, error = 1.2275991500680692, time = 0.5677094459533691
# -> [5.79268455308026e-7*deltaT**4*theta*cos(theta)**2], p = 1.3604889599999997e-06, error = 1.2062192140685888, time = 0.4312448501586914
# -> [-0.0107751480594751*deltaT*theta*cos(theta)], p = 1.4281868906495992e-09, error = 1.2450644206057022, time = 0.11654329299926758
# -> [4.16669506340939e-5*deltaT**2*theta**3*cos(theta)**4], p = 2.856373781299198e-11, error = 1.2571869810561573, time = 0.1969468593597412
# -> [-3.08677261529056e-9*deltaT**6], p = 2.2674815999999992e-05, error = 4.400565543172118, time = 0.4472780227661133

# %%
ED.get_results(5)
# Out:
# ModelBox: 5 models
# -> [0.00208863902930273*deltaT**2], p = 7.346640383999997e-07, error = 0.6556113356546375, time = 0.07729029655456543
# -> [0.00208863907710713*deltaT**2], p = 0.0011337407999999997, error = 0.6556113356546384, time = 0.13623666763305664
# -> [0.0020886386913216*deltaT**2], p = 0.004199039999999999, error = 0.655611335654658, time = 0.12546396255493164
# -> [0.00208863635853096*deltaT**2], p = 0.011663999999999997, error = 0.6556113356560924, time = 0.15433311462402344
# -> [0.00208863155644536*deltaT**2], p = 0.021599999999999998, error = 0.6556113356661527, time = 0.47377610206604004

# %% [markdown]
# Gramatike se obnesejo slabo. Poskusil bom še z linearno regresijo. Ponovno bom dodal značilki 1/eta in sin(theta), ter deltaT. Zanimajo me linearni izrazi v produktih spremenljivk.

# %%
data['sin_of_theta'] = np.sin(data['theta'])
data_lr = data.drop(columns=['Tw', 'Ta', 'eta', 'theta'])

poly = PolynomialFeatures(5, include_bias=False)
X = poly.fit_transform(data_lr.drop('Q', axis=1))

imena_stolpcev = poly.get_feature_names_out()
data_lr = pd.DataFrame(X, columns=imena_stolpcev)
data_lr.head()
# Out:
#       deltaT  1_over_eta  sin_of_theta     deltaT^2  deltaT 1_over_eta  \
# 0  42.217191    2.864645      0.316390  1782.291254         120.937275
# 1   8.535838    1.217925      0.422107    72.860533          10.396010
# 2   3.654556    1.322609      0.954452    13.355782           4.833548
# 3  12.586385    1.937483      0.868418   158.417075          24.385901
# 4  34.837551   12.000908      0.322482  1213.654987         418.082233
#
#    deltaT sin_of_theta  1_over_eta^2  1_over_eta sin_of_theta  sin_of_theta^2  \
# 0            13.357081      8.206192                 0.906344        0.100102
# 1             3.603040      1.483341                 0.514095        0.178175
# 2             3.488097      1.749294                 1.262366        0.910978
# 3            10.930248      3.753839                 1.682546        0.754151
# 4            11.234482    144.021782                 3.870076        0.103995
#
#        deltaT^3  ...  deltaT 1_over_eta^3 sin_of_theta  \
# 0  75243.331122  ...                        313.995968
# 1    621.925724  ...                          6.509246
# 2     48.809456  ...                          8.070168
# 3   1993.898215  ...                         79.495662
# 4  42280.768004  ...                      19417.589949
#
#    deltaT 1_over_eta^2 sin_of_theta^2  deltaT 1_over_eta sin_of_theta^3  \
# 0                           34.679708                          3.830247
# 1                            2.255969                          0.781872
# 2                            5.823782                          4.202693
# 3                           35.631544                         15.970769
# 4                          521.779089                         14.020969
#
#    deltaT sin_of_theta^4   1_over_eta^5  1_over_eta^4 sin_of_theta  \
# 0               0.423037     192.909764                  21.306179
# 1               0.270980       2.679802                   0.928763
# 2               3.032845       4.047219                   2.920648
# 3               7.158418      27.301659                  12.237149
# 4               0.376764  248926.107778                6689.009194
#
#    1_over_eta^3 sin_of_theta^2  1_over_eta^2 sin_of_theta^3  \
# 0                     2.353190                     0.259901
# 1                     0.321890                     0.111560
# 2                     2.107666                     1.520983
# 3                     5.484935                     2.458457
# 4                   179.743476                     4.829971
#
#    1_over_eta sin_of_theta^4  sin_of_theta^5
# 0                   0.028705        0.003170
# 1                   0.038664        0.013400
# 2                   1.097607        0.792081
# 3                   1.101930        0.493907
# 4                   0.129788        0.003488
#
# [5 rows x 55 columns]

# %%
from lr import lasso_regresija
izraz, napaka = lasso_regresija(data_lr, data['Q'], lam=1)
print(izraz)
print(napaka)
# Out:
# 500
# 0.412*deltaT + 0.623*1/eta + 0.173*sin(theta) + 0.470*deltaT^2 + 0.316*deltaT 1/eta + 0.015*deltaT sin(theta) + 0.176*1/eta^2 + 0.871*1/eta sin(theta) + 0.475*sin(theta)^2 + 0.160*deltaT^3 + 0.915*deltaT^2 1/eta + 0.323*deltaT^2 sin(theta) + 0.770*deltaT 1/eta^2 + 0.050*deltaT 1/eta sin(theta) + 0.644*deltaT sin(theta)^2 + 0.239*1/eta^3 + 0.357*1/eta^2 sin(theta) + 0.207*1/eta sin(theta)^2 + 0.329*sin(theta)^3 + 0.066*deltaT^4 + 0.332*deltaT^3 1/eta + 0.021*deltaT^3 sin(theta) + 0.217*deltaT^2 1/eta^2 + 0.388*deltaT^2 1/eta sin(theta) + 0.455*deltaT^2 sin(theta)^2 + 0.129*deltaT 1/eta^3 + 0.259*deltaT 1/eta^2 sin(theta) + 0.459*deltaT 1/eta sin(theta)^2 + 0.719*deltaT sin(theta)^3 + 0.126*1/eta^4 + 0.343*1/eta^3 sin(theta) + 0.624*1/eta^2 sin(theta)^2 + 0.798*1/eta sin(theta)^3 + 0.245*sin(theta)^4 + 0.059*deltaT^4 1/eta + 0.102*deltaT^4 sin(theta) + 0.945*deltaT^3 1/eta sin(theta) + 0.176*deltaT^3 sin(theta)^2 + 0.058*deltaT^2 1/eta^3 + 0.036*deltaT^2 1/eta^2 sin(theta) + 0.566*deltaT^2 1/eta sin(theta)^2 + 0.968*deltaT^2 sin(theta)^3 + 0.437*deltaT 1/eta^3 sin(theta) + 0.666*deltaT 1/eta^2 sin(theta)^2 + 0.957*deltaT 1/eta sin(theta)^3 + 0.351*deltaT sin(theta)^4 + 0.610*1/eta^3 sin(theta)^2 + 0.416*1/eta^2 sin(theta)^3 + 0.265*1/eta sin(theta)^4 + 0.943*sin(theta)^5
# 71820990853669.36

# %% [markdown]
# Tudi linearna regresija ne daje odličnih rezultatov.

# %%
data_pysr = data[[ 'deltaT', 'sin_of_theta', '1_over_eta']]
data_pysr.head()
# Out:
#       deltaT  sin_of_theta  1_over_eta
# 0  42.217191      0.316390    2.864645
# 1   8.535838      0.422107    1.217925
# 2   3.654556      0.954452    1.322609
# 3  12.586385      0.868418    1.937483
# 4  34.837551      0.322482   12.000908

# %%
from pysr import PySRRegressor

model = PySRRegressor(
    niterations=100,  # < Increase me for better results
    binary_operators=["+", "*"],
    unary_operators=[
        # "cos",
        # "exp",
        # "sin",
        "inv(x) = 1/x",
        # ^ Custom operator (julia syntax)
    ],
    extra_sympy_mappings={"inv": lambda x: 1 / x},
    # ^ Define operator for SymPy as well
    loss="loss(prediction, target) = (prediction - target)^2",
    # ^ Custom loss function (julia syntax)
)

# %%
model.fit(data_pysr, data['Q'])
# Out:
# /home/urh/.local/lib/python3.10/site-packages/pysr/sr.py:1296: UserWarning: Note: it looks like you are running in Jupyter. The progress bar will be turned off.
#   warnings.warn(
# /home/urh/.local/lib/python3.10/site-packages/pysr/sr.py:1364: FutureWarning: Index.is_object is deprecated.Use pandas.api.types.is_object_dtype instead
#   if X.columns.is_object() and X.columns.str.contains(" ").any():
# Compiling Julia backend...
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/pysr/julia_helpers.py:25, in _load_juliainfo()
#      24 try:
# ---> 25     juliainfo = JuliaInfo.load(julia="julia")
#      26 except FileNotFoundError:
#
# File ~/.local/lib/python3.10/site-packages/julia/juliainfo.py:68, in JuliaInfo.load(cls, julia, **popen_kwargs)
#      65 juliainfo_script = os.path.join(
#      66     os.path.dirname(os.path.realpath(__file__)), "juliainfo.jl"
#      67 )
# ---> 68 proc = subprocess.Popen(
#      69     [julia, "--startup-file=no", juliainfo_script],
#      70     stdout=subprocess.PIPE,
#      71     stderr=subprocess.PIPE,
#      72     universal_newlines=True,
#      73     **popen_kwargs
#      74 )
#      76 stdout, stderr = proc.communicate()
#
# File /usr/lib/python3.10/subprocess.py:969, in Popen.__init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, user, group, extra_groups, encoding, errors, text, umask, pipesize)
#     966             self.stderr = io.TextIOWrapper(self.stderr,
#     967                     encoding=encoding, errors=errors)
# --> 969     self._execute_child(args, executable, preexec_fn, close_fds,
#     970                         pass_fds, cwd, env,
#     971                         startupinfo, creationflags, shell,
#     972                         p2cread, p2cwrite,
#     973                         c2pread, c2pwrite,
#     974                         errread, errwrite,
#     975                         restore_signals,
#     976                         gid, gids, uid, umask,
#     977                         start_new_session)
#     978 except:
#     979     # Cleanup if the child failed starting.
#
# File /usr/lib/python3.10/subprocess.py:1845, in Popen._execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, restore_signals, gid, gids, uid, umask, start_new_session)
#    1844         err_msg = os.strerror(errno_num)
# -> 1845     raise child_exception_type(errno_num, err_msg, err_filename)
#    1846 raise child_exception_type(err_msg)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'julia'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 model.fit(data_pysr, data['Q'])
#
# File ~/.local/lib/python3.10/site-packages/pysr/sr.py:1845, in PySRRegressor.fit(self, X, y, Xresampled, weights, variable_names)
#    1842     self._checkpoint()
#    1844 # Perform the search:
# -> 1845 self._run(X, y, mutated_params, weights=weights, seed=seed)
#    1847 # Then, after fit, we save again, so the pickle file contains
#    1848 # the equations:
#    1849 if not self.temp_equation_file:
#
# File ~/.local/lib/python3.10/site-packages/pysr/sr.py:1535, in PySRRegressor._run(self, X, y, mutated_params, weights, seed)
#    1532 if not already_ran and update_verbosity != 0:
#    1533     print("Compiling Julia backend...")
# -> 1535 Main = init_julia(self.julia_project, julia_kwargs=julia_kwargs)
#    1537 if cluster_manager is not None:
#    1538     cluster_manager = _load_cluster_manager(Main, cluster_manager)
#
# File ~/.local/lib/python3.10/site-packages/pysr/julia_helpers.py:172, in init_julia(julia_project, quiet, julia_kwargs, return_aux)
#     168     julia_kwargs = {"optimize": 3}
#     170 from julia.core import JuliaInfo, UnsupportedPythonError
# --> 172 _julia_version_assertion()
#     173 processed_julia_project, is_shared = _process_julia_project(julia_project)
#     174 _set_julia_project_env(processed_julia_project, is_shared)
#
# File ~/.local/lib/python3.10/site-packages/pysr/julia_helpers.py:270, in _julia_version_assertion()
#     269 def _julia_version_assertion():
# --> 270     if not is_julia_version_greater_eq(version=(1, 6, 0)):
#     271         raise NotImplementedError(
#     272             "PySR requires Julia 1.6.0 or greater. "
#     273             "Please update your Julia installation."
#     274         )
#
# File ~/.local/lib/python3.10/site-packages/pysr/julia_helpers.py:134, in is_julia_version_greater_eq(juliainfo, version)
#     132 """Check if Julia version is greater than specified version."""
#     133 if juliainfo is None:
# --> 134     juliainfo = _load_juliainfo()
#     135 current_version = (
#     136     juliainfo.version_major,
#     137     juliainfo.version_minor,
#     138     juliainfo.version_patch,
#     139 )
#     140 return current_version >= version
#
# File ~/.local/lib/python3.10/site-packages/pysr/julia_helpers.py:28, in _load_juliainfo()
#      26     except FileNotFoundError:
#      27         env_path = os.environ["PATH"]
# ---> 28         raise FileNotFoundError(
#      29             f"Julia is not installed in your PATH. Please install Julia and add it to your PATH.\n\nCurrent PATH: {env_path}",
#      30         )
#      32 return juliainfo
#
# FileNotFoundError: Julia is not installed in your PATH. Please install Julia and add it to your PATH.
#
# Current PATH: /bin:/home/urh/.local/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/usr/games:/usr/local/games:/snap/bin:/snap/bin:/home/urh/.local/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/usr/games:/usr/local/games:/snap/bin:/snap/bin

# %% [markdown]
# ## Ročna oblika
# Poskusil bom še z ročno hervistiko. Iskal bom enačbo oblike deltaT^csin(theta)^c eta^c

# %%
data_rocno = data[ ['deltaT', 'sin_of_theta', '1_over_eta']]
data_rocno.head()
# Out:
#       deltaT  sin_of_theta  1_over_eta
# 0  42.217191      0.316390    2.864645
# 1   8.535838      0.422107    1.217925
# 2   3.654556      0.954452    1.322609
# 3  12.586385      0.868418    1.937483
# 4  34.837551      0.322482   12.000908

# %%
from scipy.optimize import minimize

def equation(params):
    a, b, c, d = params
    q = a * data['deltaT']**b * data['sin_of_theta']**c * data['1_over_eta']**d
    return np.sum((data['Q'] - q)**2) / len(data)

results= minimize(equation, [1,1,1,1])
results["x"]
# Out:
# array([0.0021297 , 2.05180646, 1.02670162, 0.22636962])

# %%
a, b, c, d = results["x"]
print(f'Povprečna kvadratna napaka enačbe {a}deltaT^{b}sin(theta)^{c}eta^(-{d}) je  {results["fun"]}' )
# Out:
# Povprečna kvadratna napaka enačbe 0.0021297039865321972deltaT^2.0518064574801134sin(theta)^1.0267016242714626eta^(-0.2263696173867843) je  0.0375624885916007
