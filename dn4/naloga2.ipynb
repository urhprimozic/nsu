# %%
from ProGEDescend import uniform_rational_grammar, fast_converging_rational_grammar, uniform_probabilities, progedescend
from DN4_2_podatky import generiraj_enacbo_1, generiraj_enacbo_2, generiraj_enacbo_3
import ProGED as pg
import numpy as np

data = generiraj_enacbo_1()

data.head()
# Out:
#          x1        x2        x3        x4        x5          y
# 0  0.976270  4.303787  2.055268  0.897664 -1.526904 -15.517263
# 1  2.917882 -1.248256  7.835460  9.273255 -2.331170  -3.503980
# 2  5.834501  0.577898  1.360891  8.511933 -8.579279  -5.839364
# 3 -8.257414 -9.595632  6.652397  5.563135  7.400243  21.277328
# 4  9.572367  5.983171 -0.770413  5.610584 -7.634511 -15.241246

# %%
probs = uniform_probabilities(4)
g1, eq1, m1 = progedescend(data, ['y'], ['x1', 'x2', 'x3', 'x4'],probabilities=probs,sampling_size=5, verbose=1, file_logging='size=5_lr=0.01.txt', max_iter=50, learning_rate=0.01)
# Out:
# Starting iteration 1..    Gradient descend..  avg=-0.01127730294396961 grad=[-0.08487654320987655, -0.08487654320987655, 0, -0.08410493827160494, -0.08410493827160494, 0, 0.08641975308641975, 0, -0.0020576131687242796, 0.03497942386831275, 0.037037037037037035, 0.03497942386831276, 0]
# error: 18.13732812972686. Min: 18.13732812972686
# Starting iteration 2..    Gradient descend..  avg=-0.020128377383493858 grad=[-0.05423971818376348, -0.054233725503908196, 0, -0.05422119500156427, -0.05421647081779485, 0, 0.052140307677875426, 0, -0.03213296886933078, 7.851379187829187e-06, -0.03295519157710705, -0.03181779508901472, 0]
# error: 18.13732812972686. Min: 18.13732812972686
# Starting iteration 3..    Gradient descend..  avg=-0.006719226896540625 grad=[-0.049844150326507776, -0.049838909178613486, 0, -0.04980529790205708, -0.04920708221199767, 0, 0.04858871163635326, 0, -7.142090587662482e-06, 0.0314021219957759, 1.574350339386533e-05, 0.03134605491921253, 0]
# ...

# %%
g1

# %%
probs = uniform_probabilities(4)
g2, eq2, m2 = progedescend(data, ['y'], ['x1', 'x2', 'x3', 'x4'],probabilities=probs,sampling_size=100, verbose=1, file_logging='size=5_lr=0.01.txt', max_iter=5, learning_rate=0.01)
# Out:
# Starting iteration 1..    Gradient descend..  avg=-0.23230163070012527 grad=[-0.7005792438590935, -0.6997974293479824, 0, -0.8193431386000497, -0.8080022314785426, 0, 0.6497395424392618, 0, -0.37722066158419487, -0.008120037217828923, -0.1301849493329703, -0.12641305012022833, 0]
# error: 13.299759894150137. Min: 13.299759894150137
# Starting iteration 2..    Gradient descend..  avg=-0.07559149150333819 grad=[-0.2832326868788587, -0.2831373701265405, 0, -0.2617630732486319, -0.2652057484608768, 0, 0.27786879110655405, 0, -0.10379951697719376, -0.020450613167444696, -0.02269380186207587, -0.02027536992832826, 0]
# error: 13.299759894150137. Min: 13.299759894150137
# Starting iteration 3..    Gradient descend..  avg=-0.0403789423995719 grad=[-0.18719081601862816, -0.1872765208443298, 0, -0.17586853215454382, -0.17707063413923727, 0, 0.2062134589692166, 0, -0.044180604438681347, 0.027169955796550942, 0.009736647089024176, 0.0035407945461939463, 0]
# ...

# %% [markdown]
# Analiza
