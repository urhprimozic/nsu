# %% [markdown]
# # 2 Meta učenje

# %%
import pandas as pd
import numpy as np
import openml as oml
PODATKI = 'podatki.csv'
RANDOM_SEED = 420

data = pd.read_csv(PODATKI)
print('Število primerov: ', len(data))
features = data.columns[:-1]
print('Število značilk:', len(features))
MAX_N_FEATURES =  100 + len(features)
MIN_N_FEATURES = len(features)
print('Maksimalno število značilk originala: ', MAX_N_FEATURES)
MAX_N_EXAMPLES = 1000 + len(data)
MIN_N_EXAMPLES = len(data)
print('Maksimalno število primerov originala: ', MAX_N_EXAMPLES)

data['y'].value_counts()

# za lažje delo spremenim y 
data['y'] = data['y'].map(lambda x : True if x == 'teamEdward' else False)
data['y'].value_counts()
# Out:
# Število primerov:  1203
# Število značilk: 30
# Maksimalno število značilk originala:  130
# Maksimalno število primerov originala:  2203
# True     1025
# False     178
# Name: y, dtype: int64

# %% [markdown]
# Meta atributi so izbrani na [podlagi opisov na spletni strani](https://pymfe.readthedocs.io/en/latest/auto_pages/meta_features_description.html).

# %%
meta_features=[ 
    # kompleksnost (izpustimo model perfomranes, ker trajajo):
    'c1', 'c2', 'f1', 'f2', 'f3', 'f4',
    # general: (izpustimo number of ..., ker vemo, da je original drugačne oblike)
    'attr_to_inst', 'cat_to_num', 'freq_class', 'nr_attr',
    # info-theory 
    'attr_conc', # koncentracija
    'attr_ent', # entropija
    'class_conc', # per class 
    'class_ent', # entropija /razred
    'eq_num_attr', 
    'joint_ent',
    'mut_inf',
    'ns_ratio',
    # statistical
    'can_cor',
    'cor',
    'cov',
    'eigenvalues',
    'g_mean',
    'gravity',
    'h_mean',
    'iq_range',
    'kurtosis',
    'lh_trace',
    'mad',
    'max',
    'mean',
    'median',
    'min',
    'nr_cor_attr',
    'nr_disc',
    'nr_norm',
    'nr_outliers',
    'p_trace',
    'range',
    'roy_root',
    'sd',
    'sd_ratio',
    'skewness',
    'sparsity',
    't_mean',
    'var',
    'w_lambda'
]

# %%
from pymfe.mfe import MFE

# mfe = MFE(groups=["general", "statistical"])
mfe = MFE(features=meta_features)
X = data.drop(columns=['y']).to_numpy()
y = data['y'].to_numpy()
mfe.fit(X,y)

attribute_names, attribute_values = mfe.extract()

print(list(zip(attribute_names, attribute_values)))
# used meta features
# Out:
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/_internal.py:1139: UserWarning: Unknown feature 'c1'. You can check available feature names with either 'MFE.valid_metafeatures()' or 'MFE.metafeature_description()' methods.
#   warnings.warn(
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/_internal.py:1139: UserWarning: Unknown feature 'f4'. You can check available feature names with either 'MFE.valid_metafeatures()' or 'MFE.metafeature_description()' methods.
#   warnings.warn(
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/_internal.py:1139: UserWarning: Unknown feature 'f3'. You can check available feature names with either 'MFE.valid_metafeatures()' or 'MFE.metafeature_description()' methods.
#   warnings.warn(
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/_internal.py:1139: UserWarning: Unknown feature 'c2'. You can check available feature names with either 'MFE.valid_metafeatures()' or 'MFE.metafeature_description()' methods.
#   warnings.warn(
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/_internal.py:1139: UserWarning: Unknown feature 'f2'. You can check available feature names with either 'MFE.valid_metafeatures()' or 'MFE.metafeature_description()' methods.
#   warnings.warn(
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/_internal.py:1139: UserWarning: Unknown feature 'f1'. You can check available feature names with either 'MFE.valid_metafeatures()' or 'MFE.metafeature_description()' methods.
#   warnings.warn(
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/_internal.py:1568: UserWarning: It is not possible make equal discretization
#   warnings.warn("It is not possible make equal discretization")
# /home/uprimozic/.local/lib/python3.10/site-packages/sklearn/preprocessing/_encoders.py:828: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'can_cor' with summary 'sd'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/statistical.py:1267: RuntimeWarning: invalid value encountered in log
#   np.log(np.linalg.det(S_i)) for S_i in sample_cov_matrices
# [('attr_conc.mean', 0.184477170590798), ('attr_conc.sd', 0.18626145238963987), ('attr_ent.mean', 2.7993325529650517), ('attr_ent.sd', 0.7011380143695096), ('attr_to_inst', 0.02493765586034913), ('can_cor.mean', 0.5821867443429916), ('can_cor.sd', nan), ('cat_to_num', 0.0), ('class_conc.mean', 0.019535145762771742), ('class_conc.sd', 0.029033032007713847), ('class_ent', 0.6047202206385474), ('cor.mean', 0.3875109674449386), ('cor.sd', 0.25029717850985206), ('cov.mean', 814587.8949260311), ('cov.sd', 12329224.492271649), ('eigenvalues.mean', 149054282.89592808), ('eigenvalues.sd', 816289673.4614395), ('eq_num_attr', 10.095791708413493), ('freq_class.mean', 0.5), ('freq_class.sd', 0.4978548991396557), ('g_mean.mean', 90.06182629979813), ('g_mean.sd', 372.3042944085837), ('gravity', 24782.739382070275), ('h_mean.mean', 8.598977349283047), ('h_mean.sd', 7.040187261369319), ('iq_range.mean', 477.52449999999993), ('iq_range.sd', 2310.4910544504232), ('joint_ent.mean', 3.344154527076326), ('joint_ent.sd', 0.7106403843864122), ('kurtosis.mean', 79.61243774839646), ('kurtosis.sd', 141.41022728372604), ('lh_trace', 0.5127252077203708), ('mad.mean', 154.7058506), ('mad.sd', 710.3410585487753), ('max.mean', 50574.53200000001), ('max.sd', 255616.96133674876), ('mean.mean', 771.6398658908286), ('mean.sd', 3809.009370951238), ('median.mean', 113.00933333333333), ('median.sd', 491.18315821074833), ('min.mean', 2.2346666666666666), ('min.sd', 0.503420940841917), ('mut_inf.mean', 0.05989824652727273), ('mut_inf.sd', 0.04346610317407691), ('nr_attr', 30), ('nr_cor_attr', 0.3310344827586207), ('nr_disc', 1), ('nr_norm', 0.0), ('nr_outliers', 28), ('ns_ratio', 45.73479968550442), ('p_trace', 0.3389414052886918), ('range.mean', 50572.297333333336), ('range.sd', 255617.00912703524), ('roy_root', 0.5127252077203708), ('sd.mean', 2415.1857017568673), ('sd.sd', 12172.091917308384), ('sd_ratio', nan), ('skewness.mean', 5.5681874581979525), ('skewness.sd', 5.1295508130779695), ('sparsity.mean', 0.024572901696889252), ('sparsity.sd', 0.04081299568344404), ('t_mean.mean', 191.6042816966344), ('t_mean.sd', 879.9400611898221), ('var.mean', 149054282.89592808), ('var.sd', 813485780.1658672), ('w_lambda', 0.6610585947113081)]

# %% [markdown]
# Najprej bomo naložili kandidate iz OpenML, nato pa iz vsakega poračunali meta atribute.

# %%
# kandidate bom umejil s številom značilk in primerov. Uporablili bomo le podatkovja s 
# številom značilk in primerov nekje med našimi podatki in originalom podatkov.
datasets = oml.datasets.list_datasets(number_instances=f'{MIN_N_EXAMPLES-100}..{MAX_N_EXAMPLES+100}', number_features=f'{MIN_N_FEATURES-10}..{MAX_N_FEATURES+10}', output_format="dataframe")
data_ids = list(datasets["did"])
print(datasets)
# Out:
#          did                                               name  version  \
# 14        14                                      mfeat-fourier        1
# 16        16                                     mfeat-karhunen        1
# 22        22                                      mfeat-zernike        1
# 315      315                                           us_crime        1
# 930      930                                    colleges_usnews        2
# ...      ...                                                ...      ...
# 44788  44788  KDDCup09-Upselling_seed_0_nrows_2000_nclasses_...        1
# 44789  44789  KDDCup09-Upselling_seed_1_nrows_2000_nclasses_...        1
# 44790  44790  KDDCup09-Upselling_seed_2_nrows_2000_nclasses_...        1
# 44791  44791  KDDCup09-Upselling_seed_3_nrows_2000_nclasses_...        1
# 44792  44792  KDDCup09-Upselling_seed_4_nrows_2000_nclasses_...        1
#
#       uploader  status format  MajorityClassSize  MaxNominalAttDistinctValues  \
# 14           1  active   ARFF              200.0                         10.0
# 16           1  active   ARFF              200.0                         10.0
# 22           1  active   ARFF              200.0                         10.0
# 315         94  active   ARFF                NaN                          NaN
# 930          2  active   ARFF              688.0                         51.0
# ...        ...     ...    ...                ...                          ...
# 44788    32840  active   arff             1853.0                          NaN
# 44789    32840  active   arff             1853.0                          NaN
# 44790    32840  active   arff             1853.0                          NaN
# 44791    32840  active   arff             1853.0                          NaN
# 44792    32840  active   arff             1853.0                          NaN
#
#        MinorityClassSize  NumberOfClasses  NumberOfFeatures  \
# 14                 200.0             10.0              77.0
# 16                 200.0             10.0              65.0
# 22                 200.0             10.0              48.0
# 315                  NaN              0.0             128.0
# 930                614.0              2.0              34.0
# ...                  ...              ...               ...
# 44788              147.0              2.0             101.0
# 44789              147.0              2.0             101.0
# 44790              147.0              2.0             101.0
# 44791              147.0              2.0             101.0
# 44792              147.0              2.0             101.0
#
#        NumberOfInstances  NumberOfInstancesWithMissingValues  \
# 14                2000.0                                 0.0
# 16                2000.0                                 0.0
# 22                2000.0                                 0.0
# 315               1994.0                              1871.0
# 930               1302.0                              1144.0
# ...                  ...                                 ...
# 44788             2000.0                              2000.0
# 44789             2000.0                              2000.0
# 44790             2000.0                              2000.0
# 44791             2000.0                                 0.0
# 44792             2000.0                              2000.0
#
#        NumberOfMissingValues  NumberOfNumericFeatures  \
# 14                       0.0                     76.0
# 16                       0.0                     64.0
# 22                       0.0                     47.0
# 315                  39202.0                    127.0
# 930                   7830.0                     32.0
# ...                      ...                      ...
# 44788                 3570.0                     99.0
# 44789                 7121.0                     99.0
# 44790                 5914.0                    100.0
# 44791                    0.0                    100.0
# 44792                 9426.0                     98.0
#
#        NumberOfSymbolicFeatures
# 14                          1.0
# 16                          1.0
# 22                          1.0
# 315                         0.0
# 930                         2.0
# ...                         ...
# 44788                       2.0
# 44789                       2.0
# 44790                       1.0
# 44791                       1.0
# 44792                       3.0
#
# [340 rows x 16 columns]

# %% [markdown]
# Nalaganje podatkov:

# %%
all_datasets = oml.datasets.get_datasets(data_ids)
print(all_datasets)
# Out:
# [OpenML Dataset
# ==============
# Name..........: mfeat-fourier
# Version.......: 1
# Format........: ARFF
# Upload Date...: 2014-04-06 23:20:17
# Licence.......: Public
# Download URL..: https://api.openml.org/data/v1/download/14/mfeat-fourier.arff
# OpenML URL....: https://www.openml.org/d/14
# # of features.: 77
# # of instances: 2000, OpenML Dataset
# ==============
# Name..........: mfeat-karhunen
# Version.......: 1
# Format........: ARFF
# Upload Date...: 2014-04-06 23:20:30
# Licence.......: Public
# Download URL..: https://api.openml.org/data/v1/download/16/mfeat-karhunen.arff
# OpenML URL....: https://www.openml.org/d/16
# # of features.: 65
# # of instances: 2000, OpenML Dataset
# ==============
# Name..........: mfeat-zernike
# Version.......: 1
# Format........: ARFF
# Upload Date...: 2014-04-06 23:21:00
# Licence.......: Public
# Download URL..: https://api.openml.org/data/v1/download/22/mfeat-zernike.arff
# OpenML URL....: https://www.openml.org/d/22
# # of features.: 48
# # of instances: 2000, OpenML Dataset
# ==============
# Name..........: us_crime
# Version.......: 1
# Format........: ARFF
# Upload Date...: 2014-08-25 11:59:53
# Licence.......: Public
# Download URL..: https://api.openml.org/data/v1/download/52219/us_crime.arff
# OpenML URL....: https://www.openml.org/d/315
# # of features.: 128
# # of instances: 1994, OpenML Dataset
# ==============
# Name..........: colleges_usnews
# Version.......: 2
# Format........: ARFF
# Upload Date...: 2014-10-04 14:37:26
# Licence.......: Public
# Download URL..: https://api.openml.org/data/v1/download/53464/colleges_usnews.arff
# OpenML URL....: https://www.openml.org/d/930
# # of features.: 35
# # of instances: 1302, OpenML Dataset
# ==============
# Name..........: mfeat-fourier
# Version.......: 2
# Format........: ARFF
# Upload Date...: 2014-10-04 22:43:50
# Licence.......: Public
# Download URL..: https://api.openml.org/data/v1/download/53505/mfeat-fourier.arff
# OpenML URL....: https://www.openml.org/d/971
# # of features.: 77
# # of instances: 2000, OpenML Dataset
# ==============
# Name..........: mfeat-zernike
# Version.......: 2
# Format........: ARFF
# Upload Date...: 2014-10-04 22:44:40
# Licence.......: Public
# Download URL..: https://api.openml.org/data/v1/download/53529/mfeat-zernike.arff
# OpenML URL....: https://www.openml.org/d/995
# # of features.: 48
# # of instances: 2000, OpenML Dataset
# ==============
# Name..........: mfeat-karhunen
# Version.......: 2
# Format........: ARFF
# Upload Date...: 2014-10-04 22:45:28
# Licence.......: Public
# Download URL..: https://api.openml.org/data/v1/download/53554/mfeat-karhunen.arff
# OpenML URL....: https://www.openml.org/d/1020
# # of features.: 65
# # of instances: 2000, OpenML Dataset
# ==============
# Name..........: pc4
# Version.......: 1
# Format........: ARFF
# Upload Date...: 2014-10-06 23:57:12
# Licence.......: Public
# Download URL..: https://api.openml.org/data/v1/download/53932/pc4.arff
# OpenML URL....: https://www.openml.org/d/1049
# # of features.: 38
# # of instances: 1458, OpenML Dataset
# ==============
# Name..........: pc3
# Version.......: 1
# Format........: ARFF
# Upload Date...: 2014-10-06 23:57:13
# Licence.......: Public
# Download URL..: https://api.openml.org/data/v1/download/53933/pc3.arff
# OpenML URL....: https://www.openml.org/d/1050
# # of features.: 38
# # of instances: 1563, OpenML Dataset
# ==============
# Name..........: kc1
# Version.......: 1
# Format........: ARFF
# Upload Date...: 2014-10-06 23:57:43
# Licence.......: Public
# Download URL..: https://api.openml.org/data/v1/download/53950/kc1.arff
# OpenML URL....: https://www.openml.org/d/1067
# # of features.: 22
# # of instances: 2109, OpenML Dataset
# ==============
# Name..........: pc1
# Version.......: 1
# Format........: ARFF
# Upload Date...: 2014-10-06 23:57:45
# Licence.......: Public
# Download URL..: https://api.openml.org/data/v1/download/53951/pc1.arff
# OpenML URL....: https://www.openml.org/d/1068
# # of features.: 22
# # of instances: 1109, OpenML Dataset
# ==============
# Name..........: cardiotocography
# Version.......: 1
# Format........: ARFF
# Upload Date...: 2015-05-21 23:05:18
# Licence.......: Public
# Download URL..: https://api.openml.org/data/v1/download/1586231/cardiotocography.arff
# OpenML URL....: https://www.openml.org/d/1466
# # of features.: 36
# # of instances: 2126, OpenML Dataset
# ==============
# Name..........: hill-valley
# Version.......: 1
# Format........: ARFF
# Upload Date...: 2015-05-22 21:11:58
# Licence.......: Public
# Download URL..: https://api.openml.org/data/v1/download/1590101/hill-valley.arff
# OpenML URL....: https://www.openml.org/d/1479
# # of features.: 101
# # of instances: 1212, OpenML Dataset
# ==============
# Name..........: one-hundred-plants-margin
# Version.......: 1
# Format........: ARFF
# Upload Date...: 2015-05-25 20:51:03
# Licence.......: Public
# Download URL..: https://api.openml.org/data/v1/download/1592283/one-hundred-plants-margin.arff
# OpenML URL....: https://www.openml.org/d/1491
# # of features.: 65
# # of instances: 1600, OpenML Dataset
# ==============
# Name..........: one-hundred-plants-shape
# Version.......: 1
# Format........: ARFF
# Upload Date...: 2015-05-25 20:58:37
# Licence.......: Public
# Download URL..: https://api.openml.org/data/v1/download/1592284/one-hundred-plants-shape.arff
# OpenML URL....: https://www.openml.org/d/1492
# # of features.: 65
# # of instances: 1600, OpenML Dataset
# ==============
# Name..........: one-hundred-plants-texture
# Version.......: 1
# Format........: ARFF
# Upload Date...: 2015-05-25 20:59:55
# Licence.......: Public
# Download URL..: https://api.openml.org/data/v1/download/1592285/one-hundred-plants-texture.arff
# OpenML URL....: https://www.openml.org/d/1493
# # of features.: 65
# # of instances: 1599, OpenML Dataset
# ==============
# Name..........: steel-plates-fault
# Version.......: 1
# Format........: ARFF
# Upload Date...: 2015-05-25 22:42:40
# Licence.......: Public
# Download URL..: https://api.openml.org/data/v1/download/1592296/steel-plates-fault.arff
# OpenML URL....: https://www.openml.org/d/1504
# # of features.: 34
# # of instances: 1941, OpenML Dataset
# ==============
# Name..........: cardiotocography
# Version.......: 2
# Format........: ARFF
# Upload Date...: 2015-06-01 22:17:25
# Licence.......: Public
# Download URL..: https://api.openml.org/data/v1/download/1593756/cardiotocography.arff
# OpenML URL....: https://www.openml.org/d/1560
# # of features.: 36
# # of instances: 2126, OpenML Dataset
# ==============
# Name..........: hill-valley
# Version.......: 2
# Format........: ARFF
# Upload Date...: 2015-06-01 22:45:05
# Licence.......: Public
# Download URL..: https://api.openml.org/data/v1/download/1593762/hill-valley.arff
# OpenML URL....: https://www.openml.org/d/1566
# # of features.: 101
# # of instances: 1212, OpenML Dataset
# ==============
# Name..........: svmguide3
# Version.......: 1
# Format........: Sparse_ARFF
# Upload Date...: 2015-06-02 12:46:41
# Licence.......: Public
# Download URL..: https://api.openml.org/data/v1/download/1594054/svmguide3.sparse_arff
# OpenML URL....: https://www.openml.org/d/1589
# # of features.: 23
# # of instances: 1243, OpenML Dataset
# ==============
# Name..........: image
# Version.......: 2
# Format........: ARFF
# Upload Date...: 2017-02-16 21:20:00
# Licence.......: Public
# Download URL..: https://api.openml.org/data/v1/download/4644185/image.arff
# OpenML URL....: https://www.openml.org/d/40592
# # of features.: 140
# # of instances: 2000, OpenML Dataset
# ==============
# Name..........: GAMETES_Epistasis_2-Way_20atts_0.1H_EDM-1_1
# Version.......: 1
# Format........: ARFF
# Upload Date...: 2017-04-06 12:09:45
# Licence.......: public
# Download URL..: https://api.openml.org/data/v1/download/4965215/GAMETES_Epistasis_2-Way_20atts_0.1H_EDM-1_1.arff
# OpenML URL....: https://www.openml.org/d/40646
# # of features.: 21
# # of instances: 1600, OpenML Dataset
# ==============
# Name..........: GAMETES_Epistasis_2-Way_20atts_0.4H_EDM-1_1
# Version.......: 1
# Format........: ARFF
# Upload Date...: 2017-04-06 12:09:48
# Licence.......: public
# Download URL..: https://api.openml.org/data/v1/download/4965216/GAMETES_Epistasis_2-Way_20atts_0.4H_EDM-1_1.arff
# OpenML URL....: https://www.openml.org/d/40647
# # of features.: 21
# # of instances: 1600, OpenML Dataset
# ==============
# Name..........: GAMETES_Epistasis_3-Way_20atts_0.2H_EDM-1_1
# Version.......: 1
# Format........: ARFF
# Upload Date...: 2017-04-06 12:09:52
# Licence.......: public
# Download URL..: https://api.openml.org/data/v1/download/4965217/GAMETES_Epistasis_3-Way_20atts_0.2H_EDM-1_1.arff
# OpenML URL....: https://www.openml.org/d/40648
# # of features.: 21
# # of instances: 1600, OpenML Dataset
# ==============
# Name..........: GAMETES_Heterogeneity_20atts_1600_Het_0.4_0.2_50_EDM-2_001
# Version.......: 1
# Format........: ARFF
# Upload Date...: 2017-04-06 12:09:55
# Licence.......: public
# Download URL..: https://api.openml.org/data/v1/download/4965218/GAMETES_Heterogeneity_20atts_1600_Het_0.4_0.2_50_EDM-2_001.arff
# OpenML URL....: https://www.openml.org/d/40649
# # of features.: 21
# # of instances: 1600, OpenML Dataset
# ==============
# Name..........: GAMETES_Heterogeneity_20atts_1600_Het_0.4_0.2_75_EDM-2_001
# Version.......: 1
# Format........: ARFF
# Upload Date...: 2017-04-06 12:09:59
# Licence.......: public
# Download URL..: https://api.openml.org/data/v1/download/4965219/GAMETES_Heterogeneity_20atts_1600_Het_0.4_0.2_75_EDM-2_001.arff
# OpenML URL....: https://www.openml.org/d/40650
# # of features.: 21
# # of instances: 1600, OpenML Dataset
# ==============
# Name..........: car-evaluation
# Version.......: 1
# Format........: ARFF
# Upload Date...: 2017-04-06 12:12:45
# Licence.......: public
# Download URL..: https://api.openml.org/data/v1/download/4965239/car-evaluation.arff
# OpenML URL....: https://www.openml.org/d/40664
# # of features.: 22
# # of instances: 1728, OpenML Dataset
# ==============
# Name..........: steel-plates-fault
# Version.......: 3
# Format........: ARFF
# Upload Date...: 2017-12-04 22:37:56
# Licence.......: Public
# Download URL..: https://api.openml.org/data/v1/download/18151921/steel-plates-fault.arff
# OpenML URL....: https://www.openml.org/d/40982
# # of features.: 28
# # of instances: 1941, OpenML Dataset
# ==============
# Name..........: image
# Version.......: 3
# Format........: ARFF
# Upload Date...: 2019-03-14 17:59:04
# Licence.......: Public
# Download URL..: https://api.openml.org/data/v1/download/21230425/image.arff
# OpenML URL....: https://www.openml.org/d/41468
# # of features.: 140
# # of instances: 2000, OpenML Dataset
# ==============
# Name..........: scpf
# Version.......: 2
# Format........: ARFF
# Upload Date...: 2019-03-14 18:09:20
# Licence.......: Public
# Download URL..: https://api.openml.org/data/v1/download/21230444/scpf.arff
# OpenML URL....: https://www.openml.org/d/41487
# # of features.: 26
# # of instances: 1137, OpenML Dataset
# ==============
# Name..........: image
# Version.......: 4
# Format........: ARFF
# Upload Date...: 2019-04-03 08:59:37
# Licence.......: Public
# Download URL..: https://api.openml.org/data/v1/download/21241890/image.arff
# OpenML URL....: https://www.openml.org/d/41546
# # of features.: 140
# # of instances: 2000, OpenML Dataset
# ==============
# Name..........: scpf
# Version.......: 3
# Format........: ARFF
# Upload Date...: 2019-04-03 09:01:16
# Licence.......: Public
# Download URL..: https://api.openml.org/data/v1/download/21241899/scpf.arff
# OpenML URL....: https://www.openml.org/d/41555
# # of features.: 26
# # of instances: 1137, OpenML Dataset
# ==============
# Name..........: CPMP-2015-regression
# Version.......: 1
# Format........: ARFF
# Upload Date...: 2019-05-28 12:07:34
# Licence.......: Public
# Download URL..: https://api.openml.org/data/v1/download/21377442/CPMP-2015-regression.arff
# OpenML URL....: https://www.openml.org/d/41700
# # of features.: 27
# # of instances: 2108, OpenML Dataset
# ==============
# Name..........: CPMP-2015-runtime-regression
# Version.......: 1
# Format........: ARFF
# Upload Date...: 2019-06-19 14:48:51
# Licence.......: Public
# Download URL..: https://api.openml.org/data/v1/download/21378721/CPMP-2015-runtime-regression.arff
# OpenML URL....: https://www.openml.org/d/41928
# # of features.: 25
# # of instances: 2108, OpenML Dataset
# ==============
# Name..........: crimecommunitynums
# Version.......: 1
# Format........: ARFF
# Upload Date...: 2019-06-26 07:40:07
# Licence.......: CC0
# Download URL..: https://api.openml.org/data/v1/download/21379105/crimecommunitynums.arff
# OpenML URL....: https://www.openml.org/d/41968
# # of features.: 127
# # of instances: 1994, OpenML Dataset
# ==============
# Name..........: crimecommunitynums2
# Version.......: 1
# Format........: ARFF
# Upload Date...: 2019-06-26 07:47:08
# Licence.......: CC0
# Download URL..: https://api.openml.org/data/v1/download/21379106/crimecommunitynums2.arff
# OpenML URL....: https://www.openml.org/d/41969
# # of features.: 127
# # of instances: 1994, OpenML Dataset
# ==============
# Name..........: house_prices
# Version.......: 1
# Format........: arff
# Upload Date...: 2019-10-04 12:57:32
# Licence.......: NA
# Download URL..: https://api.openml.org/data/v1/download/21754539/house_prices.arff
# OpenML URL....: https://www.openml.org/d/42165
# # of features.: 81
# # of instances: 1460, OpenML Dataset
# ==============
# Name..........: Waterstress
# Version.......: 1
# Format........: ARFF
# Upload Date...: 2020-05-30 07:46:36
# Licence.......: CC0
# Download URL..: https://api.openml.org/data/v1/download/21854347/Waterstress.arff
# OpenML URL....: https://www.openml.org/d/42464
# # of features.: 23
# # of instances: 1188, OpenML Dataset
# ==============
# Name..........: house_prices_nominal
# Version.......: 1
# Format........: arff
# Upload Date...: 2020-06-26 01:36:02
# Licence.......: Public
# Download URL..: https://api.openml.org/data/v1/download/21854633/house_prices_nominal.arff
# OpenML URL....: https://www.openml.org/d/42563
# # of features.: 81
# # of instances: 1460, OpenML Dataset
# ==============
# Name..........: Ishwar
# Version.......: 1
# Format........: ARFF
# Upload Date...: 2020-07-08 10:18:44
# Licence.......: CC0
# Download URL..: https://api.openml.org/data/v1/download/21854678/Ishwar.arff
# OpenML URL....: https://www.openml.org/d/42575
# # of features.: 22
# # of instances: 2205, OpenML Dataset
# ==============
# Name..........: us_crime
# Version.......: 2
# Format........: arff
# Upload Date...: 2020-11-18 08:31:13
# Licence.......: Public
# Download URL..: https://api.openml.org/data/v1/download/22044764/us_crime.arff
# OpenML URL....: https://www.openml.org/d/42730
# # of features.: 128
# # of instances: 1994, OpenML Dataset
# ==============
# Name..........: audit-data
# Version.......: 1
# Format........: arff
# Upload Date...: 2021-05-25 08:17:40
# Licence.......: Public
# Download URL..: https://api.openml.org/data/v1/download/22045580/audit-data.arff
# OpenML URL....: https://www.openml.org/d/42931
# # of features.: 37
# # of instances: 1552, OpenML Dataset
# ==============
# Name..........: cnn-stock-pred-nasdaq
# Version.......: 1
# Format........: arff
# Upload Date...: 2021-05-28 13:52:16
# Licence.......: Publicly available
# Download URL..: https://api.openml.org/data/v1/download/22045675/cnn-stock-pred-nasdaq.arff
# OpenML URL....: https://www.openml.org/d/43003
# # of features.: 84
# # of instances: 1984, OpenML Dataset
# ==============
# Name..........: cnn-stock-pred-nyse
# Version.......: 1
# Format........: arff
# Upload Date...: 2021-05-28 13:52:42
# Licence.......: Publicly available
# Download URL..: https://api.openml.org/data/v1/download/22045676/cnn-stock-pred-nyse.arff
# OpenML URL....: https://www.openml.org/d/43004
# # of features.: 84
# # of instances: 1984, OpenML Dataset
# ==============
# Name..........: cnn-stock-pred-russell
# Version.......: 1
# Format........: arff
# Upload Date...: 2021-05-28 13:53:02
# Licence.......: Publicly available
# Download URL..: https://api.openml.org/data/v1/download/22045677/cnn-stock-pred-russell.arff
# OpenML URL....: https://www.openml.org/d/43005
# # of features.: 84
# # of instances: 1984, OpenML Dataset
# ==============
# Name..........: cnn-stock-pred-sp
# Version.......: 1
# Format........: arff
# Upload Date...: 2021-05-28 13:53:23
# Licence.......: Publicly available
# Download URL..: https://api.openml.org/data/v1/download/22045678/cnn-stock-pred-sp.arff
# OpenML URL....: https://www.openml.org/d/43006
# # of features.: 84
# # of instances: 1984, OpenML Dataset
# ==============
# Name..........: AustinWeather
# Version.......: 1
# Format........: arff
# Upload Date...: 2022-03-23 10:28:04
# Licence.......: GPL2
# Download URL..: https://api.openml.org/data/v1/download/22102143/AustinWeather.arff
# OpenML URL....: https://www.openml.org/d/43318
# # of features.: 21
# # of instances: 1319, OpenML Dataset
# ==============
# Name..........: CorporateCreditRating
# Version.......: 1
# Format........: arff
# Upload Date...: 2022-03-23 10:30:25
# Licence.......: Attribution40InternationalCCBY40
# Download URL..: https://api.openml.org/data/v1/download/22102148/CorporateCreditRating.arff
# OpenML URL....: https://www.openml.org/d/43323
# # of features.: 31
# # of instances: 2029, OpenML Dataset
# ==============
# Name..........: Austin-Weather
# Version.......: 1
# Format........: arff
# Upload Date...: 2022-03-23 11:15:43
# Licence.......: GPL 2
# Download URL..: https://api.openml.org/data/v1/download/22102156/Austin-Weather.arff
# OpenML URL....: https://www.openml.org/d/43331
# # of features.: 21
# # of instances: 1319, OpenML Dataset
# ==============
# Name..........: Austin-Weather
# Version.......: 2
# Format........: arff
# Upload Date...: 2022-03-23 11:32:43
# Licence.......: GPL 2
# Download URL..: https://api.openml.org/data/v1/download/22102160/Austin-Weather.arff
# OpenML URL....: https://www.openml.org/d/43335
# # of features.: 21
# # of instances: 1319, OpenML Dataset
# ==============
# Name..........: Corporate-Credit-Rating
# Version.......: 1
# Format........: arff
# Upload Date...: 2022-03-23 12:19:04
# Licence.......: Attribution 4.0 International (CC BY 4.0)
# Download URL..: https://api.openml.org/data/v1/download/22102169/Corporate-Credit-Rating.arff
# OpenML URL....: https://www.openml.org/d/43344
# # of features.: 31
# # of instances: 2029, OpenML Dataset
# ==============
# Name..........: User-OTT-Consumption-Profile---2019
# Version.......: 1
# Format........: arff
# Upload Date...: 2022-03-23 12:28:54
# Licence.......: Attribution 4.0 International (CC BY 4.0)
# Download URL..: https://api.openml.org/data/v1/download/22102171/User-OTT-Consumption-Profile---2019.arff
# OpenML URL....: https://www.openml.org/d/43346
# # of features.: 114
# # of instances: 1249, OpenML Dataset
# ==============
# Name..........: Football-striker-performance
# Version.......: 1
# Format........: arff
# Upload Date...: 2022-03-23 13:11:48
# Licence.......: CC0: Public Domain
# Download URL..: https://api.openml.org/data/v1/download/22102226/Football-striker-performance.arff
# OpenML URL....: https://www.openml.org/d/43401
# # of features.: 32
# # of instances: 1177, OpenML Dataset
# ==============
# Name..........: Video-Game-Use-in-US-High-School-Students
# Version.......: 1
# Format........: arff
# Upload Date...: 2022-03-23 13:12:35
# Licence.......: Database: Open Database, Contents: Database Contents
# Download URL..: https://api.openml.org/data/v1/download/22102233/Video-Game-Use-in-US-High-School-Students.arff
# OpenML URL....: https://www.openml.org/d/43408
# # of features.: 24
# # of instances: 2202, OpenML Dataset
# ==============
# Name..........: depression
# Version.......: 1
# Format........: arff
# Upload Date...: 2022-03-23 13:14:10
# Licence.......: GPL 2
# Download URL..: https://api.openml.org/data/v1/download/22102244/depression.arff
# OpenML URL....: https://www.openml.org/d/43419
# # of features.: 23
# # of instances: 1429, OpenML Dataset
# ==============
# Name..........: Anime-Data
# Version.......: 1
# Format........: arff
# Upload Date...: 2022-03-23 13:31:23
# Licence.......: CC BY-NC-SA 4.0
# Download URL..: https://api.openml.org/data/v1/download/22102333/Anime-Data.arff
# OpenML URL....: https://www.openml.org/d/43508
# # of features.: 20
# # of instances: 1563, OpenML Dataset
# ==============
# Name..........: SBA-Loans-Case-Data-Set
# Version.......: 1
# Format........: arff
# Upload Date...: 2022-03-23 13:45:49
# Licence.......: CC0: Public Domain
# Download URL..: https://api.openml.org/data/v1/download/22102364/SBA-Loans-Case-Data-Set.arff
# OpenML URL....: https://www.openml.org/d/43539
# # of features.: 35
# # of instances: 2102, OpenML Dataset
# ==============
# Name..........: NBA-PLAYERS--2016-2019
# Version.......: 1
# Format........: arff
# Upload Date...: 2022-03-24 01:01:51
# Licence.......: CC0: Public Domain
# Download URL..: https://api.openml.org/data/v1/download/22102478/NBA-PLAYERS--2016-2019.arff
# OpenML URL....: https://www.openml.org/d/43653
# # of features.: 45
# # of instances: 1408, OpenML Dataset
# ==============
# Name..........: Mental-Health-in-Tech-Survey
# Version.......: 1
# Format........: arff
# Upload Date...: 2022-03-24 01:16:20
# Licence.......: CC BY-SA 4.0
# Download URL..: https://api.openml.org/data/v1/download/22102489/Mental-Health-in-Tech-Survey.arff
# OpenML URL....: https://www.openml.org/d/43664
# # of features.: 27
# # of instances: 1259, OpenML Dataset
# ==============
# Name..........: Mental-Health-in-Tech-Survey
# Version.......: 2
# Format........: arff
# Upload Date...: 2022-03-24 07:07:51
# Licence.......: CC BY-SA 4.0
# Download URL..: https://api.openml.org/data/v1/download/22102499/Mental-Health-in-Tech-Survey.arff
# OpenML URL....: https://www.openml.org/d/43674
# # of features.: 27
# # of instances: 1259, OpenML Dataset
# ==============
# Name..........: IBM-HR-Analytics-Employee-Attrition--Performance
# Version.......: 1
# Format........: arff
# Upload Date...: 2022-03-24 07:14:29
# Licence.......: Database: Open Database, Contents: Database Contents
# Download URL..: https://api.openml.org/data/v1/download/22102521/IBM-HR-Analytics-Employee-Attrition--Performance.arff
# OpenML URL....: https://www.openml.org/d/43696
# # of features.: 35
# # of instances: 1470, OpenML Dataset
# ==============
# Name..........: Performance-Prediction
# Version.......: 1
# Format........: arff
# Upload Date...: 2022-03-24 15:29:19
# Licence.......: CC0: Public Domain
# Download URL..: https://api.openml.org/data/v1/download/22102637/Performance-Prediction.arff
# OpenML URL....: https://www.openml.org/d/43812
# # of features.: 21
# # of instances: 1340, OpenML Dataset
# ==============
# Name..........: Dubai-Properties---Apartments
# Version.......: 1
# Format........: arff
# Upload Date...: 2022-03-24 15:29:31
# Licence.......: CC0: Public Domain
# Download URL..: https://api.openml.org/data/v1/download/22102639/Dubai-Properties---Apartments.arff
# OpenML URL....: https://www.openml.org/d/43814
# # of features.: 38
# # of instances: 1905, OpenML Dataset
# ==============
# Name..........: communities-and-crime-binary
# Version.......: 1
# Format........: ARFF
# Upload Date...: 2022-05-30 18:12:34
# Licence.......: Public
# Download URL..: https://api.openml.org/data/v1/download/22102796/communities-and-crime-binary.arff
# OpenML URL....: https://www.openml.org/d/43888
# # of features.: 129
# # of instances: 1994, OpenML Dataset
# ==============
# Name..........: communities-and-crime-binary
# Version.......: 2
# Format........: ARFF
# Upload Date...: 2022-05-30 18:41:17
# Licence.......: Public
# Download URL..: https://api.openml.org/data/v1/download/22102799/communities-and-crime-binary.arff
# OpenML URL....: https://www.openml.org/d/43891
# # of features.: 129
# # of instances: 1994, OpenML Dataset
# ==============
# Name..........: ibm-employee-attrition
# Version.......: 1
# Format........: ARFF
# Upload Date...: 2022-05-30 18:59:07
# Licence.......: Open Database License (ODbL) + Database Content License(DbCL)
# Download URL..: https://api.openml.org/data/v1/download/22102801/ibm-employee-attrition.arff
# OpenML URL....: https://www.openml.org/d/43893
# # of features.: 35
# # of instances: 1470, OpenML Dataset
# ==============
# Name..........: ibm-employee-attrition
# Version.......: 2
# Format........: ARFF
# Upload Date...: 2022-05-30 19:00:14
# Licence.......: Open Database License (ODbL) + Database Content License(DbCL)
# Download URL..: https://api.openml.org/data/v1/download/22102802/ibm-employee-attrition.arff
# OpenML URL....: https://www.openml.org/d/43894
# # of features.: 35
# # of instances: 1470, OpenML Dataset
# ==============
# Name..........: ibm-employee-performance
# Version.......: 1
# Format........: ARFF
# Upload Date...: 2022-05-30 19:05:52
# Licence.......: Open Database License (ODbL) + Database Content License(DbCL)
# Download URL..: https://api.openml.org/data/v1/download/22102803/ibm-employee-performance.arff
# OpenML URL....: https://www.openml.org/d/43895
# # of features.: 34
# # of instances: 1470, OpenML Dataset
# ==============
# Name..........: ibm-employee-attrition
# Version.......: 3
# Format........: ARFF
# Upload Date...: 2022-05-30 19:08:01
# Licence.......: Open Database License (ODbL) + Database Content License(DbCL)
# Download URL..: https://api.openml.org/data/v1/download/22102804/ibm-employee-attrition.arff
# OpenML URL....: https://www.openml.org/d/43896
# # of features.: 35
# # of instances: 1470, OpenML Dataset
# ==============
# Name..........: ibm-employee-performance
# Version.......: 2
# Format........: ARFF
# Upload Date...: 2022-05-30 19:08:24
# Licence.......: Open Database License (ODbL) + Database Content License(DbCL)
# Download URL..: https://api.openml.org/data/v1/download/22102805/ibm-employee-performance.arff
# OpenML URL....: https://www.openml.org/d/43897
# # of features.: 34
# # of instances: 1470, OpenML Dataset
# ==============
# Name..........: ibm-employee-performance
# Version.......: 3
# Format........: ARFF
# Upload Date...: 2022-06-01 10:56:18
# Licence.......: Open Database License (ODbL) + Database Content License(DbCL)
# Download URL..: https://api.openml.org/data/v1/download/22102815/ibm-employee-performance.arff
# OpenML URL....: https://www.openml.org/d/43905
# # of features.: 33
# # of instances: 1470, OpenML Dataset
# ==============
# Name..........: IEEE80211aa-GATS-NS3.35
# Version.......: 1
# Format........: arff
# Upload Date...: 2022-07-21 19:11:10
# Licence.......: Attribution-NonCommercial-ShareAlike
# Download URL..: https://api.openml.org/data/v1/download/22103344/IEEE80211aa-GATS-NS3.35.arff
# OpenML URL....: https://www.openml.org/d/44179
# # of features.: 24
# # of instances: 2160, OpenML Dataset
# ==============
# Name..........: IEEE80211aa-GATS-NS3.35
# Version.......: 2
# Format........: arff
# Upload Date...: 2022-07-21 19:23:43
# Licence.......: Attribution-NonCommercial-ShareAlike
# Download URL..: https://api.openml.org/data/v1/download/22103345/IEEE80211aa-GATS-NS3.35.arff
# OpenML URL....: https://www.openml.org/d/44180
# # of features.: 24
# # of instances: 2160, OpenML Dataset
# ==============
# Name..........: pol_seed_0_nrows_2000_nclasses_10_ncols_100_stratify_True
# Version.......: 1
# Format........: arff
# Upload Date...: 2022-11-17 17:56:57
# Licence.......: Public
# Download URL..: https://api.openml.org/data/v1/download/22111144/pol_seed_0_nrows_2000_nclasses_10_ncols_100_stratify_True.arff
# OpenML URL....: https://www.openml.org/d/44382
# # of features.: 27
# # of instances: 2000, OpenML Dataset
# ==============
# Name..........: pol_seed_1_nrows_2000_nclasses_10_ncols_100_stratify_True
# Version.......: 1
# Format........: arff
# Upload Date...: 2022-11-17 17:57:01
# Licence.......: Public
# Download URL..: https://api.openml.org/data/v1/download/22111145/pol_seed_1_nrows_2000_nclasses_10_ncols_100_stratify_True.arff
# OpenML URL....: https://www.openml.org/d/44383
# # of features.: 27
# # of instances: 2000, OpenML Dataset
# ==============
# Name..........: pol_seed_2_nrows_2000_nclasses_10_ncols_100_stratify_True
# Version.......: 1
# Format........: arff
# Upload Date...: 2022-11-17 17:57:06
# Licence.......: Public
# Download URL..: https://api.openml.org/data/v1/download/22111146/pol_seed_2_nrows_2000_nclasses_10_ncols_100_stratify_True.arff
# OpenML URL....: https://www.openml.org/d/44384
# # of features.: 27
# # of instances: 2000, OpenML Dataset
# ==============
# Name..........: pol_seed_3_nrows_2000_nclasses_10_ncols_100_stratify_True
# Version.......: 1
# Format........: arff
# Upload Date...: 2022-11-17 17:57:11
# Licence.......: Public
# Download URL..: https://api.openml.org/data/v1/download/22111147/pol_seed_3_nrows_2000_nclasses_10_ncols_100_stratify_True.arff
# OpenML URL....: https://www.openml.org/d/44385
# # of features.: 27
# # of instances: 2000, OpenML Dataset
# ==============
# Name..........: pol_seed_4_nrows_2000_nclasses_10_ncols_100_stratify_True
# Version.......: 1
# Format........: arff
# Upload Date...: 2022-11-17 17:57:16
# Licence.......: Public
# Download URL..: https://api.openml.org/data/v1/download/22111148/pol_seed_4_nrows_2000_nclasses_10_ncols_100_stratify_True.arff
# OpenML URL....: https://www.openml.org/d/44386
# # of features.: 27
# # of instances: 2000, OpenML Dataset
# ==============
# Name..........: kdd_ipums_la_97-small_seed_0_nrows_2000_nclasses_10_ncols_100_stratify_True
# Version.......: 1
# Format........: arff
# Upload Date...: 2022-11-17 17:57:44
# Licence.......: Public
# Download URL..: https://api.openml.org/data/v1/download/22111154/kdd_ipums_la_97-small_seed_0_nrows_2000_nclasses_10_ncols_100_stratify_True.arff
# OpenML URL....: https://www.openml.org/d/44392
# # of features.: 21
# # of instances: 2000, OpenML Dataset
# ==============
# Name..........: kdd_ipums_la_97-small_seed_1_nrows_2000_nclasses_10_ncols_100_stratify_True
# Version.......: 1
# Format........: arff
# Upload Date...: 2022-11-17 17:57:49
# Licence.......: Public
# Download URL..: https://api.openml.org/data/v1/download/22111155/kdd_ipums_la_97-small_seed_1_nrows_2000_nclasses_10_ncols_100_stratify_True.arff
# OpenML URL....: https://www.openml.org/d/44393
# # of features.: 21
# # of instances: 2000, OpenML Dataset
# ==============
# Name..........: kdd_ipums_la_97-small_seed_2_nrows_2000_nclasses_10_ncols_100_stratify_True
# Version.......: 1
# Format........: arff
# Upload Date...: 2022-11-17 17:57:53
# Licence.......: Public
# Download URL..: https://api.openml.org/data/v1/download/22111156/kdd_ipums_la_97-small_seed_2_nrows_2000_nclasses_10_ncols_100_stratify_True.arff
# OpenML URL....: https://www.openml.org/d/44394
# # of features.: 21
# # of instances: 2000, OpenML Dataset
# ==============
# Name..........: kdd_ipums_la_97-small_seed_3_nrows_2000_nclasses_10_ncols_100_stratify_True
# Version.......: 1
# Format........: arff
# Upload Date...: 2022-11-17 17:57:57
# Licence.......: Public
# Download URL..: https://api.openml.org/data/v1/download/22111157/kdd_ipums_la_97-small_seed_3_nrows_2000_nclasses_10_ncols_100_stratify_True.arff
# OpenML URL....: https://www.openml.org/d/44395
# # of features.: 21
# # of instances: 2000, OpenML Dataset
# ==============
# Name..........: kdd_ipums_la_97-small_seed_4_nrows_2000_nclasses_10_ncols_100_stratify_True
# Version.......: 1
# Format........: arff
# Upload Date...: 2022-11-17 17:58:01
# Licence.......: Public
# Download URL..: https://api.openml.org/data/v1/download/22111158/kdd_ipums_la_97-small_seed_4_nrows_2000_nclasses_10_ncols_100_stratify_True.arff
# OpenML URL....: https://www.openml.org/d/44396
# # of features.: 21
# # of instances: 2000, OpenML Dataset
# ==============
# Name..........: MiniBooNE_seed_0_nrows_2000_nclasses_10_ncols_100_stratify_True
# Version.......: 1
# Format........: arff
# Upload Date...: 2022-11-17 17:59:12
# Licence.......: CC0
# Download URL..: https://api.openml.org/data/v1/download/22111174/MiniBooNE_seed_0_nrows_2000_nclasses_10_ncols_100_stratify_True.arff
# OpenML URL....: https://www.openml.org/d/44412
# # of features.: 51
# # of instances: 2000, OpenML Dataset
# ==============
# Name..........: MiniBooNE_seed_1_nrows_2000_nclasses_10_ncols_100_stratify_True
# Version.......: 1
# Format........: arff
# Upload Date...: 2022-11-17 17:59:17
# Licence.......: CC0
# Download URL..: https://api.openml.org/data/v1/download/22111175/MiniBooNE_seed_1_nrows_2000_nclasses_10_ncols_100_stratify_True.arff
# OpenML URL....: https://www.openml.org/d/44413
# # of features.: 51
# # of instances: 2000, OpenML Dataset
# ==============
# Name..........: MiniBooNE_seed_2_nrows_2000_nclasses_10_ncols_100_stratify_True
# Version.......: 1
# Format........: arff
# Upload Date...: 2022-11-17 17:59:22
# Licence.......: CC0
# Download URL..: https://api.openml.org/data/v1/download/22111176/MiniBooNE_seed_2_nrows_2000_nclasses_10_ncols_100_stratify_True.arff
# OpenML URL....: https://www.openml.org/d/44414
# # of features.: 51
# # of instances: 2000, OpenML Dataset
# ==============
# Name..........: MiniBooNE_seed_3_nrows_2000_nclasses_10_ncols_100_stratify_True
# Version.......: 1
# Format........: arff
# Upload Date...: 2022-11-17 17:59:27
# Licence.......: CC0
# Download URL..: https://api.openml.org/data/v1/download/22111177/MiniBooNE_seed_3_nrows_2000_nclasses_10_ncols_100_stratify_True.arff
# OpenML URL....: https://www.openml.org/d/44415
# # of features.: 51
# # of instances: 2000, OpenML Dataset
# ==============
# Name..........: MiniBooNE_seed_4_nrows_2000_nclasses_10_ncols_100_stratify_True
# Version.......: 1
# Format........: arff
# Upload Date...: 2022-11-17 17:59:32
# Licence.......: CC0
# Download URL..: https://api.openml.org/data/v1/download/22111178/MiniBooNE_seed_4_nrows_2000_nclasses_10_ncols_100_stratify_True.arff
# OpenML URL....: https://www.openml.org/d/44416
# # of features.: 51
# # of instances: 2000, OpenML Dataset
# ==============
# Name..........: Higgs_seed_0_nrows_2000_nclasses_10_ncols_100_stratify_True
# Version.......: 1
# Format........: arff
# Upload Date...: 2022-11-17 17:59:38
# Licence.......: Public
# Download URL..: https://api.openml.org/data/v1/download/22111179/Higgs_seed_0_nrows_2000_nclasses_10_ncols_100_stratify_True.arff
# OpenML URL....: https://www.openml.org/d/44417
# # of features.: 25
# # of instances: 2000, OpenML Dataset
# ==============
# Name..........: Higgs_seed_1_nrows_2000_nclasses_10_ncols_100_stratify_True
# Version.......: 1
# Format........: arff
# Upload Date...: 2022-11-17 17:59:43
# Licence.......: Public
# Download URL..: https://api.openml.org/data/v1/download/22111180/Higgs_seed_1_nrows_2000_nclasses_10_ncols_100_stratify_True.arff
# OpenML URL....: https://www.openml.org/d/44418
# # of features.: 25
# # of instances: 2000, OpenML Dataset
# ==============
# Name..........: Higgs_seed_2_nrows_2000_nclasses_10_ncols_100_stratify_True
# Version.......: 1
# Format........: arff
# Upload Date...: 2022-11-17 17:59:49
# Licence.......: Public
# Download URL..: https://api.openml.org/data/v1/download/22111181/Higgs_seed_2_nrows_2000_nclasses_10_ncols_100_stratify_True.arff
# OpenML URL....: https://www.openml.org/d/44419
# # of features.: 25
# # of instances: 2000, OpenML Dataset
# ==============
# Name..........: Higgs_seed_3_nrows_2000_nclasses_10_ncols_100_stratify_True
# Version.......: 1
# Format........: arff
# Upload Date...: 2022-11-17 17:59:54
# Licence.......: Public
# Download URL..: https://api.openml.org/data/v1/download/22111182/Higgs_seed_3_nrows_2000_nclasses_10_ncols_100_stratify_True.arff
# OpenML URL....: https://www.openml.org/d/44420
# # of features.: 25
# # of instances: 2000, OpenML Dataset
# ==============
# Name..........: Higgs_seed_4_nrows_2000_nclasses_10_ncols_100_stratify_True
# Version.......: 1
# Format........: arff
# Upload Date...: 2022-11-17 17:59:59
# Licence.......: Public
# Download URL..: https://api.openml.org/data/v1/download/22111183/Higgs_seed_4_nrows_2000_nclasses_10_ncols_100_stratify_True.arff
# OpenML URL....: https://www.openml.org/d/44421
# # of features.: 25
# # of instances: 2000, OpenML Dataset
# ==============
# Name..........: Higgs_seed_4_nrows_2000_nclasses_10_ncols_100_stratify_True
# Version.......: 2
# Format........: arff
# Upload Date...: 2022-11-17 18:00:03
# Licence.......: Public
# Download URL..: https://api.openml.org/data/v1/download/22111184/Higgs_seed_4_nrows_2000_nclasses_10_ncols_100_stratify_True.arff
# OpenML URL....: https://www.openml.org/d/44422
# # of features.: 25
# # of instances: 2000, OpenML Dataset
# ==============
# Name..........: eye_movements_seed_0_nrows_2000_nclasses_10_ncols_100_stratify_True
# Version.......: 1
# Format........: arff
# Upload Date...: 2022-11-17 18:00:08
# Licence.......: Public
# Download URL..: https://api.openml.org/data/v1/download/22111185/eye_movements_seed_0_nrows_2000_nclasses_10_ncols_100_stratify_True.arff
# OpenML URL....: https://www.openml.org/d/44423
# # of features.: 21
# # of instances: 2000, OpenML Dataset
# ==============
# Name..........: eye_movements_seed_1_nrows_2000_nclasses_10_ncols_100_stratify_True
# Version.......: 1
# Format........: arff
# Upload Date...: 2022-11-17 18:00:12
# Licence.......: Public
# Download URL..: https://api.openml.org/data/v1/download/22111186/eye_movements_seed_1_nrows_2000_nclasses_10_ncols_100_stratify_True.arff
# OpenML URL....: https://www.openml.org/d/44424
# # of features.: 21
# # of instances: 2000, OpenML Dataset
# ==============
# Name..........: eye_movements_seed_2_nrows_2000_nclasses_10_ncols_100_stratify_True
# Version.......: 1
# Format........: arff
# Upload Date...: 2022-11-17 18:00:17
# Licence.......: Public
# Download URL..: https://api.openml.org/data/v1/download/22111187/eye_movements_seed_2_nrows_2000_nclasses_10_ncols_100_stratify_True.arff
# OpenML URL....: https://www.openml.org/d/44425
# # of features.: 21
# # of instances: 2000, OpenML Dataset
# ==============
# Name..........: eye_movements_seed_3_nrows_2000_nclasses_10_ncols_100_stratify_True
# Version.......: 1
# Format........: arff
# Upload Date...: 2022-11-17 18:00:22
# Licence.......: Public
# Download URL..: https://api.openml.org/data/v1/download/22111188/eye_movements_seed_3_nrows_2000_nclasses_10_ncols_100_stratify_True.arff
# OpenML URL....: https://www.openml.org/d/44426
# # of features.: 21
# # of instances: 2000, OpenML Dataset
# ==============
# Name..........: eye_movements_seed_4_nrows_2000_nclasses_10_ncols_100_stratify_True
# Version.......: 1
# Format........: arff
# Upload Date...: 2022-11-17 18:00:27
# Licence.......: Public
# Download URL..: https://api.openml.org/data/v1/download/22111189/eye_movements_seed_4_nrows_2000_nclasses_10_ncols_100_stratify_True.arff
# OpenML URL....: https://www.openml.org/d/44427
# # of features.: 21
# # of instances: 2000, OpenML Dataset
# ==============
# Name..........: jannis_seed_0_nrows_2000_nclasses_10_ncols_100_stratify_True
# Version.......: 1
# Format........: arff
# Upload Date...: 2022-11-17 18:00:31
# Licence.......: Public
# Download URL..: https://api.openml.org/data/v1/download/22111190/jannis_seed_0_nrows_2000_nclasses_10_ncols_100_stratify_True.arff
# OpenML URL....: https://www.openml.org/d/44428
# # of features.: 55
# # of instances: 2000, OpenML Dataset
# ==============
# Name..........: jannis_seed_1_nrows_2000_nclasses_10_ncols_100_stratify_True
# Version.......: 1
# Format........: arff
# Upload Date...: 2022-11-17 18:00:38
# Licence.......: Public
# Download URL..: https://api.openml.org/data/v1/download/22111191/jannis_seed_1_nrows_2000_nclasses_10_ncols_100_stratify_True.arff
# OpenML URL....: https://www.openml.org/d/44429
# # of features.: 55
# # of instances: 2000, OpenML Dataset
# ==============
# Name..........: jannis_seed_2_nrows_2000_nclasses_10_ncols_100_stratify_True
# Version.......: 1
# Format........: arff
# Upload Date...: 2022-11-17 18:00:43
# Licence.......: Public
# Download URL..: https://api.openml.org/data/v1/download/22111192/jannis_seed_2_nrows_2000_nclasses_10_ncols_100_stratify_True.arff
# OpenML URL....: https://www.openml.org/d/44430
# # of features.: 55
# # of instances: 2000, OpenML Dataset
# ==============
# Name..........: jannis_seed_3_nrows_2000_nclasses_10_ncols_100_stratify_True
# Version.......: 1
# Format........: arff
# Upload Date...: 2022-11-17 18:00:48
# Licence.......: Public
# Download URL..: https://api.openml.org/data/v1/download/22111193/jannis_seed_3_nrows_2000_nclasses_10_ncols_100_stratify_True.arff
# OpenML URL....: https://www.openml.org/d/44431
# # of features.: 55
# # of instances: 2000, OpenML Dataset
# ==============
# Name..........: jannis_seed_4_nrows_2000_nclasses_10_ncols_100_stratify_True
# Version.......: 1
# Format........: arff
# Upload Date...: 2022-11-17 18:00:52
# Licence.......: Public
# Download URL..: https://api.openml.org/data/v1/download/22111194/jannis_seed_4_nrows_2000_nclasses_10_ncols_100_stratify_True.arff
# OpenML URL....: https://www.openml.org/d/44432
# # of features.: 55
# # of instances: 2000, OpenML Dataset
# ==============
# Name..........: eye_movements_seed_0_nrows_2000_nclasses_10_ncols_100_stratify_True
# Version.......: 2
# Format........: arff
# Upload Date...: 2022-11-17 18:01:24
# Licence.......: Public
# Download URL..: https://api.openml.org/data/v1/download/22111200/eye_movements_seed_0_nrows_2000_nclasses_10_ncols_100_stratify_True.arff
# OpenML URL....: https://www.openml.org/d/44438
# # of features.: 24
# # of instances: 2000, OpenML Dataset
# ==============
# Name..........: eye_movements_seed_1_nrows_2000_nclasses_10_ncols_100_stratify_True
# Version.......: 2
# Format........: arff
# Upload Date...: 2022-11-17 18:01:29
# Licence.......: Public
# Download URL..: https://api.openml.org/data/v1/download/22111201/eye_movements_seed_1_nrows_2000_nclasses_10_ncols_100_stratify_True.arff
# OpenML URL....: https://www.openml.org/d/44439
# # of features.: 24
# # of instances: 2000, OpenML Dataset
# ==============
# Name..........: eye_movements_seed_2_nrows_2000_nclasses_10_ncols_100_stratify_True
# Version.......: 2
# Format........: arff
# Upload Date...: 2022-11-17 18:01:34
# Licence.......: Public
# Download URL..: https://api.openml.org/data/v1/download/22111202/eye_movements_seed_2_nrows_2000_nclasses_10_ncols_100_stratify_True.arff
# OpenML URL....: https://www.openml.org/d/44440
# # of features.: 24
# # of instances: 2000, OpenML Dataset
# ==============
# Name..........: eye_movements_seed_3_nrows_2000_nclasses_10_ncols_100_stratify_True
# Version.......: 2
# Format........: arff
# Upload Date...: 2022-11-17 18:01:39
# Licence.......: Public
# Download URL..: https://api.openml.org/data/v1/download/22111203/eye_movements_seed_3_nrows_2000_nclasses_10_ncols_100_stratify_True.arff
# OpenML URL....: https://www.openml.org/d/44441
# # of features.: 24
# # of instances: 2000, OpenML Dataset
# ==============
# Name..........: eye_movements_seed_4_nrows_2000_nclasses_10_ncols_100_stratify_True
# Version.......: 2
# Format........: arff
# Upload Date...: 2022-11-17 18:01:44
# Licence.......: Public
# Download URL..: https://api.openml.org/data/v1/download/22111204/eye_movements_seed_4_nrows_2000_nclasses_10_ncols_100_stratify_True.arff
# OpenML URL....: https://www.openml.org/d/44442
# # of features.: 24
# # of instances: 2000, OpenML Dataset
# ==============
# Name..........: covertype_seed_0_nrows_2000_nclasses_10_ncols_100_stratify_True
# Version.......: 2
# Format........: arff
# Upload Date...: 2022-11-17 18:01:51
# Licence.......: Public
# Download URL..: https://api.openml.org/data/v1/download/22111205/covertype_seed_0_nrows_2000_nclasses_10_ncols_100_stratify_True.arff
# OpenML URL....: https://www.openml.org/d/44443
# # of features.: 55
# # of instances: 2000, OpenML Dataset
# ==============
# Name..........: covertype_seed_1_nrows_2000_nclasses_10_ncols_100_stratify_True
# Version.......: 2
# Format........: arff
# Upload Date...: 2022-11-17 18:01:56
# Licence.......: Public
# Download URL..: https://api.openml.org/data/v1/download/22111206/covertype_seed_1_nrows_2000_nclasses_10_ncols_100_stratify_True.arff
# OpenML URL....: https://www.openml.org/d/44444
# # of features.: 55
# # of instances: 2000, OpenML Dataset
# ==============
# Name..........: covertype_seed_2_nrows_2000_nclasses_10_ncols_100_stratify_True
# Version.......: 2
# Format........: arff
# Upload Date...: 2022-11-17 18:02:01
# Licence.......: Public
# Download URL..: https://api.openml.org/data/v1/download/22111207/covertype_seed_2_nrows_2000_nclasses_10_ncols_100_stratify_True.arff
# OpenML URL....: https://www.openml.org/d/44445
# # of features.: 55
# # of instances: 2000, OpenML Dataset
# ==============
# Name..........: covertype_seed_3_nrows_2000_nclasses_10_ncols_100_stratify_True
# Version.......: 2
# Format........: arff
# Upload Date...: 2022-11-17 18:02:07
# Licence.......: Public
# Download URL..: https://api.openml.org/data/v1/download/22111208/covertype_seed_3_nrows_2000_nclasses_10_ncols_100_stratify_True.arff
# OpenML URL....: https://www.openml.org/d/44446
# # of features.: 55
# # of instances: 2000, OpenML Dataset
# ==============
# Name..........: covertype_seed_4_nrows_2000_nclasses_10_ncols_100_stratify_True
# Version.......: 2
# Format........: arff
# Upload Date...: 2022-11-17 18:02:14
# Licence.......: Public
# Download URL..: https://api.openml.org/data/v1/download/22111209/covertype_seed_4_nrows_2000_nclasses_10_ncols_100_stratify_True.arff
# OpenML URL....: https://www.openml.org/d/44447
# # of features.: 55
# # of instances: 2000, OpenML Dataset
# ==============
# Name..........: road-safety_seed_0_nrows_2000_nclasses_10_ncols_100_stratify_True
# Version.......: 1
# Format........: arff
# Upload Date...: 2022-11-17 18:02:44
# Licence.......: Public
# Download URL..: https://api.openml.org/data/v1/download/22111215/road-safety_seed_0_nrows_2000_nclasses_10_ncols_100_stratify_True.arff
# OpenML URL....: https://www.openml.org/d/44453
# # of features.: 33
# # of instances: 2000, OpenML Dataset
# ==============
# Name..........: road-safety_seed_1_nrows_2000_nclasses_10_ncols_100_stratify_True
# Version.......: 1
# Format........: arff
# Upload Date...: 2022-11-17 18:02:49
# Licence.......: Public
# Download URL..: https://api.openml.org/data/v1/download/22111216/road-safety_seed_1_nrows_2000_nclasses_10_ncols_100_stratify_True.arff
# OpenML URL....: https://www.openml.org/d/44454
# # of features.: 33
# # of instances: 2000, OpenML Dataset
# ==============
# Name..........: road-safety_seed_2_nrows_2000_nclasses_10_ncols_100_stratify_True
# Version.......: 1
# Format........: arff
# Upload Date...: 2022-11-17 18:02:54
# Licence.......: Public
# Download URL..: https://api.openml.org/data/v1/download/22111217/road-safety_seed_2_nrows_2000_nclasses_10_ncols_100_stratify_True.arff
# OpenML URL....: https://www.openml.org/d/44455
# # of features.: 33
# # of instances: 2000, OpenML Dataset
# ==============
# Name..........: road-safety_seed_3_nrows_2000_nclasses_10_ncols_100_stratify_True
# Version.......: 1
# Format........: arff
# Upload Date...: 2022-11-17 18:03:01
# Licence.......: Public
# Download URL..: https://api.openml.org/data/v1/download/22111218/road-safety_seed_3_nrows_2000_nclasses_10_ncols_100_stratify_True.arff
# OpenML URL....: https://www.openml.org/d/44456
# # of features.: 33
# # of instances: 2000, OpenML Dataset
# ==============
# Name..........: road-safety_seed_4_nrows_2000_nclasses_10_ncols_100_stratify_True
# Version.......: 1
# Format........: arff
# Upload Date...: 2022-11-17 18:03:06
# Licence.......: Public
# Download URL..: https://api.openml.org/data/v1/download/22111219/road-safety_seed_4_nrows_2000_nclasses_10_ncols_100_stratify_True.arff
# OpenML URL....: https://www.openml.org/d/44457
# # of features.: 33
# # of instances: 2000, OpenML Dataset
# ==============
# Name..........: KDDCup09_upselling_seed_0_nrows_2000_nclasses_10_ncols_100_stratify_True
# Version.......: 1
# Format........: arff
# Upload Date...: 2022-11-17 18:03:37
# Licence.......: Public
# Download URL..: https://api.openml.org/data/v1/download/22111225/KDDCup09_upselling_seed_0_nrows_2000_nclasses_10_ncols_100_stratify_True.arff
# OpenML URL....: https://www.openml.org/d/44463
# # of features.: 50
# # of instances: 2000, OpenML Dataset
# ==============
# Name..........: KDDCup09_upselling_seed_1_nrows_2000_nclasses_10_ncols_100_stratify_True
# Version.......: 1
# Format........: arff
# Upload Date...: 2022-11-17 18:03:42
# Licence.......: Public
# Download URL..: https://api.openml.org/data/v1/download/22111226/KDDCup09_upselling_seed_1_nrows_2000_nclasses_10_ncols_100_stratify_True.arff
# OpenML URL....: https://www.openml.org/d/44464
# # of features.: 50
# # of instances: 2000, OpenML Dataset
# ==============
# Name..........: KDDCup09_upselling_seed_2_nrows_2000_nclasses_10_ncols_100_stratify_True
# Version.......: 1
# Format........: arff
# Upload Date...: 2022-11-17 18:03:48
# Licence.......: Public
# Download URL..: https://api.openml.org/data/v1/download/22111227/KDDCup09_upselling_seed_2_nrows_2000_nclasses_10_ncols_100_stratify_True.arff
# OpenML URL....: https://www.openml.org/d/44465
# # of features.: 50
# # of instances: 2000, OpenML Dataset
# ==============
# Name..........: KDDCup09_upselling_seed_3_nrows_2000_nclasses_10_ncols_100_stratify_True
# Version.......: 1
# Format........: arff
# Upload Date...: 2022-11-17 18:03:52
# Licence.......: Public
# Download URL..: https://api.openml.org/data/v1/download/22111228/KDDCup09_upselling_seed_3_nrows_2000_nclasses_10_ncols_100_stratify_True.arff
# OpenML URL....: https://www.openml.org/d/44466
# # of features.: 50
# # of instances: 2000, OpenML Dataset
# ==============
# Name..........: KDDCup09_upselling_seed_4_nrows_2000_nclasses_10_ncols_100_stratify_True
# Version.......: 1
# Format........: arff
# Upload Date...: 2022-11-17 18:03:58
# Licence.......: Public
# ...
# ==============
# Name..........: robert_seed_3_nrows_2000_nclasses_10_ncols_100_stratify_True
# Version.......: 1
# Format........: arff
# Upload Date...: 2022-11-17 18:47:18
# Licence.......: Public
# Download URL..: https://api.openml.org/data/v1/download/22111503/robert_seed_3_nrows_2000_nclasses_10_ncols_100_stratify_True.arff
# OpenML URL....: https://www.openml.org/d/44741
# # of features.: 101
# # of instances: 2000, OpenML Dataset
# ==============
# Name..........: robert_seed_4_nrows_2000_nclasses_10_ncols_100_stratify_True
# Version.......: 1
# Format........: arff
# Upload Date...: 2022-11-17 18:47:23
# Licence.......: Public
# Download URL..: https://api.openml.org/data/v1/download/22111504/robert_seed_4_nrows_2000_nclasses_10_ncols_100_stratify_True.arff
# OpenML URL....: https://www.openml.org/d/44742
# # of features.: 101
# # of instances: 2000, OpenML Dataset
# ==============
# Name..........: guillermo_seed_0_nrows_2000_nclasses_10_ncols_100_stratify_True
# Version.......: 1
# Format........: arff
# Upload Date...: 2022-11-17 18:47:50
# Licence.......: Public
# Download URL..: https://api.openml.org/data/v1/download/22111510/guillermo_seed_0_nrows_2000_nclasses_10_ncols_100_stratify_True.arff
# OpenML URL....: https://www.openml.org/d/44748
# # of features.: 101
# # of instances: 2000, OpenML Dataset
# ==============
# Name..........: guillermo_seed_1_nrows_2000_nclasses_10_ncols_100_stratify_True
# Version.......: 1
# Format........: arff
# Upload Date...: 2022-11-17 18:47:56
# Licence.......: Public
# Download URL..: https://api.openml.org/data/v1/download/22111511/guillermo_seed_1_nrows_2000_nclasses_10_ncols_100_stratify_True.arff
# OpenML URL....: https://www.openml.org/d/44749
# # of features.: 101
# # of instances: 2000, OpenML Dataset
# ==============
# Name..........: guillermo_seed_2_nrows_2000_nclasses_10_ncols_100_stratify_True
# Version.......: 1
# Format........: arff
# Upload Date...: 2022-11-17 18:48:01
# Licence.......: Public
# Download URL..: https://api.openml.org/data/v1/download/22111512/guillermo_seed_2_nrows_2000_nclasses_10_ncols_100_stratify_True.arff
# OpenML URL....: https://www.openml.org/d/44750
# # of features.: 101
# # of instances: 2000, OpenML Dataset
# ==============
# Name..........: guillermo_seed_3_nrows_2000_nclasses_10_ncols_100_stratify_True
# Version.......: 1
# Format........: arff
# Upload Date...: 2022-11-17 18:48:07
# Licence.......: Public
# Download URL..: https://api.openml.org/data/v1/download/22111513/guillermo_seed_3_nrows_2000_nclasses_10_ncols_100_stratify_True.arff
# OpenML URL....: https://www.openml.org/d/44751
# # of features.: 101
# # of instances: 2000, OpenML Dataset
# ==============
# Name..........: guillermo_seed_4_nrows_2000_nclasses_10_ncols_100_stratify_True
# Version.......: 1
# Format........: arff
# Upload Date...: 2022-11-17 18:48:13
# Licence.......: Public
# Download URL..: https://api.openml.org/data/v1/download/22111514/guillermo_seed_4_nrows_2000_nclasses_10_ncols_100_stratify_True.arff
# OpenML URL....: https://www.openml.org/d/44752
# # of features.: 101
# # of instances: 2000, OpenML Dataset
# ==============
# Name..........: riccardo_seed_0_nrows_2000_nclasses_10_ncols_100_stratify_True
# Version.......: 1
# Format........: arff
# Upload Date...: 2022-11-17 18:48:19
# Licence.......: Public
# Download URL..: https://api.openml.org/data/v1/download/22111515/riccardo_seed_0_nrows_2000_nclasses_10_ncols_100_stratify_True.arff
# OpenML URL....: https://www.openml.org/d/44753
# # of features.: 101
# # of instances: 2000, OpenML Dataset
# ==============
# Name..........: riccardo_seed_1_nrows_2000_nclasses_10_ncols_100_stratify_True
# Version.......: 1
# Format........: arff
# Upload Date...: 2022-11-17 18:48:25
# Licence.......: Public
# Download URL..: https://api.openml.org/data/v1/download/22111516/riccardo_seed_1_nrows_2000_nclasses_10_ncols_100_stratify_True.arff
# OpenML URL....: https://www.openml.org/d/44754
# # of features.: 101
# # of instances: 2000, OpenML Dataset
# ==============
# Name..........: riccardo_seed_2_nrows_2000_nclasses_10_ncols_100_stratify_True
# Version.......: 1
# Format........: arff
# Upload Date...: 2022-11-17 18:48:30
# Licence.......: Public
# Download URL..: https://api.openml.org/data/v1/download/22111517/riccardo_seed_2_nrows_2000_nclasses_10_ncols_100_stratify_True.arff
# OpenML URL....: https://www.openml.org/d/44755
# # of features.: 101
# # of instances: 2000, OpenML Dataset
# ==============
# Name..........: riccardo_seed_3_nrows_2000_nclasses_10_ncols_100_stratify_True
# Version.......: 1
# Format........: arff
# Upload Date...: 2022-11-17 18:48:35
# Licence.......: Public
# Download URL..: https://api.openml.org/data/v1/download/22111518/riccardo_seed_3_nrows_2000_nclasses_10_ncols_100_stratify_True.arff
# OpenML URL....: https://www.openml.org/d/44756
# # of features.: 101
# # of instances: 2000, OpenML Dataset
# ==============
# Name..........: riccardo_seed_4_nrows_2000_nclasses_10_ncols_100_stratify_True
# Version.......: 1
# Format........: arff
# Upload Date...: 2022-11-17 18:48:41
# Licence.......: Public
# Download URL..: https://api.openml.org/data/v1/download/22111519/riccardo_seed_4_nrows_2000_nclasses_10_ncols_100_stratify_True.arff
# OpenML URL....: https://www.openml.org/d/44757
# # of features.: 101
# # of instances: 2000, OpenML Dataset
# ==============
# Name..........: kick_seed_0_nrows_2000_nclasses_10_ncols_100_stratify_True
# Version.......: 1
# Format........: arff
# Upload Date...: 2022-11-17 18:48:46
# Licence.......: CC0
# Download URL..: https://api.openml.org/data/v1/download/22111520/kick_seed_0_nrows_2000_nclasses_10_ncols_100_stratify_True.arff
# OpenML URL....: https://www.openml.org/d/44758
# # of features.: 33
# # of instances: 2000, OpenML Dataset
# ==============
# Name..........: kick_seed_1_nrows_2000_nclasses_10_ncols_100_stratify_True
# Version.......: 1
# Format........: arff
# Upload Date...: 2022-11-17 18:48:51
# Licence.......: CC0
# Download URL..: https://api.openml.org/data/v1/download/22111521/kick_seed_1_nrows_2000_nclasses_10_ncols_100_stratify_True.arff
# OpenML URL....: https://www.openml.org/d/44759
# # of features.: 33
# # of instances: 2000, OpenML Dataset
# ==============
# Name..........: kick_seed_2_nrows_2000_nclasses_10_ncols_100_stratify_True
# Version.......: 1
# Format........: arff
# Upload Date...: 2022-11-17 18:48:56
# Licence.......: CC0
# Download URL..: https://api.openml.org/data/v1/download/22111522/kick_seed_2_nrows_2000_nclasses_10_ncols_100_stratify_True.arff
# OpenML URL....: https://www.openml.org/d/44760
# # of features.: 33
# # of instances: 2000, OpenML Dataset
# ==============
# Name..........: kick_seed_3_nrows_2000_nclasses_10_ncols_100_stratify_True
# Version.......: 1
# Format........: arff
# Upload Date...: 2022-11-17 18:49:00
# Licence.......: CC0
# Download URL..: https://api.openml.org/data/v1/download/22111523/kick_seed_3_nrows_2000_nclasses_10_ncols_100_stratify_True.arff
# OpenML URL....: https://www.openml.org/d/44761
# # of features.: 33
# # of instances: 2000, OpenML Dataset
# ==============
# Name..........: kick_seed_4_nrows_2000_nclasses_10_ncols_100_stratify_True
# Version.......: 1
# Format........: arff
# Upload Date...: 2022-11-17 18:49:06
# Licence.......: CC0
# Download URL..: https://api.openml.org/data/v1/download/22111524/kick_seed_4_nrows_2000_nclasses_10_ncols_100_stratify_True.arff
# OpenML URL....: https://www.openml.org/d/44762
# # of features.: 33
# # of instances: 2000, OpenML Dataset
# ==============
# Name..........: okcupid-stem_seed_0_nrows_2000_nclasses_10_ncols_100_stratify_True
# Version.......: 1
# Format........: arff
# Upload Date...: 2022-11-17 18:49:49
# Licence.......: Public
# Download URL..: https://api.openml.org/data/v1/download/22111530/okcupid-stem_seed_0_nrows_2000_nclasses_10_ncols_100_stratify_True.arff
# OpenML URL....: https://www.openml.org/d/44768
# # of features.: 20
# # of instances: 2000, OpenML Dataset
# ==============
# Name..........: okcupid-stem_seed_1_nrows_2000_nclasses_10_ncols_100_stratify_True
# Version.......: 1
# Format........: arff
# Upload Date...: 2022-11-17 18:49:54
# Licence.......: Public
# Download URL..: https://api.openml.org/data/v1/download/22111531/okcupid-stem_seed_1_nrows_2000_nclasses_10_ncols_100_stratify_True.arff
# OpenML URL....: https://www.openml.org/d/44769
# # of features.: 20
# # of instances: 2000, OpenML Dataset
# ==============
# Name..........: okcupid-stem_seed_2_nrows_2000_nclasses_10_ncols_100_stratify_True
# Version.......: 1
# Format........: arff
# Upload Date...: 2022-11-17 18:49:59
# Licence.......: Public
# Download URL..: https://api.openml.org/data/v1/download/22111532/okcupid-stem_seed_2_nrows_2000_nclasses_10_ncols_100_stratify_True.arff
# OpenML URL....: https://www.openml.org/d/44770
# # of features.: 20
# # of instances: 2000, OpenML Dataset
# ==============
# Name..........: okcupid-stem_seed_3_nrows_2000_nclasses_10_ncols_100_stratify_True
# Version.......: 1
# Format........: arff
# Upload Date...: 2022-11-17 18:50:04
# Licence.......: Public
# Download URL..: https://api.openml.org/data/v1/download/22111533/okcupid-stem_seed_3_nrows_2000_nclasses_10_ncols_100_stratify_True.arff
# OpenML URL....: https://www.openml.org/d/44771
# # of features.: 20
# # of instances: 2000, OpenML Dataset
# ==============
# Name..........: okcupid-stem_seed_4_nrows_2000_nclasses_10_ncols_100_stratify_True
# Version.......: 1
# Format........: arff
# Upload Date...: 2022-11-17 18:50:09
# Licence.......: Public
# Download URL..: https://api.openml.org/data/v1/download/22111534/okcupid-stem_seed_4_nrows_2000_nclasses_10_ncols_100_stratify_True.arff
# OpenML URL....: https://www.openml.org/d/44772
# # of features.: 20
# # of instances: 2000, OpenML Dataset
# ==============
# Name..........: KDDCup99_seed_0_nrows_2000_nclasses_10_ncols_100_stratify_True
# Version.......: 1
# Format........: arff
# Upload Date...: 2022-11-17 18:53:17
# Licence.......: Public
# Download URL..: https://api.openml.org/data/v1/download/22111540/KDDCup99_seed_0_nrows_2000_nclasses_10_ncols_100_stratify_True.arff
# OpenML URL....: https://www.openml.org/d/44778
# # of features.: 42
# # of instances: 2000, OpenML Dataset
# ==============
# Name..........: KDDCup99_seed_1_nrows_2000_nclasses_10_ncols_100_stratify_True
# Version.......: 1
# Format........: arff
# Upload Date...: 2022-11-17 18:53:30
# Licence.......: Public
# Download URL..: https://api.openml.org/data/v1/download/22111541/KDDCup99_seed_1_nrows_2000_nclasses_10_ncols_100_stratify_True.arff
# OpenML URL....: https://www.openml.org/d/44779
# # of features.: 42
# # of instances: 2000, OpenML Dataset
# ==============
# Name..........: KDDCup99_seed_2_nrows_2000_nclasses_10_ncols_100_stratify_True
# Version.......: 1
# Format........: arff
# Upload Date...: 2022-11-17 18:53:42
# Licence.......: Public
# Download URL..: https://api.openml.org/data/v1/download/22111542/KDDCup99_seed_2_nrows_2000_nclasses_10_ncols_100_stratify_True.arff
# OpenML URL....: https://www.openml.org/d/44780
# # of features.: 42
# # of instances: 2000, OpenML Dataset
# ==============
# Name..........: KDDCup99_seed_3_nrows_2000_nclasses_10_ncols_100_stratify_True
# Version.......: 1
# Format........: arff
# Upload Date...: 2022-11-17 18:53:54
# Licence.......: Public
# Download URL..: https://api.openml.org/data/v1/download/22111543/KDDCup99_seed_3_nrows_2000_nclasses_10_ncols_100_stratify_True.arff
# OpenML URL....: https://www.openml.org/d/44781
# # of features.: 42
# # of instances: 2000, OpenML Dataset
# ==============
# Name..........: KDDCup99_seed_4_nrows_2000_nclasses_10_ncols_100_stratify_True
# Version.......: 1
# Format........: arff
# Upload Date...: 2022-11-17 18:54:06
# Licence.......: Public
# Download URL..: https://api.openml.org/data/v1/download/22111544/KDDCup99_seed_4_nrows_2000_nclasses_10_ncols_100_stratify_True.arff
# OpenML URL....: https://www.openml.org/d/44782
# # of features.: 42
# # of instances: 2000, OpenML Dataset
# ==============
# Name..........: porto-seguro_seed_0_nrows_2000_nclasses_10_ncols_100_stratify_True
# Version.......: 1
# Format........: arff
# Upload Date...: 2022-11-17 18:54:35
# Licence.......: Public
# Download URL..: https://api.openml.org/data/v1/download/22111545/porto-seguro_seed_0_nrows_2000_nclasses_10_ncols_100_stratify_True.arff
# OpenML URL....: https://www.openml.org/d/44783
# # of features.: 58
# # of instances: 2000, OpenML Dataset
# ==============
# Name..........: porto-seguro_seed_1_nrows_2000_nclasses_10_ncols_100_stratify_True
# Version.......: 1
# Format........: arff
# Upload Date...: 2022-11-17 18:54:41
# Licence.......: Public
# Download URL..: https://api.openml.org/data/v1/download/22111546/porto-seguro_seed_1_nrows_2000_nclasses_10_ncols_100_stratify_True.arff
# OpenML URL....: https://www.openml.org/d/44784
# # of features.: 58
# # of instances: 2000, OpenML Dataset
# ==============
# Name..........: porto-seguro_seed_2_nrows_2000_nclasses_10_ncols_100_stratify_True
# Version.......: 1
# Format........: arff
# Upload Date...: 2022-11-17 18:54:46
# Licence.......: Public
# Download URL..: https://api.openml.org/data/v1/download/22111547/porto-seguro_seed_2_nrows_2000_nclasses_10_ncols_100_stratify_True.arff
# OpenML URL....: https://www.openml.org/d/44785
# # of features.: 58
# # of instances: 2000, OpenML Dataset
# ==============
# Name..........: porto-seguro_seed_3_nrows_2000_nclasses_10_ncols_100_stratify_True
# Version.......: 1
# Format........: arff
# Upload Date...: 2022-11-17 18:54:52
# Licence.......: Public
# Download URL..: https://api.openml.org/data/v1/download/22111548/porto-seguro_seed_3_nrows_2000_nclasses_10_ncols_100_stratify_True.arff
# OpenML URL....: https://www.openml.org/d/44786
# # of features.: 58
# # of instances: 2000, OpenML Dataset
# ==============
# Name..........: porto-seguro_seed_4_nrows_2000_nclasses_10_ncols_100_stratify_True
# Version.......: 1
# Format........: arff
# Upload Date...: 2022-11-17 18:54:57
# Licence.......: Public
# Download URL..: https://api.openml.org/data/v1/download/22111549/porto-seguro_seed_4_nrows_2000_nclasses_10_ncols_100_stratify_True.arff
# OpenML URL....: https://www.openml.org/d/44787
# # of features.: 58
# # of instances: 2000, OpenML Dataset
# ==============
# Name..........: KDDCup09-Upselling_seed_0_nrows_2000_nclasses_10_ncols_100_stratify_True
# Version.......: 1
# Format........: arff
# Upload Date...: 2022-11-17 19:05:38
# Licence.......: Public
# Download URL..: https://api.openml.org/data/v1/download/22111550/KDDCup09-Upselling_seed_0_nrows_2000_nclasses_10_ncols_100_stratify_True.arff
# OpenML URL....: https://www.openml.org/d/44788
# # of features.: 101
# # of instances: 2000, OpenML Dataset
# ==============
# Name..........: KDDCup09-Upselling_seed_1_nrows_2000_nclasses_10_ncols_100_stratify_True
# Version.......: 1
# Format........: arff
# Upload Date...: 2022-11-17 19:05:44
# Licence.......: Public
# Download URL..: https://api.openml.org/data/v1/download/22111551/KDDCup09-Upselling_seed_1_nrows_2000_nclasses_10_ncols_100_stratify_True.arff
# OpenML URL....: https://www.openml.org/d/44789
# # of features.: 101
# # of instances: 2000, OpenML Dataset
# ==============
# Name..........: KDDCup09-Upselling_seed_2_nrows_2000_nclasses_10_ncols_100_stratify_True
# Version.......: 1
# Format........: arff
# Upload Date...: 2022-11-17 19:05:50
# Licence.......: Public
# Download URL..: https://api.openml.org/data/v1/download/22111552/KDDCup09-Upselling_seed_2_nrows_2000_nclasses_10_ncols_100_stratify_True.arff
# OpenML URL....: https://www.openml.org/d/44790
# # of features.: 101
# # of instances: 2000, OpenML Dataset
# ==============
# Name..........: KDDCup09-Upselling_seed_3_nrows_2000_nclasses_10_ncols_100_stratify_True
# Version.......: 1
# Format........: arff
# Upload Date...: 2022-11-17 19:05:55
# Licence.......: Public
# Download URL..: https://api.openml.org/data/v1/download/22111553/KDDCup09-Upselling_seed_3_nrows_2000_nclasses_10_ncols_100_stratify_True.arff
# OpenML URL....: https://www.openml.org/d/44791
# # of features.: 101
# # of instances: 2000, OpenML Dataset
# ==============
# Name..........: KDDCup09-Upselling_seed_4_nrows_2000_nclasses_10_ncols_100_stratify_True
# Version.......: 1
# Format........: arff
# Upload Date...: 2022-11-17 19:06:00
# Licence.......: Public
# Download URL..: https://api.openml.org/data/v1/download/22111554/KDDCup09-Upselling_seed_4_nrows_2000_nclasses_10_ncols_100_stratify_True.arff
# OpenML URL....: https://www.openml.org/d/44792
# # of features.: 101
# # of instances: 2000]

# %%
from tqdm import tqdm
datasets = {}
# koda iz vaj - odstrani vse neustrezne datasete (numerične spremenljivke; podvojeni dataseti; večdimenzionalen y)
for n, podatkovje in tqdm(enumerate(all_datasets), total=len(all_datasets)):
    ime_podatkovja = podatkovje.name
    target = podatkovje.default_target_attribute
    X, _, nominal, names = podatkovje.get_data()
    # Vec pogojev, da podatkovje obdrzimo:

    # ce ga nismo ze prej (tj. neke druge verzije)
    name_ok = ime_podatkovja not in datasets

    # ce ima znan target in je target en sam (in ne npr. "Spol,Starost")
    targ_ok = target is not None and "," not in target

    # ce je target nominalen (klasifikacija) in podatki nimajo nominalnih atributov
    i_target = names.index(target) if targ_ok else 0
    nomi_ok = nominal[i_target] and sum(nominal) == 1  # natanko en nominalen in to je target
    if name_ok and targ_ok and nomi_ok:
        datasets[ime_podatkovja] = n

n_vsa = len(all_datasets)
n_ok = len(datasets)
print(f"Obdrzal sem {n_ok} podatkovij ({100 * n_ok / n_vsa:.1f}%)")
# Out:
# 100%|██████████| 340/340 [00:05<00:00, 63.98it/s]
# Obdrzal sem 159 podatkovij (46.8%)

# %% [markdown]
# Izračun najbižjih sosedov

# %%
target_name = all_datasets[0].default_target_attribute
X, y, _, _ = all_datasets[0].get_data(target=target_name)

# %%
# pripravil bom tabelo obilke 
# meta atributi | indeks v all_datasets


# mfe = MFE(features=meta_features)

attribute_names, attribute_values = mfe.extract()

meta_space = []
meta_space_indexes = []

for _, index in tqdm(datasets.items(), total=len(datasets)):
    dataset = all_datasets[index]
    target_name = dataset.default_target_attribute
    X, y, _, _ = dataset.get_data(target=target_name)


    # izračuna meta atribute teh podatkov
    mfe.fit(X.to_numpy(),y.to_numpy(), suppress_warnings=True)
    test, ex = mfe.extract()

    if set(test) != set(attribute_names):
        print(test.symmetric_difference(attribute_names))
    

    meta_space.append(ex)
    meta_space_indexes.append(index)
# Out:
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'can_cor' with summary 'sd'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/statistical.py:1267: RuntimeWarning: invalid value encountered in log
#   np.log(np.linalg.det(S_i)) for S_i in sample_cov_matrices
#   1%|          | 1/159 [00:02<05:42,  2.17s/it]/home/uprimozic/.local/lib/python3.10/site-packages/pymfe/_internal.py:606: RuntimeWarning: Can't extract feature 'g_mean'.
#  Exception message: ZeroDivisionError('division by zero').
#  Will set it as 'np.nan' for all summary functions.
#   warnings.warn(
# /home/uprimozic/.local/lib/python3.10/site-packages/numpy/core/fromnumeric.py:3432: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/uprimozic/.local/lib/python3.10/site-packages/numpy/core/_methods.py:190: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'g_mean' with summary 'mean'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'g_mean' with summary 'sd'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/_internal.py:606: RuntimeWarning: Can't extract feature 'h_mean'.
#  Exception message: ValueError('Harmonic mean only defined if all elements greater than or equal to zero').
#  Will set it as 'np.nan' for all summary functions.
#   warnings.warn(
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'h_mean' with summary 'mean'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'h_mean' with summary 'sd'. Will set it as 'np.nan'.
#   warnings.warn(
#   1%|▏         | 2/159 [00:04<06:27,  2.47s/it]/home/uprimozic/.local/lib/python3.10/site-packages/pymfe/statistical.py:1267: RuntimeWarning: invalid value encountered in log
#   np.log(np.linalg.det(S_i)) for S_i in sample_cov_matrices
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/statistical.py:1272: RuntimeWarning: invalid value encountered in log
#   * np.log(np.linalg.det(pooled_cov_mat))
#   2%|▏         | 3/159 [00:07<06:03,  2.33s/it]/home/uprimozic/.local/lib/python3.10/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'g_mean' with summary 'mean'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'g_mean' with summary 'sd'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/_internal.py:606: RuntimeWarning: Can't extract feature 'h_mean'.
#  Exception message: ValueError('Harmonic mean only defined if all elements greater than or equal to zero').
#  Will set it as 'np.nan' for all summary functions.
#   warnings.warn(
# /home/uprimozic/.local/lib/python3.10/site-packages/numpy/core/fromnumeric.py:3432: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/uprimozic/.local/lib/python3.10/site-packages/numpy/core/_methods.py:190: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'h_mean' with summary 'mean'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'h_mean' with summary 'sd'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/statistical.py:1267: RuntimeWarning: divide by zero encountered in log
#   np.log(np.linalg.det(S_i)) for S_i in sample_cov_matrices
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/statistical.py:1272: RuntimeWarning: divide by zero encountered in log
#   * np.log(np.linalg.det(pooled_cov_mat))
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/statistical.py:1271: RuntimeWarning: invalid value encountered in double_scalars
#   (num_inst - num_classes)
#   3%|▎         | 4/159 [00:08<05:21,  2.08s/it]/home/uprimozic/.local/lib/python3.10/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'can_cor' with summary 'sd'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/uprimozic/.local/lib/python3.10/site-packages/numpy/linalg/linalg.py:2154: RuntimeWarning: overflow encountered in det
#   r = _umath_linalg.det(a, signature=signature)
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/statistical.py:1271: RuntimeWarning: invalid value encountered in double_scalars
#   (num_inst - num_classes)
#   3%|▎         | 5/159 [00:11<05:34,  2.17s/it]/home/uprimozic/.local/lib/python3.10/site-packages/pymfe/_internal.py:606: RuntimeWarning: Can't extract feature 'g_mean'.
#  Exception message: ZeroDivisionError('division by zero').
#  Will set it as 'np.nan' for all summary functions.
#   warnings.warn(
# /home/uprimozic/.local/lib/python3.10/site-packages/numpy/core/fromnumeric.py:3432: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/uprimozic/.local/lib/python3.10/site-packages/numpy/core/_methods.py:190: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'g_mean' with summary 'mean'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'g_mean' with summary 'sd'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/statistical.py:1267: RuntimeWarning: divide by zero encountered in log
#   np.log(np.linalg.det(S_i)) for S_i in sample_cov_matrices
#   4%|▍         | 6/159 [00:24<15:24,  6.04s/it]/home/uprimozic/.local/lib/python3.10/site-packages/pymfe/statistical.py:1267: RuntimeWarning: divide by zero encountered in log
#   np.log(np.linalg.det(S_i)) for S_i in sample_cov_matrices
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/statistical.py:1272: RuntimeWarning: divide by zero encountered in log
#   * np.log(np.linalg.det(pooled_cov_mat))
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/statistical.py:1271: RuntimeWarning: invalid value encountered in double_scalars
#   (num_inst - num_classes)
#   4%|▍         | 7/159 [00:36<19:56,  7.87s/it]/home/uprimozic/.local/lib/python3.10/site-packages/pymfe/_internal.py:606: RuntimeWarning: Can't extract feature 'g_mean'.
#  Exception message: ZeroDivisionError('division by zero').
#  Will set it as 'np.nan' for all summary functions.
#   warnings.warn(
# /home/uprimozic/.local/lib/python3.10/site-packages/numpy/core/fromnumeric.py:3432: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/uprimozic/.local/lib/python3.10/site-packages/numpy/core/_methods.py:190: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'g_mean' with summary 'mean'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'g_mean' with summary 'sd'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/statistical.py:1267: RuntimeWarning: divide by zero encountered in log
#   np.log(np.linalg.det(S_i)) for S_i in sample_cov_matrices
#   5%|▌         | 8/159 [00:48<23:16,  9.25s/it]/home/uprimozic/.local/lib/python3.10/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'can_cor' with summary 'sd'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'g_mean' with summary 'mean'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'g_mean' with summary 'sd'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/_internal.py:606: RuntimeWarning: Can't extract feature 'h_mean'.
#  Exception message: ValueError('Harmonic mean only defined if all elements greater than or equal to zero').
#  Will set it as 'np.nan' for all summary functions.
#   warnings.warn(
# /home/uprimozic/.local/lib/python3.10/site-packages/numpy/core/fromnumeric.py:3432: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/uprimozic/.local/lib/python3.10/site-packages/numpy/core/_methods.py:190: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'h_mean' with summary 'mean'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'h_mean' with summary 'sd'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/statistical.py:1267: RuntimeWarning: divide by zero encountered in log
#   np.log(np.linalg.det(S_i)) for S_i in sample_cov_matrices
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/statistical.py:1267: RuntimeWarning: invalid value encountered in log
#   np.log(np.linalg.det(S_i)) for S_i in sample_cov_matrices
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/statistical.py:1272: RuntimeWarning: invalid value encountered in log
#   * np.log(np.linalg.det(pooled_cov_mat))
#   6%|▌         | 9/159 [00:49<17:00,  6.80s/it]/home/uprimozic/.local/lib/python3.10/site-packages/sklearn/preprocessing/_encoders.py:828: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/_internal.py:606: RuntimeWarning: Can't extract feature 'can_cor'.
#  Exception message: ValueError('Input X contains NaN.\nCCA does not accept missing values encoded as NaN natively. For supervised learning, you might want to consider sklearn.ensemble.HistGradientBoostingClassifier and Regressor which accept missing values encoded as NaNs natively. Alternatively, it is possible to preprocess the data, for instance by using an imputer transformer in a pipeline or drop samples with missing values. See https://scikit-learn.org/stable/modules/impute.html You can find a list of all estimators that handle NaN values at the following page: https://scikit-learn.org/stable/modules/impute.html#estimators-that-handle-nan-values').
#  Will set it as 'np.nan' for all summary functions.
#   warnings.warn(
# /home/uprimozic/.local/lib/python3.10/site-packages/numpy/core/fromnumeric.py:3432: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/uprimozic/.local/lib/python3.10/site-packages/numpy/core/_methods.py:190: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'can_cor' with summary 'mean'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'can_cor' with summary 'sd'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'cor' with summary 'mean'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'cor' with summary 'sd'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'cov' with summary 'mean'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'cov' with summary 'sd'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/_internal.py:606: RuntimeWarning: Can't extract feature 'eigenvalues'.
#  Exception message: LinAlgError('Eigenvalues did not converge').
#  Will set it as 'np.nan' for all summary functions.
#   warnings.warn(
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'eigenvalues' with summary 'mean'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'eigenvalues' with summary 'sd'. Will set it as 'np.nan'.
#   warnings.warn(
# /usr/lib/python3/dist-packages/scipy/stats/_stats_py.py:287: RuntimeWarning: divide by zero encountered in log
#   log_a = np.log(a)
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'g_mean' with summary 'mean'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'g_mean' with summary 'sd'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/_internal.py:606: RuntimeWarning: Can't extract feature 'h_mean'.
#  Exception message: ValueError('Harmonic mean only defined if all elements greater than or equal to zero').
#  Will set it as 'np.nan' for all summary functions.
#   warnings.warn(
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'h_mean' with summary 'mean'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'h_mean' with summary 'sd'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'iq_range' with summary 'mean'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'iq_range' with summary 'sd'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'kurtosis' with summary 'mean'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'kurtosis' with summary 'sd'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/uprimozic/.local/lib/python3.10/site-packages/sklearn/preprocessing/_encoders.py:828: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/_internal.py:606: RuntimeWarning: Can't extract feature 'lh_trace'.
#  Exception message: ValueError('Input X contains NaN.\nCCA does not accept missing values encoded as NaN natively. For supervised learning, you might want to consider sklearn.ensemble.HistGradientBoostingClassifier and Regressor which accept missing values encoded as NaNs natively. Alternatively, it is possible to preprocess the data, for instance by using an imputer transformer in a pipeline or drop samples with missing values. See https://scikit-learn.org/stable/modules/impute.html You can find a list of all estimators that handle NaN values at the following page: https://scikit-learn.org/stable/modules/impute.html#estimators-that-handle-nan-values').
#   warnings.warn(
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'mad' with summary 'mean'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'mad' with summary 'sd'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'max' with summary 'mean'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'max' with summary 'sd'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'mean' with summary 'mean'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'mean' with summary 'sd'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'median' with summary 'mean'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'median' with summary 'sd'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'min' with summary 'mean'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'min' with summary 'sd'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/uprimozic/.local/lib/python3.10/site-packages/sklearn/preprocessing/_encoders.py:828: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/_internal.py:606: RuntimeWarning: Can't extract feature 'nr_disc'.
#  Exception message: ValueError('Input X contains NaN.\nCCA does not accept missing values encoded as NaN natively. For supervised learning, you might want to consider sklearn.ensemble.HistGradientBoostingClassifier and Regressor which accept missing values encoded as NaNs natively. Alternatively, it is possible to preprocess the data, for instance by using an imputer transformer in a pipeline or drop samples with missing values. See https://scikit-learn.org/stable/modules/impute.html You can find a list of all estimators that handle NaN values at the following page: https://scikit-learn.org/stable/modules/impute.html#estimators-that-handle-nan-values').
#   warnings.warn(
# /home/uprimozic/.local/lib/python3.10/site-packages/sklearn/preprocessing/_encoders.py:828: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/_internal.py:606: RuntimeWarning: Can't extract feature 'p_trace'.
#  Exception message: ValueError('Input X contains NaN.\nCCA does not accept missing values encoded as NaN natively. For supervised learning, you might want to consider sklearn.ensemble.HistGradientBoostingClassifier and Regressor which accept missing values encoded as NaNs natively. Alternatively, it is possible to preprocess the data, for instance by using an imputer transformer in a pipeline or drop samples with missing values. See https://scikit-learn.org/stable/modules/impute.html You can find a list of all estimators that handle NaN values at the following page: https://scikit-learn.org/stable/modules/impute.html#estimators-that-handle-nan-values').
#   warnings.warn(
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'range' with summary 'mean'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'range' with summary 'sd'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/uprimozic/.local/lib/python3.10/site-packages/sklearn/preprocessing/_encoders.py:828: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/_internal.py:606: RuntimeWarning: Can't extract feature 'roy_root'.
#  Exception message: ValueError('Input X contains NaN.\nCCA does not accept missing values encoded as NaN natively. For supervised learning, you might want to consider sklearn.ensemble.HistGradientBoostingClassifier and Regressor which accept missing values encoded as NaNs natively. Alternatively, it is possible to preprocess the data, for instance by using an imputer transformer in a pipeline or drop samples with missing values. See https://scikit-learn.org/stable/modules/impute.html You can find a list of all estimators that handle NaN values at the following page: https://scikit-learn.org/stable/modules/impute.html#estimators-that-handle-nan-values').
#   warnings.warn(
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'sd' with summary 'mean'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'sd' with summary 'sd'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/uprimozic/.local/lib/python3.10/site-packages/numpy/linalg/linalg.py:2154: RuntimeWarning: invalid value encountered in det
#   r = _umath_linalg.det(a, signature=signature)
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'skewness' with summary 'mean'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'skewness' with summary 'sd'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 't_mean' with summary 'mean'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 't_mean' with summary 'sd'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'var' with summary 'mean'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'var' with summary 'sd'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/uprimozic/.local/lib/python3.10/site-packages/sklearn/preprocessing/_encoders.py:828: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/_internal.py:606: RuntimeWarning: Can't extract feature 'w_lambda'.
#  Exception message: ValueError('Input X contains NaN.\nCCA does not accept missing values encoded as NaN natively. For supervised learning, you might want to consider sklearn.ensemble.HistGradientBoostingClassifier and Regressor which accept missing values encoded as NaNs natively. Alternatively, it is possible to preprocess the data, for instance by using an imputer transformer in a pipeline or drop samples with missing values. See https://scikit-learn.org/stable/modules/impute.html You can find a list of all estimators that handle NaN values at the following page: https://scikit-learn.org/stable/modules/impute.html#estimators-that-handle-nan-values').
#   warnings.warn(
#   6%|▋         | 10/159 [00:59<19:11,  7.73s/it]/home/uprimozic/.local/lib/python3.10/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'can_cor' with summary 'sd'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'cor' with summary 'mean'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'cor' with summary 'sd'. Will set it as 'np.nan'.
#   warnings.warn(
# /usr/lib/python3/dist-packages/scipy/stats/_morestats.py:1758: UserWarning: Input data for shapiro has range zero. The results may not be accurate.
#   warnings.warn("Input data for shapiro has range zero. The results "
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/statistical.py:1267: RuntimeWarning: divide by zero encountered in log
#   np.log(np.linalg.det(S_i)) for S_i in sample_cov_matrices
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/statistical.py:1272: RuntimeWarning: divide by zero encountered in log
#   * np.log(np.linalg.det(pooled_cov_mat))
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/statistical.py:1271: RuntimeWarning: invalid value encountered in double_scalars
#   (num_inst - num_classes)
#   7%|▋         | 11/159 [01:01<14:17,  5.79s/it]/home/uprimozic/.local/lib/python3.10/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'can_cor' with summary 'sd'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/statistical.py:1267: RuntimeWarning: invalid value encountered in log
#   np.log(np.linalg.det(S_i)) for S_i in sample_cov_matrices
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/statistical.py:1272: RuntimeWarning: invalid value encountered in log
#   * np.log(np.linalg.det(pooled_cov_mat))
#   8%|▊         | 12/159 [01:02<10:44,  4.39s/it]/home/uprimozic/.local/lib/python3.10/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'can_cor' with summary 'sd'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/statistical.py:1267: RuntimeWarning: invalid value encountered in log
#   np.log(np.linalg.det(S_i)) for S_i in sample_cov_matrices
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/statistical.py:1272: RuntimeWarning: invalid value encountered in log
#   * np.log(np.linalg.det(pooled_cov_mat))
#   8%|▊         | 13/159 [01:03<08:21,  3.44s/it]/home/uprimozic/.local/lib/python3.10/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'can_cor' with summary 'sd'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/statistical.py:1267: RuntimeWarning: invalid value encountered in log
#   np.log(np.linalg.det(S_i)) for S_i in sample_cov_matrices
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/statistical.py:1272: RuntimeWarning: invalid value encountered in log
#   * np.log(np.linalg.det(pooled_cov_mat))
#   9%|▉         | 14/159 [01:04<06:40,  2.76s/it]/home/uprimozic/.local/lib/python3.10/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'can_cor' with summary 'sd'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/statistical.py:1267: RuntimeWarning: invalid value encountered in log
#   np.log(np.linalg.det(S_i)) for S_i in sample_cov_matrices
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/statistical.py:1272: RuntimeWarning: invalid value encountered in log
#   * np.log(np.linalg.det(pooled_cov_mat))
#   9%|▉         | 15/159 [01:05<05:30,  2.29s/it]/home/uprimozic/.local/lib/python3.10/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'can_cor' with summary 'sd'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/statistical.py:1267: RuntimeWarning: invalid value encountered in log
#   np.log(np.linalg.det(S_i)) for S_i in sample_cov_matrices
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/statistical.py:1272: RuntimeWarning: invalid value encountered in log
#   * np.log(np.linalg.det(pooled_cov_mat))
#  10%|█         | 16/159 [01:07<04:42,  1.97s/it]/home/uprimozic/.local/lib/python3.10/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'can_cor' with summary 'sd'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'g_mean' with summary 'mean'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'g_mean' with summary 'sd'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/_internal.py:606: RuntimeWarning: Can't extract feature 'h_mean'.
#  Exception message: ValueError('Harmonic mean only defined if all elements greater than or equal to zero').
#  Will set it as 'np.nan' for all summary functions.
#   warnings.warn(
# /home/uprimozic/.local/lib/python3.10/site-packages/numpy/core/fromnumeric.py:3432: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/uprimozic/.local/lib/python3.10/site-packages/numpy/core/_methods.py:190: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'h_mean' with summary 'mean'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'h_mean' with summary 'sd'. Will set it as 'np.nan'.
#   warnings.warn(
#  11%|█         | 17/159 [01:08<04:07,  1.74s/it]/home/uprimozic/.local/lib/python3.10/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'can_cor' with summary 'sd'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'g_mean' with summary 'mean'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'g_mean' with summary 'sd'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/_internal.py:606: RuntimeWarning: Can't extract feature 'h_mean'.
#  Exception message: ValueError('Harmonic mean only defined if all elements greater than or equal to zero').
#  Will set it as 'np.nan' for all summary functions.
#   warnings.warn(
# /home/uprimozic/.local/lib/python3.10/site-packages/numpy/core/fromnumeric.py:3432: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/uprimozic/.local/lib/python3.10/site-packages/numpy/core/_methods.py:190: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'h_mean' with summary 'mean'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'h_mean' with summary 'sd'. Will set it as 'np.nan'.
#   warnings.warn(
#  11%|█▏        | 18/159 [01:09<03:42,  1.58s/it]/home/uprimozic/.local/lib/python3.10/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'can_cor' with summary 'sd'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'g_mean' with summary 'mean'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'g_mean' with summary 'sd'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/_internal.py:606: RuntimeWarning: Can't extract feature 'h_mean'.
#  Exception message: ValueError('Harmonic mean only defined if all elements greater than or equal to zero').
#  Will set it as 'np.nan' for all summary functions.
#   warnings.warn(
# /home/uprimozic/.local/lib/python3.10/site-packages/numpy/core/fromnumeric.py:3432: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/uprimozic/.local/lib/python3.10/site-packages/numpy/core/_methods.py:190: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'h_mean' with summary 'mean'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'h_mean' with summary 'sd'. Will set it as 'np.nan'.
#   warnings.warn(
#  12%|█▏        | 19/159 [01:10<03:24,  1.46s/it]/home/uprimozic/.local/lib/python3.10/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'can_cor' with summary 'sd'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'g_mean' with summary 'mean'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'g_mean' with summary 'sd'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/_internal.py:606: RuntimeWarning: Can't extract feature 'h_mean'.
#  Exception message: ValueError('Harmonic mean only defined if all elements greater than or equal to zero').
#  Will set it as 'np.nan' for all summary functions.
#   warnings.warn(
# /home/uprimozic/.local/lib/python3.10/site-packages/numpy/core/fromnumeric.py:3432: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/uprimozic/.local/lib/python3.10/site-packages/numpy/core/_methods.py:190: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'h_mean' with summary 'mean'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'h_mean' with summary 'sd'. Will set it as 'np.nan'.
#   warnings.warn(
#  13%|█▎        | 20/159 [01:11<03:13,  1.39s/it]/home/uprimozic/.local/lib/python3.10/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'can_cor' with summary 'sd'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'g_mean' with summary 'mean'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'g_mean' with summary 'sd'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/_internal.py:606: RuntimeWarning: Can't extract feature 'h_mean'.
#  Exception message: ValueError('Harmonic mean only defined if all elements greater than or equal to zero').
#  Will set it as 'np.nan' for all summary functions.
#   warnings.warn(
# /home/uprimozic/.local/lib/python3.10/site-packages/numpy/core/fromnumeric.py:3432: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/uprimozic/.local/lib/python3.10/site-packages/numpy/core/_methods.py:190: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'h_mean' with summary 'mean'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'h_mean' with summary 'sd'. Will set it as 'np.nan'.
#   warnings.warn(
#  13%|█▎        | 21/159 [01:13<03:05,  1.34s/it]/home/uprimozic/.local/lib/python3.10/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'can_cor' with summary 'sd'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'g_mean' with summary 'mean'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'g_mean' with summary 'sd'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/_internal.py:606: RuntimeWarning: Can't extract feature 'h_mean'.
#  Exception message: ValueError('Harmonic mean only defined if all elements greater than or equal to zero').
#  Will set it as 'np.nan' for all summary functions.
#   warnings.warn(
# /home/uprimozic/.local/lib/python3.10/site-packages/numpy/core/fromnumeric.py:3432: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/uprimozic/.local/lib/python3.10/site-packages/numpy/core/_methods.py:190: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'h_mean' with summary 'mean'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'h_mean' with summary 'sd'. Will set it as 'np.nan'.
#   warnings.warn(
#  14%|█▍        | 22/159 [01:14<03:08,  1.37s/it]/home/uprimozic/.local/lib/python3.10/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'can_cor' with summary 'sd'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'g_mean' with summary 'mean'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'g_mean' with summary 'sd'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/_internal.py:606: RuntimeWarning: Can't extract feature 'h_mean'.
#  Exception message: ValueError('Harmonic mean only defined if all elements greater than or equal to zero').
#  Will set it as 'np.nan' for all summary functions.
#   warnings.warn(
# /home/uprimozic/.local/lib/python3.10/site-packages/numpy/core/fromnumeric.py:3432: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/uprimozic/.local/lib/python3.10/site-packages/numpy/core/_methods.py:190: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'h_mean' with summary 'mean'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'h_mean' with summary 'sd'. Will set it as 'np.nan'.
#   warnings.warn(
#  14%|█▍        | 23/159 [01:16<03:08,  1.39s/it]/home/uprimozic/.local/lib/python3.10/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'can_cor' with summary 'sd'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'g_mean' with summary 'mean'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'g_mean' with summary 'sd'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/_internal.py:606: RuntimeWarning: Can't extract feature 'h_mean'.
#  Exception message: ValueError('Harmonic mean only defined if all elements greater than or equal to zero').
#  Will set it as 'np.nan' for all summary functions.
#   warnings.warn(
# /home/uprimozic/.local/lib/python3.10/site-packages/numpy/core/fromnumeric.py:3432: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/uprimozic/.local/lib/python3.10/site-packages/numpy/core/_methods.py:190: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'h_mean' with summary 'mean'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'h_mean' with summary 'sd'. Will set it as 'np.nan'.
#   warnings.warn(
#  15%|█▌        | 24/159 [01:17<03:06,  1.38s/it]/home/uprimozic/.local/lib/python3.10/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'can_cor' with summary 'sd'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'g_mean' with summary 'mean'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'g_mean' with summary 'sd'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/_internal.py:606: RuntimeWarning: Can't extract feature 'h_mean'.
#  Exception message: ValueError('Harmonic mean only defined if all elements greater than or equal to zero').
#  Will set it as 'np.nan' for all summary functions.
#   warnings.warn(
# /home/uprimozic/.local/lib/python3.10/site-packages/numpy/core/fromnumeric.py:3432: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/uprimozic/.local/lib/python3.10/site-packages/numpy/core/_methods.py:190: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'h_mean' with summary 'mean'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'h_mean' with summary 'sd'. Will set it as 'np.nan'.
#   warnings.warn(
#  16%|█▌        | 25/159 [01:18<03:06,  1.39s/it]/home/uprimozic/.local/lib/python3.10/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'can_cor' with summary 'sd'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'g_mean' with summary 'mean'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'g_mean' with summary 'sd'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/_internal.py:606: RuntimeWarning: Can't extract feature 'h_mean'.
#  Exception message: ValueError('Harmonic mean only defined if all elements greater than or equal to zero').
#  Will set it as 'np.nan' for all summary functions.
#   warnings.warn(
# /home/uprimozic/.local/lib/python3.10/site-packages/numpy/core/fromnumeric.py:3432: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/uprimozic/.local/lib/python3.10/site-packages/numpy/core/_methods.py:190: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'h_mean' with summary 'mean'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'h_mean' with summary 'sd'. Will set it as 'np.nan'.
#   warnings.warn(
#  16%|█▋        | 26/159 [01:20<03:04,  1.39s/it]/home/uprimozic/.local/lib/python3.10/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'can_cor' with summary 'sd'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'g_mean' with summary 'mean'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'g_mean' with summary 'sd'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/_internal.py:606: RuntimeWarning: Can't extract feature 'h_mean'.
#  Exception message: ValueError('Harmonic mean only defined if all elements greater than or equal to zero').
#  Will set it as 'np.nan' for all summary functions.
#   warnings.warn(
# /home/uprimozic/.local/lib/python3.10/site-packages/numpy/core/fromnumeric.py:3432: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/uprimozic/.local/lib/python3.10/site-packages/numpy/core/_methods.py:190: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'h_mean' with summary 'mean'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'h_mean' with summary 'sd'. Will set it as 'np.nan'.
#   warnings.warn(
#  17%|█▋        | 27/159 [01:21<03:01,  1.37s/it]/home/uprimozic/.local/lib/python3.10/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'can_cor' with summary 'sd'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'g_mean' with summary 'mean'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'g_mean' with summary 'sd'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/_internal.py:606: RuntimeWarning: Can't extract feature 'h_mean'.
#  Exception message: ValueError('Harmonic mean only defined if all elements greater than or equal to zero').
#  Will set it as 'np.nan' for all summary functions.
#   warnings.warn(
# ...
#   warnings.warn(
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'cov' with summary 'sd'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/_internal.py:606: RuntimeWarning: Can't extract feature 'eigenvalues'.
#  Exception message: LinAlgError('Eigenvalues did not converge').
#  Will set it as 'np.nan' for all summary functions.
#   warnings.warn(
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'eigenvalues' with summary 'mean'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'eigenvalues' with summary 'sd'. Will set it as 'np.nan'.
#   warnings.warn(
# /usr/lib/python3/dist-packages/scipy/stats/_stats_py.py:287: RuntimeWarning: divide by zero encountered in log
#   log_a = np.log(a)
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'g_mean' with summary 'mean'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'g_mean' with summary 'sd'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/_internal.py:606: RuntimeWarning: Can't extract feature 'h_mean'.
#  Exception message: ValueError('Harmonic mean only defined if all elements greater than or equal to zero').
#  Will set it as 'np.nan' for all summary functions.
#   warnings.warn(
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'h_mean' with summary 'mean'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'h_mean' with summary 'sd'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'iq_range' with summary 'mean'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'iq_range' with summary 'sd'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'kurtosis' with summary 'mean'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'kurtosis' with summary 'sd'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/uprimozic/.local/lib/python3.10/site-packages/sklearn/preprocessing/_encoders.py:828: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/_internal.py:606: RuntimeWarning: Can't extract feature 'lh_trace'.
#  Exception message: ValueError('Input X contains NaN.\nCCA does not accept missing values encoded as NaN natively. For supervised learning, you might want to consider sklearn.ensemble.HistGradientBoostingClassifier and Regressor which accept missing values encoded as NaNs natively. Alternatively, it is possible to preprocess the data, for instance by using an imputer transformer in a pipeline or drop samples with missing values. See https://scikit-learn.org/stable/modules/impute.html You can find a list of all estimators that handle NaN values at the following page: https://scikit-learn.org/stable/modules/impute.html#estimators-that-handle-nan-values').
#   warnings.warn(
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'mad' with summary 'mean'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'mad' with summary 'sd'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'max' with summary 'mean'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'max' with summary 'sd'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'mean' with summary 'mean'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'mean' with summary 'sd'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'median' with summary 'mean'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'median' with summary 'sd'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'min' with summary 'mean'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'min' with summary 'sd'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/uprimozic/.local/lib/python3.10/site-packages/sklearn/preprocessing/_encoders.py:828: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/_internal.py:606: RuntimeWarning: Can't extract feature 'nr_disc'.
#  Exception message: ValueError('Input X contains NaN.\nCCA does not accept missing values encoded as NaN natively. For supervised learning, you might want to consider sklearn.ensemble.HistGradientBoostingClassifier and Regressor which accept missing values encoded as NaNs natively. Alternatively, it is possible to preprocess the data, for instance by using an imputer transformer in a pipeline or drop samples with missing values. See https://scikit-learn.org/stable/modules/impute.html You can find a list of all estimators that handle NaN values at the following page: https://scikit-learn.org/stable/modules/impute.html#estimators-that-handle-nan-values').
#   warnings.warn(
# /usr/lib/python3/dist-packages/scipy/stats/_morestats.py:1758: UserWarning: Input data for shapiro has range zero. The results may not be accurate.
#   warnings.warn("Input data for shapiro has range zero. The results "
# /home/uprimozic/.local/lib/python3.10/site-packages/sklearn/preprocessing/_encoders.py:828: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/_internal.py:606: RuntimeWarning: Can't extract feature 'p_trace'.
#  Exception message: ValueError('Input X contains NaN.\nCCA does not accept missing values encoded as NaN natively. For supervised learning, you might want to consider sklearn.ensemble.HistGradientBoostingClassifier and Regressor which accept missing values encoded as NaNs natively. Alternatively, it is possible to preprocess the data, for instance by using an imputer transformer in a pipeline or drop samples with missing values. See https://scikit-learn.org/stable/modules/impute.html You can find a list of all estimators that handle NaN values at the following page: https://scikit-learn.org/stable/modules/impute.html#estimators-that-handle-nan-values').
#   warnings.warn(
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'range' with summary 'mean'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'range' with summary 'sd'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/uprimozic/.local/lib/python3.10/site-packages/sklearn/preprocessing/_encoders.py:828: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/_internal.py:606: RuntimeWarning: Can't extract feature 'roy_root'.
#  Exception message: ValueError('Input X contains NaN.\nCCA does not accept missing values encoded as NaN natively. For supervised learning, you might want to consider sklearn.ensemble.HistGradientBoostingClassifier and Regressor which accept missing values encoded as NaNs natively. Alternatively, it is possible to preprocess the data, for instance by using an imputer transformer in a pipeline or drop samples with missing values. See https://scikit-learn.org/stable/modules/impute.html You can find a list of all estimators that handle NaN values at the following page: https://scikit-learn.org/stable/modules/impute.html#estimators-that-handle-nan-values').
#   warnings.warn(
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'sd' with summary 'mean'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'sd' with summary 'sd'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/uprimozic/.local/lib/python3.10/site-packages/numpy/linalg/linalg.py:2154: RuntimeWarning: invalid value encountered in det
#   r = _umath_linalg.det(a, signature=signature)
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/statistical.py:1267: RuntimeWarning: divide by zero encountered in log
#   np.log(np.linalg.det(S_i)) for S_i in sample_cov_matrices
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/statistical.py:1272: RuntimeWarning: divide by zero encountered in log
#   * np.log(np.linalg.det(pooled_cov_mat))
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/statistical.py:1271: RuntimeWarning: invalid value encountered in double_scalars
#   (num_inst - num_classes)
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'skewness' with summary 'mean'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'skewness' with summary 'sd'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 't_mean' with summary 'mean'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 't_mean' with summary 'sd'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'var' with summary 'mean'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'var' with summary 'sd'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/uprimozic/.local/lib/python3.10/site-packages/sklearn/preprocessing/_encoders.py:828: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/_internal.py:606: RuntimeWarning: Can't extract feature 'w_lambda'.
#  Exception message: ValueError('Input X contains NaN.\nCCA does not accept missing values encoded as NaN natively. For supervised learning, you might want to consider sklearn.ensemble.HistGradientBoostingClassifier and Regressor which accept missing values encoded as NaNs natively. Alternatively, it is possible to preprocess the data, for instance by using an imputer transformer in a pipeline or drop samples with missing values. See https://scikit-learn.org/stable/modules/impute.html You can find a list of all estimators that handle NaN values at the following page: https://scikit-learn.org/stable/modules/impute.html#estimators-that-handle-nan-values').
#   warnings.warn(
#  99%|█████████▉| 158/159 [10:41<00:02,  2.15s/it]/home/uprimozic/.local/lib/python3.10/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'can_cor' with summary 'sd'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'cor' with summary 'mean'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'cor' with summary 'sd'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/_internal.py:606: RuntimeWarning: Can't extract feature 'g_mean'.
#  Exception message: ZeroDivisionError('division by zero').
#  Will set it as 'np.nan' for all summary functions.
#   warnings.warn(
# /home/uprimozic/.local/lib/python3.10/site-packages/numpy/core/fromnumeric.py:3432: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/uprimozic/.local/lib/python3.10/site-packages/numpy/core/_methods.py:190: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'g_mean' with summary 'mean'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'g_mean' with summary 'sd'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/_internal.py:606: RuntimeWarning: Can't extract feature 'h_mean'.
#  Exception message: ValueError('Harmonic mean only defined if all elements greater than or equal to zero').
#  Will set it as 'np.nan' for all summary functions.
#   warnings.warn(
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'h_mean' with summary 'mean'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'h_mean' with summary 'sd'. Will set it as 'np.nan'.
#   warnings.warn(
# /usr/lib/python3/dist-packages/scipy/stats/_morestats.py:1758: UserWarning: Input data for shapiro has range zero. The results may not be accurate.
#   warnings.warn("Input data for shapiro has range zero. The results "
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/statistical.py:1267: RuntimeWarning: divide by zero encountered in log
#   np.log(np.linalg.det(S_i)) for S_i in sample_cov_matrices
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/statistical.py:1272: RuntimeWarning: divide by zero encountered in log
#   * np.log(np.linalg.det(pooled_cov_mat))
# /home/uprimozic/.local/lib/python3.10/site-packages/pymfe/statistical.py:1271: RuntimeWarning: invalid value encountered in double_scalars
#   (num_inst - num_classes)
# 100%|██████████| 159/159 [10:43<00:00,  4.05s/it]

# %% [markdown]
# Nekateri atributi niso bili uspešno poračunani, in jih bomo odstranili

# %%
# features with: Nan values:
nan_indexes = set()
for example in meta_space:
    for f_index, value in enumerate(example):
        if np.isnan(value):
            nan_indexes.add(f_index)
len(nan_indexes)
# meta_space
# Out:
# 43

# %%
# transform to dataframe
meta_space = pd.DataFrame(meta_space, columns=meta_features)
# odstrani vse atribute, ki jih nismo mogli poračunat
nan_names = [meta_features[i] for i in nan_indexes]
meta_space = meta_space.drop(columns=nan_names)
#poračunani atributi:
meta_space.columns
# Out:
# Index(['attr_conc.mean', 'attr_conc.sd', 'attr_ent.mean', 'attr_ent.sd',
#        'attr_to_inst', 'cat_to_num', 'class_conc.mean', 'class_conc.sd',
#        'class_ent', 'eq_num_attr', 'freq_class.mean', 'freq_class.sd',
#        'joint_ent.mean', 'joint_ent.sd', 'mut_inf.mean', 'mut_inf.sd',
#        'nr_attr', 'nr_cor_attr', 'nr_norm', 'nr_outliers', 'ns_ratio',
#        'sparsity.mean', 'sparsity.sd'],
#       dtype='object')

# %%
# saving
meta_space['index_in_dataset'] = meta_space_indexes
meta_space.to_parquet('parquet/meta_space_df')
meta_space = meta_space.drop(columns=['index_in_dataset'])


import pickle



#(load:)
# with open('meta_space', 'rb') as f:
#     meta_space = pickle.load(f)
# with open('meta_space_indexes', 'rb') as f:
#     meta_space_indexes = pickle.load(f)

#save caluclated meta features


# with open('meta_space', 'wb') as f:
#     pickle.dump(meta_space, f)
# with open('meta_space_indexes', 'wb') as f:
#     pickle.dump(meta_space_indexes, f)

# %%
meta_space
# Out:
#      attr_conc.mean  attr_conc.sd  attr_ent.mean   attr_ent.sd  attr_to_inst  \
# 0          0.010805      0.006192       3.584956  1.472658e-06      0.038000
# 1          0.009831      0.004413       3.584957  1.083121e-06      0.032000
# 2          0.019942      0.023107       3.584957  1.795561e-15      0.023500
# 3          0.034694      0.047734       2.127211  1.458498e+00      0.016463
# 4          0.844564      0.022563       3.321915  1.074247e-05      0.082508
# ..              ...           ...            ...           ...           ...
# 154        0.011079      0.008169       2.312358  5.931412e-01      0.050000
# 155        0.010196      0.006804       2.303047  6.251888e-01      0.050000
# 156        0.012772      0.007451       2.355830  6.583880e-01      0.050000
# 157        0.208909      0.246970       0.396347  9.140778e-01      0.050000
# 158        0.166885      0.236447       0.210559  6.950544e-01      0.050000
#
#      cat_to_num  class_conc.mean  class_conc.sd  class_ent  eq_num_attr  ...  \
# 0           0.0         0.038622       0.034719   3.321928    11.401216  ...
# 1           0.0         0.036046       0.025179   3.321928    12.060353  ...
# 2           0.0         0.053979       0.024114   3.321928     8.330996  ...
# 3           0.0         0.358780       0.421306   2.913356     7.382268  ...
# 4           0.0         0.000899       0.000152   1.000000   170.799163  ...
# ..          ...              ...            ...        ...          ...  ...
# 154         0.0         0.001367       0.000914   0.811278   113.061852  ...
# 155         0.0         0.001404       0.001101   0.811278   117.397622  ...
# 156         0.0         0.011570       0.070136   0.811278    95.725553  ...
# 157         0.0         0.191225       0.242965   0.378851   163.597935  ...
# 158         0.0         0.165415       0.236003   0.378851   444.951914  ...
#
#      joint_ent.sd  mut_inf.mean  mut_inf.sd  nr_attr  nr_cor_attr  nr_norm  \
# 0        0.230407      0.291366    0.230407       76     0.006316      0.0
# 1        0.180866      0.275442    0.180866       64     0.000496     28.0
# 2        0.171534      0.398743    0.171534       47     0.126735      0.0
# 3        1.425964      0.394642    0.252896       35     0.053782      0.0
# 4        0.000991      0.005855    0.000990      100     1.000000      0.0
# ..            ...           ...         ...      ...          ...      ...
# 154      0.589249      0.007176    0.006061      100     0.000606      0.0
# 155      0.622071      0.006911    0.005501      100     0.000404      0.0
# 156      0.653888      0.008475    0.007439      100     0.000202      2.0
# 157      0.911294      0.002316    0.005397      100     0.003434     38.0
# 158      0.693020      0.000851    0.003311      100     0.001010     33.0
#
#      nr_outliers    ns_ratio  sparsity.mean   sparsity.sd
# 0             69   11.303958       0.000002  5.295566e-07
# 1             61   12.015286       0.000002  5.363522e-08
# 2             40    7.990640       0.000002  2.895691e-07
# 3             25    4.390225       0.186830  2.238322e-01
# 4            100  566.380328       0.000031  3.688026e-06
# ..           ...         ...            ...           ...
# 154          100  321.256243       0.003263  2.488939e-02
# 155          100  332.266949       0.000895  9.266945e-04
# 156           98  276.972689       0.020736  1.406009e-01
# 157           62  170.153218       0.520368  3.933624e-01
# 158           67  246.296336       0.578807  3.324692e-01
#
# [159 rows x 23 columns]

# %% [markdown]
# Najbližji sosedi:

# %%
from sklearn.neighbors import NearestNeighbors
knn = NearestNeighbors(n_neighbors=3)
knn.fit(X=meta_space, y=meta_space_indexes)

# atributi od našeih podatkov
value_dict = {name : value for name, value in zip(attribute_names, attribute_values)}
values = np.array([value_dict[name] for name in meta_space.columns])
values = values.reshape(1, -1)

# %%
# najbiži sosedi
indicies = knn.kneighbors(values, return_distance=False)[0]
# indicies so indeksi v razvrstvi meta_space. Idex v all_data je v meta_space_indexes
indexes = [meta_space_indexes[i]  for i in indicies]

# algoritmi: 
for index in indexes:
    dataset = all_datasets[index]
# Out:
# /home/uprimozic/.local/lib/python3.10/site-packages/sklearn/base.py:420: UserWarning: X does not have valid feature names, but NearestNeighbors was fitted with feature names
#   warnings.warn(

# %%
MFE.valid_summary()
# Out:
# ('mean',
#  'nanmean',
#  'sd',
#  'nansd',
#  'var',
#  'nanvar',
#  'count',
#  'nancount',
#  'histogram',
#  'nanhistogram',
#  'iq_range',
#  'naniq_range',
#  'kurtosis',
#  'nankurtosis',
#  'max',
#  'nanmax',
#  'median',
#  'nanmedian',
#  'min',
#  'nanmin',
#  'quantiles',
#  'nanquantiles',
#  'range',
#  'nanrange',
#  'skewness',
#  'nanskewness',
#  'sum',
#  'nansum',
#  'powersum',
#  'pnorm',
#  'nanpowersum',
#  'nanpnorm')
