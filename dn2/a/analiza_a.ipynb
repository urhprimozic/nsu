# %% [markdown]
# Analiza podatkov.

# %%
import pandas as pd
import arff
import matplotlib.pyplot as plt 

df = pd.read_csv('dn2a.csv')

df['x'].plot()
plt.show()
df['y'].plot()
plt.show()
df['c'].plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Obdržal bom vse spremenljivke.

# %%
results = pd.read_csv('fimt-results.txt')
results.head()
# Out:
#    learning evaluation instances  evaluation time (cpu seconds)  \
# 0                          100.0                       0.000687
# 1                          200.0                       0.065693
# 2                          300.0                       0.128411
# 3                          400.0                       0.188575
# 4                          500.0                       0.244433
#
#    model cost (RAM-Hours)  classified instances  mean absolute error  \
# 0            4.486422e-10                 100.0            13.415833
# 1            4.335859e-08                 200.0            12.964413
# 2            8.520861e-08                 300.0            19.381865
# 3            1.240699e-07                 400.0            16.767789
# 4            1.605738e-07                 500.0            20.866418
#
#    root mean squared error  model training instances  \
# 0                87.233524                     100.0
# 1                62.524419                     200.0
# ...
